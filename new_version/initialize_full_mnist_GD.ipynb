# %% [markdown]
# Initialize shallow feedforward fully-connected network with V1 type weights and classify __full mnist__ dataset using __Gradient descent__.

# %%
import numpy as np
import numpy.linalg as la
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from data_fns import load_mnist
from estimator import classical_weights, V1_inspired_weights
import pickle

# %%
torch.cuda.set_device(1)
train, train_labels, test, test_labels = load_mnist('./data/mnist/')
X_train = torch.from_numpy(train).float().to('cuda')
X_test = torch.from_numpy(test).float().to('cuda')
y_train = torch.from_numpy(train_labels).long().to('cuda')
y_test = torch.from_numpy(test_labels).long().to('cuda')
n, d = X_train.shape

# %%
class V1_net(nn.Module):
    def __init__(self, hidden_size, scale):
        super().__init__()
        self.fc1 = nn.Linear(d, hidden_size)
        self.fc1.weight.data = torch.FloatTensor(V1_inspired_weights(hidden_size, d, t=5, l=2, scale=scale))
        self.output = nn.Linear(hidden_size, 10)
        
    def forward(self, inputs):
        x = torch.relu(self.fc1(inputs))
        return self.output(x)
    
class He_net(nn.Module):
    def __init__(self, hidden_size, scale):
        super().__init__()
        self.fc1 = nn.Linear(d, hidden_size)
        torch.nn.init.kaiming_normal_(self.fc1.weight)
        self.output = nn.Linear(hidden_size, 10)
        
    def forward(self, inputs):
        x = torch.relu(self.fc1(inputs))
        return self.output(x)
    
class RF_net(nn.Module):
    def __init__(self, hidden_size, scale):
        super().__init__()
        self.fc1 = nn.Linear(d, hidden_size)
        self.fc1.weight.data = torch.FloatTensor(classical_weights(hidden_size, d, scale=scale))
        self.output = nn.Linear(hidden_size, 10)
        
    def forward(self, inputs):
        x = torch.relu(self.fc1(inputs))
        return self.output(x)

# %%
def predict(model, X):
    return model(X).data.max(1)[1]

def error(model, X, y):
    y_pred = predict(model, X)
    accuracy = 1.0 * torch.sum(y_pred == y) / len(y)
    return 1 - accuracy

# %%
V1_model = V1_net(100, 2/d)
RF_model = RF_net(100, 2/d)
He_model= He_net(100, 2/d)
print('V1', torch.mean(torch.norm(V1_model.fc1.weight.data, dim=1)))
print('He', torch.mean(torch.norm(He_model.fc1.weight.data, dim=1)))
print('RF', torch.mean(torch.norm(RF_model.fc1.weight.data, dim=1)))
w = torch.mean(torch.norm(RF_model.fc1.weight.data, dim=1))
# Out:
# V1 tensor(1.3522)
# He tensor(1.4110)
# RF tensor(1.4141)

# %%
n_trials, n_epochs = 10, 3001
models = {'V1': V1_net, 'He': He_net}
h_list = [50, 100, 400, 1000]
lr_list = [1e-3, 1e-2, 1e-1, 1e0]

train_err = {m: {h: {lr: np.zeros((n_trials, n_epochs)) for lr in lr_list} for h in h_list} for m in models.keys()}
test_err = {m: {h: {lr: np.zeros((n_trials, n_epochs)) for lr in lr_list} for h in h_list} for m in models.keys()}
loss_list = {m: {h: {lr: np.zeros((n_trials, n_epochs)) for lr in lr_list} for h in h_list} for m in models.keys()}

# %%
scale = 2/d
t, l = 5, 2
loss_func = nn.CrossEntropyLoss()

for h in h_list:
    for lr in lr_list:
        for m, network in models.items():
            for i in range(n_trials):
                model = network(h, scale).to('cuda')
                optim = torch.optim.SGD(model.parameters(), lr=lr)
                for j in range(n_epochs):
                    optim.zero_grad()
                    loss = loss_func(model(X_train), y_train)
                    loss.backward()
                    optim.step()

                    train_err[m][h][lr][i, j] = error(model, X_train, y_train)
                    test_err[m][h][lr][i, j] = error(model, X_test, y_test)
                    loss_list[m][h][lr][i, j] = loss.data

                    if (j % 1000 == 0):
                        print('Trial %d, Epoch: %d, %s model, h=%d, lr=%0.5f, Loss=%0.5f, test err=%0.3f' % (i,j, m, h, lr, loss.data, 
                                                                                                  test_err[m][h][lr][i, j]))
results = {'test_err': test_err, 'train_err': train_err, 'loss': loss_list}
with open('results/initialize_mnist/full_data/clf_t=%0.2f_l=%0.2f.pickle' % (t, l), 'wb') as handle:
    pickle.dump(results, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# Trial 0, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=2.35715, test err=0.879
# Trial 0, Epoch: 1000, V1 model, h=50, lr=0.00100, Loss=1.57152, test err=0.378
# Trial 0, Epoch: 2000, V1 model, h=50, lr=0.00100, Loss=1.20716, test err=0.258
# Trial 0, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=0.97671, test err=0.213
# Trial 1, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=2.48257, test err=0.908
# Trial 1, Epoch: 1000, V1 model, h=50, lr=0.00100, Loss=1.85208, test err=0.466
# Trial 1, Epoch: 2000, V1 model, h=50, lr=0.00100, Loss=1.44956, test err=0.313
# Trial 1, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=1.14667, test err=0.240
# Trial 2, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=2.40176, test err=0.912
# Trial 2, Epoch: 1000, V1 model, h=50, lr=0.00100, Loss=1.76124, test err=0.473
# Trial 2, Epoch: 2000, V1 model, h=50, lr=0.00100, Loss=1.39779, test err=0.314
# Trial 2, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=1.13257, test err=0.245
# Trial 3, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=2.61911, test err=0.848
# Trial 3, Epoch: 1000, V1 model, h=50, lr=0.00100, Loss=1.90718, test err=0.491
# Trial 3, Epoch: 2000, V1 model, h=50, lr=0.00100, Loss=1.52223, test err=0.327
# Trial 3, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=1.21515, test err=0.255
# Trial 4, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=2.60310, test err=0.899
# Trial 4, Epoch: 1000, V1 model, h=50, lr=0.00100, Loss=1.77066, test err=0.487
# Trial 4, Epoch: 2000, V1 model, h=50, lr=0.00100, Loss=1.41567, test err=0.347
# Trial 4, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=1.15707, test err=0.275
# Trial 5, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=2.60452, test err=0.906
# Trial 5, Epoch: 1000, V1 model, h=50, lr=0.00100, Loss=1.70915, test err=0.411
# Trial 5, Epoch: 2000, V1 model, h=50, lr=0.00100, Loss=1.32807, test err=0.303
# Trial 5, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=1.08108, test err=0.252
# Trial 6, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=2.51975, test err=0.922
# Trial 6, Epoch: 1000, V1 model, h=50, lr=0.00100, Loss=1.67410, test err=0.403
# Trial 6, Epoch: 2000, V1 model, h=50, lr=0.00100, Loss=1.27567, test err=0.287
# Trial 6, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=1.03838, test err=0.246
# Trial 7, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=2.51129, test err=0.938
# Trial 7, Epoch: 1000, V1 model, h=50, lr=0.00100, Loss=1.75180, test err=0.415
# Trial 7, Epoch: 2000, V1 model, h=50, lr=0.00100, Loss=1.36453, test err=0.283
# Trial 7, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=1.09315, test err=0.230
# Trial 8, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=2.38500, test err=0.931
# Trial 8, Epoch: 1000, V1 model, h=50, lr=0.00100, Loss=1.83760, test err=0.537
# Trial 8, Epoch: 2000, V1 model, h=50, lr=0.00100, Loss=1.45783, test err=0.345
# Trial 8, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=1.16895, test err=0.268
# Trial 9, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=2.64243, test err=0.901
# Trial 9, Epoch: 1000, V1 model, h=50, lr=0.00100, Loss=1.57889, test err=0.381
# Trial 9, Epoch: 2000, V1 model, h=50, lr=0.00100, Loss=1.20385, test err=0.273
# Trial 9, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=0.98045, test err=0.229
# Trial 0, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.35267, test err=0.933
# Trial 0, Epoch: 1000, He model, h=50, lr=0.00100, Loss=2.15610, test err=0.659
# Trial 0, Epoch: 2000, He model, h=50, lr=0.00100, Loss=1.91366, test err=0.402
# Trial 0, Epoch: 3000, He model, h=50, lr=0.00100, Loss=1.60652, test err=0.310
# Trial 1, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.35312, test err=0.950
# Trial 1, Epoch: 1000, He model, h=50, lr=0.00100, Loss=2.13102, test err=0.595
# Trial 1, Epoch: 2000, He model, h=50, lr=0.00100, Loss=1.86600, test err=0.365
# Trial 1, Epoch: 3000, He model, h=50, lr=0.00100, Loss=1.54590, test err=0.266
# Trial 2, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.28287, test err=0.858
# Trial 2, Epoch: 1000, He model, h=50, lr=0.00100, Loss=2.04601, test err=0.559
# Trial 2, Epoch: 2000, He model, h=50, lr=0.00100, Loss=1.74588, test err=0.360
# Trial 2, Epoch: 3000, He model, h=50, lr=0.00100, Loss=1.41628, test err=0.247
# Trial 3, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.30436, test err=0.919
# Trial 3, Epoch: 1000, He model, h=50, lr=0.00100, Loss=2.16431, test err=0.684
# Trial 3, Epoch: 2000, He model, h=50, lr=0.00100, Loss=1.94233, test err=0.367
# Trial 3, Epoch: 3000, He model, h=50, lr=0.00100, Loss=1.62796, test err=0.299
# Trial 4, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.27123, test err=0.829
# Trial 4, Epoch: 1000, He model, h=50, lr=0.00100, Loss=2.05478, test err=0.506
# Trial 4, Epoch: 2000, He model, h=50, lr=0.00100, Loss=1.77538, test err=0.347
# Trial 4, Epoch: 3000, He model, h=50, lr=0.00100, Loss=1.45448, test err=0.279
# Trial 5, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.32912, test err=0.941
# Trial 5, Epoch: 1000, He model, h=50, lr=0.00100, Loss=2.13155, test err=0.661
# Trial 5, Epoch: 2000, He model, h=50, lr=0.00100, Loss=1.88228, test err=0.431
# Trial 5, Epoch: 3000, He model, h=50, lr=0.00100, Loss=1.57678, test err=0.308
# Trial 6, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.31086, test err=0.896
# Trial 6, Epoch: 1000, He model, h=50, lr=0.00100, Loss=2.07196, test err=0.537
# Trial 6, Epoch: 2000, He model, h=50, lr=0.00100, Loss=1.77383, test err=0.384
# Trial 6, Epoch: 3000, He model, h=50, lr=0.00100, Loss=1.45307, test err=0.288
# Trial 7, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.30580, test err=0.876
# Trial 7, Epoch: 1000, He model, h=50, lr=0.00100, Loss=2.09942, test err=0.605
# Trial 7, Epoch: 2000, He model, h=50, lr=0.00100, Loss=1.83847, test err=0.378
# Trial 7, Epoch: 3000, He model, h=50, lr=0.00100, Loss=1.53233, test err=0.299
# Trial 8, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.32870, test err=0.901
# Trial 8, Epoch: 1000, He model, h=50, lr=0.00100, Loss=2.04802, test err=0.539
# Trial 8, Epoch: 2000, He model, h=50, lr=0.00100, Loss=1.72576, test err=0.348
# Trial 8, Epoch: 3000, He model, h=50, lr=0.00100, Loss=1.39470, test err=0.252
# Trial 9, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.33566, test err=0.902
# Trial 9, Epoch: 1000, He model, h=50, lr=0.00100, Loss=2.09221, test err=0.661
# Trial 9, Epoch: 2000, He model, h=50, lr=0.00100, Loss=1.83275, test err=0.413
# Trial 9, Epoch: 3000, He model, h=50, lr=0.00100, Loss=1.53132, test err=0.305
# Trial 0, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=2.60251, test err=0.878
# Trial 0, Epoch: 1000, V1 model, h=50, lr=0.01000, Loss=0.51903, test err=0.131
# Trial 0, Epoch: 2000, V1 model, h=50, lr=0.01000, Loss=0.39314, test err=0.103
# Trial 0, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.34473, test err=0.093
# Trial 1, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=2.78242, test err=0.911
# Trial 1, Epoch: 1000, V1 model, h=50, lr=0.01000, Loss=0.53107, test err=0.130
# Trial 1, Epoch: 2000, V1 model, h=50, lr=0.01000, Loss=0.39837, test err=0.105
# Trial 1, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.34749, test err=0.094
# Trial 2, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=2.43590, test err=0.934
# Trial 2, Epoch: 1000, V1 model, h=50, lr=0.01000, Loss=0.52225, test err=0.131
# Trial 2, Epoch: 2000, V1 model, h=50, lr=0.01000, Loss=0.39798, test err=0.103
# Trial 2, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.34964, test err=0.092
# Trial 3, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=2.65490, test err=0.937
# Trial 3, Epoch: 1000, V1 model, h=50, lr=0.01000, Loss=0.51220, test err=0.129
# Trial 3, Epoch: 2000, V1 model, h=50, lr=0.01000, Loss=0.39175, test err=0.103
# Trial 3, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.34506, test err=0.091
# Trial 4, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=2.42874, test err=0.927
# Trial 4, Epoch: 1000, V1 model, h=50, lr=0.01000, Loss=0.55933, test err=0.140
# Trial 4, Epoch: 2000, V1 model, h=50, lr=0.01000, Loss=0.40774, test err=0.109
# Trial 4, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.35317, test err=0.096
# Trial 5, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=2.38212, test err=0.866
# Trial 5, Epoch: 1000, V1 model, h=50, lr=0.01000, Loss=0.56516, test err=0.141
# Trial 5, Epoch: 2000, V1 model, h=50, lr=0.01000, Loss=0.40797, test err=0.105
# Trial 5, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.35352, test err=0.092
# Trial 6, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=2.43711, test err=0.948
# Trial 6, Epoch: 1000, V1 model, h=50, lr=0.01000, Loss=0.57159, test err=0.145
# Trial 6, Epoch: 2000, V1 model, h=50, lr=0.01000, Loss=0.40543, test err=0.108
# Trial 6, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.34983, test err=0.094
# Trial 7, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=2.88843, test err=0.893
# Trial 7, Epoch: 1000, V1 model, h=50, lr=0.01000, Loss=0.50456, test err=0.120
# Trial 7, Epoch: 2000, V1 model, h=50, lr=0.01000, Loss=0.38295, test err=0.099
# Trial 7, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.33690, test err=0.089
# Trial 8, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=2.59480, test err=0.919
# Trial 8, Epoch: 1000, V1 model, h=50, lr=0.01000, Loss=0.56635, test err=0.142
# Trial 8, Epoch: 2000, V1 model, h=50, lr=0.01000, Loss=0.41225, test err=0.104
# Trial 8, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.35685, test err=0.094
# Trial 9, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=2.31961, test err=0.881
# Trial 9, Epoch: 1000, V1 model, h=50, lr=0.01000, Loss=0.54102, test err=0.131
# Trial 9, Epoch: 2000, V1 model, h=50, lr=0.01000, Loss=0.40086, test err=0.102
# Trial 9, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.34810, test err=0.090
# Trial 0, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.32232, test err=0.883
# Trial 0, Epoch: 1000, He model, h=50, lr=0.01000, Loss=0.60598, test err=0.138
# Trial 0, Epoch: 2000, He model, h=50, lr=0.01000, Loss=0.42304, test err=0.107
# Trial 0, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.36557, test err=0.098
# Trial 1, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.35401, test err=0.901
# Trial 1, Epoch: 1000, He model, h=50, lr=0.01000, Loss=0.61686, test err=0.145
# Trial 1, Epoch: 2000, He model, h=50, lr=0.01000, Loss=0.42758, test err=0.109
# Trial 1, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.36793, test err=0.097
# Trial 2, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.30052, test err=0.915
# Trial 2, Epoch: 1000, He model, h=50, lr=0.01000, Loss=0.59517, test err=0.134
# Trial 2, Epoch: 2000, He model, h=50, lr=0.01000, Loss=0.42137, test err=0.107
# Trial 2, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.36789, test err=0.098
# Trial 3, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.30788, test err=0.901
# Trial 3, Epoch: 1000, He model, h=50, lr=0.01000, Loss=0.59395, test err=0.137
# Trial 3, Epoch: 2000, He model, h=50, lr=0.01000, Loss=0.42082, test err=0.106
# Trial 3, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.36684, test err=0.096
# Trial 4, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.29872, test err=0.910
# Trial 4, Epoch: 1000, He model, h=50, lr=0.01000, Loss=0.61993, test err=0.148
# Trial 4, Epoch: 2000, He model, h=50, lr=0.01000, Loss=0.42433, test err=0.111
# Trial 4, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.36706, test err=0.100
# Trial 5, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.28267, test err=0.842
# Trial 5, Epoch: 1000, He model, h=50, lr=0.01000, Loss=0.60461, test err=0.144
# Trial 5, Epoch: 2000, He model, h=50, lr=0.01000, Loss=0.42661, test err=0.112
# Trial 5, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.37079, test err=0.100
# Trial 6, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.31766, test err=0.866
# Trial 6, Epoch: 1000, He model, h=50, lr=0.01000, Loss=0.60837, test err=0.138
# Trial 6, Epoch: 2000, He model, h=50, lr=0.01000, Loss=0.42589, test err=0.108
# Trial 6, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.37102, test err=0.098
# Trial 7, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.31866, test err=0.949
# Trial 7, Epoch: 1000, He model, h=50, lr=0.01000, Loss=0.61077, test err=0.144
# Trial 7, Epoch: 2000, He model, h=50, lr=0.01000, Loss=0.42165, test err=0.111
# Trial 7, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.36566, test err=0.100
# Trial 8, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.33450, test err=0.896
# Trial 8, Epoch: 1000, He model, h=50, lr=0.01000, Loss=0.61154, test err=0.143
# Trial 8, Epoch: 2000, He model, h=50, lr=0.01000, Loss=0.42965, test err=0.111
# Trial 8, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.37261, test err=0.099
# Trial 9, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.30872, test err=0.899
# Trial 9, Epoch: 1000, He model, h=50, lr=0.01000, Loss=0.60023, test err=0.137
# Trial 9, Epoch: 2000, He model, h=50, lr=0.01000, Loss=0.41921, test err=0.107
# Trial 9, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.36539, test err=0.097
# Trial 0, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=2.56483, test err=0.878
# Trial 0, Epoch: 1000, V1 model, h=50, lr=0.10000, Loss=0.23693, test err=0.065
# Trial 0, Epoch: 2000, V1 model, h=50, lr=0.10000, Loss=0.17744, test err=0.053
# Trial 0, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.14370, test err=0.045
# Trial 1, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=2.57422, test err=0.914
# Trial 1, Epoch: 1000, V1 model, h=50, lr=0.10000, Loss=0.23639, test err=0.066
# Trial 1, Epoch: 2000, V1 model, h=50, lr=0.10000, Loss=0.17352, test err=0.050
# Trial 1, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.13997, test err=0.044
# Trial 2, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=2.40210, test err=0.918
# Trial 2, Epoch: 1000, V1 model, h=50, lr=0.10000, Loss=0.24041, test err=0.068
# Trial 2, Epoch: 2000, V1 model, h=50, lr=0.10000, Loss=0.17570, test err=0.052
# Trial 2, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.14038, test err=0.044
# Trial 3, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=2.34852, test err=0.794
# Trial 3, Epoch: 1000, V1 model, h=50, lr=0.10000, Loss=0.24633, test err=0.066
# Trial 3, Epoch: 2000, V1 model, h=50, lr=0.10000, Loss=0.18873, test err=0.053
# Trial 3, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.15370, test err=0.045
# Trial 4, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=2.31137, test err=0.824
# Trial 4, Epoch: 1000, V1 model, h=50, lr=0.10000, Loss=0.23070, test err=0.066
# Trial 4, Epoch: 2000, V1 model, h=50, lr=0.10000, Loss=0.17301, test err=0.052
# Trial 4, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.14132, test err=0.044
# Trial 5, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=2.45773, test err=0.815
# Trial 5, Epoch: 1000, V1 model, h=50, lr=0.10000, Loss=0.23641, test err=0.065
# Trial 5, Epoch: 2000, V1 model, h=50, lr=0.10000, Loss=0.17862, test err=0.052
# Trial 5, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.14672, test err=0.044
# Trial 6, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=2.41125, test err=0.853
# Trial 6, Epoch: 1000, V1 model, h=50, lr=0.10000, Loss=0.23434, test err=0.064
# Trial 6, Epoch: 2000, V1 model, h=50, lr=0.10000, Loss=0.17759, test err=0.052
# Trial 6, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.14346, test err=0.044
# Trial 7, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=2.27157, test err=0.827
# Trial 7, Epoch: 1000, V1 model, h=50, lr=0.10000, Loss=0.23749, test err=0.066
# Trial 7, Epoch: 2000, V1 model, h=50, lr=0.10000, Loss=0.17816, test err=0.050
# Trial 7, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.14515, test err=0.044
# Trial 8, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=2.66930, test err=0.926
# Trial 8, Epoch: 1000, V1 model, h=50, lr=0.10000, Loss=0.24490, test err=0.069
# Trial 8, Epoch: 2000, V1 model, h=50, lr=0.10000, Loss=0.18381, test err=0.055
# Trial 8, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.15014, test err=0.045
# Trial 9, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=2.39985, test err=0.886
# Trial 9, Epoch: 1000, V1 model, h=50, lr=0.10000, Loss=0.23328, test err=0.065
# Trial 9, Epoch: 2000, V1 model, h=50, lr=0.10000, Loss=0.17090, test err=0.051
# Trial 9, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.13694, test err=0.043
# Trial 0, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.29653, test err=0.882
# Trial 0, Epoch: 1000, He model, h=50, lr=0.10000, Loss=0.25354, test err=0.070
# Trial 0, Epoch: 2000, He model, h=50, lr=0.10000, Loss=0.19002, test err=0.059
# Trial 0, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.15448, test err=0.048
# Trial 1, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.29953, test err=0.871
# Trial 1, Epoch: 1000, He model, h=50, lr=0.10000, Loss=0.24802, test err=0.069
# Trial 1, Epoch: 2000, He model, h=50, lr=0.10000, Loss=0.18748, test err=0.057
# Trial 1, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.15158, test err=0.047
# Trial 2, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.34898, test err=0.896
# Trial 2, Epoch: 1000, He model, h=50, lr=0.10000, Loss=0.25177, test err=0.068
# Trial 2, Epoch: 2000, He model, h=50, lr=0.10000, Loss=0.18780, test err=0.054
# Trial 2, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.15109, test err=0.045
# Trial 3, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.30885, test err=0.877
# Trial 3, Epoch: 1000, He model, h=50, lr=0.10000, Loss=0.25780, test err=0.071
# Trial 3, Epoch: 2000, He model, h=50, lr=0.10000, Loss=0.19372, test err=0.059
# Trial 3, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.15507, test err=0.048
# Trial 4, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.32811, test err=0.893
# Trial 4, Epoch: 1000, He model, h=50, lr=0.10000, Loss=0.26190, test err=0.071
# Trial 4, Epoch: 2000, He model, h=50, lr=0.10000, Loss=0.19606, test err=0.056
# Trial 4, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.15928, test err=0.049
# Trial 5, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.32071, test err=0.861
# Trial 5, Epoch: 1000, He model, h=50, lr=0.10000, Loss=0.26000, test err=0.073
# Trial 5, Epoch: 2000, He model, h=50, lr=0.10000, Loss=0.19897, test err=0.058
# Trial 5, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.15977, test err=0.047
# Trial 6, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.32494, test err=0.856
# Trial 6, Epoch: 1000, He model, h=50, lr=0.10000, Loss=0.25382, test err=0.069
# Trial 6, Epoch: 2000, He model, h=50, lr=0.10000, Loss=0.19296, test err=0.056
# Trial 6, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.15828, test err=0.050
# Trial 7, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.30411, test err=0.872
# Trial 7, Epoch: 1000, He model, h=50, lr=0.10000, Loss=0.25591, test err=0.070
# Trial 7, Epoch: 2000, He model, h=50, lr=0.10000, Loss=0.19419, test err=0.056
# Trial 7, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.15652, test err=0.048
# Trial 8, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.33057, test err=0.911
# Trial 8, Epoch: 1000, He model, h=50, lr=0.10000, Loss=0.26475, test err=0.073
# Trial 8, Epoch: 2000, He model, h=50, lr=0.10000, Loss=0.19870, test err=0.058
# Trial 8, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.15701, test err=0.046
# Trial 9, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.32311, test err=0.903
# Trial 9, Epoch: 1000, He model, h=50, lr=0.10000, Loss=0.25576, test err=0.072
# Trial 9, Epoch: 2000, He model, h=50, lr=0.10000, Loss=0.18925, test err=0.056
# Trial 9, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.15211, test err=0.046
# Trial 0, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=2.46635, test err=0.707
# Trial 0, Epoch: 1000, V1 model, h=50, lr=1.00000, Loss=0.06329, test err=0.027
# Trial 0, Epoch: 2000, V1 model, h=50, lr=1.00000, Loss=0.03373, test err=0.026
# Trial 0, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=0.02046, test err=0.026
# Trial 1, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=2.38682, test err=0.765
# Trial 1, Epoch: 1000, V1 model, h=50, lr=1.00000, Loss=0.06341, test err=0.030
# Trial 1, Epoch: 2000, V1 model, h=50, lr=1.00000, Loss=0.03514, test err=0.026
# Trial 1, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=0.02187, test err=0.027
# Trial 2, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=2.51750, test err=0.772
# Trial 2, Epoch: 1000, V1 model, h=50, lr=1.00000, Loss=0.11492, test err=0.039
# Trial 2, Epoch: 2000, V1 model, h=50, lr=1.00000, Loss=0.06436, test err=0.033
# Trial 2, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=0.86169, test err=0.266
# Trial 3, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=2.80527, test err=0.810
# Trial 3, Epoch: 1000, V1 model, h=50, lr=1.00000, Loss=0.06956, test err=0.028
# Trial 3, Epoch: 2000, V1 model, h=50, lr=1.00000, Loss=0.04023, test err=0.027
# Trial 3, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=0.02622, test err=0.027
# Trial 4, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=2.80839, test err=0.819
# Trial 4, Epoch: 1000, V1 model, h=50, lr=1.00000, Loss=0.06815, test err=0.029
# Trial 4, Epoch: 2000, V1 model, h=50, lr=1.00000, Loss=0.03860, test err=0.026
# Trial 4, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=0.02463, test err=0.026
# Trial 5, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=2.47234, test err=0.797
# Trial 5, Epoch: 1000, V1 model, h=50, lr=1.00000, Loss=0.06879, test err=0.028
# Trial 5, Epoch: 2000, V1 model, h=50, lr=1.00000, Loss=0.14858, test err=0.048
# Trial 5, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=0.12394, test err=0.047
# Trial 6, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=2.64229, test err=0.773
# Trial 6, Epoch: 1000, V1 model, h=50, lr=1.00000, Loss=0.06286, test err=0.028
# Trial 6, Epoch: 2000, V1 model, h=50, lr=1.00000, Loss=0.03366, test err=0.026
# Trial 6, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=0.02048, test err=0.025
# Trial 7, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=2.44091, test err=0.833
# Trial 7, Epoch: 1000, V1 model, h=50, lr=1.00000, Loss=0.06333, test err=0.028
# Trial 7, Epoch: 2000, V1 model, h=50, lr=1.00000, Loss=0.03389, test err=0.027
# Trial 7, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=0.02064, test err=0.027
# Trial 8, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=2.45491, test err=0.803
# Trial 8, Epoch: 1000, V1 model, h=50, lr=1.00000, Loss=0.06039, test err=0.027
# Trial 8, Epoch: 2000, V1 model, h=50, lr=1.00000, Loss=0.03263, test err=0.026
# Trial 8, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=0.01966, test err=0.026
# Trial 9, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=2.48612, test err=0.790
# Trial 9, Epoch: 1000, V1 model, h=50, lr=1.00000, Loss=0.06213, test err=0.029
# Trial 9, Epoch: 2000, V1 model, h=50, lr=1.00000, Loss=0.03473, test err=0.027
# Trial 9, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=0.02177, test err=0.025
# Trial 0, Epoch: 0, He model, h=50, lr=1.00000, Loss=2.33157, test err=0.608
# Trial 0, Epoch: 1000, He model, h=50, lr=1.00000, Loss=0.06685, test err=0.028
# Trial 0, Epoch: 2000, He model, h=50, lr=1.00000, Loss=0.03656, test err=0.027
# Trial 0, Epoch: 3000, He model, h=50, lr=1.00000, Loss=0.02315, test err=0.027
# Trial 1, Epoch: 0, He model, h=50, lr=1.00000, Loss=2.34231, test err=0.568
# Trial 1, Epoch: 1000, He model, h=50, lr=1.00000, Loss=0.14005, test err=0.047
# Trial 1, Epoch: 2000, He model, h=50, lr=1.00000, Loss=1.26697, test err=0.410
# Trial 1, Epoch: 3000, He model, h=50, lr=1.00000, Loss=0.25677, test err=0.075
# Trial 2, Epoch: 0, He model, h=50, lr=1.00000, Loss=2.34586, test err=0.662
# Trial 2, Epoch: 1000, He model, h=50, lr=1.00000, Loss=0.06267, test err=0.028
# Trial 2, Epoch: 2000, He model, h=50, lr=1.00000, Loss=0.03361, test err=0.027
# Trial 2, Epoch: 3000, He model, h=50, lr=1.00000, Loss=0.02060, test err=0.026
# Trial 3, Epoch: 0, He model, h=50, lr=1.00000, Loss=2.31095, test err=0.581
# Trial 3, Epoch: 1000, He model, h=50, lr=1.00000, Loss=0.07181, test err=0.031
# Trial 3, Epoch: 2000, He model, h=50, lr=1.00000, Loss=0.04055, test err=0.029
# Trial 3, Epoch: 3000, He model, h=50, lr=1.00000, Loss=0.02563, test err=0.028
# Trial 4, Epoch: 0, He model, h=50, lr=1.00000, Loss=2.31497, test err=0.584
# Trial 4, Epoch: 1000, He model, h=50, lr=1.00000, Loss=0.06446, test err=0.029
# Trial 4, Epoch: 2000, He model, h=50, lr=1.00000, Loss=0.03472, test err=0.027
# Trial 4, Epoch: 3000, He model, h=50, lr=1.00000, Loss=0.02110, test err=0.027
# Trial 5, Epoch: 0, He model, h=50, lr=1.00000, Loss=2.33114, test err=0.679
# Trial 5, Epoch: 1000, He model, h=50, lr=1.00000, Loss=0.08827, test err=0.035
# Trial 5, Epoch: 2000, He model, h=50, lr=1.00000, Loss=0.27211, test err=0.076
# Trial 5, Epoch: 3000, He model, h=50, lr=1.00000, Loss=0.17955, test err=0.056
# Trial 6, Epoch: 0, He model, h=50, lr=1.00000, Loss=2.30514, test err=0.592
# Trial 6, Epoch: 1000, He model, h=50, lr=1.00000, Loss=0.08730, test err=0.034
# Trial 6, Epoch: 2000, He model, h=50, lr=1.00000, Loss=0.23437, test err=0.072
# Trial 6, Epoch: 3000, He model, h=50, lr=1.00000, Loss=0.20250, test err=0.064
# Trial 7, Epoch: 0, He model, h=50, lr=1.00000, Loss=2.32408, test err=0.612
# Trial 7, Epoch: 1000, He model, h=50, lr=1.00000, Loss=0.07603, test err=0.033
# Trial 7, Epoch: 2000, He model, h=50, lr=1.00000, Loss=0.16097, test err=0.058
# Trial 7, Epoch: 3000, He model, h=50, lr=1.00000, Loss=0.37320, test err=0.115
# Trial 8, Epoch: 0, He model, h=50, lr=1.00000, Loss=2.33292, test err=0.667
# Trial 8, Epoch: 1000, He model, h=50, lr=1.00000, Loss=0.12812, test err=0.044
# Trial 8, Epoch: 2000, He model, h=50, lr=1.00000, Loss=0.07422, test err=0.035
# Trial 8, Epoch: 3000, He model, h=50, lr=1.00000, Loss=0.05131, test err=0.033
# Trial 9, Epoch: 0, He model, h=50, lr=1.00000, Loss=2.32058, test err=0.678
# Trial 9, Epoch: 1000, He model, h=50, lr=1.00000, Loss=0.07741, test err=0.032
# Trial 9, Epoch: 2000, He model, h=50, lr=1.00000, Loss=0.04497, test err=0.029
# Trial 9, Epoch: 3000, He model, h=50, lr=1.00000, Loss=0.02900, test err=0.028
# Trial 0, Epoch: 0, V1 model, h=100, lr=0.00100, Loss=2.66119, test err=0.897
# Trial 0, Epoch: 1000, V1 model, h=100, lr=0.00100, Loss=1.58645, test err=0.312
# Trial 0, Epoch: 2000, V1 model, h=100, lr=0.00100, Loss=1.17251, test err=0.239
# Trial 0, Epoch: 3000, V1 model, h=100, lr=0.00100, Loss=0.94225, test err=0.205
# Trial 1, Epoch: 0, V1 model, h=100, lr=0.00100, Loss=2.50009, test err=0.902
# Trial 1, Epoch: 1000, V1 model, h=100, lr=0.00100, Loss=1.26190, test err=0.267
# Trial 1, Epoch: 2000, V1 model, h=100, lr=0.00100, Loss=0.93841, test err=0.207
# Trial 1, Epoch: 3000, V1 model, h=100, lr=0.00100, Loss=0.77735, test err=0.181
# Trial 2, Epoch: 0, V1 model, h=100, lr=0.00100, Loss=2.48742, test err=0.903
# Trial 2, Epoch: 1000, V1 model, h=100, lr=0.00100, Loss=1.46568, test err=0.306
# Trial 2, Epoch: 2000, V1 model, h=100, lr=0.00100, Loss=1.06688, test err=0.218
# Trial 2, Epoch: 3000, V1 model, h=100, lr=0.00100, Loss=0.86176, test err=0.185
# Trial 3, Epoch: 0, V1 model, h=100, lr=0.00100, Loss=2.58933, test err=0.927
# Trial 3, Epoch: 1000, V1 model, h=100, lr=0.00100, Loss=1.37905, test err=0.292
# Trial 3, Epoch: 2000, V1 model, h=100, lr=0.00100, Loss=1.02769, test err=0.224
# Trial 3, Epoch: 3000, V1 model, h=100, lr=0.00100, Loss=0.84530, test err=0.195
# Trial 4, Epoch: 0, V1 model, h=100, lr=0.00100, Loss=2.57948, test err=0.874
# Trial 4, Epoch: 1000, V1 model, h=100, lr=0.00100, Loss=1.33741, test err=0.278
# Trial 4, Epoch: 2000, V1 model, h=100, lr=0.00100, Loss=0.98178, test err=0.209
# Trial 4, Epoch: 3000, V1 model, h=100, lr=0.00100, Loss=0.80714, test err=0.182
# Trial 5, Epoch: 0, V1 model, h=100, lr=0.00100, Loss=2.56706, test err=0.904
# Trial 5, Epoch: 1000, V1 model, h=100, lr=0.00100, Loss=1.48850, test err=0.332
# Trial 5, Epoch: 2000, V1 model, h=100, lr=0.00100, Loss=1.09790, test err=0.243
# Trial 5, Epoch: 3000, V1 model, h=100, lr=0.00100, Loss=0.88795, test err=0.208
# Trial 6, Epoch: 0, V1 model, h=100, lr=0.00100, Loss=2.49326, test err=0.912
# Trial 6, Epoch: 1000, V1 model, h=100, lr=0.00100, Loss=1.34786, test err=0.283
# Trial 6, Epoch: 2000, V1 model, h=100, lr=0.00100, Loss=0.98591, test err=0.212
# Trial 6, Epoch: 3000, V1 model, h=100, lr=0.00100, Loss=0.80576, test err=0.179
# Trial 7, Epoch: 0, V1 model, h=100, lr=0.00100, Loss=2.68237, test err=0.909
# Trial 7, Epoch: 1000, V1 model, h=100, lr=0.00100, Loss=1.26548, test err=0.253
# Trial 7, Epoch: 2000, V1 model, h=100, lr=0.00100, Loss=0.92278, test err=0.198
# Trial 7, Epoch: 3000, V1 model, h=100, lr=0.00100, Loss=0.76215, test err=0.171
# Trial 8, Epoch: 0, V1 model, h=100, lr=0.00100, Loss=2.39534, test err=0.830
# Trial 8, Epoch: 1000, V1 model, h=100, lr=0.00100, Loss=1.24814, test err=0.239
# Trial 8, Epoch: 2000, V1 model, h=100, lr=0.00100, Loss=0.89938, test err=0.172
# Trial 8, Epoch: 3000, V1 model, h=100, lr=0.00100, Loss=0.73976, test err=0.153
# Trial 9, Epoch: 0, V1 model, h=100, lr=0.00100, Loss=2.49939, test err=0.922
# Trial 9, Epoch: 1000, V1 model, h=100, lr=0.00100, Loss=1.42831, test err=0.271
# Trial 9, Epoch: 2000, V1 model, h=100, lr=0.00100, Loss=1.03289, test err=0.197
# Trial 9, Epoch: 3000, V1 model, h=100, lr=0.00100, Loss=0.82947, test err=0.170
# Trial 0, Epoch: 0, He model, h=100, lr=0.00100, Loss=2.32013, test err=0.913
# Trial 0, Epoch: 1000, He model, h=100, lr=0.00100, Loss=2.08517, test err=0.507
# Trial 0, Epoch: 2000, He model, h=100, lr=0.00100, Loss=1.78119, test err=0.342
# Trial 0, Epoch: 3000, He model, h=100, lr=0.00100, Loss=1.44913, test err=0.276
# Trial 1, Epoch: 0, He model, h=100, lr=0.00100, Loss=2.31866, test err=0.894
# Trial 1, Epoch: 1000, He model, h=100, lr=0.00100, Loss=2.05663, test err=0.532
# Trial 1, Epoch: 2000, He model, h=100, lr=0.00100, Loss=1.73999, test err=0.334
# Trial 1, Epoch: 3000, He model, h=100, lr=0.00100, Loss=1.40054, test err=0.278
# Trial 2, Epoch: 0, He model, h=100, lr=0.00100, Loss=2.31432, test err=0.888
# Trial 2, Epoch: 1000, He model, h=100, lr=0.00100, Loss=2.07115, test err=0.518
# Trial 2, Epoch: 2000, He model, h=100, lr=0.00100, Loss=1.76847, test err=0.317
# Trial 2, Epoch: 3000, He model, h=100, lr=0.00100, Loss=1.43020, test err=0.247
# Trial 3, Epoch: 0, He model, h=100, lr=0.00100, Loss=2.33047, test err=0.926
# Trial 3, Epoch: 1000, He model, h=100, lr=0.00100, Loss=2.04656, test err=0.472
# Trial 3, Epoch: 2000, He model, h=100, lr=0.00100, Loss=1.70730, test err=0.315
# Trial 3, Epoch: 3000, He model, h=100, lr=0.00100, Loss=1.36686, test err=0.247
# Trial 4, Epoch: 0, He model, h=100, lr=0.00100, Loss=2.32821, test err=0.874
# Trial 4, Epoch: 1000, He model, h=100, lr=0.00100, Loss=2.07515, test err=0.518
# Trial 4, Epoch: 2000, He model, h=100, lr=0.00100, Loss=1.74983, test err=0.310
# Trial 4, Epoch: 3000, He model, h=100, lr=0.00100, Loss=1.40655, test err=0.248
# Trial 5, Epoch: 0, He model, h=100, lr=0.00100, Loss=2.32463, test err=0.921
# Trial 5, Epoch: 1000, He model, h=100, lr=0.00100, Loss=2.09035, test err=0.492
# Trial 5, Epoch: 2000, He model, h=100, lr=0.00100, Loss=1.77908, test err=0.332
# Trial 5, Epoch: 3000, He model, h=100, lr=0.00100, Loss=1.43745, test err=0.273
# Trial 6, Epoch: 0, He model, h=100, lr=0.00100, Loss=2.31029, test err=0.865
# Trial 6, Epoch: 1000, He model, h=100, lr=0.00100, Loss=2.05596, test err=0.473
# Trial 6, Epoch: 2000, He model, h=100, lr=0.00100, Loss=1.75070, test err=0.309
# Trial 6, Epoch: 3000, He model, h=100, lr=0.00100, Loss=1.41270, test err=0.244
# Trial 7, Epoch: 0, He model, h=100, lr=0.00100, Loss=2.31796, test err=0.902
# Trial 7, Epoch: 1000, He model, h=100, lr=0.00100, Loss=2.05996, test err=0.524
# Trial 7, Epoch: 2000, He model, h=100, lr=0.00100, Loss=1.75918, test err=0.345
# Trial 7, Epoch: 3000, He model, h=100, lr=0.00100, Loss=1.42487, test err=0.265
# Trial 8, Epoch: 0, He model, h=100, lr=0.00100, Loss=2.30859, test err=0.873
# Trial 8, Epoch: 1000, He model, h=100, lr=0.00100, Loss=2.04868, test err=0.489
# Trial 8, Epoch: 2000, He model, h=100, lr=0.00100, Loss=1.73587, test err=0.324
# Trial 8, Epoch: 3000, He model, h=100, lr=0.00100, Loss=1.40756, test err=0.255
# Trial 9, Epoch: 0, He model, h=100, lr=0.00100, Loss=2.30024, test err=0.880
# Trial 9, Epoch: 1000, He model, h=100, lr=0.00100, Loss=2.06521, test err=0.572
# Trial 9, Epoch: 2000, He model, h=100, lr=0.00100, Loss=1.77201, test err=0.345
# Trial 9, Epoch: 3000, He model, h=100, lr=0.00100, Loss=1.44526, test err=0.251
# Trial 0, Epoch: 0, V1 model, h=100, lr=0.01000, Loss=2.48635, test err=0.857
# Trial 0, Epoch: 1000, V1 model, h=100, lr=0.01000, Loss=0.47961, test err=0.116
# Trial 0, Epoch: 2000, V1 model, h=100, lr=0.01000, Loss=0.36972, test err=0.094
# Trial 0, Epoch: 3000, V1 model, h=100, lr=0.01000, Loss=0.32448, test err=0.087
# Trial 1, Epoch: 0, V1 model, h=100, lr=0.01000, Loss=2.40716, test err=0.929
# Trial 1, Epoch: 1000, V1 model, h=100, lr=0.01000, Loss=0.47477, test err=0.119
# Trial 1, Epoch: 2000, V1 model, h=100, lr=0.01000, Loss=0.36766, test err=0.097
# Trial 1, Epoch: 3000, V1 model, h=100, lr=0.01000, Loss=0.32265, test err=0.086
# Trial 2, Epoch: 0, V1 model, h=100, lr=0.01000, Loss=2.59170, test err=0.909
# Trial 2, Epoch: 1000, V1 model, h=100, lr=0.01000, Loss=0.46470, test err=0.118
# Trial 2, Epoch: 2000, V1 model, h=100, lr=0.01000, Loss=0.36574, test err=0.095
# Trial 2, Epoch: 3000, V1 model, h=100, lr=0.01000, Loss=0.32387, test err=0.087
# Trial 3, Epoch: 0, V1 model, h=100, lr=0.01000, Loss=2.47591, test err=0.860
# Trial 3, Epoch: 1000, V1 model, h=100, lr=0.01000, Loss=0.49621, test err=0.124
# Trial 3, Epoch: 2000, V1 model, h=100, lr=0.01000, Loss=0.37843, test err=0.099
# Trial 3, Epoch: 3000, V1 model, h=100, lr=0.01000, Loss=0.33074, test err=0.089
# Trial 4, Epoch: 0, V1 model, h=100, lr=0.01000, Loss=2.61901, test err=0.900
# Trial 4, Epoch: 1000, V1 model, h=100, lr=0.01000, Loss=0.48192, test err=0.118
# Trial 4, Epoch: 2000, V1 model, h=100, lr=0.01000, Loss=0.36910, test err=0.095
# Trial 4, Epoch: 3000, V1 model, h=100, lr=0.01000, Loss=0.32244, test err=0.085
# Trial 5, Epoch: 0, V1 model, h=100, lr=0.01000, Loss=2.37815, test err=0.842
# Trial 5, Epoch: 1000, V1 model, h=100, lr=0.01000, Loss=0.47482, test err=0.121
# Trial 5, Epoch: 2000, V1 model, h=100, lr=0.01000, Loss=0.37034, test err=0.097
# Trial 5, Epoch: 3000, V1 model, h=100, lr=0.01000, Loss=0.32598, test err=0.087
# Trial 6, Epoch: 0, V1 model, h=100, lr=0.01000, Loss=2.44055, test err=0.853
# Trial 6, Epoch: 1000, V1 model, h=100, lr=0.01000, Loss=0.48310, test err=0.126
# Trial 6, Epoch: 2000, V1 model, h=100, lr=0.01000, Loss=0.37070, test err=0.098
# Trial 6, Epoch: 3000, V1 model, h=100, lr=0.01000, Loss=0.32429, test err=0.088
# Trial 7, Epoch: 0, V1 model, h=100, lr=0.01000, Loss=2.56616, test err=0.847
# Trial 7, Epoch: 1000, V1 model, h=100, lr=0.01000, Loss=0.50453, test err=0.123
# Trial 7, Epoch: 2000, V1 model, h=100, lr=0.01000, Loss=0.38632, test err=0.099
# Trial 7, Epoch: 3000, V1 model, h=100, lr=0.01000, Loss=0.33942, test err=0.088
# Trial 8, Epoch: 0, V1 model, h=100, lr=0.01000, Loss=2.48196, test err=0.881
# Trial 8, Epoch: 1000, V1 model, h=100, lr=0.01000, Loss=0.49812, test err=0.125
# Trial 8, Epoch: 2000, V1 model, h=100, lr=0.01000, Loss=0.38021, test err=0.099
# Trial 8, Epoch: 3000, V1 model, h=100, lr=0.01000, Loss=0.33340, test err=0.089
# Trial 9, Epoch: 0, V1 model, h=100, lr=0.01000, Loss=2.64428, test err=0.903
# Trial 9, Epoch: 1000, V1 model, h=100, lr=0.01000, Loss=0.49557, test err=0.122
# Trial 9, Epoch: 2000, V1 model, h=100, lr=0.01000, Loss=0.37506, test err=0.098
# Trial 9, Epoch: 3000, V1 model, h=100, lr=0.01000, Loss=0.32559, test err=0.085
# Trial 0, Epoch: 0, He model, h=100, lr=0.01000, Loss=2.33474, test err=0.934
# Trial 0, Epoch: 1000, He model, h=100, lr=0.01000, Loss=0.56829, test err=0.126
# Trial 0, Epoch: 2000, He model, h=100, lr=0.01000, Loss=0.40704, test err=0.102
# Trial 0, Epoch: 3000, He model, h=100, lr=0.01000, Loss=0.35345, test err=0.093
# Trial 1, Epoch: 0, He model, h=100, lr=0.01000, Loss=2.33851, test err=0.905
# Trial 1, Epoch: 1000, He model, h=100, lr=0.01000, Loss=0.57124, test err=0.132
# Trial 1, Epoch: 2000, He model, h=100, lr=0.01000, Loss=0.41039, test err=0.106
# Trial 1, Epoch: 3000, He model, h=100, lr=0.01000, Loss=0.35806, test err=0.095
# Trial 2, Epoch: 0, He model, h=100, lr=0.01000, Loss=2.29417, test err=0.853
# Trial 2, Epoch: 1000, He model, h=100, lr=0.01000, Loss=0.56438, test err=0.130
# Trial 2, Epoch: 2000, He model, h=100, lr=0.01000, Loss=0.40996, test err=0.104
# Trial 2, Epoch: 3000, He model, h=100, lr=0.01000, Loss=0.35729, test err=0.092
# Trial 3, Epoch: 0, He model, h=100, lr=0.01000, Loss=2.33678, test err=0.907
# Trial 3, Epoch: 1000, He model, h=100, lr=0.01000, Loss=0.58297, test err=0.131
# Trial 3, Epoch: 2000, He model, h=100, lr=0.01000, Loss=0.41270, test err=0.103
# Trial 3, Epoch: 3000, He model, h=100, lr=0.01000, Loss=0.36002, test err=0.095
# Trial 4, Epoch: 0, He model, h=100, lr=0.01000, Loss=2.33807, test err=0.936
# Trial 4, Epoch: 1000, He model, h=100, lr=0.01000, Loss=0.57976, test err=0.136
# Trial 4, Epoch: 2000, He model, h=100, lr=0.01000, Loss=0.41355, test err=0.105
# Trial 4, Epoch: 3000, He model, h=100, lr=0.01000, Loss=0.35872, test err=0.094
# Trial 5, Epoch: 0, He model, h=100, lr=0.01000, Loss=2.31612, test err=0.895
# Trial 5, Epoch: 1000, He model, h=100, lr=0.01000, Loss=0.56065, test err=0.129
# Trial 5, Epoch: 2000, He model, h=100, lr=0.01000, Loss=0.40767, test err=0.105
# Trial 5, Epoch: 3000, He model, h=100, lr=0.01000, Loss=0.35659, test err=0.095
# Trial 6, Epoch: 0, He model, h=100, lr=0.01000, Loss=2.34481, test err=0.883
# Trial 6, Epoch: 1000, He model, h=100, lr=0.01000, Loss=0.57889, test err=0.134
# Trial 6, Epoch: 2000, He model, h=100, lr=0.01000, Loss=0.41590, test err=0.106
# Trial 6, Epoch: 3000, He model, h=100, lr=0.01000, Loss=0.36333, test err=0.097
# Trial 7, Epoch: 0, He model, h=100, lr=0.01000, Loss=2.31219, test err=0.897
# Trial 7, Epoch: 1000, He model, h=100, lr=0.01000, Loss=0.57247, test err=0.131
# Trial 7, Epoch: 2000, He model, h=100, lr=0.01000, Loss=0.41018, test err=0.106
# Trial 7, Epoch: 3000, He model, h=100, lr=0.01000, Loss=0.35877, test err=0.097
# Trial 8, Epoch: 0, He model, h=100, lr=0.01000, Loss=2.35050, test err=0.902
# Trial 8, Epoch: 1000, He model, h=100, lr=0.01000, Loss=0.58126, test err=0.139
# Trial 8, Epoch: 2000, He model, h=100, lr=0.01000, Loss=0.41190, test err=0.105
# Trial 8, Epoch: 3000, He model, h=100, lr=0.01000, Loss=0.35677, test err=0.093
# Trial 9, Epoch: 0, He model, h=100, lr=0.01000, Loss=2.28547, test err=0.879
# Trial 9, Epoch: 1000, He model, h=100, lr=0.01000, Loss=0.57301, test err=0.134
# Trial 9, Epoch: 2000, He model, h=100, lr=0.01000, Loss=0.41320, test err=0.108
# Trial 9, Epoch: 3000, He model, h=100, lr=0.01000, Loss=0.35924, test err=0.097
# Trial 0, Epoch: 0, V1 model, h=100, lr=0.10000, Loss=2.35034, test err=0.741
# Trial 0, Epoch: 1000, V1 model, h=100, lr=0.10000, Loss=0.21209, test err=0.059
# Trial 0, Epoch: 2000, V1 model, h=100, lr=0.10000, Loss=0.15429, test err=0.046
# Trial 0, Epoch: 3000, V1 model, h=100, lr=0.10000, Loss=0.12271, test err=0.039
# Trial 1, Epoch: 0, V1 model, h=100, lr=0.10000, Loss=2.45524, test err=0.755
# Trial 1, Epoch: 1000, V1 model, h=100, lr=0.10000, Loss=0.22218, test err=0.061
# Trial 1, Epoch: 2000, V1 model, h=100, lr=0.10000, Loss=0.16139, test err=0.049
# Trial 1, Epoch: 3000, V1 model, h=100, lr=0.10000, Loss=0.12690, test err=0.039
# Trial 2, Epoch: 0, V1 model, h=100, lr=0.10000, Loss=2.34721, test err=0.798
# Trial 2, Epoch: 1000, V1 model, h=100, lr=0.10000, Loss=0.20291, test err=0.056
# Trial 2, Epoch: 2000, V1 model, h=100, lr=0.10000, Loss=0.14585, test err=0.042
# Trial 2, Epoch: 3000, V1 model, h=100, lr=0.10000, Loss=0.11557, test err=0.036
# Trial 3, Epoch: 0, V1 model, h=100, lr=0.10000, Loss=2.41034, test err=0.822
# Trial 3, Epoch: 1000, V1 model, h=100, lr=0.10000, Loss=0.21244, test err=0.060
# Trial 3, Epoch: 2000, V1 model, h=100, lr=0.10000, Loss=0.15244, test err=0.046
# Trial 3, Epoch: 3000, V1 model, h=100, lr=0.10000, Loss=0.11984, test err=0.037
# Trial 4, Epoch: 0, V1 model, h=100, lr=0.10000, Loss=2.40528, test err=0.759
# Trial 4, Epoch: 1000, V1 model, h=100, lr=0.10000, Loss=0.20759, test err=0.058
# Trial 4, Epoch: 2000, V1 model, h=100, lr=0.10000, Loss=0.14837, test err=0.043
# Trial 4, Epoch: 3000, V1 model, h=100, lr=0.10000, Loss=0.11766, test err=0.035
# Trial 5, Epoch: 0, V1 model, h=100, lr=0.10000, Loss=2.47945, test err=0.815
# Trial 5, Epoch: 1000, V1 model, h=100, lr=0.10000, Loss=0.20676, test err=0.058
# Trial 5, Epoch: 2000, V1 model, h=100, lr=0.10000, Loss=0.14788, test err=0.043
# Trial 5, Epoch: 3000, V1 model, h=100, lr=0.10000, Loss=0.11582, test err=0.034
# Trial 6, Epoch: 0, V1 model, h=100, lr=0.10000, Loss=2.95001, test err=0.876
# Trial 6, Epoch: 1000, V1 model, h=100, lr=0.10000, Loss=0.22588, test err=0.063
# Trial 6, Epoch: 2000, V1 model, h=100, lr=0.10000, Loss=0.15780, test err=0.045
# Trial 6, Epoch: 3000, V1 model, h=100, lr=0.10000, Loss=0.12212, test err=0.037
# Trial 7, Epoch: 0, V1 model, h=100, lr=0.10000, Loss=2.45834, test err=0.745
# Trial 7, Epoch: 1000, V1 model, h=100, lr=0.10000, Loss=0.20598, test err=0.056
# Trial 7, Epoch: 2000, V1 model, h=100, lr=0.10000, Loss=0.14824, test err=0.042
# Trial 7, Epoch: 3000, V1 model, h=100, lr=0.10000, Loss=0.11634, test err=0.034
# Trial 8, Epoch: 0, V1 model, h=100, lr=0.10000, Loss=2.40769, test err=0.843
# Trial 8, Epoch: 1000, V1 model, h=100, lr=0.10000, Loss=0.21342, test err=0.059
# Trial 8, Epoch: 2000, V1 model, h=100, lr=0.10000, Loss=0.15250, test err=0.043
# Trial 8, Epoch: 3000, V1 model, h=100, lr=0.10000, Loss=0.12034, test err=0.035
# Trial 9, Epoch: 0, V1 model, h=100, lr=0.10000, Loss=2.59726, test err=0.843
# Trial 9, Epoch: 1000, V1 model, h=100, lr=0.10000, Loss=0.21926, test err=0.061
# Trial 9, Epoch: 2000, V1 model, h=100, lr=0.10000, Loss=0.15744, test err=0.046
# Trial 9, Epoch: 3000, V1 model, h=100, lr=0.10000, Loss=0.12328, test err=0.038
# Trial 0, Epoch: 0, He model, h=100, lr=0.10000, Loss=2.33072, test err=0.847
# Trial 0, Epoch: 1000, He model, h=100, lr=0.10000, Loss=0.24768, test err=0.068
# Trial 0, Epoch: 2000, He model, h=100, lr=0.10000, Loss=0.17938, test err=0.051
# Trial 0, Epoch: 3000, He model, h=100, lr=0.10000, Loss=0.14021, test err=0.040
# Trial 1, Epoch: 0, He model, h=100, lr=0.10000, Loss=2.33365, test err=0.876
# Trial 1, Epoch: 1000, He model, h=100, lr=0.10000, Loss=0.24691, test err=0.068
# Trial 1, Epoch: 2000, He model, h=100, lr=0.10000, Loss=0.17616, test err=0.049
# Trial 1, Epoch: 3000, He model, h=100, lr=0.10000, Loss=0.13537, test err=0.041
# Trial 2, Epoch: 0, He model, h=100, lr=0.10000, Loss=2.33816, test err=0.905
# Trial 2, Epoch: 1000, He model, h=100, lr=0.10000, Loss=0.24678, test err=0.070
# Trial 2, Epoch: 2000, He model, h=100, lr=0.10000, Loss=0.17942, test err=0.053
# Trial 2, Epoch: 3000, He model, h=100, lr=0.10000, Loss=0.14018, test err=0.044
# Trial 3, Epoch: 0, He model, h=100, lr=0.10000, Loss=2.29863, test err=0.838
# Trial 3, Epoch: 1000, He model, h=100, lr=0.10000, Loss=0.25038, test err=0.070
# Trial 3, Epoch: 2000, He model, h=100, lr=0.10000, Loss=0.17834, test err=0.053
# Trial 3, Epoch: 3000, He model, h=100, lr=0.10000, Loss=0.13758, test err=0.043
# Trial 4, Epoch: 0, He model, h=100, lr=0.10000, Loss=2.35135, test err=0.927
# Trial 4, Epoch: 1000, He model, h=100, lr=0.10000, Loss=0.25033, test err=0.069
# Trial 4, Epoch: 2000, He model, h=100, lr=0.10000, Loss=0.17895, test err=0.052
# Trial 4, Epoch: 3000, He model, h=100, lr=0.10000, Loss=0.13778, test err=0.041
# Trial 5, Epoch: 0, He model, h=100, lr=0.10000, Loss=2.30602, test err=0.857
# Trial 5, Epoch: 1000, He model, h=100, lr=0.10000, Loss=0.24292, test err=0.067
# Trial 5, Epoch: 2000, He model, h=100, lr=0.10000, Loss=0.17596, test err=0.051
# Trial 5, Epoch: 3000, He model, h=100, lr=0.10000, Loss=0.13730, test err=0.041
# Trial 6, Epoch: 0, He model, h=100, lr=0.10000, Loss=2.30107, test err=0.896
# Trial 6, Epoch: 1000, He model, h=100, lr=0.10000, Loss=0.24777, test err=0.068
# Trial 6, Epoch: 2000, He model, h=100, lr=0.10000, Loss=0.18096, test err=0.054
# Trial 6, Epoch: 3000, He model, h=100, lr=0.10000, Loss=0.14117, test err=0.044
# Trial 7, Epoch: 0, He model, h=100, lr=0.10000, Loss=2.30235, test err=0.882
# Trial 7, Epoch: 1000, He model, h=100, lr=0.10000, Loss=0.24509, test err=0.067
# Trial 7, Epoch: 2000, He model, h=100, lr=0.10000, Loss=0.17883, test err=0.053
# Trial 7, Epoch: 3000, He model, h=100, lr=0.10000, Loss=0.13977, test err=0.043
# Trial 8, Epoch: 0, He model, h=100, lr=0.10000, Loss=2.32436, test err=0.915
# Trial 8, Epoch: 1000, He model, h=100, lr=0.10000, Loss=0.25007, test err=0.071
# Trial 8, Epoch: 2000, He model, h=100, lr=0.10000, Loss=0.18369, test err=0.054
# Trial 8, Epoch: 3000, He model, h=100, lr=0.10000, Loss=0.14298, test err=0.044
# Trial 9, Epoch: 0, He model, h=100, lr=0.10000, Loss=2.30897, test err=0.863
# Trial 9, Epoch: 1000, He model, h=100, lr=0.10000, Loss=0.24329, test err=0.069
# Trial 9, Epoch: 2000, He model, h=100, lr=0.10000, Loss=0.17593, test err=0.051
# Trial 9, Epoch: 3000, He model, h=100, lr=0.10000, Loss=0.13751, test err=0.043
# Trial 0, Epoch: 0, V1 model, h=100, lr=1.00000, Loss=2.54012, test err=0.788
# Trial 0, Epoch: 1000, V1 model, h=100, lr=1.00000, Loss=0.05024, test err=0.024
# Trial 0, Epoch: 2000, V1 model, h=100, lr=1.00000, Loss=0.02469, test err=0.023
# Trial 0, Epoch: 3000, V1 model, h=100, lr=1.00000, Loss=0.01410, test err=0.022
# Trial 1, Epoch: 0, V1 model, h=100, lr=1.00000, Loss=2.33647, test err=0.890
# Trial 1, Epoch: 1000, V1 model, h=100, lr=1.00000, Loss=0.04842, test err=0.023
# Trial 1, Epoch: 2000, V1 model, h=100, lr=1.00000, Loss=0.02198, test err=0.022
# Trial 1, Epoch: 3000, V1 model, h=100, lr=1.00000, Loss=0.01191, test err=0.021
# Trial 2, Epoch: 0, V1 model, h=100, lr=1.00000, Loss=2.61151, test err=0.771
# Trial 2, Epoch: 1000, V1 model, h=100, lr=1.00000, Loss=0.04764, test err=0.023
# Trial 2, Epoch: 2000, V1 model, h=100, lr=1.00000, Loss=0.02286, test err=0.022
# Trial 2, Epoch: 3000, V1 model, h=100, lr=1.00000, Loss=0.01272, test err=0.022
# Trial 3, Epoch: 0, V1 model, h=100, lr=1.00000, Loss=2.35444, test err=0.902
# Trial 3, Epoch: 1000, V1 model, h=100, lr=1.00000, Loss=0.04912, test err=0.025
# Trial 3, Epoch: 2000, V1 model, h=100, lr=1.00000, Loss=0.02358, test err=0.023
# Trial 3, Epoch: 3000, V1 model, h=100, lr=1.00000, Loss=0.01309, test err=0.022
# Trial 4, Epoch: 0, V1 model, h=100, lr=1.00000, Loss=2.50623, test err=0.747
# Trial 4, Epoch: 1000, V1 model, h=100, lr=1.00000, Loss=0.04590, test err=0.023
# Trial 4, Epoch: 2000, V1 model, h=100, lr=1.00000, Loss=0.02187, test err=0.022
# Trial 4, Epoch: 3000, V1 model, h=100, lr=1.00000, Loss=0.01225, test err=0.022
# Trial 5, Epoch: 0, V1 model, h=100, lr=1.00000, Loss=2.46679, test err=0.736
# Trial 5, Epoch: 1000, V1 model, h=100, lr=1.00000, Loss=0.04866, test err=0.023
# Trial 5, Epoch: 2000, V1 model, h=100, lr=1.00000, Loss=0.02315, test err=0.021
# Trial 5, Epoch: 3000, V1 model, h=100, lr=1.00000, Loss=0.01292, test err=0.021
# Trial 6, Epoch: 0, V1 model, h=100, lr=1.00000, Loss=2.48933, test err=0.726
# Trial 6, Epoch: 1000, V1 model, h=100, lr=1.00000, Loss=0.04825, test err=0.023
# Trial 6, Epoch: 2000, V1 model, h=100, lr=1.00000, Loss=0.02336, test err=0.022
# Trial 6, Epoch: 3000, V1 model, h=100, lr=1.00000, Loss=0.01305, test err=0.021
# Trial 7, Epoch: 0, V1 model, h=100, lr=1.00000, Loss=2.54956, test err=0.816
# Trial 7, Epoch: 1000, V1 model, h=100, lr=1.00000, Loss=0.05258, test err=0.028
# Trial 7, Epoch: 2000, V1 model, h=100, lr=1.00000, Loss=0.02555, test err=0.025
# Trial 7, Epoch: 3000, V1 model, h=100, lr=1.00000, Loss=0.01427, test err=0.024
# Trial 8, Epoch: 0, V1 model, h=100, lr=1.00000, Loss=2.55340, test err=0.835
# Trial 8, Epoch: 1000, V1 model, h=100, lr=1.00000, Loss=0.04831, test err=0.024
# Trial 8, Epoch: 2000, V1 model, h=100, lr=1.00000, Loss=0.02317, test err=0.022
# Trial 8, Epoch: 3000, V1 model, h=100, lr=1.00000, Loss=0.01309, test err=0.023
# Trial 9, Epoch: 0, V1 model, h=100, lr=1.00000, Loss=2.39899, test err=0.686
# Trial 9, Epoch: 1000, V1 model, h=100, lr=1.00000, Loss=0.04698, test err=0.022
# Trial 9, Epoch: 2000, V1 model, h=100, lr=1.00000, Loss=0.02252, test err=0.021
# Trial 9, Epoch: 3000, V1 model, h=100, lr=1.00000, Loss=0.01242, test err=0.020
# Trial 0, Epoch: 0, He model, h=100, lr=1.00000, Loss=2.30891, test err=0.506
# Trial 0, Epoch: 1000, He model, h=100, lr=1.00000, Loss=0.04782, test err=0.025
# Trial 0, Epoch: 2000, He model, h=100, lr=1.00000, Loss=0.02216, test err=0.022
# Trial 0, Epoch: 3000, He model, h=100, lr=1.00000, Loss=0.01210, test err=0.023
# Trial 1, Epoch: 0, He model, h=100, lr=1.00000, Loss=2.31862, test err=0.594
# Trial 1, Epoch: 1000, He model, h=100, lr=1.00000, Loss=0.05571, test err=0.026
# Trial 1, Epoch: 2000, He model, h=100, lr=1.00000, Loss=0.02699, test err=0.024
# Trial 1, Epoch: 3000, He model, h=100, lr=1.00000, Loss=0.01518, test err=0.024
# Trial 2, Epoch: 0, He model, h=100, lr=1.00000, Loss=2.30158, test err=0.480
# ...
# Trial 9, Epoch: 0, He model, h=400, lr=1.00000, Loss=2.32213, test err=0.514
# Trial 9, Epoch: 1000, He model, h=400, lr=1.00000, Loss=0.03591, test err=0.021
# Trial 9, Epoch: 2000, He model, h=400, lr=1.00000, Loss=0.01374, test err=0.019
# Trial 9, Epoch: 3000, He model, h=400, lr=1.00000, Loss=0.00701, test err=0.019
# Trial 0, Epoch: 0, V1 model, h=1000, lr=0.00100, Loss=2.54148, test err=0.901
# Trial 0, Epoch: 1000, V1 model, h=1000, lr=0.00100, Loss=0.58575, test err=0.124
# Trial 0, Epoch: 2000, V1 model, h=1000, lr=0.00100, Loss=0.46071, test err=0.107
# Trial 0, Epoch: 3000, V1 model, h=1000, lr=0.00100, Loss=0.40726, test err=0.098
# Trial 1, Epoch: 0, V1 model, h=1000, lr=0.00100, Loss=2.47028, test err=0.886
# Trial 1, Epoch: 1000, V1 model, h=1000, lr=0.00100, Loss=0.60511, test err=0.129
# Trial 1, Epoch: 2000, V1 model, h=1000, lr=0.00100, Loss=0.47490, test err=0.107
# Trial 1, Epoch: 3000, V1 model, h=1000, lr=0.00100, Loss=0.41931, test err=0.099
# Trial 2, Epoch: 0, V1 model, h=1000, lr=0.00100, Loss=2.50174, test err=0.857
# Trial 2, Epoch: 1000, V1 model, h=1000, lr=0.00100, Loss=0.57651, test err=0.122
# Trial 2, Epoch: 2000, V1 model, h=1000, lr=0.00100, Loss=0.45490, test err=0.104
# Trial 2, Epoch: 3000, V1 model, h=1000, lr=0.00100, Loss=0.40278, test err=0.097
# Trial 3, Epoch: 0, V1 model, h=1000, lr=0.00100, Loss=2.47897, test err=0.953
# Trial 3, Epoch: 1000, V1 model, h=1000, lr=0.00100, Loss=0.58256, test err=0.129
# Trial 3, Epoch: 2000, V1 model, h=1000, lr=0.00100, Loss=0.45907, test err=0.110
# Trial 3, Epoch: 3000, V1 model, h=1000, lr=0.00100, Loss=0.40633, test err=0.099
# Trial 4, Epoch: 0, V1 model, h=1000, lr=0.00100, Loss=2.60499, test err=0.834
# Trial 4, Epoch: 1000, V1 model, h=1000, lr=0.00100, Loss=0.57307, test err=0.122
# Trial 4, Epoch: 2000, V1 model, h=1000, lr=0.00100, Loss=0.45248, test err=0.104
# Trial 4, Epoch: 3000, V1 model, h=1000, lr=0.00100, Loss=0.40158, test err=0.096
# Trial 5, Epoch: 0, V1 model, h=1000, lr=0.00100, Loss=2.57472, test err=0.920
# Trial 5, Epoch: 1000, V1 model, h=1000, lr=0.00100, Loss=0.58570, test err=0.128
# Trial 5, Epoch: 2000, V1 model, h=1000, lr=0.00100, Loss=0.46448, test err=0.110
# Trial 5, Epoch: 3000, V1 model, h=1000, lr=0.00100, Loss=0.41192, test err=0.099
# Trial 6, Epoch: 0, V1 model, h=1000, lr=0.00100, Loss=2.50281, test err=0.929
# Trial 6, Epoch: 1000, V1 model, h=1000, lr=0.00100, Loss=0.57549, test err=0.121
# Trial 6, Epoch: 2000, V1 model, h=1000, lr=0.00100, Loss=0.45508, test err=0.103
# Trial 6, Epoch: 3000, V1 model, h=1000, lr=0.00100, Loss=0.40427, test err=0.097
# Trial 7, Epoch: 0, V1 model, h=1000, lr=0.00100, Loss=2.54955, test err=0.903
# Trial 7, Epoch: 1000, V1 model, h=1000, lr=0.00100, Loss=0.58866, test err=0.125
# Trial 7, Epoch: 2000, V1 model, h=1000, lr=0.00100, Loss=0.46160, test err=0.106
# Trial 7, Epoch: 3000, V1 model, h=1000, lr=0.00100, Loss=0.40773, test err=0.099
# Trial 8, Epoch: 0, V1 model, h=1000, lr=0.00100, Loss=2.84248, test err=0.860
# Trial 8, Epoch: 1000, V1 model, h=1000, lr=0.00100, Loss=0.56922, test err=0.123
# Trial 8, Epoch: 2000, V1 model, h=1000, lr=0.00100, Loss=0.45391, test err=0.106
# Trial 8, Epoch: 3000, V1 model, h=1000, lr=0.00100, Loss=0.40409, test err=0.098
# Trial 9, Epoch: 0, V1 model, h=1000, lr=0.00100, Loss=2.77383, test err=0.900
# Trial 9, Epoch: 1000, V1 model, h=1000, lr=0.00100, Loss=0.56641, test err=0.122
# Trial 9, Epoch: 2000, V1 model, h=1000, lr=0.00100, Loss=0.45252, test err=0.106
# Trial 9, Epoch: 3000, V1 model, h=1000, lr=0.00100, Loss=0.40360, test err=0.098
# Trial 0, Epoch: 0, He model, h=1000, lr=0.00100, Loss=2.32833, test err=0.881
# Trial 0, Epoch: 1000, He model, h=1000, lr=0.00100, Loss=1.50668, test err=0.217
# Trial 0, Epoch: 2000, He model, h=1000, lr=0.00100, Loss=1.06149, test err=0.168
# Trial 0, Epoch: 3000, He model, h=1000, lr=0.00100, Loss=0.82909, test err=0.146
# Trial 1, Epoch: 0, He model, h=1000, lr=0.00100, Loss=2.31153, test err=0.880
# Trial 1, Epoch: 1000, He model, h=1000, lr=0.00100, Loss=1.55943, test err=0.239
# Trial 1, Epoch: 2000, He model, h=1000, lr=0.00100, Loss=1.10913, test err=0.183
# Trial 1, Epoch: 3000, He model, h=1000, lr=0.00100, Loss=0.86304, test err=0.156
# Trial 2, Epoch: 0, He model, h=1000, lr=0.00100, Loss=2.30396, test err=0.915
# Trial 2, Epoch: 1000, He model, h=1000, lr=0.00100, Loss=1.51137, test err=0.230
# Trial 2, Epoch: 2000, He model, h=1000, lr=0.00100, Loss=1.07110, test err=0.176
# Trial 2, Epoch: 3000, He model, h=1000, lr=0.00100, Loss=0.83930, test err=0.154
# Trial 3, Epoch: 0, He model, h=1000, lr=0.00100, Loss=2.32264, test err=0.918
# Trial 3, Epoch: 1000, He model, h=1000, lr=0.00100, Loss=1.50466, test err=0.224
# Trial 3, Epoch: 2000, He model, h=1000, lr=0.00100, Loss=1.07153, test err=0.177
# Trial 3, Epoch: 3000, He model, h=1000, lr=0.00100, Loss=0.84460, test err=0.155
# Trial 4, Epoch: 0, He model, h=1000, lr=0.00100, Loss=2.28753, test err=0.888
# Trial 4, Epoch: 1000, He model, h=1000, lr=0.00100, Loss=1.49169, test err=0.213
# Trial 4, Epoch: 2000, He model, h=1000, lr=0.00100, Loss=1.05618, test err=0.171
# Trial 4, Epoch: 3000, He model, h=1000, lr=0.00100, Loss=0.82893, test err=0.152
# Trial 5, Epoch: 0, He model, h=1000, lr=0.00100, Loss=2.32214, test err=0.865
# Trial 5, Epoch: 1000, He model, h=1000, lr=0.00100, Loss=1.49672, test err=0.220
# Trial 5, Epoch: 2000, He model, h=1000, lr=0.00100, Loss=1.05899, test err=0.168
# Trial 5, Epoch: 3000, He model, h=1000, lr=0.00100, Loss=0.83080, test err=0.147
# Trial 6, Epoch: 0, He model, h=1000, lr=0.00100, Loss=2.33828, test err=0.927
# Trial 6, Epoch: 1000, He model, h=1000, lr=0.00100, Loss=1.49648, test err=0.213
# Trial 6, Epoch: 2000, He model, h=1000, lr=0.00100, Loss=1.05260, test err=0.169
# Trial 6, Epoch: 3000, He model, h=1000, lr=0.00100, Loss=0.82496, test err=0.150
# Trial 7, Epoch: 0, He model, h=1000, lr=0.00100, Loss=2.31463, test err=0.860
# Trial 7, Epoch: 1000, He model, h=1000, lr=0.00100, Loss=1.51226, test err=0.248
# Trial 7, Epoch: 2000, He model, h=1000, lr=0.00100, Loss=1.07714, test err=0.182
# Trial 7, Epoch: 3000, He model, h=1000, lr=0.00100, Loss=0.84568, test err=0.158
# Trial 8, Epoch: 0, He model, h=1000, lr=0.00100, Loss=2.33808, test err=0.932
# Trial 8, Epoch: 1000, He model, h=1000, lr=0.00100, Loss=1.50916, test err=0.234
# Trial 8, Epoch: 2000, He model, h=1000, lr=0.00100, Loss=1.06758, test err=0.175
# Trial 8, Epoch: 3000, He model, h=1000, lr=0.00100, Loss=0.83895, test err=0.155
# Trial 9, Epoch: 0, He model, h=1000, lr=0.00100, Loss=2.33911, test err=0.908
# Trial 9, Epoch: 1000, He model, h=1000, lr=0.00100, Loss=1.53502, test err=0.232
# Trial 9, Epoch: 2000, He model, h=1000, lr=0.00100, Loss=1.08777, test err=0.182
# Trial 9, Epoch: 3000, He model, h=1000, lr=0.00100, Loss=0.85162, test err=0.159
# Trial 0, Epoch: 0, V1 model, h=1000, lr=0.01000, Loss=2.52936, test err=0.818
# Trial 0, Epoch: 1000, V1 model, h=1000, lr=0.01000, Loss=0.29929, test err=0.077
# Trial 0, Epoch: 2000, V1 model, h=1000, lr=0.01000, Loss=0.24899, test err=0.066
# Trial 0, Epoch: 3000, V1 model, h=1000, lr=0.01000, Loss=0.22073, test err=0.059
# Trial 1, Epoch: 0, V1 model, h=1000, lr=0.01000, Loss=2.48120, test err=0.825
# Trial 1, Epoch: 1000, V1 model, h=1000, lr=0.01000, Loss=0.29806, test err=0.078
# Trial 1, Epoch: 2000, V1 model, h=1000, lr=0.01000, Loss=0.24816, test err=0.066
# Trial 1, Epoch: 3000, V1 model, h=1000, lr=0.01000, Loss=0.21939, test err=0.058
# Trial 2, Epoch: 0, V1 model, h=1000, lr=0.01000, Loss=2.60330, test err=0.802
# Trial 2, Epoch: 1000, V1 model, h=1000, lr=0.01000, Loss=0.29568, test err=0.077
# Trial 2, Epoch: 2000, V1 model, h=1000, lr=0.01000, Loss=0.24456, test err=0.065
# Trial 2, Epoch: 3000, V1 model, h=1000, lr=0.01000, Loss=0.21577, test err=0.058
# Trial 3, Epoch: 0, V1 model, h=1000, lr=0.01000, Loss=2.78750, test err=0.809
# Trial 3, Epoch: 1000, V1 model, h=1000, lr=0.01000, Loss=0.29853, test err=0.079
# Trial 3, Epoch: 2000, V1 model, h=1000, lr=0.01000, Loss=0.24824, test err=0.067
# Trial 3, Epoch: 3000, V1 model, h=1000, lr=0.01000, Loss=0.21919, test err=0.061
# Trial 4, Epoch: 0, V1 model, h=1000, lr=0.01000, Loss=2.43084, test err=0.874
# Trial 4, Epoch: 1000, V1 model, h=1000, lr=0.01000, Loss=0.29855, test err=0.078
# Trial 4, Epoch: 2000, V1 model, h=1000, lr=0.01000, Loss=0.24742, test err=0.066
# Trial 4, Epoch: 3000, V1 model, h=1000, lr=0.01000, Loss=0.21837, test err=0.059
# Trial 5, Epoch: 0, V1 model, h=1000, lr=0.01000, Loss=2.62195, test err=0.820
# Trial 5, Epoch: 1000, V1 model, h=1000, lr=0.01000, Loss=0.29427, test err=0.076
# Trial 5, Epoch: 2000, V1 model, h=1000, lr=0.01000, Loss=0.24469, test err=0.065
# Trial 5, Epoch: 3000, V1 model, h=1000, lr=0.01000, Loss=0.21665, test err=0.058
# Trial 6, Epoch: 0, V1 model, h=1000, lr=0.01000, Loss=2.67103, test err=0.846
# Trial 6, Epoch: 1000, V1 model, h=1000, lr=0.01000, Loss=0.29830, test err=0.076
# Trial 6, Epoch: 2000, V1 model, h=1000, lr=0.01000, Loss=0.24920, test err=0.065
# Trial 6, Epoch: 3000, V1 model, h=1000, lr=0.01000, Loss=0.22106, test err=0.058
# Trial 7, Epoch: 0, V1 model, h=1000, lr=0.01000, Loss=2.32970, test err=0.749
# Trial 7, Epoch: 1000, V1 model, h=1000, lr=0.01000, Loss=0.29388, test err=0.076
# Trial 7, Epoch: 2000, V1 model, h=1000, lr=0.01000, Loss=0.24443, test err=0.064
# Trial 7, Epoch: 3000, V1 model, h=1000, lr=0.01000, Loss=0.21608, test err=0.056
# Trial 8, Epoch: 0, V1 model, h=1000, lr=0.01000, Loss=2.55041, test err=0.849
# Trial 8, Epoch: 1000, V1 model, h=1000, lr=0.01000, Loss=0.29355, test err=0.075
# Trial 8, Epoch: 2000, V1 model, h=1000, lr=0.01000, Loss=0.24341, test err=0.064
# Trial 8, Epoch: 3000, V1 model, h=1000, lr=0.01000, Loss=0.21515, test err=0.058
# Trial 9, Epoch: 0, V1 model, h=1000, lr=0.01000, Loss=2.59251, test err=0.921
# Trial 9, Epoch: 1000, V1 model, h=1000, lr=0.01000, Loss=0.30245, test err=0.077
# Trial 9, Epoch: 2000, V1 model, h=1000, lr=0.01000, Loss=0.25189, test err=0.066
# Trial 9, Epoch: 3000, V1 model, h=1000, lr=0.01000, Loss=0.22249, test err=0.059
# Trial 0, Epoch: 0, He model, h=1000, lr=0.01000, Loss=2.35206, test err=0.917
# Trial 0, Epoch: 1000, He model, h=1000, lr=0.01000, Loss=0.45561, test err=0.107
# Trial 0, Epoch: 2000, He model, h=1000, lr=0.01000, Loss=0.35634, test err=0.091
# Trial 0, Epoch: 3000, He model, h=1000, lr=0.01000, Loss=0.31548, test err=0.083
# Trial 1, Epoch: 0, He model, h=1000, lr=0.01000, Loss=2.30227, test err=0.916
# Trial 1, Epoch: 1000, He model, h=1000, lr=0.01000, Loss=0.44878, test err=0.107
# Trial 1, Epoch: 2000, He model, h=1000, lr=0.01000, Loss=0.35380, test err=0.090
# Trial 1, Epoch: 3000, He model, h=1000, lr=0.01000, Loss=0.31419, test err=0.080
# Trial 2, Epoch: 0, He model, h=1000, lr=0.01000, Loss=2.30734, test err=0.892
# Trial 2, Epoch: 1000, He model, h=1000, lr=0.01000, Loss=0.45357, test err=0.109
# Trial 2, Epoch: 2000, He model, h=1000, lr=0.01000, Loss=0.35621, test err=0.090
# Trial 2, Epoch: 3000, He model, h=1000, lr=0.01000, Loss=0.31558, test err=0.083
# Trial 3, Epoch: 0, He model, h=1000, lr=0.01000, Loss=2.29973, test err=0.877
# Trial 3, Epoch: 1000, He model, h=1000, lr=0.01000, Loss=0.45306, test err=0.108
# Trial 3, Epoch: 2000, He model, h=1000, lr=0.01000, Loss=0.35501, test err=0.090
# Trial 3, Epoch: 3000, He model, h=1000, lr=0.01000, Loss=0.31436, test err=0.081
# Trial 4, Epoch: 0, He model, h=1000, lr=0.01000, Loss=2.32906, test err=0.926
# Trial 4, Epoch: 1000, He model, h=1000, lr=0.01000, Loss=0.45739, test err=0.109
# Trial 4, Epoch: 2000, He model, h=1000, lr=0.01000, Loss=0.35807, test err=0.092
# Trial 4, Epoch: 3000, He model, h=1000, lr=0.01000, Loss=0.31728, test err=0.084
# Trial 5, Epoch: 0, He model, h=1000, lr=0.01000, Loss=2.28579, test err=0.838
# Trial 5, Epoch: 1000, He model, h=1000, lr=0.01000, Loss=0.45559, test err=0.112
# Trial 5, Epoch: 2000, He model, h=1000, lr=0.01000, Loss=0.35774, test err=0.093
# Trial 5, Epoch: 3000, He model, h=1000, lr=0.01000, Loss=0.31689, test err=0.085
# Trial 6, Epoch: 0, He model, h=1000, lr=0.01000, Loss=2.30843, test err=0.919
# Trial 6, Epoch: 1000, He model, h=1000, lr=0.01000, Loss=0.45970, test err=0.108
# Trial 6, Epoch: 2000, He model, h=1000, lr=0.01000, Loss=0.35872, test err=0.092
# Trial 6, Epoch: 3000, He model, h=1000, lr=0.01000, Loss=0.31718, test err=0.084
# Trial 7, Epoch: 0, He model, h=1000, lr=0.01000, Loss=2.30638, test err=0.796
# Trial 7, Epoch: 1000, He model, h=1000, lr=0.01000, Loss=0.45653, test err=0.111
# Trial 7, Epoch: 2000, He model, h=1000, lr=0.01000, Loss=0.35662, test err=0.093
# Trial 7, Epoch: 3000, He model, h=1000, lr=0.01000, Loss=0.31517, test err=0.084
# Trial 8, Epoch: 0, He model, h=1000, lr=0.01000, Loss=2.33494, test err=0.915
# Trial 8, Epoch: 1000, He model, h=1000, lr=0.01000, Loss=0.45621, test err=0.111
# Trial 8, Epoch: 2000, He model, h=1000, lr=0.01000, Loss=0.35642, test err=0.094
# Trial 8, Epoch: 3000, He model, h=1000, lr=0.01000, Loss=0.31550, test err=0.085
# Trial 9, Epoch: 0, He model, h=1000, lr=0.01000, Loss=2.34803, test err=0.924
# Trial 9, Epoch: 1000, He model, h=1000, lr=0.01000, Loss=0.45418, test err=0.109
# Trial 9, Epoch: 2000, He model, h=1000, lr=0.01000, Loss=0.35583, test err=0.091
# Trial 9, Epoch: 3000, He model, h=1000, lr=0.01000, Loss=0.31498, test err=0.083
# Trial 0, Epoch: 0, V1 model, h=1000, lr=0.10000, Loss=2.54624, test err=0.807
# Trial 0, Epoch: 1000, V1 model, h=1000, lr=0.10000, Loss=0.12785, test err=0.034
# Trial 0, Epoch: 2000, V1 model, h=1000, lr=0.10000, Loss=0.08944, test err=0.027
# Trial 0, Epoch: 3000, V1 model, h=1000, lr=0.10000, Loss=0.07023, test err=0.023
# Trial 1, Epoch: 0, V1 model, h=1000, lr=0.10000, Loss=2.45337, test err=0.796
# Trial 1, Epoch: 1000, V1 model, h=1000, lr=0.10000, Loss=0.12707, test err=0.033
# Trial 1, Epoch: 2000, V1 model, h=1000, lr=0.10000, Loss=0.08916, test err=0.025
# Trial 1, Epoch: 3000, V1 model, h=1000, lr=0.10000, Loss=0.07001, test err=0.021
# Trial 2, Epoch: 0, V1 model, h=1000, lr=0.10000, Loss=2.50625, test err=0.824
# Trial 2, Epoch: 1000, V1 model, h=1000, lr=0.10000, Loss=0.12940, test err=0.034
# Trial 2, Epoch: 2000, V1 model, h=1000, lr=0.10000, Loss=0.09027, test err=0.026
# Trial 2, Epoch: 3000, V1 model, h=1000, lr=0.10000, Loss=0.07085, test err=0.021
# Trial 3, Epoch: 0, V1 model, h=1000, lr=0.10000, Loss=2.41429, test err=0.856
# Trial 3, Epoch: 1000, V1 model, h=1000, lr=0.10000, Loss=0.12772, test err=0.034
# Trial 3, Epoch: 2000, V1 model, h=1000, lr=0.10000, Loss=0.08980, test err=0.026
# Trial 3, Epoch: 3000, V1 model, h=1000, lr=0.10000, Loss=0.07055, test err=0.023
# Trial 4, Epoch: 0, V1 model, h=1000, lr=0.10000, Loss=2.61724, test err=0.862
# Trial 4, Epoch: 1000, V1 model, h=1000, lr=0.10000, Loss=0.12806, test err=0.035
# Trial 4, Epoch: 2000, V1 model, h=1000, lr=0.10000, Loss=0.08947, test err=0.026
# Trial 4, Epoch: 3000, V1 model, h=1000, lr=0.10000, Loss=0.07020, test err=0.023
# Trial 5, Epoch: 0, V1 model, h=1000, lr=0.10000, Loss=2.69192, test err=0.858
# Trial 5, Epoch: 1000, V1 model, h=1000, lr=0.10000, Loss=0.12920, test err=0.035
# Trial 5, Epoch: 2000, V1 model, h=1000, lr=0.10000, Loss=0.09076, test err=0.026
# Trial 5, Epoch: 3000, V1 model, h=1000, lr=0.10000, Loss=0.07155, test err=0.023
# Trial 6, Epoch: 0, V1 model, h=1000, lr=0.10000, Loss=2.48616, test err=0.836
# Trial 6, Epoch: 1000, V1 model, h=1000, lr=0.10000, Loss=0.12837, test err=0.037
# Trial 6, Epoch: 2000, V1 model, h=1000, lr=0.10000, Loss=0.08983, test err=0.027
# Trial 6, Epoch: 3000, V1 model, h=1000, lr=0.10000, Loss=0.07020, test err=0.023
# Trial 7, Epoch: 0, V1 model, h=1000, lr=0.10000, Loss=2.40777, test err=0.834
# Trial 7, Epoch: 1000, V1 model, h=1000, lr=0.10000, Loss=0.12798, test err=0.033
# Trial 7, Epoch: 2000, V1 model, h=1000, lr=0.10000, Loss=0.09027, test err=0.025
# Trial 7, Epoch: 3000, V1 model, h=1000, lr=0.10000, Loss=0.07104, test err=0.022
# Trial 8, Epoch: 0, V1 model, h=1000, lr=0.10000, Loss=2.54018, test err=0.896
# Trial 8, Epoch: 1000, V1 model, h=1000, lr=0.10000, Loss=0.12932, test err=0.035
# Trial 8, Epoch: 2000, V1 model, h=1000, lr=0.10000, Loss=0.09055, test err=0.026

# %% [markdown]
# ## plot results

# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt

t, l, n_epochs= 5, 2, 3001
models = ['V1', 'He']
h_list = [50, 100, 400, 1000]
lr_list = [1e-3, 1e-2, 1e-1, 1e0]

for h in h_list:
    for lr in lr_list:
        with open('results/initialize_mnist/full_data/clf_t=%0.2f_l=%0.2f.pickle' % (t, l), 'rb') as handle:
            sims = pickle.load(handle)

        fig = plt.figure(figsize=(12, 5))
        plt.suptitle(r'Shallow FFW FC net w/ GD. h=%d, lr=%0.4f, '% (h, lr), fontsize=16)
        
        # loss
        ax = fig.add_subplot(131)
        plt.title('Network loss', fontsize=16)
        for m in models:
            avg_loss = np.mean(sims['loss'][m][h][lr], axis=0)
            std_loss = np.std(sims['loss'][m][h][lr], axis=0)                       
            plt.plot(np.arange(n_epochs), avg_loss, label=m, lw=3)
            plt.fill_between(np.arange(n_epochs), avg_loss - std_loss, avg_loss + std_loss, alpha=0.2)
        plt.xlabel('Epoch', fontsize=20)
        plt.ylabel('Training loss', fontsize=20)
        ax.tick_params(axis = 'both', which = 'major', labelsize = 14, width=2, length=6)
        plt.yscale('log')
        plt.legend(fontsize=18)
        
        # train err
        ax = fig.add_subplot(132)
        plt.title('Train error', fontsize=16)
        for m in models:
            avg_train_err = np.mean(sims['train_err'][m][h][lr], axis=0)
            std_train_err = np.std(sims['train_err'][m][h][lr], axis=0)
            plt.plot(np.arange(n_epochs), avg_train_err, label=m, lw=3)
            plt.fill_between(np.arange(n_epochs), avg_train_err - std_train_err, avg_train_err + std_train_err,  alpha=0.2)
        
        plt.xlabel('Epoch', fontsize=20)
        plt.ylabel('Training error', fontsize=20)
        ax.tick_params(axis = 'both', which = 'major', labelsize = 14, width=2, length=6)
        plt.yticks(np.arange(0, 1, 0.2))
        plt.yscale('log')
        plt.legend(fontsize=18)

        # test err
        ax = fig.add_subplot(133)
        plt.title('Test error', fontsize=16)
        for m in models:
            avg_test_err = np.mean(sims['test_err'][m][h][lr], axis=0)
            std_test_err = np.std(sims['test_err'][m][h][lr], axis=0)
            plt.plot(np.arange(n_epochs), avg_test_err, label=m, lw=3)
            plt.fill_between(np.arange(n_epochs), avg_test_err - std_test_err, avg_test_err + std_test_err, alpha=0.2)

        plt.xlabel('Epoch', fontsize=20)
        plt.ylabel('Test error', fontsize=20)
        ax.tick_params(axis = 'both', which = 'major', labelsize = 14, width=2, length=6)
        plt.yticks(np.arange(0, 1, 0.2))
        plt.yscale('log')
        plt.legend(fontsize=18)

        plt.tight_layout()
        plt.subplots_adjust(top=0.8)    

        print(h, lr)
        plt.savefig('results/initialize_mnist/full_data/init_t=%0.2f_l=%0.2f_h=%d_lr=%0.4f.png' % (t, l, h, lr))
        plt.close()
# Out:
# 50 0.001
# 50 0.01
# 50 0.1
# 50 1.0
# 100 0.001
# 100 0.01
# 100 0.1
# 100 1.0
# 400 0.001
# 400 0.01
# 400 0.1
# 400 1.0
# 1000 0.001
# 1000 0.01
# 1000 0.1
# 1000 1.0

# %% [markdown]
# ## Test the speed of training networks on GPUs vs CPU

# %%
import numpy as np
import numpy.linalg as la
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from estimator import classical_weights, V1_inspired_weights
from data_fns import load_mnist

# %%
train, train_labels, test, test_labels = load_mnist('./data/mnist')
X_train = torch.from_numpy(train).float()
X_test = torch.from_numpy(test).float()
y_train = torch.from_numpy(train_labels).long()
y_test = torch.from_numpy(test_labels).long()
n, d = X_train.shape

# %%
class V1_net(nn.Module):
    def __init__(self, hidden_size, scale):
        super().__init__()
        self.fc1 = nn.Linear(d, hidden_size)
        self.fc1.weight.data = torch.FloatTensor(V1_inspired_weights(hidden_size, d, t=5, l=2, scale=scale))
        self.output = nn.Linear(hidden_size, 10)
        
    def forward(self, inputs):
        x = torch.relu(self.fc1(inputs))
        return self.output(x)
    
class He_net(nn.Module):
    def __init__(self, hidden_size, scale):
        super().__init__()
        self.fc1 = nn.Linear(d, hidden_size)
        torch.nn.init.kaiming_normal_(self.fc1.weight)
        self.output = nn.Linear(hidden_size, 10)
        
    def forward(self, inputs):
        x = torch.relu(self.fc1(inputs))
        return self.output(x)
    
class RF_net(nn.Module):
    def __init__(self, hidden_size, scale):
        super().__init__()
        self.fc1 = nn.Linear(d, hidden_size)
        self.fc1.weight.data = torch.FloatTensor(classical_weights(hidden_size, d, scale=scale))
        self.output = nn.Linear(hidden_size, 10)
        
    def forward(self, inputs):
        x = torch.relu(self.fc1(inputs))
        return self.output(x)    
    
    
def predict(model, X):
    return model(X).data.max(1)[1]

def error(model, X, y):
    y_pred = predict(model, X)
    accuracy = 1.0 * torch.sum(y_pred == y) / len(y)
    return 1 - accuracy

# %%
# %%time
## Run on CPU
h, lr, scale = 1000, 0.1, 2 / d
n_epochs = 50
model = V1_net(h, scale=scale)
loss_func = nn.CrossEntropyLoss()
optim = torch.optim.SGD(model.parameters(), lr=lr)

for i in range(n_epochs):
    optim.zero_grad()
    loss = loss_func(model(X_train), y_train)
    loss.backward()
    optim.step()
    
    train_err = error(model, X_train, y_train)
    test_err = error(model, X_test, y_test)
    
    if (i % 10 == 0):
        print('Epoch: %d, Loss=%0.5f, train_err=%0.5f, test_err=%0.5f' % (i, loss.data, train_err, test_err))

# %%
# %%time
## Run on GPU
X_train_cuda, y_train_cuda = X_train.to('cuda'), y_train.to('cuda')
X_test_cuda, y_test_cuda = X_test.to('cuda'), y_test.to('cuda')

h, lr, scale = 2000, 1, 2/d
n_epochs = 2001
model = V1_net(h, scale=scale).to('cuda')
loss_func = nn.CrossEntropyLoss()
optim = torch.optim.SGD(model.parameters(), lr=lr)

test_err_list_V1 = []
for i in range(n_epochs):
    optim.zero_grad()
    loss = loss_func(model(X_train_cuda), y_train_cuda)
    loss.backward()
    optim.step()
    
    train_err = error(model, X_train_cuda, y_train_cuda)
    test_err = error(model, X_test_cuda, y_test_cuda)
    test_err_list_V1.append(test_err)
    
    if (i % 200 == 0):
        print('Epoch: %d, Loss=%0.5f, train_err=%0.5f, test_err=%0.5f' % (i, loss.data, train_err, test_err))

# %%
# %%time
## Run on GPU
X_train_cuda, y_train_cuda = X_train.to('cuda'), y_train.to('cuda')
X_test_cuda, y_test_cuda = X_test.to('cuda'), y_test.to('cuda')

h, lr, scale = 2000, 1, 2/d
n_epochs = 2001
model = He_net(h, scale=scale).to('cuda')
loss_func = nn.CrossEntropyLoss()
optim = torch.optim.SGD(model.parameters(), lr=lr)

test_err_list_He = []
for i in range(n_epochs):
    optim.zero_grad()
    loss = loss_func(model(X_train_cuda), y_train_cuda)
    loss.backward()
    optim.step()
    
    train_err = error(model, X_train_cuda, y_train_cuda)
    test_err = error(model, X_test_cuda, y_test_cuda)
    test_err_list_He.append(test_err)
    
    if (i % 200 == 0):
        print('Epoch: %d, Loss=%0.5f, train_err=%0.5f, test_err=%0.5f' % (i, loss.data, train_err, test_err))

# %%
fig = plt.figure()
plt.plot(np.arange(n_epochs), test_err_list_V1, label='V1')
plt.plot(np.arange(n_epochs), test_err_list_He, label='He')
plt.yscale('log')
plt.legend()

# %%
print(20)
