# %% [markdown]
# Initialize shallow feedforward fully-connected network with V1 type weights and classify __full mnist__ dataset using __Gradient descent__.

# %%
import numpy as np
import numpy.linalg as la
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from data_fns import load_mnist
from estimator import classical_weights, V1_inspired_weights
import pickle

# %%
torch.cuda.set_device(1)
train, train_labels, test, test_labels = load_mnist('./data/mnist/')
X_train = torch.from_numpy(train).float().to('cuda')
X_test = torch.from_numpy(test).float().to('cuda')
y_train = torch.from_numpy(train_labels).long().to('cuda')
y_test = torch.from_numpy(test_labels).long().to('cuda')
n, d = X_train.shape

# %%
class V1_net(nn.Module):
    def __init__(self, hidden_size, scale):
        super().__init__()
        self.fc1 = nn.Linear(d, hidden_size)
        self.fc1.weight.data = torch.FloatTensor(V1_inspired_weights(hidden_size, d, t=0.5, l=0.5, scale=scale))
        self.output = nn.Linear(hidden_size, 10)
        
    def forward(self, inputs):
        x = torch.relu(self.fc1(inputs))
        return self.output(x)
    
class He_net(nn.Module):
    def __init__(self, hidden_size, scale):
        super().__init__()
        self.fc1 = nn.Linear(d, hidden_size)
        torch.nn.init.kaiming_normal_(self.fc1.weight)
        self.output = nn.Linear(hidden_size, 10)
        
    def forward(self, inputs):
        x = torch.relu(self.fc1(inputs))
        return self.output(x)
    
class RF_net(nn.Module):
    def __init__(self, hidden_size, scale):
        super().__init__()
        self.fc1 = nn.Linear(d, hidden_size)
        self.fc1.weight.data = torch.FloatTensor(classical_weights(hidden_size, d, scale=scale))
        self.output = nn.Linear(hidden_size, 10)
        
    def forward(self, inputs):
        x = torch.relu(self.fc1(inputs))
        return self.output(x)

# %%
def predict(model, X):
    return model(X).data.max(1)[1]

def error(model, X, y):
    y_pred = predict(model, X)
    accuracy = 1.0 * torch.sum(y_pred == y) / len(y)
    return 1 - accuracy

# %%
V1_model = V1_net(100, 2/d)
RF_model = RF_net(100, 2/d)
He_model= He_net(100, 2/d)
print('V1', torch.mean(torch.norm(V1_model.fc1.weight.data, dim=1)))
print('He', torch.mean(torch.norm(He_model.fc1.weight.data, dim=1)))
print('RF', torch.mean(torch.norm(RF_model.fc1.weight.data, dim=1)))
w = torch.mean(torch.norm(RF_model.fc1.weight.data, dim=1))
# Out:
# V1 tensor(1.1952)
# He tensor(1.4189)
# RF tensor(1.4118)

# %%
n_trials, n_epochs = 10, 3001
models = {'V1': V1_net, 'He': He_net}
h_list = [50, 100, 400, 1000]
lr_list = [1e-3, 1e-2, 1e-1, 1e0]

train_err = {m: {h: {lr: np.zeros((n_trials, n_epochs)) for lr in lr_list} for h in h_list} for m in models.keys()}
test_err = {m: {h: {lr: np.zeros((n_trials, n_epochs)) for lr in lr_list} for h in h_list} for m in models.keys()}
loss_list = {m: {h: {lr: np.zeros((n_trials, n_epochs)) for lr in lr_list} for h in h_list} for m in models.keys()}

# %%
scale = 2/d
t, l = 0.5, 0.5
loss_func = nn.CrossEntropyLoss()

for h in h_list:
    for lr in lr_list:
        for m, network in models.items():
            for i in range(n_trials):
                model = network(h, scale).to('cuda')
                optim = torch.optim.SGD(model.parameters(), lr=lr)
                for j in range(n_epochs):
                    optim.zero_grad()
                    loss = loss_func(model(X_train), y_train)
                    loss.backward()
                    optim.step()

                    train_err[m][h][lr][i, j] = error(model, X_train, y_train)
                    test_err[m][h][lr][i, j] = error(model, X_test, y_test)
                    loss_list[m][h][lr][i, j] = loss.data

                    if (j % 1000 == 0):
                        print('Trial %d, Epoch: %d, %s model, h=%d, lr=%0.5f, Loss=%0.5f, test err=%0.3f' % (i,j, m, h, lr, loss.data, 
                                                                                                  test_err[m][h][lr][i, j]))
results = {'test_err': test_err, 'train_err': train_err, 'loss': loss_list}
with open('results/initialize_mnist/full_data/clf_t=%0.2f_l=%0.2f.pickle' % (t, l), 'wb') as handle:
    pickle.dump(results, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# Trial 0, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=2.31722, test err=0.949
# Trial 0, Epoch: 1000, V1 model, h=50, lr=0.00100, Loss=2.10278, test err=0.460
# Trial 0, Epoch: 2000, V1 model, h=50, lr=0.00100, Loss=1.83123, test err=0.357
# Trial 0, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=1.52391, test err=0.277
# Trial 1, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=2.33231, test err=0.898
# Trial 1, Epoch: 1000, V1 model, h=50, lr=0.00100, Loss=2.04281, test err=0.541
# Trial 1, Epoch: 2000, V1 model, h=50, lr=0.00100, Loss=1.73027, test err=0.334
# Trial 1, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=1.41195, test err=0.271
# Trial 2, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=2.29840, test err=0.836
# Trial 2, Epoch: 1000, V1 model, h=50, lr=0.00100, Loss=1.90151, test err=0.421
# Trial 2, Epoch: 2000, V1 model, h=50, lr=0.00100, Loss=1.55602, test err=0.304
# Trial 2, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=1.26250, test err=0.251
# Trial 3, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=2.32120, test err=0.909
# Trial 3, Epoch: 1000, V1 model, h=50, lr=0.00100, Loss=2.12328, test err=0.599
# Trial 3, Epoch: 2000, V1 model, h=50, lr=0.00100, Loss=1.87173, test err=0.363
# Trial 3, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=1.57006, test err=0.269
# Trial 4, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=2.38658, test err=0.927
# Trial 4, Epoch: 1000, V1 model, h=50, lr=0.00100, Loss=2.03837, test err=0.495
# Trial 4, Epoch: 2000, V1 model, h=50, lr=0.00100, Loss=1.70747, test err=0.400
# Trial 4, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=1.39456, test err=0.314
# Trial 5, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=2.29107, test err=0.852
# Trial 5, Epoch: 1000, V1 model, h=50, lr=0.00100, Loss=1.95480, test err=0.470
# Trial 5, Epoch: 2000, V1 model, h=50, lr=0.00100, Loss=1.61853, test err=0.345
# Trial 5, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=1.31647, test err=0.276
# Trial 6, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=2.35138, test err=0.927
# Trial 6, Epoch: 1000, V1 model, h=50, lr=0.00100, Loss=2.14055, test err=0.611
# Trial 6, Epoch: 2000, V1 model, h=50, lr=0.00100, Loss=1.89263, test err=0.429
# Trial 6, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=1.59604, test err=0.316
# Trial 7, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=2.32242, test err=0.955
# Trial 7, Epoch: 1000, V1 model, h=50, lr=0.00100, Loss=2.06391, test err=0.461
# Trial 7, Epoch: 2000, V1 model, h=50, lr=0.00100, Loss=1.74202, test err=0.267
# Trial 7, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=1.40381, test err=0.237
# Trial 8, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=2.33974, test err=0.919
# Trial 8, Epoch: 1000, V1 model, h=50, lr=0.00100, Loss=2.06837, test err=0.516
# Trial 8, Epoch: 2000, V1 model, h=50, lr=0.00100, Loss=1.76211, test err=0.332
# Trial 8, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=1.44060, test err=0.274
# Trial 9, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=2.29203, test err=0.896
# Trial 9, Epoch: 1000, V1 model, h=50, lr=0.00100, Loss=2.11231, test err=0.669
# Trial 9, Epoch: 2000, V1 model, h=50, lr=0.00100, Loss=1.86573, test err=0.403
# Trial 9, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=1.57292, test err=0.257
# Trial 0, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.33528, test err=0.881
# Trial 0, Epoch: 1000, He model, h=50, lr=0.00100, Loss=2.08498, test err=0.554
# Trial 0, Epoch: 2000, He model, h=50, lr=0.00100, Loss=1.80375, test err=0.376
# Trial 0, Epoch: 3000, He model, h=50, lr=0.00100, Loss=1.49231, test err=0.282
# Trial 1, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.32580, test err=0.945
# Trial 1, Epoch: 1000, He model, h=50, lr=0.00100, Loss=2.13964, test err=0.734
# Trial 1, Epoch: 2000, He model, h=50, lr=0.00100, Loss=1.89571, test err=0.460
# Trial 1, Epoch: 3000, He model, h=50, lr=0.00100, Loss=1.60241, test err=0.344
# Trial 2, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.29757, test err=0.891
# Trial 2, Epoch: 1000, He model, h=50, lr=0.00100, Loss=2.11125, test err=0.603
# Trial 2, Epoch: 2000, He model, h=50, lr=0.00100, Loss=1.85247, test err=0.420
# Trial 2, Epoch: 3000, He model, h=50, lr=0.00100, Loss=1.55131, test err=0.344
# Trial 3, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.32376, test err=0.923
# Trial 3, Epoch: 1000, He model, h=50, lr=0.00100, Loss=2.16085, test err=0.621
# Trial 3, Epoch: 2000, He model, h=50, lr=0.00100, Loss=1.93034, test err=0.450
# Trial 3, Epoch: 3000, He model, h=50, lr=0.00100, Loss=1.62531, test err=0.346
# Trial 4, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.32233, test err=0.898
# Trial 4, Epoch: 1000, He model, h=50, lr=0.00100, Loss=2.11104, test err=0.594
# Trial 4, Epoch: 2000, He model, h=50, lr=0.00100, Loss=1.85706, test err=0.409
# Trial 4, Epoch: 3000, He model, h=50, lr=0.00100, Loss=1.55241, test err=0.329
# Trial 5, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.33565, test err=0.881
# Trial 5, Epoch: 1000, He model, h=50, lr=0.00100, Loss=2.11325, test err=0.561
# Trial 5, Epoch: 2000, He model, h=50, lr=0.00100, Loss=1.82770, test err=0.365
# Trial 5, Epoch: 3000, He model, h=50, lr=0.00100, Loss=1.49503, test err=0.278
# Trial 6, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.30653, test err=0.898
# Trial 6, Epoch: 1000, He model, h=50, lr=0.00100, Loss=2.08186, test err=0.557
# Trial 6, Epoch: 2000, He model, h=50, lr=0.00100, Loss=1.80216, test err=0.363
# Trial 6, Epoch: 3000, He model, h=50, lr=0.00100, Loss=1.48748, test err=0.275
# Trial 7, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.28145, test err=0.877
# Trial 7, Epoch: 1000, He model, h=50, lr=0.00100, Loss=2.07631, test err=0.521
# Trial 7, Epoch: 2000, He model, h=50, lr=0.00100, Loss=1.79144, test err=0.323
# Trial 7, Epoch: 3000, He model, h=50, lr=0.00100, Loss=1.46232, test err=0.270
# Trial 8, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.30320, test err=0.879
# Trial 8, Epoch: 1000, He model, h=50, lr=0.00100, Loss=2.10003, test err=0.593
# Trial 8, Epoch: 2000, He model, h=50, lr=0.00100, Loss=1.81647, test err=0.392
# Trial 8, Epoch: 3000, He model, h=50, lr=0.00100, Loss=1.49212, test err=0.309
# Trial 9, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.29571, test err=0.833
# Trial 9, Epoch: 1000, He model, h=50, lr=0.00100, Loss=2.07224, test err=0.523
# Trial 9, Epoch: 2000, He model, h=50, lr=0.00100, Loss=1.78850, test err=0.357
# Trial 9, Epoch: 3000, He model, h=50, lr=0.00100, Loss=1.47995, test err=0.284
# Trial 0, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=2.30195, test err=0.906
# Trial 0, Epoch: 1000, V1 model, h=50, lr=0.01000, Loss=0.60395, test err=0.139
# Trial 0, Epoch: 2000, V1 model, h=50, lr=0.01000, Loss=0.42079, test err=0.106
# Trial 0, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.36472, test err=0.096
# Trial 1, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=2.32003, test err=0.908
# Trial 1, Epoch: 1000, V1 model, h=50, lr=0.01000, Loss=0.62767, test err=0.151
# Trial 1, Epoch: 2000, V1 model, h=50, lr=0.01000, Loss=0.43343, test err=0.111
# Trial 1, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.37326, test err=0.099
# Trial 2, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=2.32204, test err=0.908
# Trial 2, Epoch: 1000, V1 model, h=50, lr=0.01000, Loss=0.58554, test err=0.136
# Trial 2, Epoch: 2000, V1 model, h=50, lr=0.01000, Loss=0.41871, test err=0.107
# Trial 2, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.36652, test err=0.098
# Trial 3, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=2.33355, test err=0.892
# Trial 3, Epoch: 1000, V1 model, h=50, lr=0.01000, Loss=0.59775, test err=0.132
# Trial 3, Epoch: 2000, V1 model, h=50, lr=0.01000, Loss=0.41868, test err=0.105
# Trial 3, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.36419, test err=0.095
# Trial 4, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=2.34785, test err=0.862
# Trial 4, Epoch: 1000, V1 model, h=50, lr=0.01000, Loss=0.61223, test err=0.137
# Trial 4, Epoch: 2000, V1 model, h=50, lr=0.01000, Loss=0.42481, test err=0.106
# Trial 4, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.36774, test err=0.097
# Trial 5, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=2.28044, test err=0.898
# Trial 5, Epoch: 1000, V1 model, h=50, lr=0.01000, Loss=0.57943, test err=0.133
# Trial 5, Epoch: 2000, V1 model, h=50, lr=0.01000, Loss=0.41751, test err=0.106
# Trial 5, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.36423, test err=0.096
# Trial 6, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=2.31591, test err=0.919
# Trial 6, Epoch: 1000, V1 model, h=50, lr=0.01000, Loss=0.58499, test err=0.134
# Trial 6, Epoch: 2000, V1 model, h=50, lr=0.01000, Loss=0.41272, test err=0.104
# Trial 6, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.35973, test err=0.096
# Trial 7, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=2.30756, test err=0.910
# Trial 7, Epoch: 1000, V1 model, h=50, lr=0.01000, Loss=0.58794, test err=0.141
# Trial 7, Epoch: 2000, V1 model, h=50, lr=0.01000, Loss=0.41860, test err=0.109
# Trial 7, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.36306, test err=0.098
# Trial 8, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=2.32559, test err=0.952
# Trial 8, Epoch: 1000, V1 model, h=50, lr=0.01000, Loss=0.58021, test err=0.136
# Trial 8, Epoch: 2000, V1 model, h=50, lr=0.01000, Loss=0.42172, test err=0.110
# Trial 8, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.36981, test err=0.100
# Trial 9, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=2.34592, test err=0.865
# Trial 9, Epoch: 1000, V1 model, h=50, lr=0.01000, Loss=0.59546, test err=0.136
# Trial 9, Epoch: 2000, V1 model, h=50, lr=0.01000, Loss=0.41897, test err=0.106
# Trial 9, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.36500, test err=0.095
# Trial 0, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.35029, test err=0.892
# Trial 0, Epoch: 1000, He model, h=50, lr=0.01000, Loss=0.59303, test err=0.139
# Trial 0, Epoch: 2000, He model, h=50, lr=0.01000, Loss=0.42299, test err=0.109
# Trial 0, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.36858, test err=0.098
# Trial 1, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.32137, test err=0.897
# Trial 1, Epoch: 1000, He model, h=50, lr=0.01000, Loss=0.61369, test err=0.141
# Trial 1, Epoch: 2000, He model, h=50, lr=0.01000, Loss=0.42528, test err=0.108
# Trial 1, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.36865, test err=0.099
# Trial 2, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.32344, test err=0.900
# Trial 2, Epoch: 1000, He model, h=50, lr=0.01000, Loss=0.61275, test err=0.144
# Trial 2, Epoch: 2000, He model, h=50, lr=0.01000, Loss=0.42432, test err=0.108
# Trial 2, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.36488, test err=0.096
# Trial 3, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.31872, test err=0.852
# Trial 3, Epoch: 1000, He model, h=50, lr=0.01000, Loss=0.60214, test err=0.139
# Trial 3, Epoch: 2000, He model, h=50, lr=0.01000, Loss=0.42279, test err=0.107
# Trial 3, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.36466, test err=0.095
# Trial 4, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.32749, test err=0.910
# Trial 4, Epoch: 1000, He model, h=50, lr=0.01000, Loss=0.60909, test err=0.141
# Trial 4, Epoch: 2000, He model, h=50, lr=0.01000, Loss=0.42298, test err=0.109
# Trial 4, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.36548, test err=0.097
# Trial 5, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.35848, test err=0.931
# Trial 5, Epoch: 1000, He model, h=50, lr=0.01000, Loss=0.61759, test err=0.143
# Trial 5, Epoch: 2000, He model, h=50, lr=0.01000, Loss=0.42550, test err=0.107
# Trial 5, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.36836, test err=0.097
# Trial 6, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.32956, test err=0.928
# Trial 6, Epoch: 1000, He model, h=50, lr=0.01000, Loss=0.61364, test err=0.144
# Trial 6, Epoch: 2000, He model, h=50, lr=0.01000, Loss=0.42418, test err=0.109
# Trial 6, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.36402, test err=0.097
# Trial 7, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.31771, test err=0.924
# Trial 7, Epoch: 1000, He model, h=50, lr=0.01000, Loss=0.58762, test err=0.134
# Trial 7, Epoch: 2000, He model, h=50, lr=0.01000, Loss=0.42115, test err=0.108
# Trial 7, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.36718, test err=0.097
# Trial 8, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.34218, test err=0.904
# Trial 8, Epoch: 1000, He model, h=50, lr=0.01000, Loss=0.60874, test err=0.137
# Trial 8, Epoch: 2000, He model, h=50, lr=0.01000, Loss=0.42320, test err=0.109
# Trial 8, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.36737, test err=0.097
# Trial 9, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.33492, test err=0.884
# Trial 9, Epoch: 1000, He model, h=50, lr=0.01000, Loss=0.59611, test err=0.136
# Trial 9, Epoch: 2000, He model, h=50, lr=0.01000, Loss=0.42042, test err=0.108
# Trial 9, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.36621, test err=0.097
# Trial 0, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=2.34807, test err=0.874
# Trial 0, Epoch: 1000, V1 model, h=50, lr=0.10000, Loss=0.25147, test err=0.070
# Trial 0, Epoch: 2000, V1 model, h=50, lr=0.10000, Loss=0.18705, test err=0.056
# Trial 0, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.14874, test err=0.046
# Trial 1, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=2.30617, test err=0.895
# Trial 1, Epoch: 1000, V1 model, h=50, lr=0.10000, Loss=0.27099, test err=0.074
# Trial 1, Epoch: 2000, V1 model, h=50, lr=0.10000, Loss=0.20897, test err=0.061
# Trial 1, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.16476, test err=0.050
# Trial 2, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=2.28342, test err=0.864
# Trial 2, Epoch: 1000, V1 model, h=50, lr=0.10000, Loss=0.25398, test err=0.068
# Trial 2, Epoch: 2000, V1 model, h=50, lr=0.10000, Loss=0.19095, test err=0.054
# Trial 2, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.15451, test err=0.047
# Trial 3, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=2.29757, test err=0.846
# Trial 3, Epoch: 1000, V1 model, h=50, lr=0.10000, Loss=0.25520, test err=0.069
# Trial 3, Epoch: 2000, V1 model, h=50, lr=0.10000, Loss=0.19067, test err=0.055
# Trial 3, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.15299, test err=0.047
# Trial 4, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=2.30216, test err=0.855
# Trial 4, Epoch: 1000, V1 model, h=50, lr=0.10000, Loss=0.25824, test err=0.070
# Trial 4, Epoch: 2000, V1 model, h=50, lr=0.10000, Loss=0.19086, test err=0.054
# Trial 4, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.15347, test err=0.046
# Trial 5, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=2.27777, test err=0.826
# Trial 5, Epoch: 1000, V1 model, h=50, lr=0.10000, Loss=0.25407, test err=0.071
# Trial 5, Epoch: 2000, V1 model, h=50, lr=0.10000, Loss=0.19038, test err=0.056
# Trial 5, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.15289, test err=0.045
# Trial 6, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=2.30019, test err=0.875
# Trial 6, Epoch: 1000, V1 model, h=50, lr=0.10000, Loss=0.26818, test err=0.074
# Trial 6, Epoch: 2000, V1 model, h=50, lr=0.10000, Loss=0.20583, test err=0.061
# Trial 6, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.16442, test err=0.049
# Trial 7, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=2.33323, test err=0.910
# Trial 7, Epoch: 1000, V1 model, h=50, lr=0.10000, Loss=0.25620, test err=0.071
# Trial 7, Epoch: 2000, V1 model, h=50, lr=0.10000, Loss=0.19231, test err=0.056
# Trial 7, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.15199, test err=0.046
# Trial 8, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=2.29724, test err=0.851
# Trial 8, Epoch: 1000, V1 model, h=50, lr=0.10000, Loss=0.26582, test err=0.074
# Trial 8, Epoch: 2000, V1 model, h=50, lr=0.10000, Loss=0.20422, test err=0.061
# Trial 8, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.16500, test err=0.051
# Trial 9, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=2.31165, test err=0.864
# Trial 9, Epoch: 1000, V1 model, h=50, lr=0.10000, Loss=0.25193, test err=0.069
# Trial 9, Epoch: 2000, V1 model, h=50, lr=0.10000, Loss=0.18439, test err=0.053
# Trial 9, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.14573, test err=0.045
# Trial 0, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.32700, test err=0.896
# Trial 0, Epoch: 1000, He model, h=50, lr=0.10000, Loss=0.25150, test err=0.070
# Trial 0, Epoch: 2000, He model, h=50, lr=0.10000, Loss=0.18765, test err=0.055
# Trial 0, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.15169, test err=0.045
# Trial 1, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.29535, test err=0.880
# Trial 1, Epoch: 1000, He model, h=50, lr=0.10000, Loss=0.26400, test err=0.073
# Trial 1, Epoch: 2000, He model, h=50, lr=0.10000, Loss=0.19783, test err=0.057
# Trial 1, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.15674, test err=0.048
# Trial 2, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.30558, test err=0.859
# Trial 2, Epoch: 1000, He model, h=50, lr=0.10000, Loss=0.25514, test err=0.070
# Trial 2, Epoch: 2000, He model, h=50, lr=0.10000, Loss=0.19274, test err=0.056
# Trial 2, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.15410, test err=0.047
# Trial 3, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.30304, test err=0.907
# Trial 3, Epoch: 1000, He model, h=50, lr=0.10000, Loss=0.25574, test err=0.071
# Trial 3, Epoch: 2000, He model, h=50, lr=0.10000, Loss=0.18912, test err=0.055
# Trial 3, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.14995, test err=0.047
# Trial 4, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.33279, test err=0.887
# Trial 4, Epoch: 1000, He model, h=50, lr=0.10000, Loss=0.25340, test err=0.072
# Trial 4, Epoch: 2000, He model, h=50, lr=0.10000, Loss=0.18928, test err=0.057
# Trial 4, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.15159, test err=0.047
# Trial 5, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.34172, test err=0.892
# Trial 5, Epoch: 1000, He model, h=50, lr=0.10000, Loss=0.24845, test err=0.067
# Trial 5, Epoch: 2000, He model, h=50, lr=0.10000, Loss=0.18355, test err=0.053
# Trial 5, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.14801, test err=0.044
# Trial 6, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.32254, test err=0.887
# Trial 6, Epoch: 1000, He model, h=50, lr=0.10000, Loss=0.26145, test err=0.072
# Trial 6, Epoch: 2000, He model, h=50, lr=0.10000, Loss=0.19555, test err=0.056
# Trial 6, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.15716, test err=0.048
# Trial 7, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.37199, test err=0.942
# Trial 7, Epoch: 1000, He model, h=50, lr=0.10000, Loss=0.25691, test err=0.071
# Trial 7, Epoch: 2000, He model, h=50, lr=0.10000, Loss=0.18914, test err=0.056
# Trial 7, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.15279, test err=0.047
# Trial 8, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.32346, test err=0.885
# Trial 8, Epoch: 1000, He model, h=50, lr=0.10000, Loss=0.26595, test err=0.074
# Trial 8, Epoch: 2000, He model, h=50, lr=0.10000, Loss=0.19720, test err=0.056
# Trial 8, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.15728, test err=0.046
# Trial 9, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.32859, test err=0.876
# Trial 9, Epoch: 1000, He model, h=50, lr=0.10000, Loss=0.26011, test err=0.070
# Trial 9, Epoch: 2000, He model, h=50, lr=0.10000, Loss=0.19640, test err=0.057
# Trial 9, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.15780, test err=0.048
# Trial 0, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=2.32456, test err=0.710
# Trial 0, Epoch: 1000, V1 model, h=50, lr=1.00000, Loss=0.23156, test err=0.070
# Trial 0, Epoch: 2000, V1 model, h=50, lr=1.00000, Loss=0.21437, test err=0.065
# Trial 0, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=0.12958, test err=0.043
# Trial 1, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=2.30872, test err=0.692
# Trial 1, Epoch: 1000, V1 model, h=50, lr=1.00000, Loss=0.08099, test err=0.034
# Trial 1, Epoch: 2000, V1 model, h=50, lr=1.00000, Loss=0.04627, test err=0.031
# Trial 1, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=0.03010, test err=0.031
# Trial 2, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=2.34872, test err=0.760
# Trial 2, Epoch: 1000, V1 model, h=50, lr=1.00000, Loss=0.08199, test err=0.033
# Trial 2, Epoch: 2000, V1 model, h=50, lr=1.00000, Loss=0.05086, test err=0.027
# Trial 2, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=0.03493, test err=0.028
# Trial 3, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=2.34441, test err=0.633
# Trial 3, Epoch: 1000, V1 model, h=50, lr=1.00000, Loss=0.08264, test err=0.032
# Trial 3, Epoch: 2000, V1 model, h=50, lr=1.00000, Loss=0.10215, test err=0.042
# Trial 3, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=0.10945, test err=0.044
# Trial 4, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=2.37416, test err=0.802
# Trial 4, Epoch: 1000, V1 model, h=50, lr=1.00000, Loss=0.07728, test err=0.032
# Trial 4, Epoch: 2000, V1 model, h=50, lr=1.00000, Loss=0.04474, test err=0.030
# Trial 4, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=0.31486, test err=0.093
# Trial 5, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=2.30216, test err=0.650
# Trial 5, Epoch: 1000, V1 model, h=50, lr=1.00000, Loss=0.08347, test err=0.034
# Trial 5, Epoch: 2000, V1 model, h=50, lr=1.00000, Loss=0.27442, test err=0.078
# Trial 5, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=1.31106, test err=0.484
# Trial 6, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=2.31963, test err=0.657
# Trial 6, Epoch: 1000, V1 model, h=50, lr=1.00000, Loss=0.08520, test err=0.034
# Trial 6, Epoch: 2000, V1 model, h=50, lr=1.00000, Loss=0.11175, test err=0.043
# Trial 6, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=0.23630, test err=0.072
# Trial 7, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=2.28964, test err=0.607
# Trial 7, Epoch: 1000, V1 model, h=50, lr=1.00000, Loss=0.16941, test err=0.057
# Trial 7, Epoch: 2000, V1 model, h=50, lr=1.00000, Loss=0.23305, test err=0.073
# Trial 7, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=0.13668, test err=0.052
# Trial 8, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=2.35003, test err=0.722
# Trial 8, Epoch: 1000, V1 model, h=50, lr=1.00000, Loss=0.07940, test err=0.031
# Trial 8, Epoch: 2000, V1 model, h=50, lr=1.00000, Loss=0.04946, test err=0.029
# Trial 8, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=0.24228, test err=0.075
# Trial 9, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=2.32573, test err=0.673
# Trial 9, Epoch: 1000, V1 model, h=50, lr=1.00000, Loss=0.06870, test err=0.031
# Trial 9, Epoch: 2000, V1 model, h=50, lr=1.00000, Loss=0.03993, test err=0.030
# Trial 9, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=0.02485, test err=0.030
# Trial 0, Epoch: 0, He model, h=50, lr=1.00000, Loss=2.31441, test err=0.673
# Trial 0, Epoch: 1000, He model, h=50, lr=1.00000, Loss=0.07304, test err=0.030
# Trial 0, Epoch: 2000, He model, h=50, lr=1.00000, Loss=0.04207, test err=0.027
# Trial 0, Epoch: 3000, He model, h=50, lr=1.00000, Loss=0.02733, test err=0.028
# Trial 1, Epoch: 0, He model, h=50, lr=1.00000, Loss=2.31334, test err=0.625
# Trial 1, Epoch: 1000, He model, h=50, lr=1.00000, Loss=0.11111, test err=0.039
# Trial 1, Epoch: 2000, He model, h=50, lr=1.00000, Loss=0.08245, test err=0.033
# Trial 1, Epoch: 3000, He model, h=50, lr=1.00000, Loss=0.05682, test err=0.032
# Trial 2, Epoch: 0, He model, h=50, lr=1.00000, Loss=2.31554, test err=0.617
# Trial 2, Epoch: 1000, He model, h=50, lr=1.00000, Loss=0.09647, test err=0.037
# Trial 2, Epoch: 2000, He model, h=50, lr=1.00000, Loss=0.15481, test err=0.053
# Trial 2, Epoch: 3000, He model, h=50, lr=1.00000, Loss=0.25154, test err=0.078
# Trial 3, Epoch: 0, He model, h=50, lr=1.00000, Loss=2.33293, test err=0.660
# Trial 3, Epoch: 1000, He model, h=50, lr=1.00000, Loss=0.07446, test err=0.030
# Trial 3, Epoch: 2000, He model, h=50, lr=1.00000, Loss=0.04236, test err=0.027
# Trial 3, Epoch: 3000, He model, h=50, lr=1.00000, Loss=0.02775, test err=0.028
# Trial 4, Epoch: 0, He model, h=50, lr=1.00000, Loss=2.34236, test err=0.623
# Trial 4, Epoch: 1000, He model, h=50, lr=1.00000, Loss=0.06983, test err=0.027
# Trial 4, Epoch: 2000, He model, h=50, lr=1.00000, Loss=0.04001, test err=0.025
# Trial 4, Epoch: 3000, He model, h=50, lr=1.00000, Loss=0.02587, test err=0.024
# Trial 5, Epoch: 0, He model, h=50, lr=1.00000, Loss=2.32975, test err=0.593
# Trial 5, Epoch: 1000, He model, h=50, lr=1.00000, Loss=0.12261, test err=0.045
# Trial 5, Epoch: 2000, He model, h=50, lr=1.00000, Loss=0.26740, test err=0.081
# Trial 5, Epoch: 3000, He model, h=50, lr=1.00000, Loss=0.16856, test err=0.059
# Trial 6, Epoch: 0, He model, h=50, lr=1.00000, Loss=2.33598, test err=0.551
# Trial 6, Epoch: 1000, He model, h=50, lr=1.00000, Loss=0.07828, test err=0.032
# Trial 6, Epoch: 2000, He model, h=50, lr=1.00000, Loss=0.04648, test err=0.029
# Trial 6, Epoch: 3000, He model, h=50, lr=1.00000, Loss=0.03005, test err=0.028
# Trial 7, Epoch: 0, He model, h=50, lr=1.00000, Loss=2.31917, test err=0.591
# Trial 7, Epoch: 1000, He model, h=50, lr=1.00000, Loss=0.09087, test err=0.035
# Trial 7, Epoch: 2000, He model, h=50, lr=1.00000, Loss=0.24072, test err=0.069
# Trial 7, Epoch: 3000, He model, h=50, lr=1.00000, Loss=0.25082, test err=0.071
# Trial 8, Epoch: 0, He model, h=50, lr=1.00000, Loss=2.29160, test err=0.568
# Trial 8, Epoch: 1000, He model, h=50, lr=1.00000, Loss=0.06696, test err=0.029
# Trial 8, Epoch: 2000, He model, h=50, lr=1.00000, Loss=0.03669, test err=0.028
# Trial 8, Epoch: 3000, He model, h=50, lr=1.00000, Loss=0.02309, test err=0.027
# Trial 9, Epoch: 0, He model, h=50, lr=1.00000, Loss=2.35702, test err=0.618
# Trial 9, Epoch: 1000, He model, h=50, lr=1.00000, Loss=0.06824, test err=0.030
# Trial 9, Epoch: 2000, He model, h=50, lr=1.00000, Loss=0.03954, test err=0.026
# Trial 9, Epoch: 3000, He model, h=50, lr=1.00000, Loss=0.02535, test err=0.025
# Trial 0, Epoch: 0, V1 model, h=100, lr=0.00100, Loss=2.34453, test err=0.893
# Trial 0, Epoch: 1000, V1 model, h=100, lr=0.00100, Loss=1.88264, test err=0.462
# Trial 0, Epoch: 2000, V1 model, h=100, lr=0.00100, Loss=1.53012, test err=0.319
# Trial 0, Epoch: 3000, V1 model, h=100, lr=0.00100, Loss=1.23318, test err=0.245
# Trial 1, Epoch: 0, V1 model, h=100, lr=0.00100, Loss=2.33154, test err=0.934
# Trial 1, Epoch: 1000, V1 model, h=100, lr=0.00100, Loss=1.98670, test err=0.483
# Trial 1, Epoch: 2000, V1 model, h=100, lr=0.00100, Loss=1.65907, test err=0.328
# Trial 1, Epoch: 3000, V1 model, h=100, lr=0.00100, Loss=1.35698, test err=0.268
# Trial 2, Epoch: 0, V1 model, h=100, lr=0.00100, Loss=2.30328, test err=0.900
# Trial 2, Epoch: 1000, V1 model, h=100, lr=0.00100, Loss=1.95790, test err=0.418
# Trial 2, Epoch: 2000, V1 model, h=100, lr=0.00100, Loss=1.62393, test err=0.290
# Trial 2, Epoch: 3000, V1 model, h=100, lr=0.00100, Loss=1.31437, test err=0.234
# Trial 3, Epoch: 0, V1 model, h=100, lr=0.00100, Loss=2.35052, test err=0.935
# Trial 3, Epoch: 1000, V1 model, h=100, lr=0.00100, Loss=2.01315, test err=0.462
# Trial 3, Epoch: 2000, V1 model, h=100, lr=0.00100, Loss=1.67820, test err=0.313
# Trial 3, Epoch: 3000, V1 model, h=100, lr=0.00100, Loss=1.36387, test err=0.254
# Trial 4, Epoch: 0, V1 model, h=100, lr=0.00100, Loss=2.33104, test err=0.899
# Trial 4, Epoch: 1000, V1 model, h=100, lr=0.00100, Loss=2.05470, test err=0.440
# Trial 4, Epoch: 2000, V1 model, h=100, lr=0.00100, Loss=1.72957, test err=0.294
# Trial 4, Epoch: 3000, V1 model, h=100, lr=0.00100, Loss=1.39941, test err=0.244
# Trial 5, Epoch: 0, V1 model, h=100, lr=0.00100, Loss=2.34616, test err=0.954
# Trial 5, Epoch: 1000, V1 model, h=100, lr=0.00100, Loss=2.04125, test err=0.417
# Trial 5, Epoch: 2000, V1 model, h=100, lr=0.00100, Loss=1.72345, test err=0.278
# Trial 5, Epoch: 3000, V1 model, h=100, lr=0.00100, Loss=1.39628, test err=0.242
# Trial 6, Epoch: 0, V1 model, h=100, lr=0.00100, Loss=2.32964, test err=0.899
# Trial 6, Epoch: 1000, V1 model, h=100, lr=0.00100, Loss=2.03449, test err=0.499
# Trial 6, Epoch: 2000, V1 model, h=100, lr=0.00100, Loss=1.72251, test err=0.368
# Trial 6, Epoch: 3000, V1 model, h=100, lr=0.00100, Loss=1.41308, test err=0.294
# Trial 7, Epoch: 0, V1 model, h=100, lr=0.00100, Loss=2.32203, test err=0.897
# Trial 7, Epoch: 1000, V1 model, h=100, lr=0.00100, Loss=1.89227, test err=0.439
# Trial 7, Epoch: 2000, V1 model, h=100, lr=0.00100, Loss=1.52169, test err=0.305
# Trial 7, Epoch: 3000, V1 model, h=100, lr=0.00100, Loss=1.22355, test err=0.242
# Trial 8, Epoch: 0, V1 model, h=100, lr=0.00100, Loss=2.34809, test err=0.941
# Trial 8, Epoch: 1000, V1 model, h=100, lr=0.00100, Loss=2.05795, test err=0.460
# Trial 8, Epoch: 2000, V1 model, h=100, lr=0.00100, Loss=1.73706, test err=0.317
# Trial 8, Epoch: 3000, V1 model, h=100, lr=0.00100, Loss=1.40859, test err=0.238
# Trial 9, Epoch: 0, V1 model, h=100, lr=0.00100, Loss=2.31410, test err=0.881
# Trial 9, Epoch: 1000, V1 model, h=100, lr=0.00100, Loss=2.04211, test err=0.494
# Trial 9, Epoch: 2000, V1 model, h=100, lr=0.00100, Loss=1.72480, test err=0.326
# Trial 9, Epoch: 3000, V1 model, h=100, lr=0.00100, Loss=1.40726, test err=0.273
# Trial 0, Epoch: 0, He model, h=100, lr=0.00100, Loss=2.33148, test err=0.901
# Trial 0, Epoch: 1000, He model, h=100, lr=0.00100, Loss=2.07677, test err=0.520
# Trial 0, Epoch: 2000, He model, h=100, lr=0.00100, Loss=1.77117, test err=0.352
# Trial 0, Epoch: 3000, He model, h=100, lr=0.00100, Loss=1.43974, test err=0.272
# Trial 1, Epoch: 0, He model, h=100, lr=0.00100, Loss=2.28146, test err=0.884
# Trial 1, Epoch: 1000, He model, h=100, lr=0.00100, Loss=2.04872, test err=0.451
# Trial 1, Epoch: 2000, He model, h=100, lr=0.00100, Loss=1.75715, test err=0.324
# Trial 1, Epoch: 3000, He model, h=100, lr=0.00100, Loss=1.43344, test err=0.270
# Trial 2, Epoch: 0, He model, h=100, lr=0.00100, Loss=2.30563, test err=0.864
# Trial 2, Epoch: 1000, He model, h=100, lr=0.00100, Loss=2.06998, test err=0.473
# Trial 2, Epoch: 2000, He model, h=100, lr=0.00100, Loss=1.77034, test err=0.325
# Trial 2, Epoch: 3000, He model, h=100, lr=0.00100, Loss=1.43017, test err=0.256
# Trial 3, Epoch: 0, He model, h=100, lr=0.00100, Loss=2.33727, test err=0.922
# Trial 3, Epoch: 1000, He model, h=100, lr=0.00100, Loss=2.09052, test err=0.564
# Trial 3, Epoch: 2000, He model, h=100, lr=0.00100, Loss=1.78575, test err=0.375
# Trial 3, Epoch: 3000, He model, h=100, lr=0.00100, Loss=1.45075, test err=0.270
# Trial 4, Epoch: 0, He model, h=100, lr=0.00100, Loss=2.31488, test err=0.930
# Trial 4, Epoch: 1000, He model, h=100, lr=0.00100, Loss=2.08281, test err=0.477
# Trial 4, Epoch: 2000, He model, h=100, lr=0.00100, Loss=1.79155, test err=0.320
# Trial 4, Epoch: 3000, He model, h=100, lr=0.00100, Loss=1.45749, test err=0.260
# Trial 5, Epoch: 0, He model, h=100, lr=0.00100, Loss=2.31298, test err=0.929
# Trial 5, Epoch: 1000, He model, h=100, lr=0.00100, Loss=2.05458, test err=0.471
# Trial 5, Epoch: 2000, He model, h=100, lr=0.00100, Loss=1.74312, test err=0.307
# Trial 5, Epoch: 3000, He model, h=100, lr=0.00100, Loss=1.39839, test err=0.243
# Trial 6, Epoch: 0, He model, h=100, lr=0.00100, Loss=2.27642, test err=0.825
# Trial 6, Epoch: 1000, He model, h=100, lr=0.00100, Loss=1.98700, test err=0.442
# Trial 6, Epoch: 2000, He model, h=100, lr=0.00100, Loss=1.65151, test err=0.308
# Trial 6, Epoch: 3000, He model, h=100, lr=0.00100, Loss=1.32331, test err=0.243
# Trial 7, Epoch: 0, He model, h=100, lr=0.00100, Loss=2.32759, test err=0.913
# Trial 7, Epoch: 1000, He model, h=100, lr=0.00100, Loss=2.08476, test err=0.543
# Trial 7, Epoch: 2000, He model, h=100, lr=0.00100, Loss=1.78562, test err=0.324
# Trial 7, Epoch: 3000, He model, h=100, lr=0.00100, Loss=1.45695, test err=0.261
# Trial 8, Epoch: 0, He model, h=100, lr=0.00100, Loss=2.31629, test err=0.930
# Trial 8, Epoch: 1000, He model, h=100, lr=0.00100, Loss=2.05400, test err=0.449
# Trial 8, Epoch: 2000, He model, h=100, lr=0.00100, Loss=1.73648, test err=0.329
# Trial 8, Epoch: 3000, He model, h=100, lr=0.00100, Loss=1.39988, test err=0.260
# Trial 9, Epoch: 0, He model, h=100, lr=0.00100, Loss=2.29393, test err=0.877
# Trial 9, Epoch: 1000, He model, h=100, lr=0.00100, Loss=2.03650, test err=0.448
# Trial 9, Epoch: 2000, He model, h=100, lr=0.00100, Loss=1.71076, test err=0.281
# Trial 9, Epoch: 3000, He model, h=100, lr=0.00100, Loss=1.36520, test err=0.231
# Trial 0, Epoch: 0, V1 model, h=100, lr=0.01000, Loss=2.29037, test err=0.869
# Trial 0, Epoch: 1000, V1 model, h=100, lr=0.01000, Loss=0.59025, test err=0.135
# Trial 0, Epoch: 2000, V1 model, h=100, lr=0.01000, Loss=0.41865, test err=0.107
# Trial 0, Epoch: 3000, V1 model, h=100, lr=0.01000, Loss=0.36541, test err=0.098
# Trial 1, Epoch: 0, V1 model, h=100, lr=0.01000, Loss=2.30639, test err=0.887
# Trial 1, Epoch: 1000, V1 model, h=100, lr=0.01000, Loss=0.58003, test err=0.138
# Trial 1, Epoch: 2000, V1 model, h=100, lr=0.01000, Loss=0.41731, test err=0.109
# Trial 1, Epoch: 3000, V1 model, h=100, lr=0.01000, Loss=0.36374, test err=0.098
# Trial 2, Epoch: 0, V1 model, h=100, lr=0.01000, Loss=2.33491, test err=0.912
# Trial 2, Epoch: 1000, V1 model, h=100, lr=0.01000, Loss=0.56883, test err=0.141
# Trial 2, Epoch: 2000, V1 model, h=100, lr=0.01000, Loss=0.41600, test err=0.112
# Trial 2, Epoch: 3000, V1 model, h=100, lr=0.01000, Loss=0.36485, test err=0.100
# Trial 3, Epoch: 0, V1 model, h=100, lr=0.01000, Loss=2.40886, test err=0.950
# Trial 3, Epoch: 1000, V1 model, h=100, lr=0.01000, Loss=0.57689, test err=0.135
# Trial 3, Epoch: 2000, V1 model, h=100, lr=0.01000, Loss=0.41617, test err=0.108
# Trial 3, Epoch: 3000, V1 model, h=100, lr=0.01000, Loss=0.36423, test err=0.098
# Trial 4, Epoch: 0, V1 model, h=100, lr=0.01000, Loss=2.33927, test err=0.903
# Trial 4, Epoch: 1000, V1 model, h=100, lr=0.01000, Loss=0.56416, test err=0.133
# Trial 4, Epoch: 2000, V1 model, h=100, lr=0.01000, Loss=0.41004, test err=0.107
# Trial 4, Epoch: 3000, V1 model, h=100, lr=0.01000, Loss=0.35896, test err=0.096
# Trial 5, Epoch: 0, V1 model, h=100, lr=0.01000, Loss=2.29009, test err=0.888
# Trial 5, Epoch: 1000, V1 model, h=100, lr=0.01000, Loss=0.57109, test err=0.129
# Trial 5, Epoch: 2000, V1 model, h=100, lr=0.01000, Loss=0.40967, test err=0.104
# Trial 5, Epoch: 3000, V1 model, h=100, lr=0.01000, Loss=0.35920, test err=0.095
# Trial 6, Epoch: 0, V1 model, h=100, lr=0.01000, Loss=2.31430, test err=0.909
# Trial 6, Epoch: 1000, V1 model, h=100, lr=0.01000, Loss=0.57693, test err=0.136
# Trial 6, Epoch: 2000, V1 model, h=100, lr=0.01000, Loss=0.41877, test err=0.108
# Trial 6, Epoch: 3000, V1 model, h=100, lr=0.01000, Loss=0.36605, test err=0.097
# Trial 7, Epoch: 0, V1 model, h=100, lr=0.01000, Loss=2.31796, test err=0.904
# Trial 7, Epoch: 1000, V1 model, h=100, lr=0.01000, Loss=0.58429, test err=0.139
# Trial 7, Epoch: 2000, V1 model, h=100, lr=0.01000, Loss=0.41793, test err=0.108
# Trial 7, Epoch: 3000, V1 model, h=100, lr=0.01000, Loss=0.36487, test err=0.097
# Trial 8, Epoch: 0, V1 model, h=100, lr=0.01000, Loss=2.33707, test err=0.891
# Trial 8, Epoch: 1000, V1 model, h=100, lr=0.01000, Loss=0.57518, test err=0.141
# Trial 8, Epoch: 2000, V1 model, h=100, lr=0.01000, Loss=0.42265, test err=0.108
# Trial 8, Epoch: 3000, V1 model, h=100, lr=0.01000, Loss=0.37052, test err=0.099
# Trial 9, Epoch: 0, V1 model, h=100, lr=0.01000, Loss=2.36802, test err=0.938
# Trial 9, Epoch: 1000, V1 model, h=100, lr=0.01000, Loss=0.58847, test err=0.140
# Trial 9, Epoch: 2000, V1 model, h=100, lr=0.01000, Loss=0.41735, test err=0.104
# Trial 9, Epoch: 3000, V1 model, h=100, lr=0.01000, Loss=0.36187, test err=0.095
# Trial 0, Epoch: 0, He model, h=100, lr=0.01000, Loss=2.30891, test err=0.894
# Trial 0, Epoch: 1000, He model, h=100, lr=0.01000, Loss=0.57600, test err=0.131
# Trial 0, Epoch: 2000, He model, h=100, lr=0.01000, Loss=0.41420, test err=0.105
# Trial 0, Epoch: 3000, He model, h=100, lr=0.01000, Loss=0.36212, test err=0.098
# Trial 1, Epoch: 0, He model, h=100, lr=0.01000, Loss=2.33656, test err=0.922
# Trial 1, Epoch: 1000, He model, h=100, lr=0.01000, Loss=0.56916, test err=0.132
# Trial 1, Epoch: 2000, He model, h=100, lr=0.01000, Loss=0.41143, test err=0.108
# Trial 1, Epoch: 3000, He model, h=100, lr=0.01000, Loss=0.35974, test err=0.098
# Trial 2, Epoch: 0, He model, h=100, lr=0.01000, Loss=2.32098, test err=0.927
# Trial 2, Epoch: 1000, He model, h=100, lr=0.01000, Loss=0.57224, test err=0.133
# Trial 2, Epoch: 2000, He model, h=100, lr=0.01000, Loss=0.40813, test err=0.107
# Trial 2, Epoch: 3000, He model, h=100, lr=0.01000, Loss=0.35496, test err=0.095
# Trial 3, Epoch: 0, He model, h=100, lr=0.01000, Loss=2.33473, test err=0.911
# Trial 3, Epoch: 1000, He model, h=100, lr=0.01000, Loss=0.57259, test err=0.134
# Trial 3, Epoch: 2000, He model, h=100, lr=0.01000, Loss=0.41223, test err=0.107
# Trial 3, Epoch: 3000, He model, h=100, lr=0.01000, Loss=0.36066, test err=0.097
# Trial 4, Epoch: 0, He model, h=100, lr=0.01000, Loss=2.34625, test err=0.950
# Trial 4, Epoch: 1000, He model, h=100, lr=0.01000, Loss=0.58693, test err=0.140
# Trial 4, Epoch: 2000, He model, h=100, lr=0.01000, Loss=0.41476, test err=0.109
# Trial 4, Epoch: 3000, He model, h=100, lr=0.01000, Loss=0.36083, test err=0.097
# Trial 5, Epoch: 0, He model, h=100, lr=0.01000, Loss=2.31724, test err=0.901
# Trial 5, Epoch: 1000, He model, h=100, lr=0.01000, Loss=0.57377, test err=0.134
# Trial 5, Epoch: 2000, He model, h=100, lr=0.01000, Loss=0.41085, test err=0.107
# Trial 5, Epoch: 3000, He model, h=100, lr=0.01000, Loss=0.35633, test err=0.096
# Trial 6, Epoch: 0, He model, h=100, lr=0.01000, Loss=2.31537, test err=0.875
# Trial 6, Epoch: 1000, He model, h=100, lr=0.01000, Loss=0.58987, test err=0.138
# Trial 6, Epoch: 2000, He model, h=100, lr=0.01000, Loss=0.41714, test err=0.107
# Trial 6, Epoch: 3000, He model, h=100, lr=0.01000, Loss=0.36314, test err=0.098
# Trial 7, Epoch: 0, He model, h=100, lr=0.01000, Loss=2.31490, test err=0.880
# Trial 7, Epoch: 1000, He model, h=100, lr=0.01000, Loss=0.58039, test err=0.133
# Trial 7, Epoch: 2000, He model, h=100, lr=0.01000, Loss=0.41282, test err=0.105
# Trial 7, Epoch: 3000, He model, h=100, lr=0.01000, Loss=0.35869, test err=0.094
# Trial 8, Epoch: 0, He model, h=100, lr=0.01000, Loss=2.35348, test err=0.905
# Trial 8, Epoch: 1000, He model, h=100, lr=0.01000, Loss=0.57228, test err=0.133
# Trial 8, Epoch: 2000, He model, h=100, lr=0.01000, Loss=0.41147, test err=0.106
# Trial 8, Epoch: 3000, He model, h=100, lr=0.01000, Loss=0.35990, test err=0.096
# Trial 9, Epoch: 0, He model, h=100, lr=0.01000, Loss=2.32888, test err=0.914
# Trial 9, Epoch: 1000, He model, h=100, lr=0.01000, Loss=0.57312, test err=0.134
# Trial 9, Epoch: 2000, He model, h=100, lr=0.01000, Loss=0.41294, test err=0.108
# Trial 9, Epoch: 3000, He model, h=100, lr=0.01000, Loss=0.36034, test err=0.096
# Trial 0, Epoch: 0, V1 model, h=100, lr=0.10000, Loss=2.34786, test err=0.868
# Trial 0, Epoch: 1000, V1 model, h=100, lr=0.10000, Loss=0.25163, test err=0.070
# Trial 0, Epoch: 2000, V1 model, h=100, lr=0.10000, Loss=0.17873, test err=0.053
# Trial 0, Epoch: 3000, V1 model, h=100, lr=0.10000, Loss=0.13846, test err=0.042
# Trial 1, Epoch: 0, V1 model, h=100, lr=0.10000, Loss=2.35090, test err=0.890
# Trial 1, Epoch: 1000, V1 model, h=100, lr=0.10000, Loss=0.25033, test err=0.067
# Trial 1, Epoch: 2000, V1 model, h=100, lr=0.10000, Loss=0.17922, test err=0.051
# Trial 1, Epoch: 3000, V1 model, h=100, lr=0.10000, Loss=0.13974, test err=0.043
# Trial 2, Epoch: 0, V1 model, h=100, lr=0.10000, Loss=2.31125, test err=0.861
# Trial 2, Epoch: 1000, V1 model, h=100, lr=0.10000, Loss=0.25430, test err=0.071
# Trial 2, Epoch: 2000, V1 model, h=100, lr=0.10000, Loss=0.18309, test err=0.053
# Trial 2, Epoch: 3000, V1 model, h=100, lr=0.10000, Loss=0.14138, test err=0.043
# Trial 3, Epoch: 0, V1 model, h=100, lr=0.10000, Loss=2.30867, test err=0.862
# Trial 3, Epoch: 1000, V1 model, h=100, lr=0.10000, Loss=0.24515, test err=0.069
# Trial 3, Epoch: 2000, V1 model, h=100, lr=0.10000, Loss=0.17480, test err=0.050
# Trial 3, Epoch: 3000, V1 model, h=100, lr=0.10000, Loss=0.13527, test err=0.039
# Trial 4, Epoch: 0, V1 model, h=100, lr=0.10000, Loss=2.30759, test err=0.838
# Trial 4, Epoch: 1000, V1 model, h=100, lr=0.10000, Loss=0.24995, test err=0.070
# Trial 4, Epoch: 2000, V1 model, h=100, lr=0.10000, Loss=0.17723, test err=0.052
# Trial 4, Epoch: 3000, V1 model, h=100, lr=0.10000, Loss=0.13593, test err=0.041
# Trial 5, Epoch: 0, V1 model, h=100, lr=0.10000, Loss=2.29400, test err=0.880
# Trial 5, Epoch: 1000, V1 model, h=100, lr=0.10000, Loss=0.25806, test err=0.072
# Trial 5, Epoch: 2000, V1 model, h=100, lr=0.10000, Loss=0.19054, test err=0.057
# Trial 5, Epoch: 3000, V1 model, h=100, lr=0.10000, Loss=0.14870, test err=0.046
# Trial 6, Epoch: 0, V1 model, h=100, lr=0.10000, Loss=2.32151, test err=0.890
# Trial 6, Epoch: 1000, V1 model, h=100, lr=0.10000, Loss=0.25874, test err=0.073
# Trial 6, Epoch: 2000, V1 model, h=100, lr=0.10000, Loss=0.18722, test err=0.055
# Trial 6, Epoch: 3000, V1 model, h=100, lr=0.10000, Loss=0.14534, test err=0.046
# Trial 7, Epoch: 0, V1 model, h=100, lr=0.10000, Loss=2.30945, test err=0.866
# Trial 7, Epoch: 1000, V1 model, h=100, lr=0.10000, Loss=0.24997, test err=0.068
# Trial 7, Epoch: 2000, V1 model, h=100, lr=0.10000, Loss=0.17675, test err=0.050
# Trial 7, Epoch: 3000, V1 model, h=100, lr=0.10000, Loss=0.13546, test err=0.042
# Trial 8, Epoch: 0, V1 model, h=100, lr=0.10000, Loss=2.32371, test err=0.906
# Trial 8, Epoch: 1000, V1 model, h=100, lr=0.10000, Loss=0.25439, test err=0.067
# Trial 8, Epoch: 2000, V1 model, h=100, lr=0.10000, Loss=0.18254, test err=0.052
# Trial 8, Epoch: 3000, V1 model, h=100, lr=0.10000, Loss=0.14087, test err=0.042
# Trial 9, Epoch: 0, V1 model, h=100, lr=0.10000, Loss=2.34975, test err=0.913
# Trial 9, Epoch: 1000, V1 model, h=100, lr=0.10000, Loss=0.25764, test err=0.070
# Trial 9, Epoch: 2000, V1 model, h=100, lr=0.10000, Loss=0.18770, test err=0.054
# Trial 9, Epoch: 3000, V1 model, h=100, lr=0.10000, Loss=0.14536, test err=0.044
# Trial 0, Epoch: 0, He model, h=100, lr=0.10000, Loss=2.28573, test err=0.825
# Trial 0, Epoch: 1000, He model, h=100, lr=0.10000, Loss=0.24992, test err=0.069
# Trial 0, Epoch: 2000, He model, h=100, lr=0.10000, Loss=0.17938, test err=0.052
# Trial 0, Epoch: 3000, He model, h=100, lr=0.10000, Loss=0.13933, test err=0.042
# Trial 1, Epoch: 0, He model, h=100, lr=0.10000, Loss=2.31762, test err=0.902
# Trial 1, Epoch: 1000, He model, h=100, lr=0.10000, Loss=0.24239, test err=0.066
# Trial 1, Epoch: 2000, He model, h=100, lr=0.10000, Loss=0.17345, test err=0.051
# Trial 1, Epoch: 3000, He model, h=100, lr=0.10000, Loss=0.13588, test err=0.041
# Trial 2, Epoch: 0, He model, h=100, lr=0.10000, Loss=2.34364, test err=0.864
# Trial 2, Epoch: 1000, He model, h=100, lr=0.10000, Loss=0.24736, test err=0.068
# Trial 2, Epoch: 2000, He model, h=100, lr=0.10000, Loss=0.18140, test err=0.052
# Trial 2, Epoch: 3000, He model, h=100, lr=0.10000, Loss=0.14161, test err=0.044
# Trial 3, Epoch: 0, He model, h=100, lr=0.10000, Loss=2.33864, test err=0.870
# Trial 3, Epoch: 1000, He model, h=100, lr=0.10000, Loss=0.24888, test err=0.068
# Trial 3, Epoch: 2000, He model, h=100, lr=0.10000, Loss=0.17727, test err=0.052
# Trial 3, Epoch: 3000, He model, h=100, lr=0.10000, Loss=0.13769, test err=0.042
# Trial 4, Epoch: 0, He model, h=100, lr=0.10000, Loss=2.30759, test err=0.860
# Trial 4, Epoch: 1000, He model, h=100, lr=0.10000, Loss=0.24564, test err=0.068
# Trial 4, Epoch: 2000, He model, h=100, lr=0.10000, Loss=0.17808, test err=0.053
# Trial 4, Epoch: 3000, He model, h=100, lr=0.10000, Loss=0.13808, test err=0.044
# Trial 5, Epoch: 0, He model, h=100, lr=0.10000, Loss=2.34941, test err=0.910
# Trial 5, Epoch: 1000, He model, h=100, lr=0.10000, Loss=0.25034, test err=0.069
# Trial 5, Epoch: 2000, He model, h=100, lr=0.10000, Loss=0.18217, test err=0.052
# Trial 5, Epoch: 3000, He model, h=100, lr=0.10000, Loss=0.14111, test err=0.041
# Trial 6, Epoch: 0, He model, h=100, lr=0.10000, Loss=2.33932, test err=0.894
# Trial 6, Epoch: 1000, He model, h=100, lr=0.10000, Loss=0.25472, test err=0.072
# Trial 6, Epoch: 2000, He model, h=100, lr=0.10000, Loss=0.18458, test err=0.054
# Trial 6, Epoch: 3000, He model, h=100, lr=0.10000, Loss=0.14419, test err=0.045
# Trial 7, Epoch: 0, He model, h=100, lr=0.10000, Loss=2.34638, test err=0.880
# Trial 7, Epoch: 1000, He model, h=100, lr=0.10000, Loss=0.24869, test err=0.069
# Trial 7, Epoch: 2000, He model, h=100, lr=0.10000, Loss=0.17949, test err=0.053
# Trial 7, Epoch: 3000, He model, h=100, lr=0.10000, Loss=0.13956, test err=0.044
# Trial 8, Epoch: 0, He model, h=100, lr=0.10000, Loss=2.33574, test err=0.923
# Trial 8, Epoch: 1000, He model, h=100, lr=0.10000, Loss=0.24411, test err=0.067
# Trial 8, Epoch: 2000, He model, h=100, lr=0.10000, Loss=0.17385, test err=0.051
# Trial 8, Epoch: 3000, He model, h=100, lr=0.10000, Loss=0.13397, test err=0.041
# Trial 9, Epoch: 0, He model, h=100, lr=0.10000, Loss=2.29445, test err=0.866
# Trial 9, Epoch: 1000, He model, h=100, lr=0.10000, Loss=0.24120, test err=0.066
# Trial 9, Epoch: 2000, He model, h=100, lr=0.10000, Loss=0.17417, test err=0.051
# Trial 9, Epoch: 3000, He model, h=100, lr=0.10000, Loss=0.13681, test err=0.044
# Trial 0, Epoch: 0, V1 model, h=100, lr=1.00000, Loss=2.30408, test err=0.560
# Trial 0, Epoch: 1000, V1 model, h=100, lr=1.00000, Loss=0.06449, test err=0.029
# Trial 0, Epoch: 2000, V1 model, h=100, lr=1.00000, Loss=0.03340, test err=0.026
# Trial 0, Epoch: 3000, V1 model, h=100, lr=1.00000, Loss=0.01984, test err=0.026
# Trial 1, Epoch: 0, V1 model, h=100, lr=1.00000, Loss=2.30117, test err=0.624
# Trial 1, Epoch: 1000, V1 model, h=100, lr=1.00000, Loss=0.05389, test err=0.026
# Trial 1, Epoch: 2000, V1 model, h=100, lr=1.00000, Loss=0.02499, test err=0.023
# Trial 1, Epoch: 3000, V1 model, h=100, lr=1.00000, Loss=0.01378, test err=0.023
# Trial 2, Epoch: 0, V1 model, h=100, lr=1.00000, Loss=2.32855, test err=0.617
# Trial 2, Epoch: 1000, V1 model, h=100, lr=1.00000, Loss=0.05457, test err=0.025
# Trial 2, Epoch: 2000, V1 model, h=100, lr=1.00000, Loss=0.02587, test err=0.022
# Trial 2, Epoch: 3000, V1 model, h=100, lr=1.00000, Loss=0.01450, test err=0.022
# Trial 3, Epoch: 0, V1 model, h=100, lr=1.00000, Loss=2.29452, test err=0.642
# Trial 3, Epoch: 1000, V1 model, h=100, lr=1.00000, Loss=0.05689, test err=0.026
# Trial 3, Epoch: 2000, V1 model, h=100, lr=1.00000, Loss=0.02783, test err=0.024
# Trial 3, Epoch: 3000, V1 model, h=100, lr=1.00000, Loss=0.01598, test err=0.024
# Trial 4, Epoch: 0, V1 model, h=100, lr=1.00000, Loss=2.30338, test err=0.612
# Trial 4, Epoch: 1000, V1 model, h=100, lr=1.00000, Loss=0.05205, test err=0.026
# Trial 4, Epoch: 2000, V1 model, h=100, lr=1.00000, Loss=0.02496, test err=0.024
# Trial 4, Epoch: 3000, V1 model, h=100, lr=1.00000, Loss=0.01410, test err=0.024
# Trial 5, Epoch: 0, V1 model, h=100, lr=1.00000, Loss=2.33106, test err=0.667
# Trial 5, Epoch: 1000, V1 model, h=100, lr=1.00000, Loss=0.05393, test err=0.025
# Trial 5, Epoch: 2000, V1 model, h=100, lr=1.00000, Loss=0.02571, test err=0.023
# Trial 5, Epoch: 3000, V1 model, h=100, lr=1.00000, Loss=0.01437, test err=0.023
# Trial 6, Epoch: 0, V1 model, h=100, lr=1.00000, Loss=2.31348, test err=0.521
# Trial 6, Epoch: 1000, V1 model, h=100, lr=1.00000, Loss=0.05179, test err=0.026
# Trial 6, Epoch: 2000, V1 model, h=100, lr=1.00000, Loss=0.02316, test err=0.022
# Trial 6, Epoch: 3000, V1 model, h=100, lr=1.00000, Loss=0.01260, test err=0.022
# Trial 7, Epoch: 0, V1 model, h=100, lr=1.00000, Loss=2.33566, test err=0.580
# Trial 7, Epoch: 1000, V1 model, h=100, lr=1.00000, Loss=0.05400, test err=0.026
# Trial 7, Epoch: 2000, V1 model, h=100, lr=1.00000, Loss=0.02512, test err=0.021
# Trial 7, Epoch: 3000, V1 model, h=100, lr=1.00000, Loss=0.01392, test err=0.022
# Trial 8, Epoch: 0, V1 model, h=100, lr=1.00000, Loss=2.36422, test err=0.620
# Trial 8, Epoch: 1000, V1 model, h=100, lr=1.00000, Loss=0.05804, test err=0.027
# Trial 8, Epoch: 2000, V1 model, h=100, lr=1.00000, Loss=0.02679, test err=0.025
# Trial 8, Epoch: 3000, V1 model, h=100, lr=1.00000, Loss=0.01460, test err=0.025
# Trial 9, Epoch: 0, V1 model, h=100, lr=1.00000, Loss=2.28941, test err=0.572
# Trial 9, Epoch: 1000, V1 model, h=100, lr=1.00000, Loss=0.05429, test err=0.024
# Trial 9, Epoch: 2000, V1 model, h=100, lr=1.00000, Loss=0.02533, test err=0.022
# Trial 9, Epoch: 3000, V1 model, h=100, lr=1.00000, Loss=0.01395, test err=0.021
# Trial 0, Epoch: 0, He model, h=100, lr=1.00000, Loss=2.34516, test err=0.538
# Trial 0, Epoch: 1000, He model, h=100, lr=1.00000, Loss=0.05247, test err=0.025
# Trial 0, Epoch: 2000, He model, h=100, lr=1.00000, Loss=0.02362, test err=0.023
# Trial 0, Epoch: 3000, He model, h=100, lr=1.00000, Loss=0.01266, test err=0.022
# Trial 1, Epoch: 0, He model, h=100, lr=1.00000, Loss=2.37317, test err=0.673
# Trial 1, Epoch: 1000, He model, h=100, lr=1.00000, Loss=0.05097, test err=0.026
# Trial 1, Epoch: 2000, He model, h=100, lr=1.00000, Loss=0.02257, test err=0.023
# Trial 1, Epoch: 3000, He model, h=100, lr=1.00000, Loss=0.01200, test err=0.024
# Trial 2, Epoch: 0, He model, h=100, lr=1.00000, Loss=2.37450, test err=0.643
# ...
# Trial 9, Epoch: 2000, He model, h=400, lr=1.00000, Loss=0.01396, test err=0.019
# Trial 9, Epoch: 3000, He model, h=400, lr=1.00000, Loss=0.00712, test err=0.019
# Trial 0, Epoch: 0, V1 model, h=1000, lr=0.00100, Loss=2.30917, test err=0.927
# Trial 0, Epoch: 1000, V1 model, h=1000, lr=0.00100, Loss=1.33233, test err=0.254
# Trial 0, Epoch: 2000, V1 model, h=1000, lr=0.00100, Loss=0.98058, test err=0.208
# Trial 0, Epoch: 3000, V1 model, h=1000, lr=0.00100, Loss=0.81044, test err=0.185
# Trial 1, Epoch: 0, V1 model, h=1000, lr=0.00100, Loss=2.29721, test err=0.844
# Trial 1, Epoch: 1000, V1 model, h=1000, lr=0.00100, Loss=1.29969, test err=0.265
# Trial 1, Epoch: 2000, V1 model, h=1000, lr=0.00100, Loss=0.96262, test err=0.208
# Trial 1, Epoch: 3000, V1 model, h=1000, lr=0.00100, Loss=0.80004, test err=0.180
# Trial 2, Epoch: 0, V1 model, h=1000, lr=0.00100, Loss=2.31318, test err=0.866
# Trial 2, Epoch: 1000, V1 model, h=1000, lr=0.00100, Loss=1.39972, test err=0.250
# Trial 2, Epoch: 2000, V1 model, h=1000, lr=0.00100, Loss=1.02434, test err=0.204
# Trial 2, Epoch: 3000, V1 model, h=1000, lr=0.00100, Loss=0.83461, test err=0.179
# Trial 3, Epoch: 0, V1 model, h=1000, lr=0.00100, Loss=2.28295, test err=0.827
# Trial 3, Epoch: 1000, V1 model, h=1000, lr=0.00100, Loss=1.25695, test err=0.242
# Trial 3, Epoch: 2000, V1 model, h=1000, lr=0.00100, Loss=0.93232, test err=0.200
# Trial 3, Epoch: 3000, V1 model, h=1000, lr=0.00100, Loss=0.78058, test err=0.176
# Trial 4, Epoch: 0, V1 model, h=1000, lr=0.00100, Loss=2.30882, test err=0.901
# Trial 4, Epoch: 1000, V1 model, h=1000, lr=0.00100, Loss=1.32906, test err=0.245
# Trial 4, Epoch: 2000, V1 model, h=1000, lr=0.00100, Loss=0.97614, test err=0.198
# Trial 4, Epoch: 3000, V1 model, h=1000, lr=0.00100, Loss=0.80497, test err=0.178
# Trial 5, Epoch: 0, V1 model, h=1000, lr=0.00100, Loss=2.31455, test err=0.913
# Trial 5, Epoch: 1000, V1 model, h=1000, lr=0.00100, Loss=1.31728, test err=0.243
# Trial 5, Epoch: 2000, V1 model, h=1000, lr=0.00100, Loss=0.96610, test err=0.194
# Trial 5, Epoch: 3000, V1 model, h=1000, lr=0.00100, Loss=0.79939, test err=0.172
# Trial 6, Epoch: 0, V1 model, h=1000, lr=0.00100, Loss=2.32830, test err=0.872
# Trial 6, Epoch: 1000, V1 model, h=1000, lr=0.00100, Loss=1.27386, test err=0.230
# Trial 6, Epoch: 2000, V1 model, h=1000, lr=0.00100, Loss=0.92796, test err=0.183
# Trial 6, Epoch: 3000, V1 model, h=1000, lr=0.00100, Loss=0.76759, test err=0.162
# Trial 7, Epoch: 0, V1 model, h=1000, lr=0.00100, Loss=2.31272, test err=0.919
# Trial 7, Epoch: 1000, V1 model, h=1000, lr=0.00100, Loss=1.32260, test err=0.224
# Trial 7, Epoch: 2000, V1 model, h=1000, lr=0.00100, Loss=0.95836, test err=0.179
# Trial 7, Epoch: 3000, V1 model, h=1000, lr=0.00100, Loss=0.78564, test err=0.163
# Trial 8, Epoch: 0, V1 model, h=1000, lr=0.00100, Loss=2.30377, test err=0.863
# Trial 8, Epoch: 1000, V1 model, h=1000, lr=0.00100, Loss=1.36131, test err=0.241
# Trial 8, Epoch: 2000, V1 model, h=1000, lr=0.00100, Loss=0.99391, test err=0.195
# Trial 8, Epoch: 3000, V1 model, h=1000, lr=0.00100, Loss=0.81423, test err=0.170
# Trial 9, Epoch: 0, V1 model, h=1000, lr=0.00100, Loss=2.27953, test err=0.845
# Trial 9, Epoch: 1000, V1 model, h=1000, lr=0.00100, Loss=1.40512, test err=0.270
# Trial 9, Epoch: 2000, V1 model, h=1000, lr=0.00100, Loss=1.04047, test err=0.209
# Trial 9, Epoch: 3000, V1 model, h=1000, lr=0.00100, Loss=0.85131, test err=0.184
# Trial 0, Epoch: 0, He model, h=1000, lr=0.00100, Loss=2.30343, test err=0.895
# Trial 0, Epoch: 1000, He model, h=1000, lr=0.00100, Loss=1.50243, test err=0.213
# Trial 0, Epoch: 2000, He model, h=1000, lr=0.00100, Loss=1.06685, test err=0.172
# Trial 0, Epoch: 3000, He model, h=1000, lr=0.00100, Loss=0.83744, test err=0.152
# Trial 1, Epoch: 0, He model, h=1000, lr=0.00100, Loss=2.33487, test err=0.900
# Trial 1, Epoch: 1000, He model, h=1000, lr=0.00100, Loss=1.50938, test err=0.225
# Trial 1, Epoch: 2000, He model, h=1000, lr=0.00100, Loss=1.06911, test err=0.178
# Trial 1, Epoch: 3000, He model, h=1000, lr=0.00100, Loss=0.83960, test err=0.160
# Trial 2, Epoch: 0, He model, h=1000, lr=0.00100, Loss=2.32128, test err=0.907
# Trial 2, Epoch: 1000, He model, h=1000, lr=0.00100, Loss=1.49646, test err=0.226
# Trial 2, Epoch: 2000, He model, h=1000, lr=0.00100, Loss=1.05777, test err=0.173
# Trial 2, Epoch: 3000, He model, h=1000, lr=0.00100, Loss=0.83068, test err=0.155
# Trial 3, Epoch: 0, He model, h=1000, lr=0.00100, Loss=2.34548, test err=0.920
# Trial 3, Epoch: 1000, He model, h=1000, lr=0.00100, Loss=1.56378, test err=0.237
# Trial 3, Epoch: 2000, He model, h=1000, lr=0.00100, Loss=1.11218, test err=0.184
# Trial 3, Epoch: 3000, He model, h=1000, lr=0.00100, Loss=0.86701, test err=0.162
# Trial 4, Epoch: 0, He model, h=1000, lr=0.00100, Loss=2.31232, test err=0.918
# Trial 4, Epoch: 1000, He model, h=1000, lr=0.00100, Loss=1.50944, test err=0.232
# Trial 4, Epoch: 2000, He model, h=1000, lr=0.00100, Loss=1.07152, test err=0.180
# Trial 4, Epoch: 3000, He model, h=1000, lr=0.00100, Loss=0.84286, test err=0.159
# Trial 5, Epoch: 0, He model, h=1000, lr=0.00100, Loss=2.31448, test err=0.904
# Trial 5, Epoch: 1000, He model, h=1000, lr=0.00100, Loss=1.47713, test err=0.210
# Trial 5, Epoch: 2000, He model, h=1000, lr=0.00100, Loss=1.04172, test err=0.170
# Trial 5, Epoch: 3000, He model, h=1000, lr=0.00100, Loss=0.81923, test err=0.152
# Trial 6, Epoch: 0, He model, h=1000, lr=0.00100, Loss=2.29941, test err=0.858
# Trial 6, Epoch: 1000, He model, h=1000, lr=0.00100, Loss=1.51136, test err=0.218
# Trial 6, Epoch: 2000, He model, h=1000, lr=0.00100, Loss=1.07151, test err=0.177
# Trial 6, Epoch: 3000, He model, h=1000, lr=0.00100, Loss=0.83951, test err=0.155
# Trial 7, Epoch: 0, He model, h=1000, lr=0.00100, Loss=2.28096, test err=0.850
# Trial 7, Epoch: 1000, He model, h=1000, lr=0.00100, Loss=1.49668, test err=0.224
# Trial 7, Epoch: 2000, He model, h=1000, lr=0.00100, Loss=1.06731, test err=0.177
# Trial 7, Epoch: 3000, He model, h=1000, lr=0.00100, Loss=0.83995, test err=0.155
# Trial 8, Epoch: 0, He model, h=1000, lr=0.00100, Loss=2.30005, test err=0.875
# Trial 8, Epoch: 1000, He model, h=1000, lr=0.00100, Loss=1.53027, test err=0.237
# Trial 8, Epoch: 2000, He model, h=1000, lr=0.00100, Loss=1.09430, test err=0.183
# Trial 8, Epoch: 3000, He model, h=1000, lr=0.00100, Loss=0.85807, test err=0.160
# Trial 9, Epoch: 0, He model, h=1000, lr=0.00100, Loss=2.32240, test err=0.884
# Trial 9, Epoch: 1000, He model, h=1000, lr=0.00100, Loss=1.49694, test err=0.223
# Trial 9, Epoch: 2000, He model, h=1000, lr=0.00100, Loss=1.06209, test err=0.174
# Trial 9, Epoch: 3000, He model, h=1000, lr=0.00100, Loss=0.83519, test err=0.154
# Trial 0, Epoch: 0, V1 model, h=1000, lr=0.01000, Loss=2.31065, test err=0.900
# Trial 0, Epoch: 1000, V1 model, h=1000, lr=0.01000, Loss=0.48639, test err=0.128
# Trial 0, Epoch: 2000, V1 model, h=1000, lr=0.01000, Loss=0.39125, test err=0.106
# Trial 0, Epoch: 3000, V1 model, h=1000, lr=0.01000, Loss=0.35030, test err=0.097
# Trial 1, Epoch: 0, V1 model, h=1000, lr=0.01000, Loss=2.33932, test err=0.929
# Trial 1, Epoch: 1000, V1 model, h=1000, lr=0.01000, Loss=0.48494, test err=0.124
# Trial 1, Epoch: 2000, V1 model, h=1000, lr=0.01000, Loss=0.39030, test err=0.102
# Trial 1, Epoch: 3000, V1 model, h=1000, lr=0.01000, Loss=0.35028, test err=0.092
# Trial 2, Epoch: 0, V1 model, h=1000, lr=0.01000, Loss=2.32576, test err=0.906
# Trial 2, Epoch: 1000, V1 model, h=1000, lr=0.01000, Loss=0.49779, test err=0.122
# Trial 2, Epoch: 2000, V1 model, h=1000, lr=0.01000, Loss=0.39395, test err=0.102
# Trial 2, Epoch: 3000, V1 model, h=1000, lr=0.01000, Loss=0.35047, test err=0.091
# Trial 3, Epoch: 0, V1 model, h=1000, lr=0.01000, Loss=2.33981, test err=0.920
# Trial 3, Epoch: 1000, V1 model, h=1000, lr=0.01000, Loss=0.47349, test err=0.124
# Trial 3, Epoch: 2000, V1 model, h=1000, lr=0.01000, Loss=0.38540, test err=0.103
# Trial 3, Epoch: 3000, V1 model, h=1000, lr=0.01000, Loss=0.34810, test err=0.093
# Trial 4, Epoch: 0, V1 model, h=1000, lr=0.01000, Loss=2.28677, test err=0.840
# Trial 4, Epoch: 1000, V1 model, h=1000, lr=0.01000, Loss=0.48141, test err=0.121
# Trial 4, Epoch: 2000, V1 model, h=1000, lr=0.01000, Loss=0.38786, test err=0.101
# Trial 4, Epoch: 3000, V1 model, h=1000, lr=0.01000, Loss=0.34884, test err=0.093
# Trial 5, Epoch: 0, V1 model, h=1000, lr=0.01000, Loss=2.31089, test err=0.799
# Trial 5, Epoch: 1000, V1 model, h=1000, lr=0.01000, Loss=0.46793, test err=0.118
# Trial 5, Epoch: 2000, V1 model, h=1000, lr=0.01000, Loss=0.38160, test err=0.098
# Trial 5, Epoch: 3000, V1 model, h=1000, lr=0.01000, Loss=0.34570, test err=0.091
# Trial 6, Epoch: 0, V1 model, h=1000, lr=0.01000, Loss=2.31915, test err=0.861
# Trial 6, Epoch: 1000, V1 model, h=1000, lr=0.01000, Loss=0.48219, test err=0.122
# Trial 6, Epoch: 2000, V1 model, h=1000, lr=0.01000, Loss=0.38687, test err=0.102
# Trial 6, Epoch: 3000, V1 model, h=1000, lr=0.01000, Loss=0.34711, test err=0.093
# Trial 7, Epoch: 0, V1 model, h=1000, lr=0.01000, Loss=2.34815, test err=0.943
# Trial 7, Epoch: 1000, V1 model, h=1000, lr=0.01000, Loss=0.48857, test err=0.119
# Trial 7, Epoch: 2000, V1 model, h=1000, lr=0.01000, Loss=0.38598, test err=0.099
# Trial 7, Epoch: 3000, V1 model, h=1000, lr=0.01000, Loss=0.34541, test err=0.091
# Trial 8, Epoch: 0, V1 model, h=1000, lr=0.01000, Loss=2.33130, test err=0.907
# Trial 8, Epoch: 1000, V1 model, h=1000, lr=0.01000, Loss=0.48211, test err=0.123
# Trial 8, Epoch: 2000, V1 model, h=1000, lr=0.01000, Loss=0.38943, test err=0.103
# Trial 8, Epoch: 3000, V1 model, h=1000, lr=0.01000, Loss=0.34950, test err=0.095
# Trial 9, Epoch: 0, V1 model, h=1000, lr=0.01000, Loss=2.25802, test err=0.823
# Trial 9, Epoch: 1000, V1 model, h=1000, lr=0.01000, Loss=0.47836, test err=0.118
# Trial 9, Epoch: 2000, V1 model, h=1000, lr=0.01000, Loss=0.38584, test err=0.100
# Trial 9, Epoch: 3000, V1 model, h=1000, lr=0.01000, Loss=0.34663, test err=0.093
# Trial 0, Epoch: 0, He model, h=1000, lr=0.01000, Loss=2.33454, test err=0.913
# Trial 0, Epoch: 1000, He model, h=1000, lr=0.01000, Loss=0.45800, test err=0.111
# Trial 0, Epoch: 2000, He model, h=1000, lr=0.01000, Loss=0.35861, test err=0.093
# Trial 0, Epoch: 3000, He model, h=1000, lr=0.01000, Loss=0.31697, test err=0.084
# Trial 1, Epoch: 0, He model, h=1000, lr=0.01000, Loss=2.34703, test err=0.942
# Trial 1, Epoch: 1000, He model, h=1000, lr=0.01000, Loss=0.45136, test err=0.107
# Trial 1, Epoch: 2000, He model, h=1000, lr=0.01000, Loss=0.35399, test err=0.092
# Trial 1, Epoch: 3000, He model, h=1000, lr=0.01000, Loss=0.31345, test err=0.084
# Trial 2, Epoch: 0, He model, h=1000, lr=0.01000, Loss=2.35042, test err=0.889
# Trial 2, Epoch: 1000, He model, h=1000, lr=0.01000, Loss=0.46028, test err=0.109
# Trial 2, Epoch: 2000, He model, h=1000, lr=0.01000, Loss=0.35995, test err=0.093
# Trial 2, Epoch: 3000, He model, h=1000, lr=0.01000, Loss=0.31886, test err=0.084
# Trial 3, Epoch: 0, He model, h=1000, lr=0.01000, Loss=2.31890, test err=0.910
# Trial 3, Epoch: 1000, He model, h=1000, lr=0.01000, Loss=0.45541, test err=0.108
# Trial 3, Epoch: 2000, He model, h=1000, lr=0.01000, Loss=0.35610, test err=0.090
# Trial 3, Epoch: 3000, He model, h=1000, lr=0.01000, Loss=0.31522, test err=0.083
# Trial 4, Epoch: 0, He model, h=1000, lr=0.01000, Loss=2.30334, test err=0.873
# Trial 4, Epoch: 1000, He model, h=1000, lr=0.01000, Loss=0.44892, test err=0.106
# Trial 4, Epoch: 2000, He model, h=1000, lr=0.01000, Loss=0.35320, test err=0.091
# Trial 4, Epoch: 3000, He model, h=1000, lr=0.01000, Loss=0.31371, test err=0.083
# Trial 5, Epoch: 0, He model, h=1000, lr=0.01000, Loss=2.28059, test err=0.833
# Trial 5, Epoch: 1000, He model, h=1000, lr=0.01000, Loss=0.45511, test err=0.109
# Trial 5, Epoch: 2000, He model, h=1000, lr=0.01000, Loss=0.35690, test err=0.092
# Trial 5, Epoch: 3000, He model, h=1000, lr=0.01000, Loss=0.31597, test err=0.083
# Trial 6, Epoch: 0, He model, h=1000, lr=0.01000, Loss=2.28998, test err=0.811
# Trial 6, Epoch: 1000, He model, h=1000, lr=0.01000, Loss=0.45548, test err=0.108
# Trial 6, Epoch: 2000, He model, h=1000, lr=0.01000, Loss=0.35628, test err=0.091
# Trial 6, Epoch: 3000, He model, h=1000, lr=0.01000, Loss=0.31565, test err=0.083
# Trial 7, Epoch: 0, He model, h=1000, lr=0.01000, Loss=2.29948, test err=0.876
# Trial 7, Epoch: 1000, He model, h=1000, lr=0.01000, Loss=0.45075, test err=0.107
# Trial 7, Epoch: 2000, He model, h=1000, lr=0.01000, Loss=0.35342, test err=0.091
# Trial 7, Epoch: 3000, He model, h=1000, lr=0.01000, Loss=0.31333, test err=0.082
# Trial 8, Epoch: 0, He model, h=1000, lr=0.01000, Loss=2.31839, test err=0.861
# Trial 8, Epoch: 1000, He model, h=1000, lr=0.01000, Loss=0.45236, test err=0.108
# Trial 8, Epoch: 2000, He model, h=1000, lr=0.01000, Loss=0.35678, test err=0.091
# Trial 8, Epoch: 3000, He model, h=1000, lr=0.01000, Loss=0.31705, test err=0.083
# Trial 9, Epoch: 0, He model, h=1000, lr=0.01000, Loss=2.29042, test err=0.890
# Trial 9, Epoch: 1000, He model, h=1000, lr=0.01000, Loss=0.45063, test err=0.109
# Trial 9, Epoch: 2000, He model, h=1000, lr=0.01000, Loss=0.35368, test err=0.091
# Trial 9, Epoch: 3000, He model, h=1000, lr=0.01000, Loss=0.31395, test err=0.083
# Trial 0, Epoch: 0, V1 model, h=1000, lr=0.10000, Loss=2.34085, test err=0.664
# Trial 0, Epoch: 1000, V1 model, h=1000, lr=0.10000, Loss=0.24241, test err=0.066
# Trial 0, Epoch: 2000, V1 model, h=1000, lr=0.10000, Loss=0.16743, test err=0.050
# Trial 0, Epoch: 3000, V1 model, h=1000, lr=0.10000, Loss=0.12496, test err=0.039
# Trial 1, Epoch: 0, V1 model, h=1000, lr=0.10000, Loss=2.32456, test err=0.735
# Trial 1, Epoch: 1000, V1 model, h=1000, lr=0.10000, Loss=0.23821, test err=0.066
# Trial 1, Epoch: 2000, V1 model, h=1000, lr=0.10000, Loss=0.16358, test err=0.048
# Trial 1, Epoch: 3000, V1 model, h=1000, lr=0.10000, Loss=0.12088, test err=0.037
# Trial 2, Epoch: 0, V1 model, h=1000, lr=0.10000, Loss=2.28882, test err=0.691
# Trial 2, Epoch: 1000, V1 model, h=1000, lr=0.10000, Loss=0.24321, test err=0.067
# Trial 2, Epoch: 2000, V1 model, h=1000, lr=0.10000, Loss=0.16719, test err=0.048
# Trial 2, Epoch: 3000, V1 model, h=1000, lr=0.10000, Loss=0.12302, test err=0.036
# Trial 3, Epoch: 0, V1 model, h=1000, lr=0.10000, Loss=2.32712, test err=0.655
# Trial 3, Epoch: 1000, V1 model, h=1000, lr=0.10000, Loss=0.24437, test err=0.068
# Trial 3, Epoch: 2000, V1 model, h=1000, lr=0.10000, Loss=0.16804, test err=0.049
# Trial 3, Epoch: 3000, V1 model, h=1000, lr=0.10000, Loss=0.12473, test err=0.039
# Trial 4, Epoch: 0, V1 model, h=1000, lr=0.10000, Loss=2.33906, test err=0.674
# Trial 4, Epoch: 1000, V1 model, h=1000, lr=0.10000, Loss=0.24630, test err=0.069
# Trial 4, Epoch: 2000, V1 model, h=1000, lr=0.10000, Loss=0.16849, test err=0.049
# Trial 4, Epoch: 3000, V1 model, h=1000, lr=0.10000, Loss=0.12400, test err=0.037
# Trial 5, Epoch: 0, V1 model, h=1000, lr=0.10000, Loss=2.33266, test err=0.687
# Trial 5, Epoch: 1000, V1 model, h=1000, lr=0.10000, Loss=0.24436, test err=0.067
# Trial 5, Epoch: 2000, V1 model, h=1000, lr=0.10000, Loss=0.16592, test err=0.048
# Trial 5, Epoch: 3000, V1 model, h=1000, lr=0.10000, Loss=0.12256, test err=0.037
# Trial 6, Epoch: 0, V1 model, h=1000, lr=0.10000, Loss=2.32201, test err=0.670
# Trial 6, Epoch: 1000, V1 model, h=1000, lr=0.10000, Loss=0.24274, test err=0.067
# Trial 6, Epoch: 2000, V1 model, h=1000, lr=0.10000, Loss=0.16732, test err=0.049
# Trial 6, Epoch: 3000, V1 model, h=1000, lr=0.10000, Loss=0.12357, test err=0.038
# Trial 7, Epoch: 0, V1 model, h=1000, lr=0.10000, Loss=2.34792, test err=0.770
# Trial 7, Epoch: 1000, V1 model, h=1000, lr=0.10000, Loss=0.24206, test err=0.068
# Trial 7, Epoch: 2000, V1 model, h=1000, lr=0.10000, Loss=0.16669, test err=0.048
# Trial 7, Epoch: 3000, V1 model, h=1000, lr=0.10000, Loss=0.12401, test err=0.037
# Trial 8, Epoch: 0, V1 model, h=1000, lr=0.10000, Loss=2.37436, test err=0.632
# Trial 8, Epoch: 1000, V1 model, h=1000, lr=0.10000, Loss=0.24447, test err=0.066
# Trial 8, Epoch: 2000, V1 model, h=1000, lr=0.10000, Loss=0.16739, test err=0.049
# Trial 8, Epoch: 3000, V1 model, h=1000, lr=0.10000, Loss=0.12383, test err=0.037
# Trial 9, Epoch: 0, V1 model, h=1000, lr=0.10000, Loss=2.33416, test err=0.673

# %% [markdown]
# ## plot results

# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt

t, l, n_epochs= 5, 2, 3001
models = ['V1', 'He']
h_list = [50, 100, 400, 1000]
lr_list = [1e-3, 1e-2, 1e-1, 1e0]

for h in h_list:
    for lr in lr_list:
        with open('results/initialize_mnist/full_data/clf_t=%0.2f_l=%0.2f.pickle' % (t, l), 'rb') as handle:
            sims = pickle.load(handle)

        fig = plt.figure(figsize=(12, 5))
        plt.suptitle(r'Shallow FFW FC net w/ GD. h=%d, lr=%0.4f, '% (h, lr), fontsize=16)
        
        # loss
        ax = fig.add_subplot(131)
        plt.title('Network loss', fontsize=16)
        for m in models:
            avg_loss = np.mean(sims['loss'][m][h][lr], axis=0)
            std_loss = np.std(sims['loss'][m][h][lr], axis=0)                       
            plt.plot(np.arange(n_epochs), avg_loss, label=m, lw=3)
            plt.fill_between(np.arange(n_epochs), avg_loss - std_loss, avg_loss + std_loss, alpha=0.2)
        plt.xlabel('Epoch', fontsize=20)
        plt.ylabel('Training loss', fontsize=20)
        ax.tick_params(axis = 'both', which = 'major', labelsize = 14, width=2, length=6)
        plt.yscale('log')
        plt.legend(fontsize=18)
        
        # train err
        ax = fig.add_subplot(132)
        plt.title('Train error', fontsize=16)
        for m in models:
            avg_train_err = np.mean(sims['train_err'][m][h][lr], axis=0)
            std_train_err = np.std(sims['train_err'][m][h][lr], axis=0)
            plt.plot(np.arange(n_epochs), avg_train_err, label=m, lw=3)
            plt.fill_between(np.arange(n_epochs), avg_train_err - std_train_err, avg_train_err + std_train_err,  alpha=0.2)
        
        plt.xlabel('Epoch', fontsize=20)
        plt.ylabel('Training error', fontsize=20)
        ax.tick_params(axis = 'both', which = 'major', labelsize = 14, width=2, length=6)
        plt.yticks(np.arange(0, 1, 0.2))
        plt.yscale('log')
        plt.legend(fontsize=18)

        # test err
        ax = fig.add_subplot(133)
        plt.title('Test error', fontsize=16)
        for m in models:
            avg_test_err = np.mean(sims['test_err'][m][h][lr], axis=0)
            std_test_err = np.std(sims['test_err'][m][h][lr], axis=0)
            plt.plot(np.arange(n_epochs), avg_test_err, label=m, lw=3)
            plt.fill_between(np.arange(n_epochs), avg_test_err - std_test_err, avg_test_err + std_test_err, alpha=0.2)

        plt.xlabel('Epoch', fontsize=20)
        plt.ylabel('Test error', fontsize=20)
        ax.tick_params(axis = 'both', which = 'major', labelsize = 14, width=2, length=6)
        plt.yticks(np.arange(0, 1, 0.2))
        plt.yscale('log')
        plt.legend(fontsize=18)

        plt.tight_layout()
        plt.subplots_adjust(top=0.8)    

        print(h, lr)
        plt.savefig('results/initialize_mnist/full_data/init_t=%0.2f_l=%0.2f_h=%d_lr=%0.4f.png' % (t, l, h, lr))
        plt.close()
# Out:
# 50 0.001
# 50 0.01
# 50 0.1
# 50 1.0
# 100 0.001
# 100 0.01
# 100 0.1
# 100 1.0
# 400 0.001
# 400 0.01
# 400 0.1
# 400 1.0
# 1000 0.001
# 1000 0.01
# 1000 0.1
# 1000 1.0

# %% [markdown]
# ## Test the speed of training networks on GPUs vs CPU

# %%
import numpy as np
import numpy.linalg as la
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from estimator import classical_weights, V1_inspired_weights
from data_fns import load_mnist

# %%
train, train_labels, test, test_labels = load_mnist('./data/mnist')
X_train = torch.from_numpy(train).float()
X_test = torch.from_numpy(test).float()
y_train = torch.from_numpy(train_labels).long()
y_test = torch.from_numpy(test_labels).long()
n, d = X_train.shape

# %%
class V1_net(nn.Module):
    def __init__(self, hidden_size, scale):
        super().__init__()
        self.fc1 = nn.Linear(d, hidden_size)
        self.fc1.weight.data = torch.FloatTensor(V1_inspired_weights(hidden_size, d, t=5, l=2, scale=scale))
        self.output = nn.Linear(hidden_size, 10)
        
    def forward(self, inputs):
        x = torch.relu(self.fc1(inputs))
        return self.output(x)
    
class He_net(nn.Module):
    def __init__(self, hidden_size, scale):
        super().__init__()
        self.fc1 = nn.Linear(d, hidden_size)
        torch.nn.init.kaiming_normal_(self.fc1.weight)
        self.output = nn.Linear(hidden_size, 10)
        
    def forward(self, inputs):
        x = torch.relu(self.fc1(inputs))
        return self.output(x)
    
class RF_net(nn.Module):
    def __init__(self, hidden_size, scale):
        super().__init__()
        self.fc1 = nn.Linear(d, hidden_size)
        self.fc1.weight.data = torch.FloatTensor(classical_weights(hidden_size, d, scale=scale))
        self.output = nn.Linear(hidden_size, 10)
        
    def forward(self, inputs):
        x = torch.relu(self.fc1(inputs))
        return self.output(x)    
    
    
def predict(model, X):
    return model(X).data.max(1)[1]

def error(model, X, y):
    y_pred = predict(model, X)
    accuracy = 1.0 * torch.sum(y_pred == y) / len(y)
    return 1 - accuracy

# %%
# %%time
## Run on CPU
h, lr, scale = 1000, 0.1, 2 / d
n_epochs = 50
model = V1_net(h, scale=scale)
loss_func = nn.CrossEntropyLoss()
optim = torch.optim.SGD(model.parameters(), lr=lr)

for i in range(n_epochs):
    optim.zero_grad()
    loss = loss_func(model(X_train), y_train)
    loss.backward()
    optim.step()
    
    train_err = error(model, X_train, y_train)
    test_err = error(model, X_test, y_test)
    
    if (i % 10 == 0):
        print('Epoch: %d, Loss=%0.5f, train_err=%0.5f, test_err=%0.5f' % (i, loss.data, train_err, test_err))

# %%
# %%time
## Run on GPU
X_train_cuda, y_train_cuda = X_train.to('cuda'), y_train.to('cuda')
X_test_cuda, y_test_cuda = X_test.to('cuda'), y_test.to('cuda')

h, lr, scale = 2000, 1, 2/d
n_epochs = 2001
model = V1_net(h, scale=scale).to('cuda')
loss_func = nn.CrossEntropyLoss()
optim = torch.optim.SGD(model.parameters(), lr=lr)

test_err_list_V1 = []
for i in range(n_epochs):
    optim.zero_grad()
    loss = loss_func(model(X_train_cuda), y_train_cuda)
    loss.backward()
    optim.step()
    
    train_err = error(model, X_train_cuda, y_train_cuda)
    test_err = error(model, X_test_cuda, y_test_cuda)
    test_err_list_V1.append(test_err)
    
    if (i % 200 == 0):
        print('Epoch: %d, Loss=%0.5f, train_err=%0.5f, test_err=%0.5f' % (i, loss.data, train_err, test_err))

# %%
# %%time
## Run on GPU
X_train_cuda, y_train_cuda = X_train.to('cuda'), y_train.to('cuda')
X_test_cuda, y_test_cuda = X_test.to('cuda'), y_test.to('cuda')

h, lr, scale = 2000, 1, 2/d
n_epochs = 2001
model = He_net(h, scale=scale).to('cuda')
loss_func = nn.CrossEntropyLoss()
optim = torch.optim.SGD(model.parameters(), lr=lr)

test_err_list_He = []
for i in range(n_epochs):
    optim.zero_grad()
    loss = loss_func(model(X_train_cuda), y_train_cuda)
    loss.backward()
    optim.step()
    
    train_err = error(model, X_train_cuda, y_train_cuda)
    test_err = error(model, X_test_cuda, y_test_cuda)
    test_err_list_He.append(test_err)
    
    if (i % 200 == 0):
        print('Epoch: %d, Loss=%0.5f, train_err=%0.5f, test_err=%0.5f' % (i, loss.data, train_err, test_err))

# %%
fig = plt.figure()
plt.plot(np.arange(n_epochs), test_err_list_V1, label='V1')
plt.plot(np.arange(n_epochs), test_err_list_He, label='He')
plt.yscale('log')
plt.legend()

# %%
print(20)
