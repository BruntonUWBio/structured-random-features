# %% [markdown]
# Initialize shallow feedforward fully-connected network with V1 type weights and classify __full fashion mnist__ dataset using __Gradient descent__.

# %%
import numpy as np
import numpy.linalg as la
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from data_fns import load_fashion_mnist
from estimator import classical_weights, V1_inspired_weights, V1_weights_multiple_scales
import pickle

# %%
torch.cuda.set_device(0)
train, train_labels, test, test_labels = load_fashion_mnist('./data/fashion_mnist/')
X_train = torch.from_numpy(train).float().to('cuda')
X_test = torch.from_numpy(test).float().to('cuda')
y_train = torch.from_numpy(train_labels).long().to('cuda')
y_test = torch.from_numpy(test_labels).long().to('cuda')
n, d = X_train.shape

# %%
class V1_net(nn.Module):
    def __init__(self, hidden_size, scale):
        super().__init__()
        self.fc1 = nn.Linear(d, hidden_size)
        self.fc1.weight.data = torch.FloatTensor(V1_inspired_weights(hidden_size, d, t=5, l=2, scale=scale))
        self.output = nn.Linear(hidden_size, 10)
        
    def forward(self, inputs):
        x = torch.relu(self.fc1(inputs))
        return self.output(x)
    
class He_net(nn.Module):
    def __init__(self, hidden_size, scale):
        super().__init__()
        self.fc1 = nn.Linear(d, hidden_size)
        torch.nn.init.kaiming_normal_(self.fc1.weight)
        self.output = nn.Linear(hidden_size, 10)
        
    def forward(self, inputs):
        x = torch.relu(self.fc1(inputs))
        return self.output(x)
    
class RF_net(nn.Module):
    def __init__(self, hidden_size, scale):
        super().__init__()
        self.fc1 = nn.Linear(d, hidden_size)
        self.fc1.weight.data = torch.FloatTensor(classical_weights(hidden_size, d, scale=scale))
        self.output = nn.Linear(hidden_size, 10)
        
    def forward(self, inputs):
        x = torch.relu(self.fc1(inputs))
        return self.output(x)

# %%
def predict(model, X):
    return model(X).data.max(1)[1]

def error(model, X, y):
    y_pred = predict(model, X)
    accuracy = 1.0 * torch.sum(y_pred == y) / len(y)
    return 1 - accuracy

# %%
V1_model = V1_net(100, 2/d)
RF_model = RF_net(100, 2/d)
He_model= He_net(100, 2/d)
print('V1', torch.mean(torch.norm(V1_model.fc1.weight.data, dim=1)))
print('He', torch.mean(torch.norm(He_model.fc1.weight.data, dim=1)))
print('RF', torch.mean(torch.norm(RF_model.fc1.weight.data, dim=1)))
w = torch.mean(torch.norm(RF_model.fc1.weight.data, dim=1))
# Out:
# V1 tensor(1.4182)
# He tensor(1.4097)
# RF tensor(1.4103)

# %%
n_trials, n_epochs = 10, 3001
models = {'V1': V1_net, 'He': He_net}
h_list = [50, 100, 400, 1000]
lr_list = [1e-3, 1e-2, 1e-1, 1e0]

train_err = {m: {h: {lr: np.zeros((n_trials, n_epochs)) for lr in lr_list} for h in h_list} for m in models.keys()}
test_err = {m: {h: {lr: np.zeros((n_trials, n_epochs)) for lr in lr_list} for h in h_list} for m in models.keys()}
loss_list = {m: {h: {lr: np.zeros((n_trials, n_epochs)) for lr in lr_list} for h in h_list} for m in models.keys()}

# %%
scale = 2/d
t, l = 5, 2
loss_func = nn.CrossEntropyLoss()

for h in h_list:
    for lr in lr_list:
        for m, network in models.items():
            for i in range(n_trials):
                model = network(h, scale).to('cuda')
                optim = torch.optim.SGD(model.parameters(), lr=lr)
                for j in range(n_epochs):
                    optim.zero_grad()
                    loss = loss_func(model(X_train), y_train)
                    loss.backward()
                    optim.step()

                    train_err[m][h][lr][i, j] = error(model, X_train, y_train)
                    test_err[m][h][lr][i, j] = error(model, X_test, y_test)
                    loss_list[m][h][lr][i, j] = loss.data

                    if (j % 600 == 0):
                        print('Trial %d, Epoch: %d, %s model, h=%d, lr=%0.5f, Loss=%0.5f, test err=%0.3f' % (i,j, m, h, lr, loss.data, 
                                                                                                  test_err[m][h][lr][i, j]))
results = {'test_err': test_err, 'train_err': train_err, 'loss': loss_list}
with open('results/initialize_fashion_mnist/full_data/clf_t=%0.2f_l=%0.2f.pickle' % (t, l), 'wb') as handle:
    pickle.dump(results, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# Trial 0, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=2.63943, test err=0.866
# Trial 0, Epoch: 600, V1 model, h=50, lr=0.00100, Loss=1.62902, test err=0.485
# Trial 0, Epoch: 1200, V1 model, h=50, lr=0.00100, Loss=1.31281, test err=0.391
# Trial 0, Epoch: 1800, V1 model, h=50, lr=0.00100, Loss=1.14445, test err=0.364
# Trial 0, Epoch: 2400, V1 model, h=50, lr=0.00100, Loss=1.04262, test err=0.346
# Trial 0, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=0.97460, test err=0.339
# Trial 1, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=3.35059, test err=0.912
# Trial 1, Epoch: 600, V1 model, h=50, lr=0.00100, Loss=1.53798, test err=0.444
# Trial 1, Epoch: 1200, V1 model, h=50, lr=0.00100, Loss=1.23642, test err=0.377
# Trial 1, Epoch: 1800, V1 model, h=50, lr=0.00100, Loss=1.08296, test err=0.349
# Trial 1, Epoch: 2400, V1 model, h=50, lr=0.00100, Loss=0.99204, test err=0.332
# Trial 1, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=0.93195, test err=0.319
# Trial 2, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=3.06157, test err=0.840
# Trial 2, Epoch: 600, V1 model, h=50, lr=0.00100, Loss=1.58238, test err=0.469
# Trial 2, Epoch: 1200, V1 model, h=50, lr=0.00100, Loss=1.29496, test err=0.390
# Trial 2, Epoch: 1800, V1 model, h=50, lr=0.00100, Loss=1.14133, test err=0.371
# Trial 2, Epoch: 2400, V1 model, h=50, lr=0.00100, Loss=1.04740, test err=0.363
# Trial 2, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=0.98373, test err=0.353
# Trial 3, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=2.47793, test err=0.893
# Trial 3, Epoch: 600, V1 model, h=50, lr=0.00100, Loss=1.55009, test err=0.469
# Trial 3, Epoch: 1200, V1 model, h=50, lr=0.00100, Loss=1.27572, test err=0.398
# Trial 3, Epoch: 1800, V1 model, h=50, lr=0.00100, Loss=1.13184, test err=0.368
# Trial 3, Epoch: 2400, V1 model, h=50, lr=0.00100, Loss=1.04029, test err=0.351
# Trial 3, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=0.97532, test err=0.337
# Trial 4, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=2.84572, test err=0.892
# Trial 4, Epoch: 600, V1 model, h=50, lr=0.00100, Loss=1.63291, test err=0.430
# Trial 4, Epoch: 1200, V1 model, h=50, lr=0.00100, Loss=1.29837, test err=0.377
# Trial 4, Epoch: 1800, V1 model, h=50, lr=0.00100, Loss=1.12907, test err=0.352
# Trial 4, Epoch: 2400, V1 model, h=50, lr=0.00100, Loss=1.02793, test err=0.331
# Trial 4, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=0.96021, test err=0.319
# Trial 5, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=2.48872, test err=0.813
# Trial 5, Epoch: 600, V1 model, h=50, lr=0.00100, Loss=1.55380, test err=0.410
# Trial 5, Epoch: 1200, V1 model, h=50, lr=0.00100, Loss=1.26236, test err=0.355
# Trial 5, Epoch: 1800, V1 model, h=50, lr=0.00100, Loss=1.10424, test err=0.340
# Trial 5, Epoch: 2400, V1 model, h=50, lr=0.00100, Loss=1.00791, test err=0.329
# Trial 5, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=0.94375, test err=0.321
# Trial 6, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=3.43042, test err=0.893
# Trial 6, Epoch: 600, V1 model, h=50, lr=0.00100, Loss=1.40993, test err=0.401
# Trial 6, Epoch: 1200, V1 model, h=50, lr=0.00100, Loss=1.15901, test err=0.359
# Trial 6, Epoch: 1800, V1 model, h=50, lr=0.00100, Loss=1.03674, test err=0.340
# Trial 6, Epoch: 2400, V1 model, h=50, lr=0.00100, Loss=0.96276, test err=0.323
# Trial 6, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=0.91189, test err=0.311
# Trial 7, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=2.99720, test err=0.807
# Trial 7, Epoch: 600, V1 model, h=50, lr=0.00100, Loss=1.44193, test err=0.429
# Trial 7, Epoch: 1200, V1 model, h=50, lr=0.00100, Loss=1.17007, test err=0.364
# Trial 7, Epoch: 1800, V1 model, h=50, lr=0.00100, Loss=1.03559, test err=0.336
# Trial 7, Epoch: 2400, V1 model, h=50, lr=0.00100, Loss=0.95435, test err=0.318
# Trial 7, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=0.89889, test err=0.304
# Trial 8, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=2.67113, test err=0.892
# Trial 8, Epoch: 600, V1 model, h=50, lr=0.00100, Loss=1.54404, test err=0.463
# Trial 8, Epoch: 1200, V1 model, h=50, lr=0.00100, Loss=1.23853, test err=0.381
# Trial 8, Epoch: 1800, V1 model, h=50, lr=0.00100, Loss=1.08465, test err=0.353
# Trial 8, Epoch: 2400, V1 model, h=50, lr=0.00100, Loss=0.99410, test err=0.340
# Trial 8, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=0.93389, test err=0.326
# Trial 9, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=2.85145, test err=0.996
# Trial 9, Epoch: 600, V1 model, h=50, lr=0.00100, Loss=1.48163, test err=0.396
# Trial 9, Epoch: 1200, V1 model, h=50, lr=0.00100, Loss=1.21143, test err=0.359
# Trial 9, Epoch: 1800, V1 model, h=50, lr=0.00100, Loss=1.07484, test err=0.342
# Trial 9, Epoch: 2400, V1 model, h=50, lr=0.00100, Loss=0.99182, test err=0.328
# Trial 9, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=0.93467, test err=0.316
# Trial 0, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.31155, test err=0.871
# Trial 0, Epoch: 600, He model, h=50, lr=0.00100, Loss=2.00178, test err=0.541
# Trial 0, Epoch: 1200, He model, h=50, lr=0.00100, Loss=1.71112, test err=0.424
# Trial 0, Epoch: 1800, He model, h=50, lr=0.00100, Loss=1.45147, test err=0.386
# Trial 0, Epoch: 2400, He model, h=50, lr=0.00100, Loss=1.26844, test err=0.364
# Trial 0, Epoch: 3000, He model, h=50, lr=0.00100, Loss=1.14260, test err=0.349
# Trial 1, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.31369, test err=0.915
# Trial 1, Epoch: 600, He model, h=50, lr=0.00100, Loss=1.94922, test err=0.492
# Trial 1, Epoch: 1200, He model, h=50, lr=0.00100, Loss=1.64420, test err=0.395
# Trial 1, Epoch: 1800, He model, h=50, lr=0.00100, Loss=1.39962, test err=0.371
# Trial 1, Epoch: 2400, He model, h=50, lr=0.00100, Loss=1.22986, test err=0.361
# Trial 1, Epoch: 3000, He model, h=50, lr=0.00100, Loss=1.11290, test err=0.351
# Trial 2, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.27682, test err=0.904
# Trial 2, Epoch: 600, He model, h=50, lr=0.00100, Loss=1.99440, test err=0.579
# Trial 2, Epoch: 1200, He model, h=50, lr=0.00100, Loss=1.71606, test err=0.456
# Trial 2, Epoch: 1800, He model, h=50, lr=0.00100, Loss=1.46640, test err=0.390
# Trial 2, Epoch: 2400, He model, h=50, lr=0.00100, Loss=1.28208, test err=0.361
# Trial 2, Epoch: 3000, He model, h=50, lr=0.00100, Loss=1.15344, test err=0.345
# Trial 3, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.36979, test err=0.968
# Trial 3, Epoch: 600, He model, h=50, lr=0.00100, Loss=2.08120, test err=0.692
# Trial 3, Epoch: 1200, He model, h=50, lr=0.00100, Loss=1.83836, test err=0.528
# Trial 3, Epoch: 1800, He model, h=50, lr=0.00100, Loss=1.61297, test err=0.431
# Trial 3, Epoch: 2400, He model, h=50, lr=0.00100, Loss=1.42437, test err=0.380
# Trial 3, Epoch: 3000, He model, h=50, lr=0.00100, Loss=1.27632, test err=0.366
# Trial 4, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.34350, test err=0.940
# Trial 4, Epoch: 600, He model, h=50, lr=0.00100, Loss=2.09958, test err=0.685
# Trial 4, Epoch: 1200, He model, h=50, lr=0.00100, Loss=1.84628, test err=0.470
# Trial 4, Epoch: 1800, He model, h=50, lr=0.00100, Loss=1.55883, test err=0.362
# Trial 4, Epoch: 2400, He model, h=50, lr=0.00100, Loss=1.33982, test err=0.349
# Trial 4, Epoch: 3000, He model, h=50, lr=0.00100, Loss=1.19039, test err=0.342
# Trial 5, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.31445, test err=0.849
# Trial 5, Epoch: 600, He model, h=50, lr=0.00100, Loss=1.99431, test err=0.606
# Trial 5, Epoch: 1200, He model, h=50, lr=0.00100, Loss=1.69492, test err=0.459
# Trial 5, Epoch: 1800, He model, h=50, lr=0.00100, Loss=1.44467, test err=0.430
# Trial 5, Epoch: 2400, He model, h=50, lr=0.00100, Loss=1.27287, test err=0.399
# Trial 5, Epoch: 3000, He model, h=50, lr=0.00100, Loss=1.15546, test err=0.376
# Trial 6, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.33731, test err=0.908
# Trial 6, Epoch: 600, He model, h=50, lr=0.00100, Loss=2.06336, test err=0.700
# Trial 6, Epoch: 1200, He model, h=50, lr=0.00100, Loss=1.77535, test err=0.467
# Trial 6, Epoch: 1800, He model, h=50, lr=0.00100, Loss=1.50473, test err=0.384
# Trial 6, Epoch: 2400, He model, h=50, lr=0.00100, Loss=1.29975, test err=0.357
# Trial 6, Epoch: 3000, He model, h=50, lr=0.00100, Loss=1.15746, test err=0.348
# Trial 7, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.36322, test err=0.881
# Trial 7, Epoch: 600, He model, h=50, lr=0.00100, Loss=2.06431, test err=0.635
# Trial 7, Epoch: 1200, He model, h=50, lr=0.00100, Loss=1.80308, test err=0.427
# Trial 7, Epoch: 1800, He model, h=50, lr=0.00100, Loss=1.53852, test err=0.378
# Trial 7, Epoch: 2400, He model, h=50, lr=0.00100, Loss=1.33283, test err=0.362
# Trial 7, Epoch: 3000, He model, h=50, lr=0.00100, Loss=1.18856, test err=0.351
# Trial 8, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.36000, test err=0.934
# Trial 8, Epoch: 600, He model, h=50, lr=0.00100, Loss=2.04461, test err=0.602
# Trial 8, Epoch: 1200, He model, h=50, lr=0.00100, Loss=1.75626, test err=0.504
# Trial 8, Epoch: 1800, He model, h=50, lr=0.00100, Loss=1.49651, test err=0.412
# Trial 8, Epoch: 2400, He model, h=50, lr=0.00100, Loss=1.30586, test err=0.361
# Trial 8, Epoch: 3000, He model, h=50, lr=0.00100, Loss=1.17241, test err=0.338
# Trial 9, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.36778, test err=0.865
# Trial 9, Epoch: 600, He model, h=50, lr=0.00100, Loss=2.02672, test err=0.699
# Trial 9, Epoch: 1200, He model, h=50, lr=0.00100, Loss=1.75706, test err=0.469
# Trial 9, Epoch: 1800, He model, h=50, lr=0.00100, Loss=1.49003, test err=0.369
# Trial 9, Epoch: 2400, He model, h=50, lr=0.00100, Loss=1.29384, test err=0.368
# Trial 9, Epoch: 3000, He model, h=50, lr=0.00100, Loss=1.16253, test err=0.359
# Trial 0, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=2.96121, test err=0.890
# Trial 0, Epoch: 600, V1 model, h=50, lr=0.01000, Loss=0.79418, test err=0.282
# Trial 0, Epoch: 1200, V1 model, h=50, lr=0.01000, Loss=0.67344, test err=0.241
# Trial 0, Epoch: 1800, V1 model, h=50, lr=0.01000, Loss=0.60924, test err=0.218
# Trial 0, Epoch: 2400, V1 model, h=50, lr=0.01000, Loss=0.56779, test err=0.203
# Trial 0, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.53809, test err=0.194
# Trial 1, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=2.78858, test err=0.880
# Trial 1, Epoch: 600, V1 model, h=50, lr=0.01000, Loss=0.77177, test err=0.274
# Trial 1, Epoch: 1200, V1 model, h=50, lr=0.01000, Loss=0.65631, test err=0.236
# Trial 1, Epoch: 1800, V1 model, h=50, lr=0.01000, Loss=0.59572, test err=0.213
# Trial 1, Epoch: 2400, V1 model, h=50, lr=0.01000, Loss=0.55700, test err=0.200
# Trial 1, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.53022, test err=0.189
# Trial 2, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=2.85418, test err=0.889
# Trial 2, Epoch: 600, V1 model, h=50, lr=0.01000, Loss=0.78991, test err=0.277
# Trial 2, Epoch: 1200, V1 model, h=50, lr=0.01000, Loss=0.67024, test err=0.241
# Trial 2, Epoch: 1800, V1 model, h=50, lr=0.01000, Loss=0.60843, test err=0.218
# Trial 2, Epoch: 2400, V1 model, h=50, lr=0.01000, Loss=0.56822, test err=0.204
# Trial 2, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.53934, test err=0.194
# Trial 3, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=2.46413, test err=0.855
# Trial 3, Epoch: 600, V1 model, h=50, lr=0.01000, Loss=0.78239, test err=0.284
# Trial 3, Epoch: 1200, V1 model, h=50, lr=0.01000, Loss=0.66697, test err=0.245
# Trial 3, Epoch: 1800, V1 model, h=50, lr=0.01000, Loss=0.60750, test err=0.220
# Trial 3, Epoch: 2400, V1 model, h=50, lr=0.01000, Loss=0.56853, test err=0.205
# Trial 3, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.54008, test err=0.196
# Trial 4, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=3.12608, test err=0.911
# Trial 4, Epoch: 600, V1 model, h=50, lr=0.01000, Loss=0.82274, test err=0.300
# Trial 4, Epoch: 1200, V1 model, h=50, lr=0.01000, Loss=0.69265, test err=0.256
# Trial 4, Epoch: 1800, V1 model, h=50, lr=0.01000, Loss=0.62369, test err=0.227
# Trial 4, Epoch: 2400, V1 model, h=50, lr=0.01000, Loss=0.57886, test err=0.210
# Trial 4, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.54741, test err=0.200
# Trial 5, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=2.57533, test err=0.893
# Trial 5, Epoch: 600, V1 model, h=50, lr=0.01000, Loss=0.86889, test err=0.300
# Trial 5, Epoch: 1200, V1 model, h=50, lr=0.01000, Loss=0.70521, test err=0.250
# Trial 5, Epoch: 1800, V1 model, h=50, lr=0.01000, Loss=0.63311, test err=0.226
# Trial 5, Epoch: 2400, V1 model, h=50, lr=0.01000, Loss=0.58774, test err=0.210
# Trial 5, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.55550, test err=0.200
# Trial 6, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=2.80982, test err=0.968
# Trial 6, Epoch: 600, V1 model, h=50, lr=0.01000, Loss=0.78013, test err=0.279
# Trial 6, Epoch: 1200, V1 model, h=50, lr=0.01000, Loss=0.66279, test err=0.239
# Trial 6, Epoch: 1800, V1 model, h=50, lr=0.01000, Loss=0.60192, test err=0.214
# Trial 6, Epoch: 2400, V1 model, h=50, lr=0.01000, Loss=0.56251, test err=0.198
# Trial 6, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.53429, test err=0.188
# Trial 7, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=2.84238, test err=0.947
# Trial 7, Epoch: 600, V1 model, h=50, lr=0.01000, Loss=0.78962, test err=0.279
# Trial 7, Epoch: 1200, V1 model, h=50, lr=0.01000, Loss=0.67330, test err=0.246
# Trial 7, Epoch: 1800, V1 model, h=50, lr=0.01000, Loss=0.61385, test err=0.224
# Trial 7, Epoch: 2400, V1 model, h=50, lr=0.01000, Loss=0.57319, test err=0.208
# Trial 7, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.54290, test err=0.195
# Trial 8, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=3.14581, test err=0.923
# Trial 8, Epoch: 600, V1 model, h=50, lr=0.01000, Loss=0.78407, test err=0.282
# Trial 8, Epoch: 1200, V1 model, h=50, lr=0.01000, Loss=0.66635, test err=0.245
# Trial 8, Epoch: 1800, V1 model, h=50, lr=0.01000, Loss=0.60712, test err=0.226
# Trial 8, Epoch: 2400, V1 model, h=50, lr=0.01000, Loss=0.56840, test err=0.210
# Trial 8, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.54039, test err=0.199
# Trial 9, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=2.86267, test err=0.981
# Trial 9, Epoch: 600, V1 model, h=50, lr=0.01000, Loss=0.79137, test err=0.287
# Trial 9, Epoch: 1200, V1 model, h=50, lr=0.01000, Loss=0.67191, test err=0.244
# Trial 9, Epoch: 1800, V1 model, h=50, lr=0.01000, Loss=0.60923, test err=0.220
# Trial 9, Epoch: 2400, V1 model, h=50, lr=0.01000, Loss=0.56875, test err=0.206
# Trial 9, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.54029, test err=0.196
# Trial 0, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.32784, test err=0.873
# Trial 0, Epoch: 600, He model, h=50, lr=0.01000, Loss=0.88349, test err=0.312
# Trial 0, Epoch: 1200, He model, h=50, lr=0.01000, Loss=0.70110, test err=0.251
# Trial 0, Epoch: 1800, He model, h=50, lr=0.01000, Loss=0.61967, test err=0.220
# Trial 0, Epoch: 2400, He model, h=50, lr=0.01000, Loss=0.57135, test err=0.206
# Trial 0, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.53944, test err=0.196
# Trial 1, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.38576, test err=0.831
# Trial 1, Epoch: 600, He model, h=50, lr=0.01000, Loss=0.87315, test err=0.305
# Trial 1, Epoch: 1200, He model, h=50, lr=0.01000, Loss=0.69756, test err=0.252
# Trial 1, Epoch: 1800, He model, h=50, lr=0.01000, Loss=0.62068, test err=0.223
# Trial 1, Epoch: 2400, He model, h=50, lr=0.01000, Loss=0.57463, test err=0.207
# Trial 1, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.54374, test err=0.195
# Trial 2, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.34234, test err=0.890
# Trial 2, Epoch: 600, He model, h=50, lr=0.01000, Loss=0.88124, test err=0.317
# Trial 2, Epoch: 1200, He model, h=50, lr=0.01000, Loss=0.70415, test err=0.256
# Trial 2, Epoch: 1800, He model, h=50, lr=0.01000, Loss=0.62367, test err=0.225
# Trial 2, Epoch: 2400, He model, h=50, lr=0.01000, Loss=0.57510, test err=0.207
# Trial 2, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.54227, test err=0.195
# Trial 3, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.34135, test err=0.848
# Trial 3, Epoch: 600, He model, h=50, lr=0.01000, Loss=0.85596, test err=0.300
# Trial 3, Epoch: 1200, He model, h=50, lr=0.01000, Loss=0.68867, test err=0.246
# Trial 3, Epoch: 1800, He model, h=50, lr=0.01000, Loss=0.61482, test err=0.219
# Trial 3, Epoch: 2400, He model, h=50, lr=0.01000, Loss=0.57081, test err=0.205
# Trial 3, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.54145, test err=0.195
# Trial 4, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.37750, test err=0.895
# Trial 4, Epoch: 600, He model, h=50, lr=0.01000, Loss=0.85913, test err=0.307
# Trial 4, Epoch: 1200, He model, h=50, lr=0.01000, Loss=0.69736, test err=0.255
# Trial 4, Epoch: 1800, He model, h=50, lr=0.01000, Loss=0.62130, test err=0.226
# Trial 4, Epoch: 2400, He model, h=50, lr=0.01000, Loss=0.57443, test err=0.207
# Trial 4, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.54262, test err=0.197
# Trial 5, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.35802, test err=0.895
# Trial 5, Epoch: 600, He model, h=50, lr=0.01000, Loss=0.86451, test err=0.307
# Trial 5, Epoch: 1200, He model, h=50, lr=0.01000, Loss=0.69510, test err=0.244
# Trial 5, Epoch: 1800, He model, h=50, lr=0.01000, Loss=0.61662, test err=0.216
# Trial 5, Epoch: 2400, He model, h=50, lr=0.01000, Loss=0.56976, test err=0.200
# Trial 5, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.53902, test err=0.191
# Trial 6, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.37859, test err=0.913
# Trial 6, Epoch: 600, He model, h=50, lr=0.01000, Loss=0.87180, test err=0.302
# Trial 6, Epoch: 1200, He model, h=50, lr=0.01000, Loss=0.69311, test err=0.242
# Trial 6, Epoch: 1800, He model, h=50, lr=0.01000, Loss=0.61477, test err=0.216
# Trial 6, Epoch: 2400, He model, h=50, lr=0.01000, Loss=0.56966, test err=0.203
# Trial 6, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.53992, test err=0.194
# Trial 7, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.33943, test err=0.912
# Trial 7, Epoch: 600, He model, h=50, lr=0.01000, Loss=0.89522, test err=0.311
# Trial 7, Epoch: 1200, He model, h=50, lr=0.01000, Loss=0.70976, test err=0.253
# Trial 7, Epoch: 1800, He model, h=50, lr=0.01000, Loss=0.62749, test err=0.222
# Trial 7, Epoch: 2400, He model, h=50, lr=0.01000, Loss=0.57749, test err=0.206
# Trial 7, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.54381, test err=0.196
# Trial 8, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.30848, test err=0.887
# Trial 8, Epoch: 600, He model, h=50, lr=0.01000, Loss=0.88133, test err=0.315
# Trial 8, Epoch: 1200, He model, h=50, lr=0.01000, Loss=0.70511, test err=0.258
# Trial 8, Epoch: 1800, He model, h=50, lr=0.01000, Loss=0.62541, test err=0.227
# Trial 8, Epoch: 2400, He model, h=50, lr=0.01000, Loss=0.57644, test err=0.206
# Trial 8, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.54349, test err=0.196
# Trial 9, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.34617, test err=0.913
# Trial 9, Epoch: 600, He model, h=50, lr=0.01000, Loss=0.89065, test err=0.316
# Trial 9, Epoch: 1200, He model, h=50, lr=0.01000, Loss=0.70620, test err=0.256
# Trial 9, Epoch: 1800, He model, h=50, lr=0.01000, Loss=0.62370, test err=0.223
# Trial 9, Epoch: 2400, He model, h=50, lr=0.01000, Loss=0.57477, test err=0.207
# Trial 9, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.54277, test err=0.196
# Trial 0, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=3.48000, test err=0.759
# Trial 0, Epoch: 600, V1 model, h=50, lr=0.10000, Loss=0.47781, test err=0.179
# Trial 0, Epoch: 1200, V1 model, h=50, lr=0.10000, Loss=0.41642, test err=0.157
# Trial 0, Epoch: 1800, V1 model, h=50, lr=0.10000, Loss=0.38721, test err=0.149
# Trial 0, Epoch: 2400, V1 model, h=50, lr=0.10000, Loss=0.36752, test err=0.145
# Trial 0, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.35262, test err=0.139
# Trial 1, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=2.95919, test err=0.885
# Trial 1, Epoch: 600, V1 model, h=50, lr=0.10000, Loss=0.49200, test err=0.185
# Trial 1, Epoch: 1200, V1 model, h=50, lr=0.10000, Loss=0.42058, test err=0.160
# Trial 1, Epoch: 1800, V1 model, h=50, lr=0.10000, Loss=0.39000, test err=0.151
# Trial 1, Epoch: 2400, V1 model, h=50, lr=0.10000, Loss=0.36717, test err=0.147
# Trial 1, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.35332, test err=0.142
# Trial 2, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=2.68495, test err=0.742
# Trial 2, Epoch: 600, V1 model, h=50, lr=0.10000, Loss=0.48995, test err=0.183
# Trial 2, Epoch: 1200, V1 model, h=50, lr=0.10000, Loss=0.42365, test err=0.163
# Trial 2, Epoch: 1800, V1 model, h=50, lr=0.10000, Loss=0.38940, test err=0.150
# Trial 2, Epoch: 2400, V1 model, h=50, lr=0.10000, Loss=0.37459, test err=0.147
# Trial 2, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.34765, test err=0.141
# Trial 3, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=2.37059, test err=0.744
# Trial 3, Epoch: 600, V1 model, h=50, lr=0.10000, Loss=0.48139, test err=0.178
# Trial 3, Epoch: 1200, V1 model, h=50, lr=0.10000, Loss=0.42139, test err=0.162
# Trial 3, Epoch: 1800, V1 model, h=50, lr=0.10000, Loss=0.38628, test err=0.152
# Trial 3, Epoch: 2400, V1 model, h=50, lr=0.10000, Loss=0.36754, test err=0.145
# Trial 3, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.35053, test err=0.141
# Trial 4, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=2.85872, test err=0.815
# Trial 4, Epoch: 600, V1 model, h=50, lr=0.10000, Loss=0.49085, test err=0.181
# Trial 4, Epoch: 1200, V1 model, h=50, lr=0.10000, Loss=0.41743, test err=0.157
# Trial 4, Epoch: 1800, V1 model, h=50, lr=0.10000, Loss=0.38544, test err=0.148
# Trial 4, Epoch: 2400, V1 model, h=50, lr=0.10000, Loss=0.36383, test err=0.143
# Trial 4, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.34857, test err=0.139
# Trial 5, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=3.58170, test err=0.850
# Trial 5, Epoch: 600, V1 model, h=50, lr=0.10000, Loss=0.48004, test err=0.179
# Trial 5, Epoch: 1200, V1 model, h=50, lr=0.10000, Loss=0.41490, test err=0.158
# Trial 5, Epoch: 1800, V1 model, h=50, lr=0.10000, Loss=0.38540, test err=0.150
# Trial 5, Epoch: 2400, V1 model, h=50, lr=0.10000, Loss=0.36530, test err=0.145
# Trial 5, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.35473, test err=0.143
# Trial 6, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=3.06405, test err=0.788
# Trial 6, Epoch: 600, V1 model, h=50, lr=0.10000, Loss=0.48001, test err=0.175
# Trial 6, Epoch: 1200, V1 model, h=50, lr=0.10000, Loss=0.42226, test err=0.158
# Trial 6, Epoch: 1800, V1 model, h=50, lr=0.10000, Loss=0.38850, test err=0.149
# Trial 6, Epoch: 2400, V1 model, h=50, lr=0.10000, Loss=0.36438, test err=0.143
# Trial 6, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.34768, test err=0.141
# Trial 7, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=2.53367, test err=0.779
# Trial 7, Epoch: 600, V1 model, h=50, lr=0.10000, Loss=0.48860, test err=0.181
# Trial 7, Epoch: 1200, V1 model, h=50, lr=0.10000, Loss=0.42687, test err=0.161
# Trial 7, Epoch: 1800, V1 model, h=50, lr=0.10000, Loss=0.39277, test err=0.151
# Trial 7, Epoch: 2400, V1 model, h=50, lr=0.10000, Loss=0.37190, test err=0.145
# Trial 7, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.35633, test err=0.141
# Trial 8, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=2.94271, test err=0.889
# Trial 8, Epoch: 600, V1 model, h=50, lr=0.10000, Loss=0.48602, test err=0.181
# Trial 8, Epoch: 1200, V1 model, h=50, lr=0.10000, Loss=0.42156, test err=0.162
# Trial 8, Epoch: 1800, V1 model, h=50, lr=0.10000, Loss=0.39003, test err=0.150
# Trial 8, Epoch: 2400, V1 model, h=50, lr=0.10000, Loss=0.36695, test err=0.143
# Trial 8, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.35028, test err=0.137
# Trial 9, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=2.83605, test err=0.786
# Trial 9, Epoch: 600, V1 model, h=50, lr=0.10000, Loss=0.47844, test err=0.181
# Trial 9, Epoch: 1200, V1 model, h=50, lr=0.10000, Loss=0.41512, test err=0.161
# Trial 9, Epoch: 1800, V1 model, h=50, lr=0.10000, Loss=0.38157, test err=0.149
# Trial 9, Epoch: 2400, V1 model, h=50, lr=0.10000, Loss=0.36103, test err=0.142
# Trial 9, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.34496, test err=0.142
# Trial 0, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.33155, test err=0.883
# Trial 0, Epoch: 600, He model, h=50, lr=0.10000, Loss=0.48964, test err=0.181
# Trial 0, Epoch: 1200, He model, h=50, lr=0.10000, Loss=0.42805, test err=0.161
# Trial 0, Epoch: 1800, He model, h=50, lr=0.10000, Loss=0.39124, test err=0.152
# Trial 0, Epoch: 2400, He model, h=50, lr=0.10000, Loss=0.37137, test err=0.149
# Trial 0, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.35634, test err=0.146
# Trial 1, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.40520, test err=0.903
# Trial 1, Epoch: 600, He model, h=50, lr=0.10000, Loss=0.48608, test err=0.180
# Trial 1, Epoch: 1200, He model, h=50, lr=0.10000, Loss=0.42353, test err=0.163
# Trial 1, Epoch: 1800, He model, h=50, lr=0.10000, Loss=0.39241, test err=0.153
# Trial 1, Epoch: 2400, He model, h=50, lr=0.10000, Loss=0.37458, test err=0.149
# Trial 1, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.35450, test err=0.141
# Trial 2, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.31032, test err=0.856
# Trial 2, Epoch: 600, He model, h=50, lr=0.10000, Loss=0.49075, test err=0.185
# Trial 2, Epoch: 1200, He model, h=50, lr=0.10000, Loss=0.42921, test err=0.165
# Trial 2, Epoch: 1800, He model, h=50, lr=0.10000, Loss=0.39414, test err=0.154
# Trial 2, Epoch: 2400, He model, h=50, lr=0.10000, Loss=0.37118, test err=0.147
# Trial 2, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.35840, test err=0.145
# Trial 3, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.32811, test err=0.882
# Trial 3, Epoch: 600, He model, h=50, lr=0.10000, Loss=0.48960, test err=0.183
# Trial 3, Epoch: 1200, He model, h=50, lr=0.10000, Loss=0.42557, test err=0.165
# Trial 3, Epoch: 1800, He model, h=50, lr=0.10000, Loss=0.39290, test err=0.154
# Trial 3, Epoch: 2400, He model, h=50, lr=0.10000, Loss=0.37152, test err=0.148
# Trial 3, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.35469, test err=0.144
# Trial 4, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.32925, test err=0.861
# Trial 4, Epoch: 600, He model, h=50, lr=0.10000, Loss=0.49122, test err=0.185
# Trial 4, Epoch: 1200, He model, h=50, lr=0.10000, Loss=0.42847, test err=0.166
# Trial 4, Epoch: 1800, He model, h=50, lr=0.10000, Loss=0.39356, test err=0.154
# Trial 4, Epoch: 2400, He model, h=50, lr=0.10000, Loss=0.37500, test err=0.147
# Trial 4, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.35566, test err=0.143
# Trial 5, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.30120, test err=0.827
# Trial 5, Epoch: 600, He model, h=50, lr=0.10000, Loss=0.49348, test err=0.186
# Trial 5, Epoch: 1200, He model, h=50, lr=0.10000, Loss=0.42865, test err=0.166
# Trial 5, Epoch: 1800, He model, h=50, lr=0.10000, Loss=0.39864, test err=0.156
# Trial 5, Epoch: 2400, He model, h=50, lr=0.10000, Loss=0.37606, test err=0.150
# Trial 5, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.35991, test err=0.147
# Trial 6, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.35658, test err=0.826
# Trial 6, Epoch: 600, He model, h=50, lr=0.10000, Loss=0.48926, test err=0.184
# Trial 6, Epoch: 1200, He model, h=50, lr=0.10000, Loss=0.43057, test err=0.164
# Trial 6, Epoch: 1800, He model, h=50, lr=0.10000, Loss=0.39687, test err=0.154
# Trial 6, Epoch: 2400, He model, h=50, lr=0.10000, Loss=0.37834, test err=0.153
# Trial 6, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.35788, test err=0.146
# Trial 7, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.36882, test err=0.895
# Trial 7, Epoch: 600, He model, h=50, lr=0.10000, Loss=0.49201, test err=0.185
# Trial 7, Epoch: 1200, He model, h=50, lr=0.10000, Loss=0.42787, test err=0.166
# Trial 7, Epoch: 1800, He model, h=50, lr=0.10000, Loss=0.40231, test err=0.160
# Trial 7, Epoch: 2400, He model, h=50, lr=0.10000, Loss=0.37489, test err=0.151
# Trial 7, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.35743, test err=0.146
# Trial 8, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.33053, test err=0.882
# Trial 8, Epoch: 600, He model, h=50, lr=0.10000, Loss=0.49118, test err=0.185
# Trial 8, Epoch: 1200, He model, h=50, lr=0.10000, Loss=0.42855, test err=0.166
# Trial 8, Epoch: 1800, He model, h=50, lr=0.10000, Loss=0.39294, test err=0.155
# Trial 8, Epoch: 2400, He model, h=50, lr=0.10000, Loss=0.37102, test err=0.149
# Trial 8, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.35451, test err=0.144
# Trial 9, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.40345, test err=0.852
# Trial 9, Epoch: 600, He model, h=50, lr=0.10000, Loss=0.48849, test err=0.183
# Trial 9, Epoch: 1200, He model, h=50, lr=0.10000, Loss=0.42531, test err=0.162
# Trial 9, Epoch: 1800, He model, h=50, lr=0.10000, Loss=0.39656, test err=0.155
# Trial 9, Epoch: 2400, He model, h=50, lr=0.10000, Loss=0.37220, test err=0.148
# Trial 9, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.35506, test err=0.142
# Trial 0, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=2.90054, test err=0.804
# Trial 0, Epoch: 600, V1 model, h=50, lr=1.00000, Loss=1.52108, test err=0.568
# Trial 0, Epoch: 1200, V1 model, h=50, lr=1.00000, Loss=0.61170, test err=0.221
# Trial 0, Epoch: 1800, V1 model, h=50, lr=1.00000, Loss=0.68062, test err=0.304
# Trial 0, Epoch: 2400, V1 model, h=50, lr=1.00000, Loss=0.81432, test err=0.331
# Trial 0, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=2.30236, test err=0.900
# Trial 1, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=2.61526, test err=0.770
# Trial 1, Epoch: 600, V1 model, h=50, lr=1.00000, Loss=0.61347, test err=0.249
# Trial 1, Epoch: 1200, V1 model, h=50, lr=1.00000, Loss=0.73573, test err=0.294
# Trial 1, Epoch: 1800, V1 model, h=50, lr=1.00000, Loss=0.92985, test err=0.426
# Trial 1, Epoch: 2400, V1 model, h=50, lr=1.00000, Loss=1.23434, test err=0.548
# Trial 1, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=0.64786, test err=0.282
# Trial 2, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=2.74065, test err=0.797
# Trial 2, Epoch: 600, V1 model, h=50, lr=1.00000, Loss=0.64686, test err=0.266
# Trial 2, Epoch: 1200, V1 model, h=50, lr=1.00000, Loss=0.45281, test err=0.171
# Trial 2, Epoch: 1800, V1 model, h=50, lr=1.00000, Loss=0.40618, test err=0.166
# Trial 2, Epoch: 2400, V1 model, h=50, lr=1.00000, Loss=0.38564, test err=0.164
# Trial 2, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=0.38553, test err=0.162
# Trial 3, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=3.01664, test err=0.662
# Trial 3, Epoch: 600, V1 model, h=50, lr=1.00000, Loss=1.95855, test err=0.882
# Trial 3, Epoch: 1200, V1 model, h=50, lr=1.00000, Loss=1.70361, test err=0.635
# Trial 3, Epoch: 1800, V1 model, h=50, lr=1.00000, Loss=1.34903, test err=0.524
# Trial 3, Epoch: 2400, V1 model, h=50, lr=1.00000, Loss=1.49862, test err=0.519
# Trial 3, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=2.01954, test err=0.738
# Trial 4, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=2.63156, test err=0.799
# Trial 4, Epoch: 600, V1 model, h=50, lr=1.00000, Loss=1.73285, test err=0.713
# Trial 4, Epoch: 1200, V1 model, h=50, lr=1.00000, Loss=1.68320, test err=0.749
# Trial 4, Epoch: 1800, V1 model, h=50, lr=1.00000, Loss=1.94364, test err=0.751
# Trial 4, Epoch: 2400, V1 model, h=50, lr=1.00000, Loss=2.40183, test err=0.900
# Trial 4, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=1.77559, test err=0.711
# Trial 5, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=2.62127, test err=0.668
# Trial 5, Epoch: 600, V1 model, h=50, lr=1.00000, Loss=0.63546, test err=0.258
# Trial 5, Epoch: 1200, V1 model, h=50, lr=1.00000, Loss=0.46055, test err=0.181
# Trial 5, Epoch: 1800, V1 model, h=50, lr=1.00000, Loss=1.00259, test err=0.396
# Trial 5, Epoch: 2400, V1 model, h=50, lr=1.00000, Loss=1.26783, test err=0.512
# Trial 5, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=1.67656, test err=0.606
# Trial 6, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=2.71330, test err=0.808
# Trial 6, Epoch: 600, V1 model, h=50, lr=1.00000, Loss=2.21208, test err=0.833
# Trial 6, Epoch: 1200, V1 model, h=50, lr=1.00000, Loss=0.68061, test err=0.296
# Trial 6, Epoch: 1800, V1 model, h=50, lr=1.00000, Loss=0.48921, test err=0.187
# Trial 6, Epoch: 2400, V1 model, h=50, lr=1.00000, Loss=0.50653, test err=0.173
# Trial 6, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=1.48464, test err=0.580
# Trial 7, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=2.99398, test err=0.741
# Trial 7, Epoch: 600, V1 model, h=50, lr=1.00000, Loss=2.16202, test err=0.803
# Trial 7, Epoch: 1200, V1 model, h=50, lr=1.00000, Loss=2.31712, test err=0.900
# Trial 7, Epoch: 1800, V1 model, h=50, lr=1.00000, Loss=2.13673, test err=0.796
# Trial 7, Epoch: 2400, V1 model, h=50, lr=1.00000, Loss=2.30248, test err=0.900
# Trial 7, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=2.36526, test err=0.899
# Trial 8, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=2.82712, test err=0.818
# Trial 8, Epoch: 600, V1 model, h=50, lr=1.00000, Loss=2.30273, test err=0.900
# Trial 8, Epoch: 1200, V1 model, h=50, lr=1.00000, Loss=2.30255, test err=0.899
# Trial 8, Epoch: 1800, V1 model, h=50, lr=1.00000, Loss=2.30152, test err=0.898
# Trial 8, Epoch: 2400, V1 model, h=50, lr=1.00000, Loss=2.03785, test err=0.866
# Trial 8, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=2.30239, test err=0.900
# Trial 9, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=2.50611, test err=0.839
# Trial 9, Epoch: 600, V1 model, h=50, lr=1.00000, Loss=0.89378, test err=0.400
# Trial 9, Epoch: 1200, V1 model, h=50, lr=1.00000, Loss=1.45589, test err=0.569
# Trial 9, Epoch: 1800, V1 model, h=50, lr=1.00000, Loss=0.78878, test err=0.287
# Trial 9, Epoch: 2400, V1 model, h=50, lr=1.00000, Loss=1.63223, test err=0.627
# Trial 9, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=1.26180, test err=0.524
# Trial 0, Epoch: 0, He model, h=50, lr=1.00000, Loss=2.33627, test err=0.717
# Trial 0, Epoch: 600, He model, h=50, lr=1.00000, Loss=1.98417, test err=0.760
# Trial 0, Epoch: 1200, He model, h=50, lr=1.00000, Loss=2.02380, test err=0.804
# Trial 0, Epoch: 1800, He model, h=50, lr=1.00000, Loss=2.30253, test err=0.900
# Trial 0, Epoch: 2400, He model, h=50, lr=1.00000, Loss=2.30176, test err=0.899
# Trial 0, Epoch: 3000, He model, h=50, lr=1.00000, Loss=2.30235, test err=0.900
# Trial 1, Epoch: 0, He model, h=50, lr=1.00000, Loss=2.34331, test err=0.662
# Trial 1, Epoch: 600, He model, h=50, lr=1.00000, Loss=0.79995, test err=0.389
# Trial 1, Epoch: 1200, He model, h=50, lr=1.00000, Loss=1.33196, test err=0.577
# Trial 1, Epoch: 1800, He model, h=50, lr=1.00000, Loss=2.09168, test err=0.726
# Trial 1, Epoch: 2400, He model, h=50, lr=1.00000, Loss=1.52465, test err=0.642
# Trial 1, Epoch: 3000, He model, h=50, lr=1.00000, Loss=1.85301, test err=0.749
# Trial 2, Epoch: 0, He model, h=50, lr=1.00000, Loss=2.37899, test err=0.900
# Trial 2, Epoch: 600, He model, h=50, lr=1.00000, Loss=2.27556, test err=0.900
# Trial 2, Epoch: 1200, He model, h=50, lr=1.00000, Loss=2.30246, test err=0.900
# Trial 2, Epoch: 1800, He model, h=50, lr=1.00000, Loss=2.30162, test err=0.900
# Trial 2, Epoch: 2400, He model, h=50, lr=1.00000, Loss=1.88296, test err=0.799
# Trial 2, Epoch: 3000, He model, h=50, lr=1.00000, Loss=1.79704, test err=0.802
# Trial 3, Epoch: 0, He model, h=50, lr=1.00000, Loss=2.27166, test err=0.575
# Trial 3, Epoch: 600, He model, h=50, lr=1.00000, Loss=1.24676, test err=0.540
# Trial 3, Epoch: 1200, He model, h=50, lr=1.00000, Loss=1.55366, test err=0.688
# Trial 3, Epoch: 1800, He model, h=50, lr=1.00000, Loss=2.41393, test err=0.900
# Trial 3, Epoch: 2400, He model, h=50, lr=1.00000, Loss=2.27213, test err=0.868
# Trial 3, Epoch: 3000, He model, h=50, lr=1.00000, Loss=1.63663, test err=0.656
# Trial 4, Epoch: 0, He model, h=50, lr=1.00000, Loss=2.31837, test err=0.710
# Trial 4, Epoch: 600, He model, h=50, lr=1.00000, Loss=2.30308, test err=0.900
# Trial 4, Epoch: 1200, He model, h=50, lr=1.00000, Loss=2.30251, test err=0.900
# Trial 4, Epoch: 1800, He model, h=50, lr=1.00000, Loss=2.30237, test err=0.900
# Trial 4, Epoch: 2400, He model, h=50, lr=1.00000, Loss=2.30087, test err=0.898
# Trial 4, Epoch: 3000, He model, h=50, lr=1.00000, Loss=2.30262, test err=0.900
# Trial 5, Epoch: 0, He model, h=50, lr=1.00000, Loss=2.33911, test err=0.781
# Trial 5, Epoch: 600, He model, h=50, lr=1.00000, Loss=2.07275, test err=0.792
# Trial 5, Epoch: 1200, He model, h=50, lr=1.00000, Loss=2.22263, test err=0.737
# Trial 5, Epoch: 1800, He model, h=50, lr=1.00000, Loss=1.91977, test err=0.714
# Trial 5, Epoch: 2400, He model, h=50, lr=1.00000, Loss=2.25376, test err=0.762
# Trial 5, Epoch: 3000, He model, h=50, lr=1.00000, Loss=2.30339, test err=0.900
# Trial 6, Epoch: 0, He model, h=50, lr=1.00000, Loss=2.36306, test err=0.638
# Trial 6, Epoch: 600, He model, h=50, lr=1.00000, Loss=2.24085, test err=0.798
# Trial 6, Epoch: 1200, He model, h=50, lr=1.00000, Loss=0.89274, test err=0.401
# Trial 6, Epoch: 1800, He model, h=50, lr=1.00000, Loss=2.05386, test err=0.796
# Trial 6, Epoch: 2400, He model, h=50, lr=1.00000, Loss=2.00580, test err=0.789
# Trial 6, Epoch: 3000, He model, h=50, lr=1.00000, Loss=1.46994, test err=0.673
# Trial 7, Epoch: 0, He model, h=50, lr=1.00000, Loss=2.33211, test err=0.763
# Trial 7, Epoch: 600, He model, h=50, lr=1.00000, Loss=1.55201, test err=0.707
# Trial 7, Epoch: 1200, He model, h=50, lr=1.00000, Loss=1.64476, test err=0.613
# Trial 7, Epoch: 1800, He model, h=50, lr=1.00000, Loss=2.06611, test err=0.786
# Trial 7, Epoch: 2400, He model, h=50, lr=1.00000, Loss=2.21831, test err=0.827
# Trial 7, Epoch: 3000, He model, h=50, lr=1.00000, Loss=2.30263, test err=0.900
# Trial 8, Epoch: 0, He model, h=50, lr=1.00000, Loss=2.31958, test err=0.792
# Trial 8, Epoch: 600, He model, h=50, lr=1.00000, Loss=2.17741, test err=0.816
# Trial 8, Epoch: 1200, He model, h=50, lr=1.00000, Loss=1.29762, test err=0.539
# Trial 8, Epoch: 1800, He model, h=50, lr=1.00000, Loss=2.30256, test err=0.900
# Trial 8, Epoch: 2400, He model, h=50, lr=1.00000, Loss=2.30220, test err=0.900
# Trial 8, Epoch: 3000, He model, h=50, lr=1.00000, Loss=1.53711, test err=0.642
# Trial 9, Epoch: 0, He model, h=50, lr=1.00000, Loss=2.30704, test err=0.734
# Trial 9, Epoch: 600, He model, h=50, lr=1.00000, Loss=1.52232, test err=0.730
# Trial 9, Epoch: 1200, He model, h=50, lr=1.00000, Loss=1.73461, test err=0.649
# Trial 9, Epoch: 1800, He model, h=50, lr=1.00000, Loss=2.30258, test err=0.900
# Trial 9, Epoch: 2400, He model, h=50, lr=1.00000, Loss=2.30255, test err=0.900
# Trial 9, Epoch: 3000, He model, h=50, lr=1.00000, Loss=2.29719, test err=0.900
# Trial 0, Epoch: 0, V1 model, h=100, lr=0.00100, Loss=3.08486, test err=0.885
# Trial 0, Epoch: 600, V1 model, h=100, lr=0.00100, Loss=1.26602, test err=0.389
# Trial 0, Epoch: 1200, V1 model, h=100, lr=0.00100, Loss=1.04210, test err=0.349
# Trial 0, Epoch: 1800, V1 model, h=100, lr=0.00100, Loss=0.94099, test err=0.331
# Trial 0, Epoch: 2400, V1 model, h=100, lr=0.00100, Loss=0.88042, test err=0.315
# Trial 0, Epoch: 3000, V1 model, h=100, lr=0.00100, Loss=0.83833, test err=0.301
# Trial 1, Epoch: 0, V1 model, h=100, lr=0.00100, Loss=2.90185, test err=0.900
# Trial 1, Epoch: 600, V1 model, h=100, lr=0.00100, Loss=1.31145, test err=0.370
# Trial 1, Epoch: 1200, V1 model, h=100, lr=0.00100, Loss=1.07124, test err=0.338
# Trial 1, Epoch: 1800, V1 model, h=100, lr=0.00100, Loss=0.96079, test err=0.319
# Trial 1, Epoch: 2400, V1 model, h=100, lr=0.00100, Loss=0.89473, test err=0.307
# Trial 1, Epoch: 3000, V1 model, h=100, lr=0.00100, Loss=0.84928, test err=0.295
# Trial 2, Epoch: 0, V1 model, h=100, lr=0.00100, Loss=2.75687, test err=0.969
# Trial 2, Epoch: 600, V1 model, h=100, lr=0.00100, Loss=1.44132, test err=0.434
# Trial 2, Epoch: 1200, V1 model, h=100, lr=0.00100, Loss=1.14625, test err=0.377
# Trial 2, Epoch: 1800, V1 model, h=100, lr=0.00100, Loss=1.01506, test err=0.353
# Trial 2, Epoch: 2400, V1 model, h=100, lr=0.00100, Loss=0.93911, test err=0.334
# Trial 2, Epoch: 3000, V1 model, h=100, lr=0.00100, Loss=0.88809, test err=0.320
# Trial 3, Epoch: 0, V1 model, h=100, lr=0.00100, Loss=3.73549, test err=0.920
# Trial 3, Epoch: 600, V1 model, h=100, lr=0.00100, Loss=1.26702, test err=0.377
# Trial 3, Epoch: 1200, V1 model, h=100, lr=0.00100, Loss=1.02870, test err=0.339
# Trial 3, Epoch: 1800, V1 model, h=100, lr=0.00100, Loss=0.92542, test err=0.316
# Trial 3, Epoch: 2400, V1 model, h=100, lr=0.00100, Loss=0.86491, test err=0.300
# Trial 3, Epoch: 3000, V1 model, h=100, lr=0.00100, Loss=0.82349, test err=0.289
# Trial 4, Epoch: 0, V1 model, h=100, lr=0.00100, Loss=2.59944, test err=0.933
# Trial 4, Epoch: 600, V1 model, h=100, lr=0.00100, Loss=1.29504, test err=0.387
# Trial 4, Epoch: 1200, V1 model, h=100, lr=0.00100, Loss=1.05386, test err=0.354
# Trial 4, Epoch: 1800, V1 model, h=100, lr=0.00100, Loss=0.94665, test err=0.332
# Trial 4, Epoch: 2400, V1 model, h=100, lr=0.00100, Loss=0.88272, test err=0.316
# Trial 4, Epoch: 3000, V1 model, h=100, lr=0.00100, Loss=0.83858, test err=0.302
# Trial 5, Epoch: 0, V1 model, h=100, lr=0.00100, Loss=2.53251, test err=0.896
# Trial 5, Epoch: 600, V1 model, h=100, lr=0.00100, Loss=1.29260, test err=0.395
# Trial 5, Epoch: 1200, V1 model, h=100, lr=0.00100, Loss=1.06827, test err=0.349
# Trial 5, Epoch: 1800, V1 model, h=100, lr=0.00100, Loss=0.96714, test err=0.326
# Trial 5, Epoch: 2400, V1 model, h=100, lr=0.00100, Loss=0.90633, test err=0.314
# Trial 5, Epoch: 3000, V1 model, h=100, lr=0.00100, Loss=0.86400, test err=0.306
# Trial 6, Epoch: 0, V1 model, h=100, lr=0.00100, Loss=2.72608, test err=0.832
# Trial 6, Epoch: 600, V1 model, h=100, lr=0.00100, Loss=1.29949, test err=0.377
# Trial 6, Epoch: 1200, V1 model, h=100, lr=0.00100, Loss=1.06650, test err=0.345
# Trial 6, Epoch: 1800, V1 model, h=100, lr=0.00100, Loss=0.96162, test err=0.329
# Trial 6, Epoch: 2400, V1 model, h=100, lr=0.00100, Loss=0.89876, test err=0.311
# Trial 6, Epoch: 3000, V1 model, h=100, lr=0.00100, Loss=0.85544, test err=0.300
# Trial 7, Epoch: 0, V1 model, h=100, lr=0.00100, Loss=2.57144, test err=0.956
# Trial 7, Epoch: 600, V1 model, h=100, lr=0.00100, Loss=1.33442, test err=0.377
# Trial 7, Epoch: 1200, V1 model, h=100, lr=0.00100, Loss=1.09416, test err=0.342
# Trial 7, Epoch: 1800, V1 model, h=100, lr=0.00100, Loss=0.97921, test err=0.319
# Trial 7, Epoch: 2400, V1 model, h=100, lr=0.00100, Loss=0.91005, test err=0.302
# Trial 7, Epoch: 3000, V1 model, h=100, lr=0.00100, Loss=0.86265, test err=0.293
# Trial 8, Epoch: 0, V1 model, h=100, lr=0.00100, Loss=2.53736, test err=0.846
# Trial 8, Epoch: 600, V1 model, h=100, lr=0.00100, Loss=1.29537, test err=0.376
# Trial 8, Epoch: 1200, V1 model, h=100, lr=0.00100, Loss=1.06188, test err=0.349
# Trial 8, Epoch: 1800, V1 model, h=100, lr=0.00100, Loss=0.95580, test err=0.328
# Trial 8, Epoch: 2400, V1 model, h=100, lr=0.00100, Loss=0.89326, test err=0.317
# Trial 8, Epoch: 3000, V1 model, h=100, lr=0.00100, Loss=0.85060, test err=0.304
# Trial 9, Epoch: 0, V1 model, h=100, lr=0.00100, Loss=2.97815, test err=0.900
# Trial 9, Epoch: 600, V1 model, h=100, lr=0.00100, Loss=1.29630, test err=0.382
# Trial 9, Epoch: 1200, V1 model, h=100, lr=0.00100, Loss=1.06080, test err=0.345
# Trial 9, Epoch: 1800, V1 model, h=100, lr=0.00100, Loss=0.95192, test err=0.326
# Trial 9, Epoch: 2400, V1 model, h=100, lr=0.00100, Loss=0.88580, test err=0.313
# Trial 9, Epoch: 3000, V1 model, h=100, lr=0.00100, Loss=0.83989, test err=0.301
# Trial 0, Epoch: 0, He model, h=100, lr=0.00100, Loss=2.31668, test err=0.901
# Trial 0, Epoch: 600, He model, h=100, lr=0.00100, Loss=1.94686, test err=0.535
# Trial 0, Epoch: 1200, He model, h=100, lr=0.00100, Loss=1.62632, test err=0.412
# Trial 0, Epoch: 1800, He model, h=100, lr=0.00100, Loss=1.37511, test err=0.368
# Trial 0, Epoch: 2400, He model, h=100, lr=0.00100, Loss=1.20503, test err=0.352
# Trial 0, Epoch: 3000, He model, h=100, lr=0.00100, Loss=1.08990, test err=0.341
# Trial 1, Epoch: 0, He model, h=100, lr=0.00100, Loss=2.36589, test err=0.936
# Trial 1, Epoch: 600, He model, h=100, lr=0.00100, Loss=2.01421, test err=0.541
# Trial 1, Epoch: 1200, He model, h=100, lr=0.00100, Loss=1.69529, test err=0.401
# Trial 1, Epoch: 1800, He model, h=100, lr=0.00100, Loss=1.42265, test err=0.368
# Trial 1, Epoch: 2400, He model, h=100, lr=0.00100, Loss=1.23213, test err=0.352
# Trial 1, Epoch: 3000, He model, h=100, lr=0.00100, Loss=1.10530, test err=0.341
# Trial 2, Epoch: 0, He model, h=100, lr=0.00100, Loss=2.31936, test err=0.897
# Trial 2, Epoch: 600, He model, h=100, lr=0.00100, Loss=1.95304, test err=0.489
# Trial 2, Epoch: 1200, He model, h=100, lr=0.00100, Loss=1.63074, test err=0.406
# Trial 2, Epoch: 1800, He model, h=100, lr=0.00100, Loss=1.37561, test err=0.376
# Trial 2, Epoch: 2400, He model, h=100, lr=0.00100, Loss=1.20444, test err=0.358
# Trial 2, Epoch: 3000, He model, h=100, lr=0.00100, Loss=1.08998, test err=0.349
# Trial 3, Epoch: 0, He model, h=100, lr=0.00100, Loss=2.36674, test err=0.902
# Trial 3, Epoch: 600, He model, h=100, lr=0.00100, Loss=2.01425, test err=0.471
# Trial 3, Epoch: 1200, He model, h=100, lr=0.00100, Loss=1.69150, test err=0.369
# Trial 3, Epoch: 1800, He model, h=100, lr=0.00100, Loss=1.41693, test err=0.351
# Trial 3, Epoch: 2400, He model, h=100, lr=0.00100, Loss=1.22731, test err=0.339
# Trial 3, Epoch: 3000, He model, h=100, lr=0.00100, Loss=1.10080, test err=0.333
# Trial 4, Epoch: 0, He model, h=100, lr=0.00100, Loss=2.33473, test err=0.888
# Trial 4, Epoch: 600, He model, h=100, lr=0.00100, Loss=1.94094, test err=0.471
# Trial 4, Epoch: 1200, He model, h=100, lr=0.00100, Loss=1.62083, test err=0.384
# Trial 4, Epoch: 1800, He model, h=100, lr=0.00100, Loss=1.37240, test err=0.359
# Trial 4, Epoch: 2400, He model, h=100, lr=0.00100, Loss=1.20414, test err=0.347
# Trial 4, Epoch: 3000, He model, h=100, lr=0.00100, Loss=1.08997, test err=0.338
# Trial 5, Epoch: 0, He model, h=100, lr=0.00100, Loss=2.29638, test err=0.882
# Trial 5, Epoch: 600, He model, h=100, lr=0.00100, Loss=1.94574, test err=0.522
# Trial 5, Epoch: 1200, He model, h=100, lr=0.00100, Loss=1.63491, test err=0.386
# Trial 5, Epoch: 1800, He model, h=100, lr=0.00100, Loss=1.38448, test err=0.363
# Trial 5, Epoch: 2400, He model, h=100, lr=0.00100, Loss=1.20785, test err=0.349
# Trial 5, Epoch: 3000, He model, h=100, lr=0.00100, Loss=1.08722, test err=0.335
# Trial 6, Epoch: 0, He model, h=100, lr=0.00100, Loss=2.37902, test err=0.915
# Trial 6, Epoch: 600, He model, h=100, lr=0.00100, Loss=2.00580, test err=0.548
# Trial 6, Epoch: 1200, He model, h=100, lr=0.00100, Loss=1.69296, test err=0.387
# Trial 6, Epoch: 1800, He model, h=100, lr=0.00100, Loss=1.42173, test err=0.352
# Trial 6, Epoch: 2400, He model, h=100, lr=0.00100, Loss=1.22925, test err=0.341
# Trial 6, Epoch: 3000, He model, h=100, lr=0.00100, Loss=1.09920, test err=0.331
# Trial 7, Epoch: 0, He model, h=100, lr=0.00100, Loss=2.32109, test err=0.899
# Trial 7, Epoch: 600, He model, h=100, lr=0.00100, Loss=2.02657, test err=0.545
# Trial 7, Epoch: 1200, He model, h=100, lr=0.00100, Loss=1.73028, test err=0.398
# Trial 7, Epoch: 1800, He model, h=100, lr=0.00100, Loss=1.45769, test err=0.365
# Trial 7, Epoch: 2400, He model, h=100, lr=0.00100, Loss=1.25927, test err=0.351
# Trial 7, Epoch: 3000, He model, h=100, lr=0.00100, Loss=1.12418, test err=0.343
# Trial 8, Epoch: 0, He model, h=100, lr=0.00100, Loss=2.28729, test err=0.877
# Trial 8, Epoch: 600, He model, h=100, lr=0.00100, Loss=1.96273, test err=0.510
# Trial 8, Epoch: 1200, He model, h=100, lr=0.00100, Loss=1.64906, test err=0.396
# Trial 8, Epoch: 1800, He model, h=100, lr=0.00100, Loss=1.39982, test err=0.368
# Trial 8, Epoch: 2400, He model, h=100, lr=0.00100, Loss=1.22489, test err=0.349
# Trial 8, Epoch: 3000, He model, h=100, lr=0.00100, Loss=1.10408, test err=0.340
# Trial 9, Epoch: 0, He model, h=100, lr=0.00100, Loss=2.33647, test err=0.900
# Trial 9, Epoch: 600, He model, h=100, lr=0.00100, Loss=1.95475, test err=0.504
# Trial 9, Epoch: 1200, He model, h=100, lr=0.00100, Loss=1.63076, test err=0.394
# Trial 9, Epoch: 1800, He model, h=100, lr=0.00100, Loss=1.37642, test err=0.360
# Trial 9, Epoch: 2400, He model, h=100, lr=0.00100, Loss=1.20184, test err=0.345
# Trial 9, Epoch: 3000, He model, h=100, lr=0.00100, Loss=1.08343, test err=0.334
# Trial 0, Epoch: 0, V1 model, h=100, lr=0.01000, Loss=3.33808, test err=0.908
# Trial 0, Epoch: 600, V1 model, h=100, lr=0.01000, Loss=0.73511, test err=0.266
# Trial 0, Epoch: 1200, V1 model, h=100, lr=0.01000, Loss=0.63429, test err=0.225
# Trial 0, Epoch: 1800, V1 model, h=100, lr=0.01000, Loss=0.57895, test err=0.204
# Trial 0, Epoch: 2400, V1 model, h=100, lr=0.01000, Loss=0.54201, test err=0.189
# Trial 0, Epoch: 3000, V1 model, h=100, lr=0.01000, Loss=0.51535, test err=0.182
# Trial 1, Epoch: 0, V1 model, h=100, lr=0.01000, Loss=2.89713, test err=0.858
# Trial 1, Epoch: 600, V1 model, h=100, lr=0.01000, Loss=0.77389, test err=0.277
# Trial 1, Epoch: 1200, V1 model, h=100, lr=0.01000, Loss=0.65275, test err=0.233
# Trial 1, Epoch: 1800, V1 model, h=100, lr=0.01000, Loss=0.59233, test err=0.210
# Trial 1, Epoch: 2400, V1 model, h=100, lr=0.01000, Loss=0.55408, test err=0.194
# ...
# Trial 1, Epoch: 3000, V1 model, h=400, lr=1.00000, Loss=0.24823, test err=0.128
# Trial 2, Epoch: 0, V1 model, h=400, lr=1.00000, Loss=2.82747, test err=0.817
# Trial 2, Epoch: 600, V1 model, h=400, lr=1.00000, Loss=0.33188, test err=0.142
# Trial 2, Epoch: 1200, V1 model, h=400, lr=1.00000, Loss=0.28237, test err=0.132
# Trial 2, Epoch: 1800, V1 model, h=400, lr=1.00000, Loss=0.47110, test err=0.188
# Trial 2, Epoch: 2400, V1 model, h=400, lr=1.00000, Loss=0.35517, test err=0.151
# Trial 2, Epoch: 3000, V1 model, h=400, lr=1.00000, Loss=0.31088, test err=0.139
# Trial 3, Epoch: 0, V1 model, h=400, lr=1.00000, Loss=3.09130, test err=0.745
# Trial 3, Epoch: 600, V1 model, h=400, lr=1.00000, Loss=0.39154, test err=0.176
# Trial 3, Epoch: 1200, V1 model, h=400, lr=1.00000, Loss=0.33349, test err=0.134
# Trial 3, Epoch: 1800, V1 model, h=400, lr=1.00000, Loss=0.26839, test err=0.124
# Trial 3, Epoch: 2400, V1 model, h=400, lr=1.00000, Loss=0.44422, test err=0.172
# Trial 3, Epoch: 3000, V1 model, h=400, lr=1.00000, Loss=0.31208, test err=0.138
# Trial 4, Epoch: 0, V1 model, h=400, lr=1.00000, Loss=2.71293, test err=0.803
# Trial 4, Epoch: 600, V1 model, h=400, lr=1.00000, Loss=0.37903, test err=0.154
# Trial 4, Epoch: 1200, V1 model, h=400, lr=1.00000, Loss=0.31618, test err=0.136
# Trial 4, Epoch: 1800, V1 model, h=400, lr=1.00000, Loss=0.26533, test err=0.126
# Trial 4, Epoch: 2400, V1 model, h=400, lr=1.00000, Loss=0.24173, test err=0.121
# Trial 4, Epoch: 3000, V1 model, h=400, lr=1.00000, Loss=0.22612, test err=0.122
# Trial 5, Epoch: 0, V1 model, h=400, lr=1.00000, Loss=2.59750, test err=0.893
# Trial 5, Epoch: 600, V1 model, h=400, lr=1.00000, Loss=0.37252, test err=0.150
# Trial 5, Epoch: 1200, V1 model, h=400, lr=1.00000, Loss=0.30171, test err=0.130
# Trial 5, Epoch: 1800, V1 model, h=400, lr=1.00000, Loss=0.27110, test err=0.126
# Trial 5, Epoch: 2400, V1 model, h=400, lr=1.00000, Loss=0.23322, test err=0.125
# Trial 5, Epoch: 3000, V1 model, h=400, lr=1.00000, Loss=0.21158, test err=0.118
# Trial 6, Epoch: 0, V1 model, h=400, lr=1.00000, Loss=2.61997, test err=0.900
# Trial 6, Epoch: 600, V1 model, h=400, lr=1.00000, Loss=0.42513, test err=0.201
# Trial 6, Epoch: 1200, V1 model, h=400, lr=1.00000, Loss=0.33848, test err=0.139
# Trial 6, Epoch: 1800, V1 model, h=400, lr=1.00000, Loss=0.31900, test err=0.137
# Trial 6, Epoch: 2400, V1 model, h=400, lr=1.00000, Loss=0.28448, test err=0.133
# Trial 6, Epoch: 3000, V1 model, h=400, lr=1.00000, Loss=1.43402, test err=0.541
# Trial 7, Epoch: 0, V1 model, h=400, lr=1.00000, Loss=2.73378, test err=0.803
# Trial 7, Epoch: 600, V1 model, h=400, lr=1.00000, Loss=0.42925, test err=0.161
# Trial 7, Epoch: 1200, V1 model, h=400, lr=1.00000, Loss=0.31750, test err=0.141
# Trial 7, Epoch: 1800, V1 model, h=400, lr=1.00000, Loss=0.30219, test err=0.139
# Trial 7, Epoch: 2400, V1 model, h=400, lr=1.00000, Loss=0.25051, test err=0.126
# Trial 7, Epoch: 3000, V1 model, h=400, lr=1.00000, Loss=0.23638, test err=0.121
# Trial 8, Epoch: 0, V1 model, h=400, lr=1.00000, Loss=2.55273, test err=0.814
# Trial 8, Epoch: 600, V1 model, h=400, lr=1.00000, Loss=0.35412, test err=0.150
# Trial 8, Epoch: 1200, V1 model, h=400, lr=1.00000, Loss=0.28856, test err=0.129
# Trial 8, Epoch: 1800, V1 model, h=400, lr=1.00000, Loss=0.25317, test err=0.122
# Trial 8, Epoch: 2400, V1 model, h=400, lr=1.00000, Loss=0.23288, test err=0.123
# Trial 8, Epoch: 3000, V1 model, h=400, lr=1.00000, Loss=0.20647, test err=0.118
# Trial 9, Epoch: 0, V1 model, h=400, lr=1.00000, Loss=2.41252, test err=0.816
# Trial 9, Epoch: 600, V1 model, h=400, lr=1.00000, Loss=0.36253, test err=0.154
# Trial 9, Epoch: 1200, V1 model, h=400, lr=1.00000, Loss=0.29180, test err=0.133
# Trial 9, Epoch: 1800, V1 model, h=400, lr=1.00000, Loss=0.26408, test err=0.128
# Trial 9, Epoch: 2400, V1 model, h=400, lr=1.00000, Loss=0.40420, test err=0.156
# Trial 9, Epoch: 3000, V1 model, h=400, lr=1.00000, Loss=0.31124, test err=0.142
# Trial 0, Epoch: 0, He model, h=400, lr=1.00000, Loss=2.38400, test err=0.801
# Trial 0, Epoch: 600, He model, h=400, lr=1.00000, Loss=0.72471, test err=0.258
# Trial 0, Epoch: 1200, He model, h=400, lr=1.00000, Loss=0.39969, test err=0.161
# Trial 0, Epoch: 1800, He model, h=400, lr=1.00000, Loss=0.36741, test err=0.153
# Trial 0, Epoch: 2400, He model, h=400, lr=1.00000, Loss=0.89777, test err=0.421
# Trial 0, Epoch: 3000, He model, h=400, lr=1.00000, Loss=1.04746, test err=0.377
# Trial 1, Epoch: 0, He model, h=400, lr=1.00000, Loss=2.36075, test err=0.706
# Trial 1, Epoch: 600, He model, h=400, lr=1.00000, Loss=0.66963, test err=0.283
# Trial 1, Epoch: 1200, He model, h=400, lr=1.00000, Loss=0.52553, test err=0.186
# Trial 1, Epoch: 1800, He model, h=400, lr=1.00000, Loss=0.36465, test err=0.155
# Trial 1, Epoch: 2400, He model, h=400, lr=1.00000, Loss=0.34442, test err=0.145
# Trial 1, Epoch: 3000, He model, h=400, lr=1.00000, Loss=0.31526, test err=0.138
# Trial 2, Epoch: 0, He model, h=400, lr=1.00000, Loss=2.28968, test err=0.725
# Trial 2, Epoch: 600, He model, h=400, lr=1.00000, Loss=0.58053, test err=0.299
# Trial 2, Epoch: 1200, He model, h=400, lr=1.00000, Loss=0.40605, test err=0.165
# Trial 2, Epoch: 1800, He model, h=400, lr=1.00000, Loss=0.36818, test err=0.158
# Trial 2, Epoch: 2400, He model, h=400, lr=1.00000, Loss=0.31993, test err=0.137
# Trial 2, Epoch: 3000, He model, h=400, lr=1.00000, Loss=0.29861, test err=0.132
# Trial 3, Epoch: 0, He model, h=400, lr=1.00000, Loss=2.33749, test err=0.769
# Trial 3, Epoch: 600, He model, h=400, lr=1.00000, Loss=0.52678, test err=0.225
# Trial 3, Epoch: 1200, He model, h=400, lr=1.00000, Loss=0.36461, test err=0.152
# Trial 3, Epoch: 1800, He model, h=400, lr=1.00000, Loss=0.31929, test err=0.140
# Trial 3, Epoch: 2400, He model, h=400, lr=1.00000, Loss=0.29230, test err=0.135
# Trial 3, Epoch: 3000, He model, h=400, lr=1.00000, Loss=8.34245, test err=0.714
# Trial 4, Epoch: 0, He model, h=400, lr=1.00000, Loss=2.27101, test err=0.645
# Trial 4, Epoch: 600, He model, h=400, lr=1.00000, Loss=0.64454, test err=0.291
# Trial 4, Epoch: 1200, He model, h=400, lr=1.00000, Loss=0.44973, test err=0.197
# Trial 4, Epoch: 1800, He model, h=400, lr=1.00000, Loss=0.34304, test err=0.152
# Trial 4, Epoch: 2400, He model, h=400, lr=1.00000, Loss=0.69665, test err=0.279
# Trial 4, Epoch: 3000, He model, h=400, lr=1.00000, Loss=0.87813, test err=0.358
# Trial 5, Epoch: 0, He model, h=400, lr=1.00000, Loss=2.29443, test err=0.558
# Trial 5, Epoch: 600, He model, h=400, lr=1.00000, Loss=0.49601, test err=0.196
# Trial 5, Epoch: 1200, He model, h=400, lr=1.00000, Loss=0.36427, test err=0.148
# Trial 5, Epoch: 1800, He model, h=400, lr=1.00000, Loss=0.31221, test err=0.137
# Trial 5, Epoch: 2400, He model, h=400, lr=1.00000, Loss=0.27881, test err=0.135
# Trial 5, Epoch: 3000, He model, h=400, lr=1.00000, Loss=0.52458, test err=0.214
# Trial 6, Epoch: 0, He model, h=400, lr=1.00000, Loss=2.32575, test err=0.654
# Trial 6, Epoch: 600, He model, h=400, lr=1.00000, Loss=0.49781, test err=0.198
# Trial 6, Epoch: 1200, He model, h=400, lr=1.00000, Loss=0.36572, test err=0.161
# Trial 6, Epoch: 1800, He model, h=400, lr=1.00000, Loss=0.56261, test err=0.234
# Trial 6, Epoch: 2400, He model, h=400, lr=1.00000, Loss=0.36961, test err=0.153
# Trial 6, Epoch: 3000, He model, h=400, lr=1.00000, Loss=0.33443, test err=0.152
# Trial 7, Epoch: 0, He model, h=400, lr=1.00000, Loss=2.31021, test err=0.805
# Trial 7, Epoch: 600, He model, h=400, lr=1.00000, Loss=0.60589, test err=0.268
# Trial 7, Epoch: 1200, He model, h=400, lr=1.00000, Loss=0.41129, test err=0.171
# Trial 7, Epoch: 1800, He model, h=400, lr=1.00000, Loss=0.37740, test err=0.148
# Trial 7, Epoch: 2400, He model, h=400, lr=1.00000, Loss=0.34034, test err=0.143
# Trial 7, Epoch: 3000, He model, h=400, lr=1.00000, Loss=0.30169, test err=0.136
# Trial 8, Epoch: 0, He model, h=400, lr=1.00000, Loss=2.28116, test err=0.720
# Trial 8, Epoch: 600, He model, h=400, lr=1.00000, Loss=0.43732, test err=0.216
# Trial 8, Epoch: 1200, He model, h=400, lr=1.00000, Loss=0.33565, test err=0.140
# Trial 8, Epoch: 1800, He model, h=400, lr=1.00000, Loss=0.29512, test err=0.132
# Trial 8, Epoch: 2400, He model, h=400, lr=1.00000, Loss=0.26275, test err=0.129
# Trial 8, Epoch: 3000, He model, h=400, lr=1.00000, Loss=0.25219, test err=0.122
# Trial 9, Epoch: 0, He model, h=400, lr=1.00000, Loss=2.32163, test err=0.692
# Trial 9, Epoch: 600, He model, h=400, lr=1.00000, Loss=0.46375, test err=0.200
# Trial 9, Epoch: 1200, He model, h=400, lr=1.00000, Loss=0.34783, test err=0.150
# Trial 9, Epoch: 1800, He model, h=400, lr=1.00000, Loss=0.30746, test err=0.140
# Trial 9, Epoch: 2400, He model, h=400, lr=1.00000, Loss=0.28317, test err=0.132
# Trial 9, Epoch: 3000, He model, h=400, lr=1.00000, Loss=0.25235, test err=0.128
# Trial 0, Epoch: 0, V1 model, h=1000, lr=0.00100, Loss=2.85453, test err=0.929
# Trial 0, Epoch: 600, V1 model, h=1000, lr=0.00100, Loss=0.78339, test err=0.274
# Trial 0, Epoch: 1200, V1 model, h=1000, lr=0.00100, Loss=0.69592, test err=0.249
# Trial 0, Epoch: 1800, V1 model, h=1000, lr=0.00100, Loss=0.65288, test err=0.235
# Trial 0, Epoch: 2400, V1 model, h=1000, lr=0.00100, Loss=0.62504, test err=0.225
# Trial 0, Epoch: 3000, V1 model, h=1000, lr=0.00100, Loss=0.60470, test err=0.219
# Trial 1, Epoch: 0, V1 model, h=1000, lr=0.00100, Loss=2.66738, test err=0.920
# Trial 1, Epoch: 600, V1 model, h=1000, lr=0.00100, Loss=0.78153, test err=0.274
# Trial 1, Epoch: 1200, V1 model, h=1000, lr=0.00100, Loss=0.69512, test err=0.248
# Trial 1, Epoch: 1800, V1 model, h=1000, lr=0.00100, Loss=0.65231, test err=0.235
# Trial 1, Epoch: 2400, V1 model, h=1000, lr=0.00100, Loss=0.62464, test err=0.225
# Trial 1, Epoch: 3000, V1 model, h=1000, lr=0.00100, Loss=0.60445, test err=0.218
# Trial 2, Epoch: 0, V1 model, h=1000, lr=0.00100, Loss=2.86620, test err=0.882
# Trial 2, Epoch: 600, V1 model, h=1000, lr=0.00100, Loss=0.77666, test err=0.271
# Trial 2, Epoch: 1200, V1 model, h=1000, lr=0.00100, Loss=0.69103, test err=0.246
# Trial 2, Epoch: 1800, V1 model, h=1000, lr=0.00100, Loss=0.64910, test err=0.231
# Trial 2, Epoch: 2400, V1 model, h=1000, lr=0.00100, Loss=0.62193, test err=0.222
# Trial 2, Epoch: 3000, V1 model, h=1000, lr=0.00100, Loss=0.60202, test err=0.216
# Trial 3, Epoch: 0, V1 model, h=1000, lr=0.00100, Loss=3.00685, test err=0.984
# Trial 3, Epoch: 600, V1 model, h=1000, lr=0.00100, Loss=0.77446, test err=0.278
# Trial 3, Epoch: 1200, V1 model, h=1000, lr=0.00100, Loss=0.69214, test err=0.247
# Trial 3, Epoch: 1800, V1 model, h=1000, lr=0.00100, Loss=0.65134, test err=0.235
# Trial 3, Epoch: 2400, V1 model, h=1000, lr=0.00100, Loss=0.62466, test err=0.224
# Trial 3, Epoch: 3000, V1 model, h=1000, lr=0.00100, Loss=0.60494, test err=0.216
# Trial 4, Epoch: 0, V1 model, h=1000, lr=0.00100, Loss=3.02195, test err=0.890
# Trial 4, Epoch: 600, V1 model, h=1000, lr=0.00100, Loss=0.78274, test err=0.275
# Trial 4, Epoch: 1200, V1 model, h=1000, lr=0.00100, Loss=0.69905, test err=0.251
# Trial 4, Epoch: 1800, V1 model, h=1000, lr=0.00100, Loss=0.65737, test err=0.236
# Trial 4, Epoch: 2400, V1 model, h=1000, lr=0.00100, Loss=0.63004, test err=0.228
# Trial 4, Epoch: 3000, V1 model, h=1000, lr=0.00100, Loss=0.60986, test err=0.222
# Trial 5, Epoch: 0, V1 model, h=1000, lr=0.00100, Loss=3.00856, test err=0.883
# Trial 5, Epoch: 600, V1 model, h=1000, lr=0.00100, Loss=0.76380, test err=0.272
# Trial 5, Epoch: 1200, V1 model, h=1000, lr=0.00100, Loss=0.68534, test err=0.248
# Trial 5, Epoch: 1800, V1 model, h=1000, lr=0.00100, Loss=0.64560, test err=0.234
# Trial 5, Epoch: 2400, V1 model, h=1000, lr=0.00100, Loss=0.61941, test err=0.225
# Trial 5, Epoch: 3000, V1 model, h=1000, lr=0.00100, Loss=0.60003, test err=0.221
# Trial 6, Epoch: 0, V1 model, h=1000, lr=0.00100, Loss=2.68804, test err=0.853
# Trial 6, Epoch: 600, V1 model, h=1000, lr=0.00100, Loss=0.78403, test err=0.282
# Trial 6, Epoch: 1200, V1 model, h=1000, lr=0.00100, Loss=0.70019, test err=0.254
# Trial 6, Epoch: 1800, V1 model, h=1000, lr=0.00100, Loss=0.65779, test err=0.240
# Trial 6, Epoch: 2400, V1 model, h=1000, lr=0.00100, Loss=0.62992, test err=0.230
# Trial 6, Epoch: 3000, V1 model, h=1000, lr=0.00100, Loss=0.60937, test err=0.222
# Trial 7, Epoch: 0, V1 model, h=1000, lr=0.00100, Loss=2.95213, test err=0.900
# Trial 7, Epoch: 600, V1 model, h=1000, lr=0.00100, Loss=0.80072, test err=0.289
# Trial 7, Epoch: 1200, V1 model, h=1000, lr=0.00100, Loss=0.71180, test err=0.260
# Trial 7, Epoch: 1800, V1 model, h=1000, lr=0.00100, Loss=0.66705, test err=0.243
# Trial 7, Epoch: 2400, V1 model, h=1000, lr=0.00100, Loss=0.63784, test err=0.233
# Trial 7, Epoch: 3000, V1 model, h=1000, lr=0.00100, Loss=0.61643, test err=0.224
# Trial 8, Epoch: 0, V1 model, h=1000, lr=0.00100, Loss=2.84161, test err=0.903
# Trial 8, Epoch: 600, V1 model, h=1000, lr=0.00100, Loss=0.78475, test err=0.277
# Trial 8, Epoch: 1200, V1 model, h=1000, lr=0.00100, Loss=0.70154, test err=0.251
# Trial 8, Epoch: 1800, V1 model, h=1000, lr=0.00100, Loss=0.65927, test err=0.239
# Trial 8, Epoch: 2400, V1 model, h=1000, lr=0.00100, Loss=0.63144, test err=0.232
# Trial 8, Epoch: 3000, V1 model, h=1000, lr=0.00100, Loss=0.61089, test err=0.225
# Trial 9, Epoch: 0, V1 model, h=1000, lr=0.00100, Loss=2.58829, test err=0.890
# Trial 9, Epoch: 600, V1 model, h=1000, lr=0.00100, Loss=0.77732, test err=0.272
# Trial 9, Epoch: 1200, V1 model, h=1000, lr=0.00100, Loss=0.69053, test err=0.244
# Trial 9, Epoch: 1800, V1 model, h=1000, lr=0.00100, Loss=0.64790, test err=0.231
# Trial 9, Epoch: 2400, V1 model, h=1000, lr=0.00100, Loss=0.62026, test err=0.223
# Trial 9, Epoch: 3000, V1 model, h=1000, lr=0.00100, Loss=0.60001, test err=0.217
# Trial 0, Epoch: 0, He model, h=1000, lr=0.00100, Loss=2.34774, test err=0.855
# Trial 0, Epoch: 600, He model, h=1000, lr=0.00100, Loss=1.40311, test err=0.342
# Trial 0, Epoch: 1200, He model, h=1000, lr=0.00100, Loss=1.09021, test err=0.313
# Trial 0, Epoch: 1800, He model, h=1000, lr=0.00100, Loss=0.94486, test err=0.289
# Trial 0, Epoch: 2400, He model, h=1000, lr=0.00100, Loss=0.86081, test err=0.270
# Trial 0, Epoch: 3000, He model, h=1000, lr=0.00100, Loss=0.80488, test err=0.258
# Trial 1, Epoch: 0, He model, h=1000, lr=0.00100, Loss=2.32021, test err=0.963
# Trial 1, Epoch: 600, He model, h=1000, lr=0.00100, Loss=1.42165, test err=0.349
# Trial 1, Epoch: 1200, He model, h=1000, lr=0.00100, Loss=1.10784, test err=0.330
# Trial 1, Epoch: 1800, He model, h=1000, lr=0.00100, Loss=0.96222, test err=0.305
# Trial 1, Epoch: 2400, He model, h=1000, lr=0.00100, Loss=0.87793, test err=0.282
# Trial 1, Epoch: 3000, He model, h=1000, lr=0.00100, Loss=0.82169, test err=0.271
# Trial 2, Epoch: 0, He model, h=1000, lr=0.00100, Loss=2.32950, test err=0.951
# Trial 2, Epoch: 600, He model, h=1000, lr=0.00100, Loss=1.40701, test err=0.350
# Trial 2, Epoch: 1200, He model, h=1000, lr=0.00100, Loss=1.10107, test err=0.331
# Trial 2, Epoch: 1800, He model, h=1000, lr=0.00100, Loss=0.95993, test err=0.308
# Trial 2, Epoch: 2400, He model, h=1000, lr=0.00100, Loss=0.87785, test err=0.285
# Trial 2, Epoch: 3000, He model, h=1000, lr=0.00100, Loss=0.82265, test err=0.269
# Trial 3, Epoch: 0, He model, h=1000, lr=0.00100, Loss=2.31439, test err=0.899
# Trial 3, Epoch: 600, He model, h=1000, lr=0.00100, Loss=1.41810, test err=0.356
# Trial 3, Epoch: 1200, He model, h=1000, lr=0.00100, Loss=1.10983, test err=0.334
# Trial 3, Epoch: 1800, He model, h=1000, lr=0.00100, Loss=0.96499, test err=0.309
# Trial 3, Epoch: 2400, He model, h=1000, lr=0.00100, Loss=0.88016, test err=0.285
# Trial 3, Epoch: 3000, He model, h=1000, lr=0.00100, Loss=0.82309, test err=0.267
# Trial 4, Epoch: 0, He model, h=1000, lr=0.00100, Loss=2.34090, test err=0.826
# Trial 4, Epoch: 600, He model, h=1000, lr=0.00100, Loss=1.43218, test err=0.343
# Trial 4, Epoch: 1200, He model, h=1000, lr=0.00100, Loss=1.11727, test err=0.323
# Trial 4, Epoch: 1800, He model, h=1000, lr=0.00100, Loss=0.96819, test err=0.297
# Trial 4, Epoch: 2400, He model, h=1000, lr=0.00100, Loss=0.88126, test err=0.278
# Trial 4, Epoch: 3000, He model, h=1000, lr=0.00100, Loss=0.82310, test err=0.265
# Trial 5, Epoch: 0, He model, h=1000, lr=0.00100, Loss=2.30415, test err=0.881

# %% [markdown]
# ## plot results

# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt

t, l, n_epochs= 5, 2, 3001
models = ['V1', 'He']
h_list = [50, 100, 400, 1000]
lr_list = [1e-3, 1e-2, 1e-1, 1e0]

for h in h_list:
    for lr in lr_list:
        with open('results/initialize_fashion_mnist/full_data/clf_t=%0.2f_l=%0.2f.pickle' % (t, l), 'rb') as handle:
            sims = pickle.load(handle)

        fig = plt.figure(figsize=(12, 5))
        plt.suptitle(r'Shallow FFW FC net w/ GD. h=%d, lr=%0.4f, '% (h, lr), fontsize=16)
        
        # loss
        ax = fig.add_subplot(131)
        plt.title('Network loss', fontsize=16)
        for m in models:
            avg_loss = np.mean(sims['loss'][m][h][lr], axis=0)
            std_loss = np.std(sims['loss'][m][h][lr], axis=0)                       
            plt.plot(np.arange(n_epochs), avg_loss, label=m, lw=3)
            plt.fill_between(np.arange(n_epochs), avg_loss - std_loss, avg_loss + std_loss, alpha=0.2)
        plt.xlabel('Epoch', fontsize=20)
        plt.ylabel('Training loss', fontsize=20)
        ax.tick_params(axis = 'both', which = 'major', labelsize = 14, width=2, length=6)
        plt.yscale('log')
        plt.legend(fontsize=18)
        
        # train err
        ax = fig.add_subplot(132)
        plt.title('Train error', fontsize=16)
        for m in models:
            avg_train_err = np.mean(sims['train_err'][m][h][lr], axis=0)
            std_train_err = np.std(sims['train_err'][m][h][lr], axis=0)
            plt.plot(np.arange(n_epochs), avg_train_err, label=m, lw=3)
            plt.fill_between(np.arange(n_epochs), avg_train_err - std_train_err, avg_train_err + std_train_err,  alpha=0.2)
        
        plt.xlabel('Epoch', fontsize=20)
        plt.ylabel('Training error', fontsize=20)
        ax.tick_params(axis = 'both', which = 'major', labelsize = 14, width=2, length=6)
        plt.yticks(np.arange(0, 1, 0.2))
        plt.yscale('log')
        plt.legend(fontsize=18)

        # test err
        ax = fig.add_subplot(133)
        plt.title('Test error', fontsize=16)
        for m in models:
            avg_test_err = np.mean(sims['test_err'][m][h][lr], axis=0)
            std_test_err = np.std(sims['test_err'][m][h][lr], axis=0)
            plt.plot(np.arange(n_epochs), avg_test_err, label=m, lw=3)
            plt.fill_between(np.arange(n_epochs), avg_test_err - std_test_err, avg_test_err + std_test_err, alpha=0.2)

        plt.xlabel('Epoch', fontsize=20)
        plt.ylabel('Test error', fontsize=20)
        ax.tick_params(axis = 'both', which = 'major', labelsize = 14, width=2, length=6)
        plt.yticks(np.arange(0, 1, 0.2))
        plt.yscale('log')
        plt.legend(fontsize=18)

        plt.tight_layout()
        plt.subplots_adjust(top=0.8)    

        print(h, lr)
        plt.savefig('results/initialize_fashion_mnist/full_data/init_t=%0.2f_l=%0.2f_h=%d_lr=%0.4f.png' % (t, l, h, lr))
        plt.close()
# Out:
# 50 0.001
# 50 0.01
# 50 0.1
# 50 1.0
# 100 0.001
# 100 0.01
# 100 0.1
# 100 1.0
# 400 0.001
# 400 0.01
# 400 0.1
# 400 1.0
# 1000 0.001
# 1000 0.01
# 1000 0.1
# 1000 1.0

# %% [markdown]
# ## Test the speed of training networks on GPUs vs CPU

# %%
import numpy as np
import numpy.linalg as la
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from estimator import classical_weights, V1_inspired_weights
from data_fns import load_fashion_mnist

# %%
train, train_labels, test, test_labels = load_fashion_mnist('./data/fashion_mnist')
X_train = torch.from_numpy(train).float()
X_test = torch.from_numpy(test).float()
y_train = torch.from_numpy(train_labels).long()
y_test = torch.from_numpy(test_labels).long()
n, d = X_train.shape

# %%
class V1_net(nn.Module):
    def __init__(self, hidden_size, scale):
        super().__init__()
        self.fc1 = nn.Linear(d, hidden_size)
        self.fc1.weight.data = torch.FloatTensor(V1_inspired_weights(hidden_size, d, t=5, l=2, scale=scale))
        self.output = nn.Linear(hidden_size, 10)
        
    def forward(self, inputs):
        x = torch.relu(self.fc1(inputs))
        return self.output(x)
    
class He_net(nn.Module):
    def __init__(self, hidden_size, scale):
        super().__init__()
        self.fc1 = nn.Linear(d, hidden_size)
        torch.nn.init.kaiming_normal_(self.fc1.weight)
        self.output = nn.Linear(hidden_size, 10)
        
    def forward(self, inputs):
        x = torch.relu(self.fc1(inputs))
        return self.output(x)
    
class RF_net(nn.Module):
    def __init__(self, hidden_size, scale):
        super().__init__()
        self.fc1 = nn.Linear(d, hidden_size)
        self.fc1.weight.data = torch.FloatTensor(classical_weights(hidden_size, d, scale=scale))
        self.output = nn.Linear(hidden_size, 10)
        
    def forward(self, inputs):
        x = torch.relu(self.fc1(inputs))
        return self.output(x)    
    
class V1_net_multiscale(nn.Module):
    def __init__(self, hidden_size, scale):
        super().__init__()
        self.fc1 = nn.Linear(d, hidden_size)
        self.fc1.weight.data = torch.FloatTensor(V1_weights_multiple_scales(hidden_size, d, scale=scale))
        self.output = nn.Linear(hidden_size, 10)
        
    def forward(self, inputs):
        x = torch.relu(self.fc1(inputs))
        return self.output(x)
    
    
def predict(model, X):
    return model(X).data.max(1)[1]

def error(model, X, y):
    y_pred = predict(model, X)
    accuracy = 1.0 * torch.sum(y_pred == y) / len(y)
    return 1 - accuracy

# %%
# %%time
## Run on GPU
X_train_cuda, y_train_cuda = X_train.to('cuda'), y_train.to('cuda')
X_test_cuda, y_test_cuda = X_test.to('cuda'), y_test.to('cuda')

h, lr, scale = 1000, 0.1, 2/d
n_epochs = 2001
model = V1_net(h, scale=scale).to('cuda')
loss_func = nn.CrossEntropyLoss()
optim = torch.optim.SGD(model.parameters(), lr=lr)

test_err_list_V1 = []
for i in range(n_epochs):
    optim.zero_grad()
    loss = loss_func(model(X_train_cuda), y_train_cuda)
    loss.backward()
    optim.step()
    
    train_err = error(model, X_train_cuda, y_train_cuda)
    test_err = error(model, X_test_cuda, y_test_cuda)
    test_err_list_V1.append(test_err)
    
    if (i % 200 == 0):
        print('Epoch: %d, Loss=%0.5f, train_err=%0.5f, test_err=%0.5f' % (i, loss.data, train_err, test_err))

# %%
# %%time
# ## Run on GPU
# X_train_cuda, y_train_cuda = X_train.to('cuda'), y_train.to('cuda')
# X_test_cuda, y_test_cuda = X_test.to('cuda'), y_test.to('cuda')

# h, lr, scale = 500, 0.1, 2/d
# n_epochs = 2001
# model = He_net(h, scale=scale).to('cuda')
# loss_func = nn.CrossEntropyLoss()
# optim = torch.optim.SGD(model.parameters(), lr=lr)

# test_err_list_He = []
# for i in range(n_epochs):
#     optim.zero_grad()
#     loss = loss_func(model(X_train_cuda), y_train_cuda)
#     loss.backward()
#     optim.step()
    
#     train_err = error(model, X_train_cuda, y_train_cuda)
#     test_err = error(model, X_test_cuda, y_test_cuda)
#     test_err_list_He.append(test_err)
    
#     if (i % 200 == 0):
#         print('Epoch: %d, Loss=%0.5f, train_err=%0.5f, test_err=%0.5f' % (i, loss.data, train_err, test_err))

# %%
fig = plt.figure()
plt.plot(np.arange(n_epochs), test_err_list_V1, label='V1')
plt.plot(np.arange(n_epochs), test_err_list_He, label='He')
plt.yscale('log')
plt.legend()

# %%
np.random.multivariate_normal((5, 3), np.eye(2), (100))
