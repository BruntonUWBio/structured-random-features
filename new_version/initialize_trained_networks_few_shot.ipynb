# %%
import numpy as np
import numpy.linalg as la
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from estimator import classical_weights, V1_inspired_weights
from data_fns import load_mnist
from sklearn.model_selection import train_test_split
import pickle

# %%
from mnist import MNIST
train, train_labels, test, test_labels = load_mnist()
n, d = train.shape

num_train = 50
X_train, _, y_train, _ = train_test_split(train, train_labels, train_size=num_train, stratify=train_labels, 
                                          random_state=42)

X_train, y_train = torch.from_numpy(X_train).float(), torch.from_numpy(y_train).long()
X_test, y_test = torch.from_numpy(test).float(), torch.from_numpy(test_labels).long()

# %%
class V1_net(nn.Module):
    def __init__(self, hidden_size, scale):
        super().__init__()
        self.fc1 = nn.Linear(d, hidden_size)
        self.fc1.weight.data = torch.FloatTensor(V1_inspired_weights(hidden_size, d, t=5, l=2, scale=scale))
        self.output = nn.Linear(hidden_size, 10)
        
    def forward(self, inputs):
        x = torch.relu(self.fc1(inputs))
        return self.output(x)
    
class He_net(nn.Module):
    def __init__(self, hidden_size, scale):
        super().__init__()
        self.fc1 = nn.Linear(d, hidden_size)
        torch.nn.init.kaiming_normal_(self.fc1.weight)
        self.output = nn.Linear(hidden_size, 10)
        
    def forward(self, inputs):
        x = torch.relu(self.fc1(inputs))
        return self.output(x)
    
class RF_net(nn.Module):
    def __init__(self, hidden_size, scale):
        super().__init__()
        self.fc1 = nn.Linear(d, hidden_size)
        self.fc1.weight.data = torch.FloatTensor(classical_weights(hidden_size, d, scale=scale))
        self.output = nn.Linear(hidden_size, 10)
        
    def forward(self, inputs):
        x = torch.relu(self.fc1(inputs))
        return self.output(x)

# %%
def predict(model, X):
    return model(X).data.max(1)[1]

def error(model, X, y):
    y_pred = predict(model, X)
    accuracy = 1.0 * torch.sum(y_pred == y) / len(y)
    return 1 - accuracy

# %%
scale = 1/32
models = {'V1': V1_net, 'RF': RF_net, 'He': He_net}
n_epochs = 7000
n_trials = 5
t, l = 5, 3
loss_func = nn.CrossEntropyLoss()

for h in [50, 100, 400, 1000]:
    for lr in [1e-3, 1e-2, 1e-1, 1e0]:
        train_err = {m: np.zeros((n_trials, n_epochs)) for m in models.keys()}
        test_err = {m: np.zeros((n_trials, n_epochs)) for m in models.keys()}
        loss_list = {m: np.zeros((n_trials, n_epochs)) for m in models.keys()}
        for m, network in models.items():
            for i in range(n_trials):
                model = network(h, scale)
                optim = torch.optim.SGD(model.parameters(), lr=lr)
                for j in range(n_epochs):
                    optim.zero_grad()
                    loss = loss_func(model(X_train), y_train)
                    loss.backward()
                    optim.step()

                    train_err[m][i, j] = error(model, X_train, y_train)
                    test_err[m][i, j] = error(model, X_test, y_test)
                    loss_list[m][i, j] = loss.data

                    if (j % 500 == 0):
                        print('Trial %d, Epoch: %d, %s model, h=%d, lr=%0.5f, Loss=%0.5f, test err=%0.3f' % (i,j, m, 
                                                                                                             h, lr, 
                                                                                                             loss, 
                                                                                                  test_err[m][i, j]))

        results = {'test_err': test_err, 'train_err': train_err, 'loss': loss_list}
        with open('results/initialize_mnist/clf_t=%0.2f_l=%0.2f_h=%d_lr=%0.4f_scale=%0.6f_fewshot.pickle' % (t, l, 
                                                                                                     h, lr, 
                                                                                                     scale), 
                  'wb') as handle:
            pickle.dump(results, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# Trial 0, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=4.93333, test err=0.884
# Trial 0, Epoch: 400, V1 model, h=50, lr=0.00100, Loss=0.96775, test err=0.485
# Trial 0, Epoch: 800, V1 model, h=50, lr=0.00100, Loss=0.58889, test err=0.430
# Trial 0, Epoch: 1200, V1 model, h=50, lr=0.00100, Loss=0.41699, test err=0.411
# Trial 0, Epoch: 1600, V1 model, h=50, lr=0.00100, Loss=0.31728, test err=0.400
# Trial 0, Epoch: 2000, V1 model, h=50, lr=0.00100, Loss=0.25222, test err=0.394
# Trial 0, Epoch: 2400, V1 model, h=50, lr=0.00100, Loss=0.20669, test err=0.390
# Trial 0, Epoch: 2800, V1 model, h=50, lr=0.00100, Loss=0.17333, test err=0.388
# Trial 0, Epoch: 3200, V1 model, h=50, lr=0.00100, Loss=0.14810, test err=0.387
# Trial 0, Epoch: 3600, V1 model, h=50, lr=0.00100, Loss=0.12845, test err=0.386
# Trial 0, Epoch: 4000, V1 model, h=50, lr=0.00100, Loss=0.11284, test err=0.385
# Trial 0, Epoch: 4400, V1 model, h=50, lr=0.00100, Loss=0.10020, test err=0.385
# Trial 0, Epoch: 4800, V1 model, h=50, lr=0.00100, Loss=0.08981, test err=0.384
# Trial 0, Epoch: 5200, V1 model, h=50, lr=0.00100, Loss=0.08114, test err=0.384
# Trial 0, Epoch: 5600, V1 model, h=50, lr=0.00100, Loss=0.07383, test err=0.383
# Trial 0, Epoch: 6000, V1 model, h=50, lr=0.00100, Loss=0.06759, test err=0.382
# Trial 0, Epoch: 6400, V1 model, h=50, lr=0.00100, Loss=0.06222, test err=0.382
# Trial 0, Epoch: 6800, V1 model, h=50, lr=0.00100, Loss=0.05754, test err=0.382
# Trial 1, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=3.96288, test err=0.913
# Trial 1, Epoch: 400, V1 model, h=50, lr=0.00100, Loss=1.04556, test err=0.504
# Trial 1, Epoch: 800, V1 model, h=50, lr=0.00100, Loss=0.70444, test err=0.451
# Trial 1, Epoch: 1200, V1 model, h=50, lr=0.00100, Loss=0.52434, test err=0.431
# Trial 1, Epoch: 1600, V1 model, h=50, lr=0.00100, Loss=0.41095, test err=0.414
# Trial 1, Epoch: 2000, V1 model, h=50, lr=0.00100, Loss=0.33303, test err=0.405
# Trial 1, Epoch: 2400, V1 model, h=50, lr=0.00100, Loss=0.27630, test err=0.399
# Trial 1, Epoch: 2800, V1 model, h=50, lr=0.00100, Loss=0.23351, test err=0.395
# Trial 1, Epoch: 3200, V1 model, h=50, lr=0.00100, Loss=0.20021, test err=0.391
# Trial 1, Epoch: 3600, V1 model, h=50, lr=0.00100, Loss=0.17382, test err=0.387
# Trial 1, Epoch: 4000, V1 model, h=50, lr=0.00100, Loss=0.15261, test err=0.385
# Trial 1, Epoch: 4400, V1 model, h=50, lr=0.00100, Loss=0.13527, test err=0.383
# Trial 1, Epoch: 4800, V1 model, h=50, lr=0.00100, Loss=0.12089, test err=0.381
# Trial 1, Epoch: 5200, V1 model, h=50, lr=0.00100, Loss=0.10884, test err=0.379
# Trial 1, Epoch: 5600, V1 model, h=50, lr=0.00100, Loss=0.09861, test err=0.378
# Trial 1, Epoch: 6000, V1 model, h=50, lr=0.00100, Loss=0.08985, test err=0.377
# Trial 1, Epoch: 6400, V1 model, h=50, lr=0.00100, Loss=0.08230, test err=0.376
# Trial 1, Epoch: 6800, V1 model, h=50, lr=0.00100, Loss=0.07573, test err=0.376
# Trial 2, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=4.04146, test err=0.878
# Trial 2, Epoch: 400, V1 model, h=50, lr=0.00100, Loss=1.12675, test err=0.557
# Trial 2, Epoch: 800, V1 model, h=50, lr=0.00100, Loss=0.75727, test err=0.502
# Trial 2, Epoch: 1200, V1 model, h=50, lr=0.00100, Loss=0.57565, test err=0.476
# Trial 2, Epoch: 1600, V1 model, h=50, lr=0.00100, Loss=0.45901, test err=0.460
# Trial 2, Epoch: 2000, V1 model, h=50, lr=0.00100, Loss=0.37588, test err=0.450
# Trial 2, Epoch: 2400, V1 model, h=50, lr=0.00100, Loss=0.31357, test err=0.446
# Trial 2, Epoch: 2800, V1 model, h=50, lr=0.00100, Loss=0.26542, test err=0.441
# Trial 2, Epoch: 3200, V1 model, h=50, lr=0.00100, Loss=0.22742, test err=0.439
# Trial 2, Epoch: 3600, V1 model, h=50, lr=0.00100, Loss=0.19698, test err=0.437
# Trial 2, Epoch: 4000, V1 model, h=50, lr=0.00100, Loss=0.17220, test err=0.436
# Trial 2, Epoch: 4400, V1 model, h=50, lr=0.00100, Loss=0.15176, test err=0.434
# Trial 2, Epoch: 4800, V1 model, h=50, lr=0.00100, Loss=0.13472, test err=0.434
# Trial 2, Epoch: 5200, V1 model, h=50, lr=0.00100, Loss=0.12048, test err=0.433
# Trial 2, Epoch: 5600, V1 model, h=50, lr=0.00100, Loss=0.10844, test err=0.430
# Trial 2, Epoch: 6000, V1 model, h=50, lr=0.00100, Loss=0.09820, test err=0.429
# Trial 2, Epoch: 6400, V1 model, h=50, lr=0.00100, Loss=0.08942, test err=0.428
# Trial 2, Epoch: 6800, V1 model, h=50, lr=0.00100, Loss=0.08184, test err=0.428
# Trial 3, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=4.81013, test err=0.911
# Trial 3, Epoch: 400, V1 model, h=50, lr=0.00100, Loss=1.26401, test err=0.604
# Trial 3, Epoch: 800, V1 model, h=50, lr=0.00100, Loss=0.83105, test err=0.516
# Trial 3, Epoch: 1200, V1 model, h=50, lr=0.00100, Loss=0.60623, test err=0.481
# Trial 3, Epoch: 1600, V1 model, h=50, lr=0.00100, Loss=0.46881, test err=0.462
# Trial 3, Epoch: 2000, V1 model, h=50, lr=0.00100, Loss=0.37677, test err=0.453
# Trial 3, Epoch: 2400, V1 model, h=50, lr=0.00100, Loss=0.31131, test err=0.446
# Trial 3, Epoch: 2800, V1 model, h=50, lr=0.00100, Loss=0.26275, test err=0.442
# Trial 3, Epoch: 3200, V1 model, h=50, lr=0.00100, Loss=0.22553, test err=0.438
# Trial 3, Epoch: 3600, V1 model, h=50, lr=0.00100, Loss=0.19607, test err=0.434
# Trial 3, Epoch: 4000, V1 model, h=50, lr=0.00100, Loss=0.17222, test err=0.431
# Trial 3, Epoch: 4400, V1 model, h=50, lr=0.00100, Loss=0.15263, test err=0.428
# Trial 3, Epoch: 4800, V1 model, h=50, lr=0.00100, Loss=0.13630, test err=0.426
# Trial 3, Epoch: 5200, V1 model, h=50, lr=0.00100, Loss=0.12260, test err=0.424
# Trial 3, Epoch: 5600, V1 model, h=50, lr=0.00100, Loss=0.11097, test err=0.421
# Trial 3, Epoch: 6000, V1 model, h=50, lr=0.00100, Loss=0.10107, test err=0.420
# Trial 3, Epoch: 6400, V1 model, h=50, lr=0.00100, Loss=0.09252, test err=0.419
# Trial 3, Epoch: 6800, V1 model, h=50, lr=0.00100, Loss=0.08507, test err=0.416
# Trial 4, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=4.30601, test err=0.869
# Trial 4, Epoch: 400, V1 model, h=50, lr=0.00100, Loss=0.92932, test err=0.470
# Trial 4, Epoch: 800, V1 model, h=50, lr=0.00100, Loss=0.57672, test err=0.406
# Trial 4, Epoch: 1200, V1 model, h=50, lr=0.00100, Loss=0.41409, test err=0.386
# Trial 4, Epoch: 1600, V1 model, h=50, lr=0.00100, Loss=0.31898, test err=0.379
# Trial 4, Epoch: 2000, V1 model, h=50, lr=0.00100, Loss=0.25608, test err=0.377
# Trial 4, Epoch: 2400, V1 model, h=50, lr=0.00100, Loss=0.21143, test err=0.374
# Trial 4, Epoch: 2800, V1 model, h=50, lr=0.00100, Loss=0.17830, test err=0.373
# Trial 4, Epoch: 3200, V1 model, h=50, lr=0.00100, Loss=0.15291, test err=0.373
# Trial 4, Epoch: 3600, V1 model, h=50, lr=0.00100, Loss=0.13293, test err=0.371
# Trial 4, Epoch: 4000, V1 model, h=50, lr=0.00100, Loss=0.11689, test err=0.369
# Trial 4, Epoch: 4400, V1 model, h=50, lr=0.00100, Loss=0.10383, test err=0.369
# Trial 4, Epoch: 4800, V1 model, h=50, lr=0.00100, Loss=0.09303, test err=0.369
# Trial 4, Epoch: 5200, V1 model, h=50, lr=0.00100, Loss=0.08400, test err=0.368
# Trial 4, Epoch: 5600, V1 model, h=50, lr=0.00100, Loss=0.07635, test err=0.368
# Trial 4, Epoch: 6000, V1 model, h=50, lr=0.00100, Loss=0.06981, test err=0.368
# Trial 4, Epoch: 6400, V1 model, h=50, lr=0.00100, Loss=0.06419, test err=0.367
# Trial 4, Epoch: 6800, V1 model, h=50, lr=0.00100, Loss=0.05930, test err=0.367
# Trial 0, Epoch: 0, RF model, h=50, lr=0.00100, Loss=2.36212, test err=0.892
# Trial 0, Epoch: 400, RF model, h=50, lr=0.00100, Loss=1.85544, test err=0.735
# Trial 0, Epoch: 800, RF model, h=50, lr=0.00100, Loss=1.49710, test err=0.617
# Trial 0, Epoch: 1200, RF model, h=50, lr=0.00100, Loss=1.19740, test err=0.544
# Trial 0, Epoch: 1600, RF model, h=50, lr=0.00100, Loss=0.94920, test err=0.497
# Trial 0, Epoch: 2000, RF model, h=50, lr=0.00100, Loss=0.75201, test err=0.460
# Trial 0, Epoch: 2400, RF model, h=50, lr=0.00100, Loss=0.59880, test err=0.436
# Trial 0, Epoch: 2800, RF model, h=50, lr=0.00100, Loss=0.48116, test err=0.419
# Trial 0, Epoch: 3200, RF model, h=50, lr=0.00100, Loss=0.39150, test err=0.408
# Trial 0, Epoch: 3600, RF model, h=50, lr=0.00100, Loss=0.32299, test err=0.399
# Trial 0, Epoch: 4000, RF model, h=50, lr=0.00100, Loss=0.27002, test err=0.394
# Trial 0, Epoch: 4400, RF model, h=50, lr=0.00100, Loss=0.22865, test err=0.390
# Trial 0, Epoch: 4800, RF model, h=50, lr=0.00100, Loss=0.19605, test err=0.384
# Trial 0, Epoch: 5200, RF model, h=50, lr=0.00100, Loss=0.17010, test err=0.381
# Trial 0, Epoch: 5600, RF model, h=50, lr=0.00100, Loss=0.14911, test err=0.378
# Trial 0, Epoch: 6000, RF model, h=50, lr=0.00100, Loss=0.13190, test err=0.376
# Trial 0, Epoch: 6400, RF model, h=50, lr=0.00100, Loss=0.11759, test err=0.374
# Trial 0, Epoch: 6800, RF model, h=50, lr=0.00100, Loss=0.10565, test err=0.372
# Trial 1, Epoch: 0, RF model, h=50, lr=0.00100, Loss=2.47185, test err=0.887
# Trial 1, Epoch: 400, RF model, h=50, lr=0.00100, Loss=1.85637, test err=0.704
# Trial 1, Epoch: 800, RF model, h=50, lr=0.00100, Loss=1.51861, test err=0.570
# Trial 1, Epoch: 1200, RF model, h=50, lr=0.00100, Loss=1.24800, test err=0.513
# Trial 1, Epoch: 1600, RF model, h=50, lr=0.00100, Loss=1.02602, test err=0.481
# Trial 1, Epoch: 2000, RF model, h=50, lr=0.00100, Loss=0.84233, test err=0.460
# Trial 1, Epoch: 2400, RF model, h=50, lr=0.00100, Loss=0.69166, test err=0.444
# Trial 1, Epoch: 2800, RF model, h=50, lr=0.00100, Loss=0.56833, test err=0.429
# Trial 1, Epoch: 3200, RF model, h=50, lr=0.00100, Loss=0.46826, test err=0.421
# Trial 1, Epoch: 3600, RF model, h=50, lr=0.00100, Loss=0.38850, test err=0.412
# Trial 1, Epoch: 4000, RF model, h=50, lr=0.00100, Loss=0.32524, test err=0.407
# Trial 1, Epoch: 4400, RF model, h=50, lr=0.00100, Loss=0.27470, test err=0.403
# Trial 1, Epoch: 4800, RF model, h=50, lr=0.00100, Loss=0.23453, test err=0.398
# Trial 1, Epoch: 5200, RF model, h=50, lr=0.00100, Loss=0.20237, test err=0.394
# Trial 1, Epoch: 5600, RF model, h=50, lr=0.00100, Loss=0.17632, test err=0.391
# Trial 1, Epoch: 6000, RF model, h=50, lr=0.00100, Loss=0.15501, test err=0.389
# Trial 1, Epoch: 6400, RF model, h=50, lr=0.00100, Loss=0.13749, test err=0.388
# Trial 1, Epoch: 6800, RF model, h=50, lr=0.00100, Loss=0.12303, test err=0.386
# Trial 2, Epoch: 0, RF model, h=50, lr=0.00100, Loss=2.54260, test err=0.891
# Trial 2, Epoch: 400, RF model, h=50, lr=0.00100, Loss=1.93361, test err=0.766
# Trial 2, Epoch: 800, RF model, h=50, lr=0.00100, Loss=1.56773, test err=0.626
# Trial 2, Epoch: 1200, RF model, h=50, lr=0.00100, Loss=1.27292, test err=0.555
# Trial 2, Epoch: 1600, RF model, h=50, lr=0.00100, Loss=1.03600, test err=0.512
# Trial 2, Epoch: 2000, RF model, h=50, lr=0.00100, Loss=0.84597, test err=0.486
# Trial 2, Epoch: 2400, RF model, h=50, lr=0.00100, Loss=0.69360, test err=0.469
# Trial 2, Epoch: 2800, RF model, h=50, lr=0.00100, Loss=0.57106, test err=0.458
# Trial 2, Epoch: 3200, RF model, h=50, lr=0.00100, Loss=0.47253, test err=0.448
# Trial 2, Epoch: 3600, RF model, h=50, lr=0.00100, Loss=0.39347, test err=0.438
# Trial 2, Epoch: 4000, RF model, h=50, lr=0.00100, Loss=0.32998, test err=0.429
# Trial 2, Epoch: 4400, RF model, h=50, lr=0.00100, Loss=0.27909, test err=0.424
# Trial 2, Epoch: 4800, RF model, h=50, lr=0.00100, Loss=0.23827, test err=0.420
# Trial 2, Epoch: 5200, RF model, h=50, lr=0.00100, Loss=0.20541, test err=0.416
# Trial 2, Epoch: 5600, RF model, h=50, lr=0.00100, Loss=0.17869, test err=0.414
# Trial 2, Epoch: 6000, RF model, h=50, lr=0.00100, Loss=0.15664, test err=0.411
# Trial 2, Epoch: 6400, RF model, h=50, lr=0.00100, Loss=0.13845, test err=0.408
# Trial 2, Epoch: 6800, RF model, h=50, lr=0.00100, Loss=0.12332, test err=0.404
# Trial 3, Epoch: 0, RF model, h=50, lr=0.00100, Loss=2.57972, test err=0.892
# Trial 3, Epoch: 400, RF model, h=50, lr=0.00100, Loss=1.86347, test err=0.743
# Trial 3, Epoch: 800, RF model, h=50, lr=0.00100, Loss=1.49846, test err=0.592
# Trial 3, Epoch: 1200, RF model, h=50, lr=0.00100, Loss=1.19680, test err=0.522
# Trial 3, Epoch: 1600, RF model, h=50, lr=0.00100, Loss=0.95563, test err=0.480
# Trial 3, Epoch: 2000, RF model, h=50, lr=0.00100, Loss=0.76478, test err=0.448
# Trial 3, Epoch: 2400, RF model, h=50, lr=0.00100, Loss=0.61723, test err=0.427
# Trial 3, Epoch: 2800, RF model, h=50, lr=0.00100, Loss=0.50229, test err=0.409
# Trial 3, Epoch: 3200, RF model, h=50, lr=0.00100, Loss=0.41371, test err=0.396
# Trial 3, Epoch: 3600, RF model, h=50, lr=0.00100, Loss=0.34466, test err=0.387
# Trial 3, Epoch: 4000, RF model, h=50, lr=0.00100, Loss=0.29006, test err=0.381
# Trial 3, Epoch: 4400, RF model, h=50, lr=0.00100, Loss=0.24678, test err=0.376
# Trial 3, Epoch: 4800, RF model, h=50, lr=0.00100, Loss=0.21220, test err=0.373
# Trial 3, Epoch: 5200, RF model, h=50, lr=0.00100, Loss=0.18422, test err=0.369
# Trial 3, Epoch: 5600, RF model, h=50, lr=0.00100, Loss=0.16127, test err=0.366
# Trial 3, Epoch: 6000, RF model, h=50, lr=0.00100, Loss=0.14236, test err=0.364
# Trial 3, Epoch: 6400, RF model, h=50, lr=0.00100, Loss=0.12667, test err=0.363
# Trial 3, Epoch: 6800, RF model, h=50, lr=0.00100, Loss=0.11354, test err=0.361
# Trial 4, Epoch: 0, RF model, h=50, lr=0.00100, Loss=2.48266, test err=0.955
# Trial 4, Epoch: 400, RF model, h=50, lr=0.00100, Loss=1.95876, test err=0.804
# Trial 4, Epoch: 800, RF model, h=50, lr=0.00100, Loss=1.59877, test err=0.630
# Trial 4, Epoch: 1200, RF model, h=50, lr=0.00100, Loss=1.29317, test err=0.539
# Trial 4, Epoch: 1600, RF model, h=50, lr=0.00100, Loss=1.03609, test err=0.492
# Trial 4, Epoch: 2000, RF model, h=50, lr=0.00100, Loss=0.82678, test err=0.465
# Trial 4, Epoch: 2400, RF model, h=50, lr=0.00100, Loss=0.66202, test err=0.445
# Trial 4, Epoch: 2800, RF model, h=50, lr=0.00100, Loss=0.53361, test err=0.431
# Trial 4, Epoch: 3200, RF model, h=50, lr=0.00100, Loss=0.43440, test err=0.420
# Trial 4, Epoch: 3600, RF model, h=50, lr=0.00100, Loss=0.35835, test err=0.410
# Trial 4, Epoch: 4000, RF model, h=50, lr=0.00100, Loss=0.29940, test err=0.404
# Trial 4, Epoch: 4400, RF model, h=50, lr=0.00100, Loss=0.25330, test err=0.399
# Trial 4, Epoch: 4800, RF model, h=50, lr=0.00100, Loss=0.21678, test err=0.395
# Trial 4, Epoch: 5200, RF model, h=50, lr=0.00100, Loss=0.18752, test err=0.393
# Trial 4, Epoch: 5600, RF model, h=50, lr=0.00100, Loss=0.16386, test err=0.390
# Trial 4, Epoch: 6000, RF model, h=50, lr=0.00100, Loss=0.14448, test err=0.388
# Trial 4, Epoch: 6400, RF model, h=50, lr=0.00100, Loss=0.12841, test err=0.386
# Trial 4, Epoch: 6800, RF model, h=50, lr=0.00100, Loss=0.11503, test err=0.384
# Trial 0, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.30926, test err=0.860
# Trial 0, Epoch: 400, He model, h=50, lr=0.00100, Loss=2.16689, test err=0.761
# Trial 0, Epoch: 800, He model, h=50, lr=0.00100, Loss=2.01485, test err=0.623
# Trial 0, Epoch: 1200, He model, h=50, lr=0.00100, Loss=1.84759, test err=0.539
# Trial 0, Epoch: 1600, He model, h=50, lr=0.00100, Loss=1.66189, test err=0.479
# Trial 0, Epoch: 2000, He model, h=50, lr=0.00100, Loss=1.46201, test err=0.430
# Trial 0, Epoch: 2400, He model, h=50, lr=0.00100, Loss=1.25520, test err=0.399
# Trial 0, Epoch: 2800, He model, h=50, lr=0.00100, Loss=1.05646, test err=0.379
# Trial 0, Epoch: 3200, He model, h=50, lr=0.00100, Loss=0.87942, test err=0.363
# Trial 0, Epoch: 3600, He model, h=50, lr=0.00100, Loss=0.72860, test err=0.353
# Trial 0, Epoch: 4000, He model, h=50, lr=0.00100, Loss=0.60320, test err=0.347
# Trial 0, Epoch: 4400, He model, h=50, lr=0.00100, Loss=0.50121, test err=0.342
# Trial 0, Epoch: 4800, He model, h=50, lr=0.00100, Loss=0.41927, test err=0.339
# Trial 0, Epoch: 5200, He model, h=50, lr=0.00100, Loss=0.35372, test err=0.336
# Trial 0, Epoch: 5600, He model, h=50, lr=0.00100, Loss=0.30125, test err=0.334
# Trial 0, Epoch: 6000, He model, h=50, lr=0.00100, Loss=0.25903, test err=0.334
# Trial 0, Epoch: 6400, He model, h=50, lr=0.00100, Loss=0.22482, test err=0.333
# Trial 0, Epoch: 6800, He model, h=50, lr=0.00100, Loss=0.19682, test err=0.332
# Trial 1, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.29487, test err=0.915
# Trial 1, Epoch: 400, He model, h=50, lr=0.00100, Loss=2.13231, test err=0.830
# Trial 1, Epoch: 800, He model, h=50, lr=0.00100, Loss=1.97107, test err=0.676
# Trial 1, Epoch: 1200, He model, h=50, lr=0.00100, Loss=1.78650, test err=0.531
# Trial 1, Epoch: 1600, He model, h=50, lr=0.00100, Loss=1.58117, test err=0.446
# Trial 1, Epoch: 2000, He model, h=50, lr=0.00100, Loss=1.36617, test err=0.399
# Trial 1, Epoch: 2400, He model, h=50, lr=0.00100, Loss=1.15935, test err=0.377
# Trial 1, Epoch: 2800, He model, h=50, lr=0.00100, Loss=0.97097, test err=0.363
# Trial 1, Epoch: 3200, He model, h=50, lr=0.00100, Loss=0.80684, test err=0.355
# Trial 1, Epoch: 3600, He model, h=50, lr=0.00100, Loss=0.66957, test err=0.348
# Trial 1, Epoch: 4000, He model, h=50, lr=0.00100, Loss=0.55664, test err=0.342
# Trial 1, Epoch: 4400, He model, h=50, lr=0.00100, Loss=0.46498, test err=0.338
# Trial 1, Epoch: 4800, He model, h=50, lr=0.00100, Loss=0.39113, test err=0.333
# Trial 1, Epoch: 5200, He model, h=50, lr=0.00100, Loss=0.33179, test err=0.330
# Trial 1, Epoch: 5600, He model, h=50, lr=0.00100, Loss=0.28399, test err=0.327
# Trial 1, Epoch: 6000, He model, h=50, lr=0.00100, Loss=0.24529, test err=0.326
# Trial 1, Epoch: 6400, He model, h=50, lr=0.00100, Loss=0.21373, test err=0.325
# Trial 1, Epoch: 6800, He model, h=50, lr=0.00100, Loss=0.18779, test err=0.324
# Trial 2, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.37081, test err=0.925
# Trial 2, Epoch: 400, He model, h=50, lr=0.00100, Loss=2.20757, test err=0.829
# Trial 2, Epoch: 800, He model, h=50, lr=0.00100, Loss=2.07456, test err=0.724
# Trial 2, Epoch: 1200, He model, h=50, lr=0.00100, Loss=1.92562, test err=0.600
# Trial 2, Epoch: 1600, He model, h=50, lr=0.00100, Loss=1.75352, test err=0.508
# Trial 2, Epoch: 2000, He model, h=50, lr=0.00100, Loss=1.56100, test err=0.454
# Trial 2, Epoch: 2400, He model, h=50, lr=0.00100, Loss=1.36013, test err=0.417
# Trial 2, Epoch: 2800, He model, h=50, lr=0.00100, Loss=1.16224, test err=0.387
# Trial 2, Epoch: 3200, He model, h=50, lr=0.00100, Loss=0.97911, test err=0.371
# Trial 2, Epoch: 3600, He model, h=50, lr=0.00100, Loss=0.81964, test err=0.358
# Trial 2, Epoch: 4000, He model, h=50, lr=0.00100, Loss=0.68541, test err=0.351
# Trial 2, Epoch: 4400, He model, h=50, lr=0.00100, Loss=0.57463, test err=0.344
# Trial 2, Epoch: 4800, He model, h=50, lr=0.00100, Loss=0.48402, test err=0.340
# Trial 2, Epoch: 5200, He model, h=50, lr=0.00100, Loss=0.40986, test err=0.336
# Trial 2, Epoch: 5600, He model, h=50, lr=0.00100, Loss=0.34911, test err=0.332
# Trial 2, Epoch: 6000, He model, h=50, lr=0.00100, Loss=0.29960, test err=0.330
# Trial 2, Epoch: 6400, He model, h=50, lr=0.00100, Loss=0.25902, test err=0.328
# Trial 2, Epoch: 6800, He model, h=50, lr=0.00100, Loss=0.22558, test err=0.326
# Trial 3, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.35027, test err=0.892
# Trial 3, Epoch: 400, He model, h=50, lr=0.00100, Loss=2.16697, test err=0.831
# Trial 3, Epoch: 800, He model, h=50, lr=0.00100, Loss=1.99552, test err=0.680
# Trial 3, Epoch: 1200, He model, h=50, lr=0.00100, Loss=1.80399, test err=0.515
# Trial 3, Epoch: 1600, He model, h=50, lr=0.00100, Loss=1.59438, test err=0.435
# Trial 3, Epoch: 2000, He model, h=50, lr=0.00100, Loss=1.37343, test err=0.382
# Trial 3, Epoch: 2400, He model, h=50, lr=0.00100, Loss=1.15832, test err=0.355
# Trial 3, Epoch: 2800, He model, h=50, lr=0.00100, Loss=0.96397, test err=0.336
# Trial 3, Epoch: 3200, He model, h=50, lr=0.00100, Loss=0.79725, test err=0.327
# Trial 3, Epoch: 3600, He model, h=50, lr=0.00100, Loss=0.66008, test err=0.320
# Trial 3, Epoch: 4000, He model, h=50, lr=0.00100, Loss=0.54843, test err=0.316
# Trial 3, Epoch: 4400, He model, h=50, lr=0.00100, Loss=0.45844, test err=0.316
# Trial 3, Epoch: 4800, He model, h=50, lr=0.00100, Loss=0.38624, test err=0.313
# Trial 3, Epoch: 5200, He model, h=50, lr=0.00100, Loss=0.32828, test err=0.314
# Trial 3, Epoch: 5600, He model, h=50, lr=0.00100, Loss=0.28158, test err=0.313
# Trial 3, Epoch: 6000, He model, h=50, lr=0.00100, Loss=0.24366, test err=0.314
# Trial 3, Epoch: 6400, He model, h=50, lr=0.00100, Loss=0.21267, test err=0.314
# Trial 3, Epoch: 6800, He model, h=50, lr=0.00100, Loss=0.18714, test err=0.314
# Trial 4, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.33109, test err=0.890
# Trial 4, Epoch: 400, He model, h=50, lr=0.00100, Loss=2.18687, test err=0.806
# Trial 4, Epoch: 800, He model, h=50, lr=0.00100, Loss=2.04697, test err=0.676
# Trial 4, Epoch: 1200, He model, h=50, lr=0.00100, Loss=1.88959, test err=0.581
# Trial 4, Epoch: 1600, He model, h=50, lr=0.00100, Loss=1.70750, test err=0.518
# Trial 4, Epoch: 2000, He model, h=50, lr=0.00100, Loss=1.50492, test err=0.463
# Trial 4, Epoch: 2400, He model, h=50, lr=0.00100, Loss=1.29081, test err=0.420
# Trial 4, Epoch: 2800, He model, h=50, lr=0.00100, Loss=1.08193, test err=0.392
# Trial 4, Epoch: 3200, He model, h=50, lr=0.00100, Loss=0.89268, test err=0.372
# Trial 4, Epoch: 3600, He model, h=50, lr=0.00100, Loss=0.73223, test err=0.359
# Trial 4, Epoch: 4000, He model, h=50, lr=0.00100, Loss=0.60154, test err=0.351
# Trial 4, Epoch: 4400, He model, h=50, lr=0.00100, Loss=0.49766, test err=0.343
# Trial 4, Epoch: 4800, He model, h=50, lr=0.00100, Loss=0.41516, test err=0.338
# Trial 4, Epoch: 5200, He model, h=50, lr=0.00100, Loss=0.34948, test err=0.336
# Trial 4, Epoch: 5600, He model, h=50, lr=0.00100, Loss=0.29706, test err=0.335
# Trial 4, Epoch: 6000, He model, h=50, lr=0.00100, Loss=0.25496, test err=0.332
# Trial 4, Epoch: 6400, He model, h=50, lr=0.00100, Loss=0.22087, test err=0.332
# Trial 4, Epoch: 6800, He model, h=50, lr=0.00100, Loss=0.19311, test err=0.331
# Trial 0, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=4.35222, test err=0.899
# Trial 0, Epoch: 400, V1 model, h=50, lr=0.01000, Loss=0.17400, test err=0.401
# Trial 0, Epoch: 800, V1 model, h=50, lr=0.01000, Loss=0.06520, test err=0.379
# Trial 0, Epoch: 1200, V1 model, h=50, lr=0.01000, Loss=0.03515, test err=0.372
# Trial 0, Epoch: 1600, V1 model, h=50, lr=0.01000, Loss=0.02288, test err=0.367
# Trial 0, Epoch: 2000, V1 model, h=50, lr=0.01000, Loss=0.01655, test err=0.365
# Trial 0, Epoch: 2400, V1 model, h=50, lr=0.01000, Loss=0.01282, test err=0.363
# Trial 0, Epoch: 2800, V1 model, h=50, lr=0.01000, Loss=0.01038, test err=0.362
# Trial 0, Epoch: 3200, V1 model, h=50, lr=0.01000, Loss=0.00867, test err=0.360
# Trial 0, Epoch: 3600, V1 model, h=50, lr=0.01000, Loss=0.00742, test err=0.359
# Trial 0, Epoch: 4000, V1 model, h=50, lr=0.01000, Loss=0.00646, test err=0.358
# Trial 0, Epoch: 4400, V1 model, h=50, lr=0.01000, Loss=0.00571, test err=0.357
# Trial 0, Epoch: 4800, V1 model, h=50, lr=0.01000, Loss=0.00511, test err=0.356
# Trial 0, Epoch: 5200, V1 model, h=50, lr=0.01000, Loss=0.00461, test err=0.356
# Trial 0, Epoch: 5600, V1 model, h=50, lr=0.01000, Loss=0.00420, test err=0.355
# Trial 0, Epoch: 6000, V1 model, h=50, lr=0.01000, Loss=0.00385, test err=0.355
# Trial 0, Epoch: 6400, V1 model, h=50, lr=0.01000, Loss=0.00355, test err=0.355
# Trial 0, Epoch: 6800, V1 model, h=50, lr=0.01000, Loss=0.00330, test err=0.355
# Trial 1, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=3.76890, test err=0.859
# Trial 1, Epoch: 400, V1 model, h=50, lr=0.01000, Loss=0.14374, test err=0.383
# Trial 1, Epoch: 800, V1 model, h=50, lr=0.01000, Loss=0.05769, test err=0.368
# Trial 1, Epoch: 1200, V1 model, h=50, lr=0.01000, Loss=0.03285, test err=0.362
# Trial 1, Epoch: 1600, V1 model, h=50, lr=0.01000, Loss=0.02211, test err=0.357
# Trial 1, Epoch: 2000, V1 model, h=50, lr=0.01000, Loss=0.01636, test err=0.356
# Trial 1, Epoch: 2400, V1 model, h=50, lr=0.01000, Loss=0.01285, test err=0.354
# Trial 1, Epoch: 2800, V1 model, h=50, lr=0.01000, Loss=0.01050, test err=0.352
# Trial 1, Epoch: 3200, V1 model, h=50, lr=0.01000, Loss=0.00884, test err=0.352
# Trial 1, Epoch: 3600, V1 model, h=50, lr=0.01000, Loss=0.00761, test err=0.350
# Trial 1, Epoch: 4000, V1 model, h=50, lr=0.01000, Loss=0.00666, test err=0.349
# Trial 1, Epoch: 4400, V1 model, h=50, lr=0.01000, Loss=0.00591, test err=0.349
# Trial 1, Epoch: 4800, V1 model, h=50, lr=0.01000, Loss=0.00530, test err=0.348
# Trial 1, Epoch: 5200, V1 model, h=50, lr=0.01000, Loss=0.00479, test err=0.348
# Trial 1, Epoch: 5600, V1 model, h=50, lr=0.01000, Loss=0.00437, test err=0.348
# Trial 1, Epoch: 6000, V1 model, h=50, lr=0.01000, Loss=0.00402, test err=0.347
# Trial 1, Epoch: 6400, V1 model, h=50, lr=0.01000, Loss=0.00371, test err=0.346
# Trial 1, Epoch: 6800, V1 model, h=50, lr=0.01000, Loss=0.00345, test err=0.346
# Trial 2, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=4.49714, test err=0.926
# Trial 2, Epoch: 400, V1 model, h=50, lr=0.01000, Loss=0.15347, test err=0.416
# Trial 2, Epoch: 800, V1 model, h=50, lr=0.01000, Loss=0.06328, test err=0.409
# Trial 2, Epoch: 1200, V1 model, h=50, lr=0.01000, Loss=0.03577, test err=0.407
# Trial 2, Epoch: 1600, V1 model, h=50, lr=0.01000, Loss=0.02375, test err=0.405
# Trial 2, Epoch: 2000, V1 model, h=50, lr=0.01000, Loss=0.01738, test err=0.404
# Trial 2, Epoch: 2400, V1 model, h=50, lr=0.01000, Loss=0.01354, test err=0.403
# Trial 2, Epoch: 2800, V1 model, h=50, lr=0.01000, Loss=0.01101, test err=0.402
# Trial 2, Epoch: 3200, V1 model, h=50, lr=0.01000, Loss=0.00922, test err=0.401
# Trial 2, Epoch: 3600, V1 model, h=50, lr=0.01000, Loss=0.00790, test err=0.399
# Trial 2, Epoch: 4000, V1 model, h=50, lr=0.01000, Loss=0.00689, test err=0.398
# Trial 2, Epoch: 4400, V1 model, h=50, lr=0.01000, Loss=0.00610, test err=0.398
# Trial 2, Epoch: 4800, V1 model, h=50, lr=0.01000, Loss=0.00547, test err=0.398
# Trial 2, Epoch: 5200, V1 model, h=50, lr=0.01000, Loss=0.00494, test err=0.398
# Trial 2, Epoch: 5600, V1 model, h=50, lr=0.01000, Loss=0.00451, test err=0.397
# Trial 2, Epoch: 6000, V1 model, h=50, lr=0.01000, Loss=0.00414, test err=0.396
# Trial 2, Epoch: 6400, V1 model, h=50, lr=0.01000, Loss=0.00382, test err=0.396
# Trial 2, Epoch: 6800, V1 model, h=50, lr=0.01000, Loss=0.00355, test err=0.396
# Trial 3, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=8.40417, test err=0.887
# Trial 3, Epoch: 400, V1 model, h=50, lr=0.01000, Loss=0.12084, test err=0.383
# Trial 3, Epoch: 800, V1 model, h=50, lr=0.01000, Loss=0.04737, test err=0.374
# Trial 3, Epoch: 1200, V1 model, h=50, lr=0.01000, Loss=0.02744, test err=0.371
# Trial 3, Epoch: 1600, V1 model, h=50, lr=0.01000, Loss=0.01881, test err=0.367
# Trial 3, Epoch: 2000, V1 model, h=50, lr=0.01000, Loss=0.01412, test err=0.367
# Trial 3, Epoch: 2400, V1 model, h=50, lr=0.01000, Loss=0.01121, test err=0.366
# Trial 3, Epoch: 2800, V1 model, h=50, lr=0.01000, Loss=0.00925, test err=0.364
# Trial 3, Epoch: 3200, V1 model, h=50, lr=0.01000, Loss=0.00784, test err=0.364
# Trial 3, Epoch: 3600, V1 model, h=50, lr=0.01000, Loss=0.00679, test err=0.363
# Trial 3, Epoch: 4000, V1 model, h=50, lr=0.01000, Loss=0.00597, test err=0.363
# Trial 3, Epoch: 4400, V1 model, h=50, lr=0.01000, Loss=0.00532, test err=0.362
# Trial 3, Epoch: 4800, V1 model, h=50, lr=0.01000, Loss=0.00479, test err=0.361
# Trial 3, Epoch: 5200, V1 model, h=50, lr=0.01000, Loss=0.00435, test err=0.361
# Trial 3, Epoch: 5600, V1 model, h=50, lr=0.01000, Loss=0.00399, test err=0.360
# Trial 3, Epoch: 6000, V1 model, h=50, lr=0.01000, Loss=0.00367, test err=0.359
# Trial 3, Epoch: 6400, V1 model, h=50, lr=0.01000, Loss=0.00340, test err=0.359
# Trial 3, Epoch: 6800, V1 model, h=50, lr=0.01000, Loss=0.00317, test err=0.359
# Trial 4, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=3.24718, test err=0.852
# Trial 4, Epoch: 400, V1 model, h=50, lr=0.01000, Loss=0.12509, test err=0.357
# Trial 4, Epoch: 800, V1 model, h=50, lr=0.01000, Loss=0.05171, test err=0.350
# Trial 4, Epoch: 1200, V1 model, h=50, lr=0.01000, Loss=0.03027, test err=0.347
# Trial 4, Epoch: 1600, V1 model, h=50, lr=0.01000, Loss=0.02070, test err=0.345
# Trial 4, Epoch: 2000, V1 model, h=50, lr=0.01000, Loss=0.01545, test err=0.343
# Trial 4, Epoch: 2400, V1 model, h=50, lr=0.01000, Loss=0.01221, test err=0.342
# Trial 4, Epoch: 2800, V1 model, h=50, lr=0.01000, Loss=0.01003, test err=0.341
# Trial 4, Epoch: 3200, V1 model, h=50, lr=0.01000, Loss=0.00847, test err=0.341
# Trial 4, Epoch: 3600, V1 model, h=50, lr=0.01000, Loss=0.00731, test err=0.340
# Trial 4, Epoch: 4000, V1 model, h=50, lr=0.01000, Loss=0.00641, test err=0.339
# Trial 4, Epoch: 4400, V1 model, h=50, lr=0.01000, Loss=0.00570, test err=0.338
# Trial 4, Epoch: 4800, V1 model, h=50, lr=0.01000, Loss=0.00512, test err=0.337
# Trial 4, Epoch: 5200, V1 model, h=50, lr=0.01000, Loss=0.00465, test err=0.337
# Trial 4, Epoch: 5600, V1 model, h=50, lr=0.01000, Loss=0.00424, test err=0.336
# Trial 4, Epoch: 6000, V1 model, h=50, lr=0.01000, Loss=0.00390, test err=0.336
# Trial 4, Epoch: 6400, V1 model, h=50, lr=0.01000, Loss=0.00361, test err=0.336
# Trial 4, Epoch: 6800, V1 model, h=50, lr=0.01000, Loss=0.00336, test err=0.335
# Trial 0, Epoch: 0, RF model, h=50, lr=0.01000, Loss=2.53110, test err=0.898
# Trial 0, Epoch: 400, RF model, h=50, lr=0.01000, Loss=0.34873, test err=0.425
# Trial 0, Epoch: 800, RF model, h=50, lr=0.01000, Loss=0.09288, test err=0.399
# Trial 0, Epoch: 1200, RF model, h=50, lr=0.01000, Loss=0.04568, test err=0.390
# Trial 0, Epoch: 1600, RF model, h=50, lr=0.01000, Loss=0.02873, test err=0.385
# Trial 0, Epoch: 2000, RF model, h=50, lr=0.01000, Loss=0.02043, test err=0.381
# Trial 0, Epoch: 2400, RF model, h=50, lr=0.01000, Loss=0.01564, test err=0.379
# Trial 0, Epoch: 2800, RF model, h=50, lr=0.01000, Loss=0.01256, test err=0.377
# Trial 0, Epoch: 3200, RF model, h=50, lr=0.01000, Loss=0.01042, test err=0.376
# Trial 0, Epoch: 3600, RF model, h=50, lr=0.01000, Loss=0.00887, test err=0.375
# Trial 0, Epoch: 4000, RF model, h=50, lr=0.01000, Loss=0.00770, test err=0.373
# Trial 0, Epoch: 4400, RF model, h=50, lr=0.01000, Loss=0.00678, test err=0.373
# Trial 0, Epoch: 4800, RF model, h=50, lr=0.01000, Loss=0.00605, test err=0.371
# Trial 0, Epoch: 5200, RF model, h=50, lr=0.01000, Loss=0.00544, test err=0.370
# Trial 0, Epoch: 5600, RF model, h=50, lr=0.01000, Loss=0.00494, test err=0.370
# Trial 0, Epoch: 6000, RF model, h=50, lr=0.01000, Loss=0.00452, test err=0.369
# Trial 0, Epoch: 6400, RF model, h=50, lr=0.01000, Loss=0.00416, test err=0.369
# Trial 0, Epoch: 6800, RF model, h=50, lr=0.01000, Loss=0.00385, test err=0.368
# Trial 1, Epoch: 0, RF model, h=50, lr=0.01000, Loss=2.53917, test err=0.896
# Trial 1, Epoch: 400, RF model, h=50, lr=0.01000, Loss=0.31849, test err=0.429
# Trial 1, Epoch: 800, RF model, h=50, lr=0.01000, Loss=0.09778, test err=0.406
# Trial 1, Epoch: 1200, RF model, h=50, lr=0.01000, Loss=0.04882, test err=0.399
# Trial 1, Epoch: 1600, RF model, h=50, lr=0.01000, Loss=0.03075, test err=0.395
# Trial 1, Epoch: 2000, RF model, h=50, lr=0.01000, Loss=0.02189, test err=0.393
# Trial 1, Epoch: 2400, RF model, h=50, lr=0.01000, Loss=0.01675, test err=0.390
# Trial 1, Epoch: 2800, RF model, h=50, lr=0.01000, Loss=0.01345, test err=0.388
# Trial 1, Epoch: 3200, RF model, h=50, lr=0.01000, Loss=0.01116, test err=0.388
# Trial 1, Epoch: 3600, RF model, h=50, lr=0.01000, Loss=0.00950, test err=0.387
# Trial 1, Epoch: 4000, RF model, h=50, lr=0.01000, Loss=0.00824, test err=0.386
# Trial 1, Epoch: 4400, RF model, h=50, lr=0.01000, Loss=0.00725, test err=0.384
# Trial 1, Epoch: 4800, RF model, h=50, lr=0.01000, Loss=0.00646, test err=0.384
# Trial 1, Epoch: 5200, RF model, h=50, lr=0.01000, Loss=0.00582, test err=0.384
# Trial 1, Epoch: 5600, RF model, h=50, lr=0.01000, Loss=0.00529, test err=0.383
# Trial 1, Epoch: 6000, RF model, h=50, lr=0.01000, Loss=0.00484, test err=0.382
# Trial 1, Epoch: 6400, RF model, h=50, lr=0.01000, Loss=0.00445, test err=0.382
# Trial 1, Epoch: 6800, RF model, h=50, lr=0.01000, Loss=0.00412, test err=0.381
# Trial 2, Epoch: 0, RF model, h=50, lr=0.01000, Loss=2.44485, test err=0.893
# Trial 2, Epoch: 400, RF model, h=50, lr=0.01000, Loss=0.34123, test err=0.401
# Trial 2, Epoch: 800, RF model, h=50, lr=0.01000, Loss=0.09237, test err=0.377
# Trial 2, Epoch: 1200, RF model, h=50, lr=0.01000, Loss=0.04499, test err=0.368
# Trial 2, Epoch: 1600, RF model, h=50, lr=0.01000, Loss=0.02830, test err=0.366
# Trial 2, Epoch: 2000, RF model, h=50, lr=0.01000, Loss=0.02015, test err=0.363
# Trial 2, Epoch: 2400, RF model, h=50, lr=0.01000, Loss=0.01544, test err=0.362
# Trial 2, Epoch: 2800, RF model, h=50, lr=0.01000, Loss=0.01242, test err=0.360
# Trial 2, Epoch: 3600, RF model, h=50, lr=0.01000, Loss=0.00881, test err=0.359
# Trial 2, Epoch: 4000, RF model, h=50, lr=0.01000, Loss=0.00765, test err=0.358
# Trial 2, Epoch: 4400, RF model, h=50, lr=0.01000, Loss=0.00675, test err=0.357
# Trial 2, Epoch: 4800, RF model, h=50, lr=0.01000, Loss=0.00603, test err=0.357
# Trial 2, Epoch: 5200, RF model, h=50, lr=0.01000, Loss=0.00543, test err=0.356
# Trial 2, Epoch: 5600, RF model, h=50, lr=0.01000, Loss=0.00494, test err=0.356
# Trial 2, Epoch: 6000, RF model, h=50, lr=0.01000, Loss=0.00452, test err=0.355
# Trial 2, Epoch: 6400, RF model, h=50, lr=0.01000, Loss=0.00417, test err=0.355
# Trial 2, Epoch: 6800, RF model, h=50, lr=0.01000, Loss=0.00386, test err=0.355
# Trial 3, Epoch: 0, RF model, h=50, lr=0.01000, Loss=2.68007, test err=0.941
# Trial 3, Epoch: 400, RF model, h=50, lr=0.01000, Loss=0.29505, test err=0.407
# Trial 3, Epoch: 800, RF model, h=50, lr=0.01000, Loss=0.08379, test err=0.390
# Trial 3, Epoch: 1200, RF model, h=50, lr=0.01000, Loss=0.04263, test err=0.384
# Trial 3, Epoch: 1600, RF model, h=50, lr=0.01000, Loss=0.02739, test err=0.381
# Trial 3, Epoch: 2000, RF model, h=50, lr=0.01000, Loss=0.01977, test err=0.378
# Trial 3, Epoch: 2400, RF model, h=50, lr=0.01000, Loss=0.01529, test err=0.376
# Trial 3, Epoch: 2800, RF model, h=50, lr=0.01000, Loss=0.01237, test err=0.373
# Trial 3, Epoch: 3200, RF model, h=50, lr=0.01000, Loss=0.01033, test err=0.373
# Trial 3, Epoch: 3600, RF model, h=50, lr=0.01000, Loss=0.00883, test err=0.372
# Trial 3, Epoch: 4000, RF model, h=50, lr=0.01000, Loss=0.00769, test err=0.371
# Trial 3, Epoch: 4400, RF model, h=50, lr=0.01000, Loss=0.00679, test err=0.370
# Trial 3, Epoch: 4800, RF model, h=50, lr=0.01000, Loss=0.00607, test err=0.370
# Trial 3, Epoch: 5200, RF model, h=50, lr=0.01000, Loss=0.00548, test err=0.370
# Trial 3, Epoch: 5600, RF model, h=50, lr=0.01000, Loss=0.00499, test err=0.369
# Trial 3, Epoch: 6000, RF model, h=50, lr=0.01000, Loss=0.00458, test err=0.369
# Trial 3, Epoch: 6400, RF model, h=50, lr=0.01000, Loss=0.00422, test err=0.368
# Trial 3, Epoch: 6800, RF model, h=50, lr=0.01000, Loss=0.00392, test err=0.367
# Trial 4, Epoch: 0, RF model, h=50, lr=0.01000, Loss=2.67528, test err=0.899
# Trial 4, Epoch: 400, RF model, h=50, lr=0.01000, Loss=0.30801, test err=0.471
# Trial 4, Epoch: 800, RF model, h=50, lr=0.01000, Loss=0.08535, test err=0.426
# Trial 4, Epoch: 1200, RF model, h=50, lr=0.01000, Loss=0.04254, test err=0.413
# Trial 4, Epoch: 1600, RF model, h=50, lr=0.01000, Loss=0.02700, test err=0.405
# Trial 4, Epoch: 2000, RF model, h=50, lr=0.01000, Loss=0.01936, test err=0.401
# Trial 4, Epoch: 2400, RF model, h=50, lr=0.01000, Loss=0.01492, test err=0.398
# Trial 4, Epoch: 2800, RF model, h=50, lr=0.01000, Loss=0.01205, test err=0.396
# Trial 4, Epoch: 3200, RF model, h=50, lr=0.01000, Loss=0.01006, test err=0.394
# Trial 4, Epoch: 3600, RF model, h=50, lr=0.01000, Loss=0.00860, test err=0.392
# Trial 4, Epoch: 4000, RF model, h=50, lr=0.01000, Loss=0.00749, test err=0.391
# Trial 4, Epoch: 4400, RF model, h=50, lr=0.01000, Loss=0.00663, test err=0.390
# Trial 4, Epoch: 4800, RF model, h=50, lr=0.01000, Loss=0.00593, test err=0.389
# Trial 4, Epoch: 5200, RF model, h=50, lr=0.01000, Loss=0.00535, test err=0.388
# Trial 4, Epoch: 5600, RF model, h=50, lr=0.01000, Loss=0.00487, test err=0.388
# Trial 4, Epoch: 6000, RF model, h=50, lr=0.01000, Loss=0.00447, test err=0.388
# Trial 4, Epoch: 6400, RF model, h=50, lr=0.01000, Loss=0.00412, test err=0.388
# Trial 4, Epoch: 6800, RF model, h=50, lr=0.01000, Loss=0.00382, test err=0.387
# Trial 0, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.32749, test err=0.873
# Trial 0, Epoch: 400, He model, h=50, lr=0.01000, Loss=0.59102, test err=0.321
# Trial 0, Epoch: 800, He model, h=50, lr=0.01000, Loss=0.14056, test err=0.308
# Trial 0, Epoch: 1200, He model, h=50, lr=0.01000, Loss=0.06172, test err=0.309
# Trial 0, Epoch: 1600, He model, h=50, lr=0.01000, Loss=0.03648, test err=0.307
# Trial 0, Epoch: 2000, He model, h=50, lr=0.01000, Loss=0.02499, test err=0.308
# Trial 0, Epoch: 2400, He model, h=50, lr=0.01000, Loss=0.01865, test err=0.308
# Trial 0, Epoch: 2800, He model, h=50, lr=0.01000, Loss=0.01471, test err=0.308
# Trial 0, Epoch: 3200, He model, h=50, lr=0.01000, Loss=0.01206, test err=0.307
# Trial 0, Epoch: 3600, He model, h=50, lr=0.01000, Loss=0.01016, test err=0.307
# Trial 0, Epoch: 4000, He model, h=50, lr=0.01000, Loss=0.00874, test err=0.307
# Trial 0, Epoch: 4400, He model, h=50, lr=0.01000, Loss=0.00765, test err=0.307
# Trial 0, Epoch: 4800, He model, h=50, lr=0.01000, Loss=0.00679, test err=0.308
# Trial 0, Epoch: 5200, He model, h=50, lr=0.01000, Loss=0.00609, test err=0.308
# Trial 0, Epoch: 5600, He model, h=50, lr=0.01000, Loss=0.00551, test err=0.308
# Trial 0, Epoch: 6000, He model, h=50, lr=0.01000, Loss=0.00503, test err=0.308
# Trial 0, Epoch: 6400, He model, h=50, lr=0.01000, Loss=0.00461, test err=0.307
# Trial 0, Epoch: 6800, He model, h=50, lr=0.01000, Loss=0.00426, test err=0.307
# Trial 1, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.32151, test err=0.920
# Trial 1, Epoch: 400, He model, h=50, lr=0.01000, Loss=0.65753, test err=0.354
# Trial 1, Epoch: 800, He model, h=50, lr=0.01000, Loss=0.14781, test err=0.329
# Trial 1, Epoch: 1200, He model, h=50, lr=0.01000, Loss=0.06303, test err=0.325
# Trial 1, Epoch: 1600, He model, h=50, lr=0.01000, Loss=0.03673, test err=0.324
# Trial 1, Epoch: 2000, He model, h=50, lr=0.01000, Loss=0.02500, test err=0.323
# Trial 1, Epoch: 2400, He model, h=50, lr=0.01000, Loss=0.01861, test err=0.323
# Trial 1, Epoch: 2800, He model, h=50, lr=0.01000, Loss=0.01465, test err=0.323
# Trial 1, Epoch: 3200, He model, h=50, lr=0.01000, Loss=0.01200, test err=0.323
# Trial 1, Epoch: 3600, He model, h=50, lr=0.01000, Loss=0.01010, test err=0.322
# Trial 1, Epoch: 4000, He model, h=50, lr=0.01000, Loss=0.00869, test err=0.322
# Trial 1, Epoch: 4400, He model, h=50, lr=0.01000, Loss=0.00761, test err=0.321
# Trial 1, Epoch: 4800, He model, h=50, lr=0.01000, Loss=0.00675, test err=0.321
# Trial 1, Epoch: 5200, He model, h=50, lr=0.01000, Loss=0.00605, test err=0.321
# Trial 1, Epoch: 5600, He model, h=50, lr=0.01000, Loss=0.00547, test err=0.321
# Trial 1, Epoch: 6000, He model, h=50, lr=0.01000, Loss=0.00499, test err=0.321
# Trial 1, Epoch: 6400, He model, h=50, lr=0.01000, Loss=0.00458, test err=0.321
# Trial 1, Epoch: 6800, He model, h=50, lr=0.01000, Loss=0.00423, test err=0.320
# Trial 2, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.33055, test err=0.903
# Trial 2, Epoch: 400, He model, h=50, lr=0.01000, Loss=0.60770, test err=0.325
# Trial 2, Epoch: 800, He model, h=50, lr=0.01000, Loss=0.14653, test err=0.306
# Trial 2, Epoch: 1200, He model, h=50, lr=0.01000, Loss=0.06441, test err=0.304
# Trial 2, Epoch: 1600, He model, h=50, lr=0.01000, Loss=0.03795, test err=0.303
# Trial 2, Epoch: 2000, He model, h=50, lr=0.01000, Loss=0.02595, test err=0.304
# Trial 2, Epoch: 2400, He model, h=50, lr=0.01000, Loss=0.01933, test err=0.304
# Trial 2, Epoch: 2800, He model, h=50, lr=0.01000, Loss=0.01523, test err=0.304
# Trial 2, Epoch: 3200, He model, h=50, lr=0.01000, Loss=0.01245, test err=0.304
# Trial 2, Epoch: 3600, He model, h=50, lr=0.01000, Loss=0.01047, test err=0.303
# Trial 2, Epoch: 4000, He model, h=50, lr=0.01000, Loss=0.00900, test err=0.303
# Trial 2, Epoch: 4400, He model, h=50, lr=0.01000, Loss=0.00786, test err=0.304
# Trial 2, Epoch: 4800, He model, h=50, lr=0.01000, Loss=0.00697, test err=0.305
# Trial 2, Epoch: 5200, He model, h=50, lr=0.01000, Loss=0.00624, test err=0.305
# Trial 2, Epoch: 5600, He model, h=50, lr=0.01000, Loss=0.00565, test err=0.305
# Trial 2, Epoch: 6000, He model, h=50, lr=0.01000, Loss=0.00515, test err=0.304
# Trial 2, Epoch: 6400, He model, h=50, lr=0.01000, Loss=0.00472, test err=0.304
# Trial 2, Epoch: 6800, He model, h=50, lr=0.01000, Loss=0.00436, test err=0.304
# Trial 3, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.34577, test err=0.909
# Trial 3, Epoch: 400, He model, h=50, lr=0.01000, Loss=0.74742, test err=0.361
# Trial 3, Epoch: 800, He model, h=50, lr=0.01000, Loss=0.16139, test err=0.317
# Trial 3, Epoch: 1200, He model, h=50, lr=0.01000, Loss=0.06668, test err=0.315
# Trial 3, Epoch: 1600, He model, h=50, lr=0.01000, Loss=0.03838, test err=0.316
# Trial 3, Epoch: 2000, He model, h=50, lr=0.01000, Loss=0.02598, test err=0.316
# Trial 3, Epoch: 2400, He model, h=50, lr=0.01000, Loss=0.01927, test err=0.316
# Trial 3, Epoch: 2800, He model, h=50, lr=0.01000, Loss=0.01514, test err=0.315
# Trial 3, Epoch: 3200, He model, h=50, lr=0.01000, Loss=0.01237, test err=0.316
# Trial 3, Epoch: 3600, He model, h=50, lr=0.01000, Loss=0.01040, test err=0.315
# Trial 3, Epoch: 4000, He model, h=50, lr=0.01000, Loss=0.00894, test err=0.315
# Trial 3, Epoch: 4400, He model, h=50, lr=0.01000, Loss=0.00781, test err=0.315
# Trial 3, Epoch: 4800, He model, h=50, lr=0.01000, Loss=0.00692, test err=0.314
# Trial 3, Epoch: 5200, He model, h=50, lr=0.01000, Loss=0.00620, test err=0.314
# Trial 3, Epoch: 5600, He model, h=50, lr=0.01000, Loss=0.00561, test err=0.314
# Trial 3, Epoch: 6000, He model, h=50, lr=0.01000, Loss=0.00512, test err=0.314
# Trial 3, Epoch: 6400, He model, h=50, lr=0.01000, Loss=0.00470, test err=0.314
# Trial 3, Epoch: 6800, He model, h=50, lr=0.01000, Loss=0.00433, test err=0.314
# Trial 4, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.33414, test err=0.893
# Trial 4, Epoch: 400, He model, h=50, lr=0.01000, Loss=0.62591, test err=0.314
# Trial 4, Epoch: 800, He model, h=50, lr=0.01000, Loss=0.14477, test err=0.301
# Trial 4, Epoch: 1200, He model, h=50, lr=0.01000, Loss=0.06282, test err=0.302
# Trial 4, Epoch: 1600, He model, h=50, lr=0.01000, Loss=0.03679, test err=0.300
# Trial 4, Epoch: 2000, He model, h=50, lr=0.01000, Loss=0.02511, test err=0.300
# Trial 4, Epoch: 2400, He model, h=50, lr=0.01000, Loss=0.01870, test err=0.301
# Trial 4, Epoch: 2800, He model, h=50, lr=0.01000, Loss=0.01473, test err=0.301
# Trial 4, Epoch: 3200, He model, h=50, lr=0.01000, Loss=0.01206, test err=0.302
# Trial 4, Epoch: 3600, He model, h=50, lr=0.01000, Loss=0.01016, test err=0.302
# Trial 4, Epoch: 4000, He model, h=50, lr=0.01000, Loss=0.00874, test err=0.302
# Trial 4, Epoch: 4400, He model, h=50, lr=0.01000, Loss=0.00765, test err=0.303
# Trial 4, Epoch: 4800, He model, h=50, lr=0.01000, Loss=0.00678, test err=0.303
# Trial 4, Epoch: 5200, He model, h=50, lr=0.01000, Loss=0.00608, test err=0.304
# Trial 4, Epoch: 5600, He model, h=50, lr=0.01000, Loss=0.00551, test err=0.304
# Trial 4, Epoch: 6000, He model, h=50, lr=0.01000, Loss=0.00502, test err=0.304
# Trial 4, Epoch: 6400, He model, h=50, lr=0.01000, Loss=0.00461, test err=0.304
# Trial 4, Epoch: 6800, He model, h=50, lr=0.01000, Loss=0.00426, test err=0.304
# Trial 0, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=3.28491, test err=0.771
# Trial 0, Epoch: 400, V1 model, h=50, lr=0.10000, Loss=0.00617, test err=0.359
# Trial 0, Epoch: 800, V1 model, h=50, lr=0.10000, Loss=0.00266, test err=0.355
# Trial 0, Epoch: 1200, V1 model, h=50, lr=0.10000, Loss=0.00165, test err=0.354
# Trial 0, Epoch: 1600, V1 model, h=50, lr=0.10000, Loss=0.00118, test err=0.352
# Trial 0, Epoch: 2000, V1 model, h=50, lr=0.10000, Loss=0.00091, test err=0.351
# Trial 0, Epoch: 2400, V1 model, h=50, lr=0.10000, Loss=0.00074, test err=0.350
# Trial 0, Epoch: 2800, V1 model, h=50, lr=0.10000, Loss=0.00062, test err=0.350
# Trial 0, Epoch: 3200, V1 model, h=50, lr=0.10000, Loss=0.00053, test err=0.349
# Trial 0, Epoch: 3600, V1 model, h=50, lr=0.10000, Loss=0.00047, test err=0.349
# Trial 0, Epoch: 4000, V1 model, h=50, lr=0.10000, Loss=0.00041, test err=0.348
# Trial 0, Epoch: 4400, V1 model, h=50, lr=0.10000, Loss=0.00037, test err=0.347
# Trial 0, Epoch: 4800, V1 model, h=50, lr=0.10000, Loss=0.00034, test err=0.347
# Trial 0, Epoch: 5200, V1 model, h=50, lr=0.10000, Loss=0.00031, test err=0.348
# Trial 0, Epoch: 5600, V1 model, h=50, lr=0.10000, Loss=0.00028, test err=0.347
# Trial 0, Epoch: 6000, V1 model, h=50, lr=0.10000, Loss=0.00026, test err=0.348
# Trial 0, Epoch: 6400, V1 model, h=50, lr=0.10000, Loss=0.00024, test err=0.347
# Trial 0, Epoch: 6800, V1 model, h=50, lr=0.10000, Loss=0.00023, test err=0.347
# Trial 1, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=3.11169, test err=0.825
# Trial 1, Epoch: 400, V1 model, h=50, lr=0.10000, Loss=0.00618, test err=0.319
# Trial 1, Epoch: 800, V1 model, h=50, lr=0.10000, Loss=0.00272, test err=0.317
# Trial 1, Epoch: 1200, V1 model, h=50, lr=0.10000, Loss=0.00169, test err=0.316
# Trial 1, Epoch: 1600, V1 model, h=50, lr=0.10000, Loss=0.00122, test err=0.315
# Trial 1, Epoch: 2000, V1 model, h=50, lr=0.10000, Loss=0.00094, test err=0.315
# Trial 1, Epoch: 2400, V1 model, h=50, lr=0.10000, Loss=0.00076, test err=0.314
# Trial 1, Epoch: 2800, V1 model, h=50, lr=0.10000, Loss=0.00064, test err=0.314
# Trial 1, Epoch: 3200, V1 model, h=50, lr=0.10000, Loss=0.00055, test err=0.314
# Trial 1, Epoch: 3600, V1 model, h=50, lr=0.10000, Loss=0.00048, test err=0.313
# Trial 1, Epoch: 4000, V1 model, h=50, lr=0.10000, Loss=0.00043, test err=0.313
# Trial 1, Epoch: 4400, V1 model, h=50, lr=0.10000, Loss=0.00038, test err=0.313
# Trial 1, Epoch: 4800, V1 model, h=50, lr=0.10000, Loss=0.00035, test err=0.313
# Trial 1, Epoch: 5200, V1 model, h=50, lr=0.10000, Loss=0.00032, test err=0.313
# Trial 1, Epoch: 5600, V1 model, h=50, lr=0.10000, Loss=0.00029, test err=0.313
# Trial 1, Epoch: 6000, V1 model, h=50, lr=0.10000, Loss=0.00027, test err=0.312
# Trial 1, Epoch: 6400, V1 model, h=50, lr=0.10000, Loss=0.00025, test err=0.313
# Trial 1, Epoch: 6800, V1 model, h=50, lr=0.10000, Loss=0.00024, test err=0.313
# Trial 2, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=4.61664, test err=0.870
# Trial 2, Epoch: 400, V1 model, h=50, lr=0.10000, Loss=0.00578, test err=0.332
# Trial 2, Epoch: 800, V1 model, h=50, lr=0.10000, Loss=0.00256, test err=0.327
# Trial 2, Epoch: 1200, V1 model, h=50, lr=0.10000, Loss=0.00160, test err=0.326
# Trial 2, Epoch: 1600, V1 model, h=50, lr=0.10000, Loss=0.00115, test err=0.324
# Trial 2, Epoch: 2000, V1 model, h=50, lr=0.10000, Loss=0.00089, test err=0.322
# Trial 2, Epoch: 2400, V1 model, h=50, lr=0.10000, Loss=0.00073, test err=0.321
# Trial 2, Epoch: 2800, V1 model, h=50, lr=0.10000, Loss=0.00061, test err=0.321
# Trial 2, Epoch: 3200, V1 model, h=50, lr=0.10000, Loss=0.00052, test err=0.320
# Trial 2, Epoch: 3600, V1 model, h=50, lr=0.10000, Loss=0.00046, test err=0.319
# Trial 2, Epoch: 4000, V1 model, h=50, lr=0.10000, Loss=0.00041, test err=0.319
# Trial 2, Epoch: 4400, V1 model, h=50, lr=0.10000, Loss=0.00037, test err=0.319
# Trial 2, Epoch: 4800, V1 model, h=50, lr=0.10000, Loss=0.00033, test err=0.318
# Trial 2, Epoch: 5200, V1 model, h=50, lr=0.10000, Loss=0.00030, test err=0.318
# Trial 2, Epoch: 5600, V1 model, h=50, lr=0.10000, Loss=0.00028, test err=0.317
# Trial 2, Epoch: 6000, V1 model, h=50, lr=0.10000, Loss=0.00026, test err=0.317
# Trial 2, Epoch: 6400, V1 model, h=50, lr=0.10000, Loss=0.00024, test err=0.317
# Trial 2, Epoch: 6800, V1 model, h=50, lr=0.10000, Loss=0.00023, test err=0.317
# Trial 3, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=3.64278, test err=0.785
# Trial 3, Epoch: 400, V1 model, h=50, lr=0.10000, Loss=0.00683, test err=0.362
# Trial 3, Epoch: 800, V1 model, h=50, lr=0.10000, Loss=0.00290, test err=0.359
# Trial 3, Epoch: 1200, V1 model, h=50, lr=0.10000, Loss=0.00178, test err=0.357
# Trial 3, Epoch: 1600, V1 model, h=50, lr=0.10000, Loss=0.00127, test err=0.357
# Trial 3, Epoch: 2000, V1 model, h=50, lr=0.10000, Loss=0.00098, test err=0.356
# Trial 3, Epoch: 2400, V1 model, h=50, lr=0.10000, Loss=0.00079, test err=0.355
# Trial 3, Epoch: 2800, V1 model, h=50, lr=0.10000, Loss=0.00066, test err=0.355
# Trial 3, Epoch: 3200, V1 model, h=50, lr=0.10000, Loss=0.00057, test err=0.355
# Trial 3, Epoch: 3600, V1 model, h=50, lr=0.10000, Loss=0.00050, test err=0.355
# Trial 3, Epoch: 4000, V1 model, h=50, lr=0.10000, Loss=0.00044, test err=0.354
# Trial 3, Epoch: 4400, V1 model, h=50, lr=0.10000, Loss=0.00040, test err=0.354
# Trial 3, Epoch: 4800, V1 model, h=50, lr=0.10000, Loss=0.00036, test err=0.353
# Trial 3, Epoch: 5200, V1 model, h=50, lr=0.10000, Loss=0.00033, test err=0.353
# Trial 3, Epoch: 5600, V1 model, h=50, lr=0.10000, Loss=0.00030, test err=0.353
# Trial 3, Epoch: 6000, V1 model, h=50, lr=0.10000, Loss=0.00028, test err=0.353
# ...
# Trial 4, Epoch: 6800, V1 model, h=400, lr=0.00100, Loss=0.00611, test err=0.284
# Trial 0, Epoch: 0, RF model, h=400, lr=0.00100, Loss=2.36650, test err=0.891
# Trial 0, Epoch: 400, RF model, h=400, lr=0.00100, Loss=0.70865, test err=0.402
# Trial 0, Epoch: 800, RF model, h=400, lr=0.00100, Loss=0.34705, test err=0.366
# Trial 0, Epoch: 1200, RF model, h=400, lr=0.00100, Loss=0.21502, test err=0.356
# Trial 0, Epoch: 1600, RF model, h=400, lr=0.00100, Loss=0.15112, test err=0.355
# Trial 0, Epoch: 2000, RF model, h=400, lr=0.00100, Loss=0.11470, test err=0.354
# Trial 0, Epoch: 2400, RF model, h=400, lr=0.00100, Loss=0.09162, test err=0.354
# Trial 0, Epoch: 2800, RF model, h=400, lr=0.00100, Loss=0.07585, test err=0.353
# Trial 0, Epoch: 3200, RF model, h=400, lr=0.00100, Loss=0.06449, test err=0.352
# Trial 0, Epoch: 3600, RF model, h=400, lr=0.00100, Loss=0.05595, test err=0.352
# Trial 0, Epoch: 4000, RF model, h=400, lr=0.00100, Loss=0.04931, test err=0.352
# Trial 0, Epoch: 4400, RF model, h=400, lr=0.00100, Loss=0.04402, test err=0.351
# Trial 0, Epoch: 4800, RF model, h=400, lr=0.00100, Loss=0.03971, test err=0.350
# Trial 0, Epoch: 5200, RF model, h=400, lr=0.00100, Loss=0.03614, test err=0.350
# Trial 0, Epoch: 5600, RF model, h=400, lr=0.00100, Loss=0.03313, test err=0.350
# Trial 0, Epoch: 6000, RF model, h=400, lr=0.00100, Loss=0.03056, test err=0.349
# Trial 0, Epoch: 6400, RF model, h=400, lr=0.00100, Loss=0.02835, test err=0.350
# Trial 0, Epoch: 6800, RF model, h=400, lr=0.00100, Loss=0.02643, test err=0.349
# Trial 1, Epoch: 0, RF model, h=400, lr=0.00100, Loss=2.42695, test err=0.856
# Trial 1, Epoch: 400, RF model, h=400, lr=0.00100, Loss=0.75067, test err=0.420
# Trial 1, Epoch: 800, RF model, h=400, lr=0.00100, Loss=0.36354, test err=0.376
# Trial 1, Epoch: 1200, RF model, h=400, lr=0.00100, Loss=0.22112, test err=0.361
# Trial 1, Epoch: 1600, RF model, h=400, lr=0.00100, Loss=0.15340, test err=0.355
# Trial 1, Epoch: 2000, RF model, h=400, lr=0.00100, Loss=0.11546, test err=0.351
# Trial 1, Epoch: 2400, RF model, h=400, lr=0.00100, Loss=0.09171, test err=0.348
# Trial 1, Epoch: 2800, RF model, h=400, lr=0.00100, Loss=0.07563, test err=0.348
# Trial 1, Epoch: 3200, RF model, h=400, lr=0.00100, Loss=0.06411, test err=0.347
# Trial 1, Epoch: 3600, RF model, h=400, lr=0.00100, Loss=0.05549, test err=0.346
# Trial 1, Epoch: 4000, RF model, h=400, lr=0.00100, Loss=0.04882, test err=0.345
# Trial 1, Epoch: 4400, RF model, h=400, lr=0.00100, Loss=0.04352, test err=0.344
# Trial 1, Epoch: 4800, RF model, h=400, lr=0.00100, Loss=0.03921, test err=0.344
# Trial 1, Epoch: 5200, RF model, h=400, lr=0.00100, Loss=0.03565, test err=0.343
# Trial 1, Epoch: 5600, RF model, h=400, lr=0.00100, Loss=0.03265, test err=0.342
# Trial 1, Epoch: 6000, RF model, h=400, lr=0.00100, Loss=0.03010, test err=0.342
# Trial 1, Epoch: 6400, RF model, h=400, lr=0.00100, Loss=0.02791, test err=0.341
# Trial 1, Epoch: 6800, RF model, h=400, lr=0.00100, Loss=0.02600, test err=0.341
# Trial 2, Epoch: 0, RF model, h=400, lr=0.00100, Loss=2.51529, test err=0.871
# Trial 2, Epoch: 400, RF model, h=400, lr=0.00100, Loss=0.77820, test err=0.411
# Trial 2, Epoch: 800, RF model, h=400, lr=0.00100, Loss=0.38408, test err=0.374
# Trial 2, Epoch: 1200, RF model, h=400, lr=0.00100, Loss=0.23529, test err=0.366
# Trial 2, Epoch: 1600, RF model, h=400, lr=0.00100, Loss=0.16357, test err=0.360
# Trial 2, Epoch: 2000, RF model, h=400, lr=0.00100, Loss=0.12315, test err=0.359
# Trial 2, Epoch: 2400, RF model, h=400, lr=0.00100, Loss=0.09777, test err=0.358
# Trial 2, Epoch: 2800, RF model, h=400, lr=0.00100, Loss=0.08056, test err=0.357
# Trial 2, Epoch: 3200, RF model, h=400, lr=0.00100, Loss=0.06824, test err=0.355
# Trial 2, Epoch: 3600, RF model, h=400, lr=0.00100, Loss=0.05901, test err=0.354
# Trial 2, Epoch: 4000, RF model, h=400, lr=0.00100, Loss=0.05188, test err=0.354
# Trial 2, Epoch: 4400, RF model, h=400, lr=0.00100, Loss=0.04622, test err=0.354
# Trial 2, Epoch: 4800, RF model, h=400, lr=0.00100, Loss=0.04162, test err=0.353
# Trial 2, Epoch: 5200, RF model, h=400, lr=0.00100, Loss=0.03781, test err=0.352
# Trial 2, Epoch: 5600, RF model, h=400, lr=0.00100, Loss=0.03461, test err=0.352
# Trial 2, Epoch: 6000, RF model, h=400, lr=0.00100, Loss=0.03189, test err=0.352
# Trial 2, Epoch: 6400, RF model, h=400, lr=0.00100, Loss=0.02955, test err=0.351
# Trial 2, Epoch: 6800, RF model, h=400, lr=0.00100, Loss=0.02752, test err=0.351
# Trial 3, Epoch: 0, RF model, h=400, lr=0.00100, Loss=2.65944, test err=0.924
# Trial 3, Epoch: 400, RF model, h=400, lr=0.00100, Loss=0.66011, test err=0.405
# Trial 3, Epoch: 800, RF model, h=400, lr=0.00100, Loss=0.31633, test err=0.364
# Trial 3, Epoch: 1200, RF model, h=400, lr=0.00100, Loss=0.19395, test err=0.352
# Trial 3, Epoch: 1600, RF model, h=400, lr=0.00100, Loss=0.13555, test err=0.348
# Trial 3, Epoch: 2000, RF model, h=400, lr=0.00100, Loss=0.10262, test err=0.346
# Trial 3, Epoch: 2400, RF model, h=400, lr=0.00100, Loss=0.08189, test err=0.343
# Trial 3, Epoch: 2800, RF model, h=400, lr=0.00100, Loss=0.06778, test err=0.343
# Trial 3, Epoch: 3200, RF model, h=400, lr=0.00100, Loss=0.05763, test err=0.342
# Trial 3, Epoch: 3600, RF model, h=400, lr=0.00100, Loss=0.05002, test err=0.342
# Trial 3, Epoch: 4000, RF model, h=400, lr=0.00100, Loss=0.04410, test err=0.342
# Trial 3, Epoch: 4400, RF model, h=400, lr=0.00100, Loss=0.03939, test err=0.341
# Trial 3, Epoch: 4800, RF model, h=400, lr=0.00100, Loss=0.03556, test err=0.340
# Trial 3, Epoch: 5200, RF model, h=400, lr=0.00100, Loss=0.03238, test err=0.340
# Trial 3, Epoch: 5600, RF model, h=400, lr=0.00100, Loss=0.02970, test err=0.340
# Trial 3, Epoch: 6000, RF model, h=400, lr=0.00100, Loss=0.02742, test err=0.339
# Trial 3, Epoch: 6400, RF model, h=400, lr=0.00100, Loss=0.02545, test err=0.339
# Trial 3, Epoch: 6800, RF model, h=400, lr=0.00100, Loss=0.02374, test err=0.339
# Trial 4, Epoch: 0, RF model, h=400, lr=0.00100, Loss=2.53401, test err=0.895
# Trial 4, Epoch: 400, RF model, h=400, lr=0.00100, Loss=0.76793, test err=0.389
# Trial 4, Epoch: 800, RF model, h=400, lr=0.00100, Loss=0.37196, test err=0.348
# Trial 4, Epoch: 1200, RF model, h=400, lr=0.00100, Loss=0.22659, test err=0.340
# Trial 4, Epoch: 1600, RF model, h=400, lr=0.00100, Loss=0.15734, test err=0.337
# Trial 4, Epoch: 2000, RF model, h=400, lr=0.00100, Loss=0.11849, test err=0.336
# Trial 4, Epoch: 2400, RF model, h=400, lr=0.00100, Loss=0.09414, test err=0.335
# Trial 4, Epoch: 2800, RF model, h=400, lr=0.00100, Loss=0.07765, test err=0.335
# Trial 4, Epoch: 3200, RF model, h=400, lr=0.00100, Loss=0.06583, test err=0.334
# Trial 4, Epoch: 3600, RF model, h=400, lr=0.00100, Loss=0.05698, test err=0.333
# Trial 4, Epoch: 4000, RF model, h=400, lr=0.00100, Loss=0.05013, test err=0.332
# Trial 4, Epoch: 4400, RF model, h=400, lr=0.00100, Loss=0.04468, test err=0.332
# Trial 4, Epoch: 4800, RF model, h=400, lr=0.00100, Loss=0.04025, test err=0.331
# Trial 4, Epoch: 5200, RF model, h=400, lr=0.00100, Loss=0.03659, test err=0.331
# Trial 4, Epoch: 5600, RF model, h=400, lr=0.00100, Loss=0.03351, test err=0.331
# Trial 4, Epoch: 6000, RF model, h=400, lr=0.00100, Loss=0.03089, test err=0.331
# Trial 4, Epoch: 6400, RF model, h=400, lr=0.00100, Loss=0.02864, test err=0.331
# Trial 4, Epoch: 6800, RF model, h=400, lr=0.00100, Loss=0.02668, test err=0.331
# Trial 0, Epoch: 0, He model, h=400, lr=0.00100, Loss=2.29378, test err=0.855
# Trial 0, Epoch: 400, He model, h=400, lr=0.00100, Loss=1.93111, test err=0.524
# Trial 0, Epoch: 800, He model, h=400, lr=0.00100, Loss=1.60049, test err=0.416
# Trial 0, Epoch: 1200, He model, h=400, lr=0.00100, Loss=1.29477, test err=0.369
# Trial 0, Epoch: 1600, He model, h=400, lr=0.00100, Loss=1.02879, test err=0.352
# Trial 0, Epoch: 2000, He model, h=400, lr=0.00100, Loss=0.81181, test err=0.337
# Trial 0, Epoch: 2400, He model, h=400, lr=0.00100, Loss=0.64311, test err=0.328
# Trial 0, Epoch: 2800, He model, h=400, lr=0.00100, Loss=0.51489, test err=0.323
# Trial 0, Epoch: 3200, He model, h=400, lr=0.00100, Loss=0.41778, test err=0.321
# Trial 0, Epoch: 3600, He model, h=400, lr=0.00100, Loss=0.34366, test err=0.318
# Trial 0, Epoch: 4000, He model, h=400, lr=0.00100, Loss=0.28655, test err=0.319
# Trial 0, Epoch: 4400, He model, h=400, lr=0.00100, Loss=0.24208, test err=0.319
# Trial 0, Epoch: 4800, He model, h=400, lr=0.00100, Loss=0.20707, test err=0.319
# Trial 0, Epoch: 5200, He model, h=400, lr=0.00100, Loss=0.17915, test err=0.317
# Trial 0, Epoch: 5600, He model, h=400, lr=0.00100, Loss=0.15662, test err=0.316
# Trial 0, Epoch: 6000, He model, h=400, lr=0.00100, Loss=0.13820, test err=0.315
# Trial 0, Epoch: 6400, He model, h=400, lr=0.00100, Loss=0.12299, test err=0.316
# Trial 0, Epoch: 6800, He model, h=400, lr=0.00100, Loss=0.11029, test err=0.316
# Trial 1, Epoch: 0, He model, h=400, lr=0.00100, Loss=2.28343, test err=0.865
# Trial 1, Epoch: 400, He model, h=400, lr=0.00100, Loss=1.89370, test err=0.465
# Trial 1, Epoch: 800, He model, h=400, lr=0.00100, Loss=1.55435, test err=0.374
# Trial 1, Epoch: 1200, He model, h=400, lr=0.00100, Loss=1.24690, test err=0.338
# Trial 1, Epoch: 1600, He model, h=400, lr=0.00100, Loss=0.98430, test err=0.321
# Trial 1, Epoch: 2000, He model, h=400, lr=0.00100, Loss=0.77399, test err=0.313
# Trial 1, Epoch: 2400, He model, h=400, lr=0.00100, Loss=0.61145, test err=0.307
# Trial 1, Epoch: 2800, He model, h=400, lr=0.00100, Loss=0.48807, test err=0.302
# Trial 1, Epoch: 3200, He model, h=400, lr=0.00100, Loss=0.39490, test err=0.297
# Trial 1, Epoch: 3600, He model, h=400, lr=0.00100, Loss=0.32421, test err=0.294
# Trial 1, Epoch: 4000, He model, h=400, lr=0.00100, Loss=0.27010, test err=0.292
# Trial 1, Epoch: 4400, He model, h=400, lr=0.00100, Loss=0.22817, test err=0.293
# Trial 1, Epoch: 4800, He model, h=400, lr=0.00100, Loss=0.19523, test err=0.293
# Trial 1, Epoch: 5200, He model, h=400, lr=0.00100, Loss=0.16905, test err=0.293
# Trial 1, Epoch: 5600, He model, h=400, lr=0.00100, Loss=0.14798, test err=0.293
# Trial 1, Epoch: 6000, He model, h=400, lr=0.00100, Loss=0.13082, test err=0.293
# Trial 1, Epoch: 6400, He model, h=400, lr=0.00100, Loss=0.11668, test err=0.293
# Trial 1, Epoch: 6800, He model, h=400, lr=0.00100, Loss=0.10487, test err=0.294
# Trial 2, Epoch: 0, He model, h=400, lr=0.00100, Loss=2.31187, test err=0.897
# Trial 2, Epoch: 400, He model, h=400, lr=0.00100, Loss=1.92427, test err=0.556
# Trial 2, Epoch: 800, He model, h=400, lr=0.00100, Loss=1.59023, test err=0.395
# Trial 2, Epoch: 1200, He model, h=400, lr=0.00100, Loss=1.28360, test err=0.344
# Trial 2, Epoch: 1600, He model, h=400, lr=0.00100, Loss=1.01786, test err=0.320
# Trial 2, Epoch: 2000, He model, h=400, lr=0.00100, Loss=0.80241, test err=0.308
# Trial 2, Epoch: 2400, He model, h=400, lr=0.00100, Loss=0.63541, test err=0.299
# Trial 2, Epoch: 2800, He model, h=400, lr=0.00100, Loss=0.50837, test err=0.298
# Trial 2, Epoch: 3200, He model, h=400, lr=0.00100, Loss=0.41178, test err=0.296
# Trial 2, Epoch: 3600, He model, h=400, lr=0.00100, Loss=0.33810, test err=0.295
# Trial 2, Epoch: 4000, He model, h=400, lr=0.00100, Loss=0.28155, test err=0.294
# Trial 2, Epoch: 4400, He model, h=400, lr=0.00100, Loss=0.23768, test err=0.294
# Trial 2, Epoch: 4800, He model, h=400, lr=0.00100, Loss=0.20322, test err=0.295
# Trial 2, Epoch: 5200, He model, h=400, lr=0.00100, Loss=0.17586, test err=0.295
# Trial 2, Epoch: 5600, He model, h=400, lr=0.00100, Loss=0.15383, test err=0.295
# Trial 2, Epoch: 6000, He model, h=400, lr=0.00100, Loss=0.13588, test err=0.294
# Trial 2, Epoch: 6400, He model, h=400, lr=0.00100, Loss=0.12109, test err=0.294
# Trial 2, Epoch: 6800, He model, h=400, lr=0.00100, Loss=0.10874, test err=0.295
# Trial 3, Epoch: 0, He model, h=400, lr=0.00100, Loss=2.27660, test err=0.878
# Trial 3, Epoch: 400, He model, h=400, lr=0.00100, Loss=1.91469, test err=0.543
# Trial 3, Epoch: 800, He model, h=400, lr=0.00100, Loss=1.58201, test err=0.402
# Trial 3, Epoch: 1200, He model, h=400, lr=0.00100, Loss=1.27703, test err=0.370
# Trial 3, Epoch: 1600, He model, h=400, lr=0.00100, Loss=1.01422, test err=0.353
# Trial 3, Epoch: 2000, He model, h=400, lr=0.00100, Loss=0.80145, test err=0.345
# Trial 3, Epoch: 2400, He model, h=400, lr=0.00100, Loss=0.63677, test err=0.337
# Trial 3, Epoch: 2800, He model, h=400, lr=0.00100, Loss=0.51108, test err=0.332
# Trial 3, Epoch: 3200, He model, h=400, lr=0.00100, Loss=0.41516, test err=0.326
# Trial 3, Epoch: 3600, He model, h=400, lr=0.00100, Loss=0.34149, test err=0.324
# Trial 3, Epoch: 4000, He model, h=400, lr=0.00100, Loss=0.28473, test err=0.322
# Trial 3, Epoch: 4400, He model, h=400, lr=0.00100, Loss=0.24052, test err=0.321
# Trial 3, Epoch: 4800, He model, h=400, lr=0.00100, Loss=0.20575, test err=0.319
# Trial 3, Epoch: 5200, He model, h=400, lr=0.00100, Loss=0.17806, test err=0.320
# Trial 3, Epoch: 5600, He model, h=400, lr=0.00100, Loss=0.15575, test err=0.319
# Trial 3, Epoch: 6000, He model, h=400, lr=0.00100, Loss=0.13755, test err=0.318
# Trial 3, Epoch: 6400, He model, h=400, lr=0.00100, Loss=0.12252, test err=0.318
# Trial 3, Epoch: 6800, He model, h=400, lr=0.00100, Loss=0.10997, test err=0.318
# Trial 4, Epoch: 0, He model, h=400, lr=0.00100, Loss=2.34691, test err=0.935
# Trial 4, Epoch: 400, He model, h=400, lr=0.00100, Loss=1.99062, test err=0.594
# Trial 4, Epoch: 800, He model, h=400, lr=0.00100, Loss=1.66183, test err=0.420
# Trial 4, Epoch: 1200, He model, h=400, lr=0.00100, Loss=1.35198, test err=0.372
# Trial 4, Epoch: 1600, He model, h=400, lr=0.00100, Loss=1.07611, test err=0.352
# Trial 4, Epoch: 2000, He model, h=400, lr=0.00100, Loss=0.84794, test err=0.339
# Trial 4, Epoch: 2400, He model, h=400, lr=0.00100, Loss=0.66914, test err=0.327
# Trial 4, Epoch: 2800, He model, h=400, lr=0.00100, Loss=0.53290, test err=0.322
# Trial 4, Epoch: 3200, He model, h=400, lr=0.00100, Loss=0.42966, test err=0.318
# Trial 4, Epoch: 3600, He model, h=400, lr=0.00100, Loss=0.35137, test err=0.316
# Trial 4, Epoch: 4000, He model, h=400, lr=0.00100, Loss=0.29164, test err=0.316
# Trial 4, Epoch: 4400, He model, h=400, lr=0.00100, Loss=0.24557, test err=0.315
# Trial 4, Epoch: 4800, He model, h=400, lr=0.00100, Loss=0.20959, test err=0.313
# Trial 4, Epoch: 5200, He model, h=400, lr=0.00100, Loss=0.18104, test err=0.313
# Trial 4, Epoch: 5600, He model, h=400, lr=0.00100, Loss=0.15809, test err=0.313
# Trial 4, Epoch: 6000, He model, h=400, lr=0.00100, Loss=0.13943, test err=0.313
# Trial 4, Epoch: 6400, He model, h=400, lr=0.00100, Loss=0.12406, test err=0.313
# Trial 4, Epoch: 6800, He model, h=400, lr=0.00100, Loss=0.11127, test err=0.313
# Trial 0, Epoch: 0, V1 model, h=400, lr=0.01000, Loss=3.99439, test err=0.843
# Trial 0, Epoch: 400, V1 model, h=400, lr=0.01000, Loss=0.00988, test err=0.311
# Trial 0, Epoch: 800, V1 model, h=400, lr=0.01000, Loss=0.00500, test err=0.308
# Trial 0, Epoch: 1200, V1 model, h=400, lr=0.01000, Loss=0.00334, test err=0.308
# Trial 0, Epoch: 1600, V1 model, h=400, lr=0.01000, Loss=0.00251, test err=0.308
# Trial 0, Epoch: 2000, V1 model, h=400, lr=0.01000, Loss=0.00200, test err=0.307
# Trial 0, Epoch: 2400, V1 model, h=400, lr=0.01000, Loss=0.00167, test err=0.307
# Trial 0, Epoch: 2800, V1 model, h=400, lr=0.01000, Loss=0.00143, test err=0.307
# Trial 0, Epoch: 3200, V1 model, h=400, lr=0.01000, Loss=0.00125, test err=0.307
# Trial 0, Epoch: 3600, V1 model, h=400, lr=0.01000, Loss=0.00111, test err=0.307
# Trial 0, Epoch: 4000, V1 model, h=400, lr=0.01000, Loss=0.00100, test err=0.307
# Trial 0, Epoch: 4400, V1 model, h=400, lr=0.01000, Loss=0.00091, test err=0.307
# Trial 0, Epoch: 4800, V1 model, h=400, lr=0.01000, Loss=0.00083, test err=0.307
# Trial 0, Epoch: 5200, V1 model, h=400, lr=0.01000, Loss=0.00077, test err=0.307
# Trial 0, Epoch: 5600, V1 model, h=400, lr=0.01000, Loss=0.00071, test err=0.306
# Trial 0, Epoch: 6000, V1 model, h=400, lr=0.01000, Loss=0.00067, test err=0.306
# Trial 0, Epoch: 6400, V1 model, h=400, lr=0.01000, Loss=0.00062, test err=0.306
# Trial 0, Epoch: 6800, V1 model, h=400, lr=0.01000, Loss=0.00059, test err=0.305
# Trial 1, Epoch: 0, V1 model, h=400, lr=0.01000, Loss=4.68565, test err=0.897

# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt

t, l, n_epochs= 5, 3, 7000
models = ['V1', 'RF', 'He']

for scale in [1/8, 1/16, 1/32]:
    for h in [50, 100, 400, 1000]:
        for lr in [1e-3, 1e-2, 1e-1, 1e0]:

            with open('results/initialize_mnist/clf_t=%0.2f_l=%0.2f_h=%d_lr=%0.4f_scale=%0.6f_fewshot.pickle' % (t, l, 
                                                                                                         h, lr, 
                                                                                                         scale), 
                      'rb') as handle:
                sims = pickle.load(handle)

            avg_train_err = {m: np.mean(sims['train_err'][m], axis=0) for m in models}
            avg_test_err = {m: np.mean(sims['test_err'][m], axis=0) for m in models}
            avg_loss_list = {m: np.mean(sims['loss'][m], axis=0) for m in models}

            std_train_err = {m: np.std(sims['train_err'][m], axis=0) for m in models}
            std_test_err = {m: np.std(sims['train_err'][m], axis=0) for m in models}
            std_loss_list = {m: np.std(sims['train_err'][m], axis=0) for m in models}

            fig = plt.figure(figsize=(12, 5))
            plt.suptitle(r'Shallow FFW FC net w/ GD. h=%d, scale=%0.5f, lr=%0.4f, '%(h, scale, lr), fontsize=16)
            ax = fig.add_subplot(131)
            plt.title('Network loss', fontsize=16)
            plt.plot(np.arange(n_epochs), avg_loss_list['V1'], label='V1-inspired', lw=3)
            plt.plot(np.arange(n_epochs), avg_loss_list['RF'], label='classical', lw=3)
            plt.plot(np.arange(n_epochs), avg_loss_list['He'], label='He', lw=3)

            plt.fill_between(np.arange(n_epochs), avg_loss_list['V1'] - std_loss_list['V1'], 
                             avg_loss_list['V1'] + std_loss_list['V1'], alpha=0.2)
            plt.fill_between(np.arange(n_epochs), avg_loss_list['RF'] - std_loss_list['RF'], 
                             avg_loss_list['RF'] + std_loss_list['RF'], alpha=0.2)
            plt.fill_between(np.arange(n_epochs), avg_loss_list['He'] - std_loss_list['He'], 
                             avg_loss_list['He'] + std_loss_list['He'], alpha=0.2)

            plt.xlabel('Epoch', fontsize=20)
            plt.ylabel('Training loss', fontsize=20)
            ax.tick_params(axis = 'both', which = 'major', labelsize = 14, width=2, length=6)
            plt.yscale('log')
            plt.legend(fontsize=18)

            ax = fig.add_subplot(132)
            plt.title('Train error', fontsize=16)
            plt.plot(np.arange(n_epochs), avg_train_err['V1'], label='V1-inspired', lw=3)
            plt.plot(np.arange(n_epochs), avg_train_err['RF'],  label='classical', lw=3)
            plt.plot(np.arange(n_epochs), avg_train_err['He'],  label='He', lw=3)
            plt.fill_between(np.arange(n_epochs), avg_train_err['V1'] - std_train_err['V1'], 
                             avg_train_err['V1'] + std_train_err['V1'],  alpha=0.2 )
            plt.fill_between(np.arange(n_epochs), avg_train_err['RF'] - std_train_err['RF'], 
                             avg_train_err['RF'] + std_train_err['RF'],  alpha=0.2 )
            plt.fill_between(np.arange(n_epochs), avg_train_err['He'] - std_train_err['He'], 
                             avg_train_err['He'] + std_train_err['He'],  alpha=0.2 )
            plt.xlabel('Epoch', fontsize=20)
            plt.ylabel('Training error', fontsize=20)
            ax.tick_params(axis = 'both', which = 'major', labelsize = 14, width=2, length=6)
            plt.yticks(np.arange(0, 1, 0.2))
            plt.yscale('log')
            plt.legend(fontsize=18)

            ax = fig.add_subplot(133)
            plt.title('Test error', fontsize=16)
            plt.plot(np.arange(n_epochs), avg_test_err['V1'], label='V1-inspired', lw=3)
            plt.plot(np.arange(n_epochs), avg_test_err['RF'], label='classical', lw=3)
            plt.plot(np.arange(n_epochs), avg_test_err['He'], label='He', lw=3)
            plt.fill_between(np.arange(n_epochs), avg_test_err['V1'] - std_test_err['V1'], 
                             avg_test_err['V1'] + std_test_err['V1'], alpha=0.2 )
            plt.fill_between(np.arange(n_epochs), avg_test_err['RF'] - std_test_err['RF'], 
                             avg_test_err['RF'] + std_test_err['RF'], alpha=0.2 )
            plt.fill_between(np.arange(n_epochs), avg_test_err['He'] - std_test_err['He'], 
                             avg_test_err['He'] + std_test_err['He'], alpha=0.2 )
            plt.xlabel('Epoch', fontsize=20)
            plt.ylabel('Test error', fontsize=20)
            ax.tick_params(axis = 'both', which = 'major', labelsize = 14, width=2, length=6)
            plt.yticks(np.arange(0, 1, 0.2))
            plt.yscale('log')
            plt.legend(fontsize=18)

            plt.tight_layout()
            plt.subplots_adjust(top=0.8)    

            print(scale, h, lr, 'Test err, V1: %0.4f, RF: %0.4f, He: %0.4f' % (avg_test_err['V1'][-1], 
                                                                 avg_test_err['RF'][-1],
                                                                avg_test_err['He'][-1]))
            
            plt.savefig('results/initialize_mnist/figures_fewshot/init_t=%0.2f_l=%0.2f_h=%d_lr=%0.4f_scale=%0.6f.png' % (t, 
                                                                                                                 l,h, 
                                                                                                                 lr, 
                                                                                                             scale))
            plt.close()
# Out:
# 0.125 50 0.001 Test err, V1: 0.3976, RF: 0.4645, He: 0.3243
# 0.125 50 0.01 Test err, V1: 0.4074, RF: 0.4192, He: 0.3207
# 0.125 50 0.1 Test err, V1: 0.4009, RF: 0.4288, He: 0.3171
# 0.125 50 1.0 Test err, V1: 0.4090, RF: 0.4169, He: 0.3208
# 0.125 100 0.001 Test err, V1: 0.3541, RF: 0.4149, He: 0.3188
# 0.125 100 0.01 Test err, V1: 0.3470, RF: 0.4131, He: 0.3204
# 0.125 100 0.1 Test err, V1: 0.3553, RF: 0.3925, He: 0.3126
# 0.125 100 1.0 Test err, V1: 0.4366, RF: 0.4205, He: 0.3153
# 0.125 400 0.001 Test err, V1: 0.3004, RF: 0.3591, He: 0.3166
# 0.125 400 0.01 Test err, V1: 0.2928, RF: 0.3441, He: 0.3126
# 0.125 400 0.1 Test err, V1: 0.2975, RF: 0.3324, He: 0.3112
# 0.125 400 1.0 Test err, V1: 0.4303, RF: 0.4051, He: 0.3092
# 0.125 1000 0.001 Test err, V1: 0.2933, RF: 0.3388, He: 0.3080
# 0.125 1000 0.01 Test err, V1: 0.2722, RF: 0.3322, He: 0.3082
# 0.125 1000 0.1 Test err, V1: 0.3279, RF: 0.3685, He: 0.3124
# 0.125 1000 1.0 Test err, V1: 0.3901, RF: 0.4476, He: 0.3082
# 0.0625 50 0.001 Test err, V1: 0.4095, RF: 0.4238, He: 0.3217
# 0.0625 50 0.01 Test err, V1: 0.3811, RF: 0.3910, He: 0.3173
# 0.0625 50 0.1 Test err, V1: 0.3749, RF: 0.3842, He: 0.3194
# 0.0625 50 1.0 Test err, V1: 0.4043, RF: 0.3754, He: 0.3165
# 0.0625 100 0.001 Test err, V1: 0.3496, RF: 0.3991, He: 0.3140
# 0.0625 100 0.01 Test err, V1: 0.3287, RF: 0.3769, He: 0.3130
# 0.0625 100 0.1 Test err, V1: 0.3390, RF: 0.3756, He: 0.3169
# 0.0625 100 1.0 Test err, V1: 0.4162, RF: 0.3889, He: 0.3165
# 0.0625 400 0.001 Test err, V1: 0.2946, RF: 0.3539, He: 0.3140
# 0.0625 400 0.01 Test err, V1: 0.2851, RF: 0.3466, He: 0.3140
# 0.0625 400 0.1 Test err, V1: 0.3243, RF: 0.3315, He: 0.3167
# 0.0625 400 1.0 Test err, V1: 0.3965, RF: 0.3875, He: 0.3140
# 0.0625 1000 0.001 Test err, V1: 0.2823, RF: 0.3297, He: 0.3104
# 0.0625 1000 0.01 Test err, V1: 0.2710, RF: 0.3281, He: 0.3110
# 0.0625 1000 0.1 Test err, V1: 0.3003, RF: 0.3241, He: 0.3142
# 0.0625 1000 1.0 Test err, V1: 0.3917, RF: 0.4107, He: 0.3085
# 0.03125 50 0.001 Test err, V1: 0.3933, RF: 0.3803, He: 0.3255
# 0.03125 50 0.01 Test err, V1: 0.3579, RF: 0.3715, He: 0.3099
# 0.03125 50 0.1 Test err, V1: 0.3292, RF: 0.3571, He: 0.3158
# 0.03125 50 1.0 Test err, V1: 0.3419, RF: 0.3492, He: 0.3275
# 0.03125 100 0.001 Test err, V1: 0.3283, RF: 0.3698, He: 0.3224
# 0.03125 100 0.01 Test err, V1: 0.3234, RF: 0.3566, He: 0.3166
# 0.03125 100 0.1 Test err, V1: 0.3233, RF: 0.3493, He: 0.3084
# 0.03125 100 1.0 Test err, V1: 0.3713, RF: 0.3590, He: 0.3167
# 0.03125 400 0.001 Test err, V1: 0.2884, RF: 0.3420, He: 0.3070
# 0.03125 400 0.01 Test err, V1: 0.2918, RF: 0.3351, He: 0.3149
# 0.03125 400 0.1 Test err, V1: 0.3143, RF: 0.3325, He: 0.3143
# 0.03125 400 1.0 Test err, V1: 0.3819, RF: 0.3455, He: 0.3145
# 0.03125 1000 0.001 Test err, V1: 0.2809, RF: 0.3206, He: 0.3099
# 0.03125 1000 0.01 Test err, V1: 0.2719, RF: 0.3222, He: 0.3120
# 0.03125 1000 0.1 Test err, V1: 0.2916, RF: 0.3149, He: 0.3135
# 0.03125 1000 1.0 Test err, V1: 0.3900, RF: 0.3659, He: 0.3080
