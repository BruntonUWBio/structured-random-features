# %% [markdown]
# Initialize shallow feedforward fully-connected network with V1 type weights and classify __full kuzushizi mnist__ dataset using __Gradient descent__.

# %%
import numpy as np
import numpy.linalg as la
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from data_fns import load_kmnist
from estimator import classical_weights, V1_inspired_weights
import pickle

# %%
torch.cuda.set_device(0)
train, train_labels, test, test_labels = load_kmnist('./data/kmnist/')
X_train = torch.from_numpy(train).float().to('cuda')
X_test = torch.from_numpy(test).float().to('cuda')
y_train = torch.from_numpy(train_labels).long().to('cuda')
y_test = torch.from_numpy(test_labels).long().to('cuda')
n, d = X_train.shape

# %%
class V1_net(nn.Module):
    def __init__(self, hidden_size, scale):
        super().__init__()
        self.fc1 = nn.Linear(d, hidden_size)
        self.fc1.weight.data = torch.FloatTensor(V1_inspired_weights(hidden_size, d, t=5, l=2, scale=scale))
        self.output = nn.Linear(hidden_size, 10)
        
    def forward(self, inputs):
        x = torch.relu(self.fc1(inputs))
        return self.output(x)
    
class He_net(nn.Module):
    def __init__(self, hidden_size, scale):
        super().__init__()
        self.fc1 = nn.Linear(d, hidden_size)
        torch.nn.init.kaiming_normal_(self.fc1.weight)
        self.output = nn.Linear(hidden_size, 10)
        
    def forward(self, inputs):
        x = torch.relu(self.fc1(inputs))
        return self.output(x)
    
class RF_net(nn.Module):
    def __init__(self, hidden_size, scale):
        super().__init__()
        self.fc1 = nn.Linear(d, hidden_size)
        self.fc1.weight.data = torch.FloatTensor(classical_weights(hidden_size, d, scale=scale))
        self.output = nn.Linear(hidden_size, 10)
        
    def forward(self, inputs):
        x = torch.relu(self.fc1(inputs))
        return self.output(x)

# %%
def predict(model, X):
    return model(X).data.max(1)[1]

def error(model, X, y):
    y_pred = predict(model, X)
    accuracy = 1.0 * torch.sum(y_pred == y) / len(y)
    return 1 - accuracy

# %%
V1_model = V1_net(100, 2/d)
RF_model = RF_net(100, 2/d)
He_model= He_net(100, 2/d)
print('V1', torch.mean(torch.norm(V1_model.fc1.weight.data, dim=1)))
print('He', torch.mean(torch.norm(He_model.fc1.weight.data, dim=1)))
print('RF', torch.mean(torch.norm(RF_model.fc1.weight.data, dim=1)))
w = torch.mean(torch.norm(RF_model.fc1.weight.data, dim=1))
# Out:
# V1 tensor(1.3507)
# He tensor(1.4163)
# RF tensor(1.4146)

# %%
n_trials, n_epochs = 10, 3001
models = {'V1': V1_net, 'He': He_net}
h_list = [50, 100, 400, 1000]
lr_list = [1e-3, 1e-2, 1e-1, 1e0]

train_err = {m: {h: {lr: np.zeros((n_trials, n_epochs)) for lr in lr_list} for h in h_list} for m in models.keys()}
test_err = {m: {h: {lr: np.zeros((n_trials, n_epochs)) for lr in lr_list} for h in h_list} for m in models.keys()}
loss_list = {m: {h: {lr: np.zeros((n_trials, n_epochs)) for lr in lr_list} for h in h_list} for m in models.keys()}

# %%
scale = 2/d
t, l = 5, 2
loss_func = nn.CrossEntropyLoss()

for h in h_list:
    for lr in lr_list:
        for m, network in models.items():
            for i in range(n_trials):
                model = network(h, scale).to('cuda')
                optim = torch.optim.SGD(model.parameters(), lr=lr)
                for j in range(n_epochs):
                    optim.zero_grad()
                    loss = loss_func(model(X_train), y_train)
                    loss.backward()
                    optim.step()

                    train_err[m][h][lr][i, j] = error(model, X_train, y_train)
                    test_err[m][h][lr][i, j] = error(model, X_test, y_test)
                    loss_list[m][h][lr][i, j] = loss.data

                    if (j % 1000 == 0):
                        print('Trial %d, Epoch: %d, %s model, h=%d, lr=%0.5f, Loss=%0.5f, test err=%0.3f' % (i,j, m, h, lr, loss.data, 
                                                                                                  test_err[m][h][lr][i, j]))
results = {'test_err': test_err, 'train_err': train_err, 'loss': loss_list}
with open('results/initialize_kmnist/full_data/clf_t=%0.2f_l=%0.2f.pickle' % (t, l), 'wb') as handle:
    pickle.dump(results, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# Trial 0, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=2.52709, test err=0.894
# Trial 0, Epoch: 1000, V1 model, h=50, lr=0.00100, Loss=1.81623, test err=0.654
# Trial 0, Epoch: 2000, V1 model, h=50, lr=0.00100, Loss=1.55292, test err=0.584
# Trial 0, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=1.38970, test err=0.551
# Trial 1, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=2.65591, test err=0.931
# Trial 1, Epoch: 1000, V1 model, h=50, lr=0.00100, Loss=1.67940, test err=0.633
# Trial 1, Epoch: 2000, V1 model, h=50, lr=0.00100, Loss=1.38530, test err=0.545
# Trial 1, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=1.22030, test err=0.510
# Trial 2, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=2.49633, test err=0.897
# Trial 2, Epoch: 1000, V1 model, h=50, lr=0.00100, Loss=1.80020, test err=0.649
# Trial 2, Epoch: 2000, V1 model, h=50, lr=0.00100, Loss=1.51678, test err=0.568
# Trial 2, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=1.34541, test err=0.534
# Trial 3, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=2.55189, test err=0.909
# Trial 3, Epoch: 1000, V1 model, h=50, lr=0.00100, Loss=1.67873, test err=0.639
# Trial 3, Epoch: 2000, V1 model, h=50, lr=0.00100, Loss=1.41939, test err=0.564
# Trial 3, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=1.26207, test err=0.524
# Trial 4, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=2.94151, test err=0.958
# Trial 4, Epoch: 1000, V1 model, h=50, lr=0.00100, Loss=1.72008, test err=0.645
# Trial 4, Epoch: 2000, V1 model, h=50, lr=0.00100, Loss=1.42659, test err=0.559
# Trial 4, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=1.26150, test err=0.519
# Trial 5, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=3.04795, test err=0.934
# Trial 5, Epoch: 1000, V1 model, h=50, lr=0.00100, Loss=1.73662, test err=0.668
# Trial 5, Epoch: 2000, V1 model, h=50, lr=0.00100, Loss=1.42749, test err=0.555
# Trial 5, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=1.24728, test err=0.512
# Trial 6, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=2.80359, test err=0.907
# Trial 6, Epoch: 1000, V1 model, h=50, lr=0.00100, Loss=1.82286, test err=0.688
# Trial 6, Epoch: 2000, V1 model, h=50, lr=0.00100, Loss=1.55125, test err=0.602
# Trial 6, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=1.38032, test err=0.551
# Trial 7, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=2.64628, test err=0.936
# Trial 7, Epoch: 1000, V1 model, h=50, lr=0.00100, Loss=1.74477, test err=0.657
# Trial 7, Epoch: 2000, V1 model, h=50, lr=0.00100, Loss=1.49134, test err=0.586
# Trial 7, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=1.33527, test err=0.545
# Trial 8, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=2.76526, test err=0.932
# Trial 8, Epoch: 1000, V1 model, h=50, lr=0.00100, Loss=1.84727, test err=0.633
# Trial 8, Epoch: 2000, V1 model, h=50, lr=0.00100, Loss=1.52218, test err=0.538
# Trial 8, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=1.32740, test err=0.508
# Trial 9, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=2.74567, test err=0.927
# Trial 9, Epoch: 1000, V1 model, h=50, lr=0.00100, Loss=1.82264, test err=0.673
# Trial 9, Epoch: 2000, V1 model, h=50, lr=0.00100, Loss=1.55416, test err=0.596
# Trial 9, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=1.38115, test err=0.552
# Trial 0, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.30223, test err=0.881
# Trial 0, Epoch: 1000, He model, h=50, lr=0.00100, Loss=2.12407, test err=0.781
# Trial 0, Epoch: 2000, He model, h=50, lr=0.00100, Loss=1.90702, test err=0.647
# Trial 0, Epoch: 3000, He model, h=50, lr=0.00100, Loss=1.68238, test err=0.553
# Trial 1, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.32602, test err=0.884
# Trial 1, Epoch: 1000, He model, h=50, lr=0.00100, Loss=2.07624, test err=0.755
# Trial 1, Epoch: 2000, He model, h=50, lr=0.00100, Loss=1.82169, test err=0.601
# Trial 1, Epoch: 3000, He model, h=50, lr=0.00100, Loss=1.58548, test err=0.535
# Trial 2, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.34116, test err=0.910
# Trial 2, Epoch: 1000, He model, h=50, lr=0.00100, Loss=2.17243, test err=0.752
# Trial 2, Epoch: 2000, He model, h=50, lr=0.00100, Loss=1.96397, test err=0.619
# Trial 2, Epoch: 3000, He model, h=50, lr=0.00100, Loss=1.72405, test err=0.558
# Trial 3, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.32293, test err=0.883
# Trial 3, Epoch: 1000, He model, h=50, lr=0.00100, Loss=2.10561, test err=0.748
# Trial 3, Epoch: 2000, He model, h=50, lr=0.00100, Loss=1.86192, test err=0.630
# Trial 3, Epoch: 3000, He model, h=50, lr=0.00100, Loss=1.63390, test err=0.569
# Trial 4, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.31276, test err=0.888
# Trial 4, Epoch: 1000, He model, h=50, lr=0.00100, Loss=2.09824, test err=0.717
# Trial 4, Epoch: 2000, He model, h=50, lr=0.00100, Loss=1.86221, test err=0.622
# Trial 4, Epoch: 3000, He model, h=50, lr=0.00100, Loss=1.63561, test err=0.561
# Trial 5, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.34552, test err=0.912
# Trial 5, Epoch: 1000, He model, h=50, lr=0.00100, Loss=2.14648, test err=0.762
# Trial 5, Epoch: 2000, He model, h=50, lr=0.00100, Loss=1.92867, test err=0.655
# Trial 5, Epoch: 3000, He model, h=50, lr=0.00100, Loss=1.69284, test err=0.562
# Trial 6, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.34717, test err=0.896
# Trial 6, Epoch: 1000, He model, h=50, lr=0.00100, Loss=2.17285, test err=0.773
# Trial 6, Epoch: 2000, He model, h=50, lr=0.00100, Loss=1.96283, test err=0.626
# Trial 6, Epoch: 3000, He model, h=50, lr=0.00100, Loss=1.71950, test err=0.542
# Trial 7, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.31638, test err=0.902
# Trial 7, Epoch: 1000, He model, h=50, lr=0.00100, Loss=2.12068, test err=0.769
# Trial 7, Epoch: 2000, He model, h=50, lr=0.00100, Loss=1.89141, test err=0.621
# Trial 7, Epoch: 3000, He model, h=50, lr=0.00100, Loss=1.66737, test err=0.543
# Trial 8, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.35522, test err=0.921
# Trial 8, Epoch: 1000, He model, h=50, lr=0.00100, Loss=2.13359, test err=0.727
# Trial 8, Epoch: 2000, He model, h=50, lr=0.00100, Loss=1.89361, test err=0.597
# Trial 8, Epoch: 3000, He model, h=50, lr=0.00100, Loss=1.63583, test err=0.530
# Trial 9, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.32644, test err=0.908
# Trial 9, Epoch: 1000, He model, h=50, lr=0.00100, Loss=2.16177, test err=0.761
# Trial 9, Epoch: 2000, He model, h=50, lr=0.00100, Loss=1.95675, test err=0.638
# Trial 9, Epoch: 3000, He model, h=50, lr=0.00100, Loss=1.72102, test err=0.557
# Trial 0, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=2.70620, test err=0.930
# Trial 0, Epoch: 1000, V1 model, h=50, lr=0.01000, Loss=0.85507, test err=0.400
# Trial 0, Epoch: 2000, V1 model, h=50, lr=0.01000, Loss=0.67252, test err=0.337
# Trial 0, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.59199, test err=0.313
# Trial 1, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=2.33918, test err=0.908
# Trial 1, Epoch: 1000, V1 model, h=50, lr=0.01000, Loss=0.82676, test err=0.389
# Trial 1, Epoch: 2000, V1 model, h=50, lr=0.01000, Loss=0.65227, test err=0.326
# Trial 1, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.57392, test err=0.298
# Trial 2, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=2.55252, test err=0.888
# Trial 2, Epoch: 1000, V1 model, h=50, lr=0.01000, Loss=0.83811, test err=0.403
# Trial 2, Epoch: 2000, V1 model, h=50, lr=0.01000, Loss=0.64967, test err=0.335
# Trial 2, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.56310, test err=0.304
# Trial 3, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=2.48844, test err=0.877
# Trial 3, Epoch: 1000, V1 model, h=50, lr=0.01000, Loss=0.81550, test err=0.397
# Trial 3, Epoch: 2000, V1 model, h=50, lr=0.01000, Loss=0.64587, test err=0.333
# Trial 3, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.56810, test err=0.307
# Trial 4, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=2.58169, test err=0.892
# Trial 4, Epoch: 1000, V1 model, h=50, lr=0.01000, Loss=0.87720, test err=0.406
# Trial 4, Epoch: 2000, V1 model, h=50, lr=0.01000, Loss=0.66066, test err=0.333
# Trial 4, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.56664, test err=0.301
# Trial 5, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=3.01301, test err=0.946
# Trial 5, Epoch: 1000, V1 model, h=50, lr=0.01000, Loss=0.84319, test err=0.398
# Trial 5, Epoch: 2000, V1 model, h=50, lr=0.01000, Loss=0.66611, test err=0.345
# Trial 5, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.58116, test err=0.312
# Trial 6, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=2.54774, test err=0.905
# Trial 6, Epoch: 1000, V1 model, h=50, lr=0.01000, Loss=0.88490, test err=0.404
# Trial 6, Epoch: 2000, V1 model, h=50, lr=0.01000, Loss=0.67348, test err=0.340
# Trial 6, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.57462, test err=0.301
# Trial 7, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=2.47969, test err=0.896
# Trial 7, Epoch: 1000, V1 model, h=50, lr=0.01000, Loss=0.86299, test err=0.394
# Trial 7, Epoch: 2000, V1 model, h=50, lr=0.01000, Loss=0.66289, test err=0.336
# Trial 7, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.57552, test err=0.311
# Trial 8, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=2.63057, test err=0.879
# Trial 8, Epoch: 1000, V1 model, h=50, lr=0.01000, Loss=0.84449, test err=0.402
# Trial 8, Epoch: 2000, V1 model, h=50, lr=0.01000, Loss=0.65856, test err=0.335
# Trial 8, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.57487, test err=0.303
# Trial 9, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=2.64571, test err=0.893
# Trial 9, Epoch: 1000, V1 model, h=50, lr=0.01000, Loss=0.86000, test err=0.405
# Trial 9, Epoch: 2000, V1 model, h=50, lr=0.01000, Loss=0.66449, test err=0.337
# Trial 9, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.57531, test err=0.305
# Trial 0, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.33986, test err=0.904
# Trial 0, Epoch: 1000, He model, h=50, lr=0.01000, Loss=0.89722, test err=0.407
# Trial 0, Epoch: 2000, He model, h=50, lr=0.01000, Loss=0.68557, test err=0.344
# Trial 0, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.60257, test err=0.315
# Trial 1, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.32998, test err=0.923
# Trial 1, Epoch: 1000, He model, h=50, lr=0.01000, Loss=0.90290, test err=0.409
# Trial 1, Epoch: 2000, He model, h=50, lr=0.01000, Loss=0.67366, test err=0.339
# Trial 1, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.58554, test err=0.311
# Trial 2, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.31589, test err=0.896
# Trial 2, Epoch: 1000, He model, h=50, lr=0.01000, Loss=0.91623, test err=0.424
# Trial 2, Epoch: 2000, He model, h=50, lr=0.01000, Loss=0.68012, test err=0.342
# Trial 2, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.59563, test err=0.315
# Trial 3, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.32210, test err=0.893
# Trial 3, Epoch: 1000, He model, h=50, lr=0.01000, Loss=0.93514, test err=0.411
# Trial 3, Epoch: 2000, He model, h=50, lr=0.01000, Loss=0.70697, test err=0.347
# Trial 3, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.61863, test err=0.321
# Trial 4, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.34423, test err=0.946
# Trial 4, Epoch: 1000, He model, h=50, lr=0.01000, Loss=0.90674, test err=0.408
# Trial 4, Epoch: 2000, He model, h=50, lr=0.01000, Loss=0.67779, test err=0.345
# Trial 4, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.59061, test err=0.315
# Trial 5, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.33484, test err=0.878
# Trial 5, Epoch: 1000, He model, h=50, lr=0.01000, Loss=0.94301, test err=0.417
# Trial 5, Epoch: 2000, He model, h=50, lr=0.01000, Loss=0.69435, test err=0.344
# Trial 5, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.60172, test err=0.315
# Trial 6, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.31643, test err=0.887
# Trial 6, Epoch: 1000, He model, h=50, lr=0.01000, Loss=0.91490, test err=0.415
# Trial 6, Epoch: 2000, He model, h=50, lr=0.01000, Loss=0.68581, test err=0.343
# Trial 6, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.59947, test err=0.315
# Trial 7, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.33680, test err=0.887
# Trial 7, Epoch: 1000, He model, h=50, lr=0.01000, Loss=0.92102, test err=0.414
# Trial 7, Epoch: 2000, He model, h=50, lr=0.01000, Loss=0.68784, test err=0.345
# Trial 7, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.59500, test err=0.310
# Trial 8, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.34635, test err=0.940
# Trial 8, Epoch: 1000, He model, h=50, lr=0.01000, Loss=0.96557, test err=0.435
# Trial 8, Epoch: 2000, He model, h=50, lr=0.01000, Loss=0.68937, test err=0.344
# Trial 8, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.59317, test err=0.311
# Trial 9, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.32155, test err=0.892
# Trial 9, Epoch: 1000, He model, h=50, lr=0.01000, Loss=0.90289, test err=0.410
# Trial 9, Epoch: 2000, He model, h=50, lr=0.01000, Loss=0.69660, test err=0.353
# Trial 9, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.61440, test err=0.321
# Trial 0, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=2.67627, test err=0.911
# Trial 0, Epoch: 1000, V1 model, h=50, lr=0.10000, Loss=0.36007, test err=0.221
# Trial 0, Epoch: 2000, V1 model, h=50, lr=0.10000, Loss=0.27120, test err=0.189
# Trial 0, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.22487, test err=0.175
# Trial 1, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=2.52280, test err=0.848
# Trial 1, Epoch: 1000, V1 model, h=50, lr=0.10000, Loss=0.36085, test err=0.225
# Trial 1, Epoch: 2000, V1 model, h=50, lr=0.10000, Loss=0.27077, test err=0.186
# Trial 1, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.22344, test err=0.168
# Trial 2, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=2.32263, test err=0.877
# Trial 2, Epoch: 1000, V1 model, h=50, lr=0.10000, Loss=0.37933, test err=0.231
# Trial 2, Epoch: 2000, V1 model, h=50, lr=0.10000, Loss=0.28822, test err=0.194
# Trial 2, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.24034, test err=0.178
# Trial 3, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=2.74842, test err=0.894
# Trial 3, Epoch: 1000, V1 model, h=50, lr=0.10000, Loss=0.37662, test err=0.228
# Trial 3, Epoch: 2000, V1 model, h=50, lr=0.10000, Loss=0.28700, test err=0.197
# Trial 3, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.23947, test err=0.180
# Trial 4, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=2.76425, test err=0.876
# Trial 4, Epoch: 1000, V1 model, h=50, lr=0.10000, Loss=0.37082, test err=0.226
# Trial 4, Epoch: 2000, V1 model, h=50, lr=0.10000, Loss=0.27501, test err=0.185
# Trial 4, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.22662, test err=0.168
# Trial 5, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=2.54213, test err=0.864
# Trial 5, Epoch: 1000, V1 model, h=50, lr=0.10000, Loss=0.36508, test err=0.229
# Trial 5, Epoch: 2000, V1 model, h=50, lr=0.10000, Loss=0.27301, test err=0.192
# Trial 5, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.22653, test err=0.177
# Trial 6, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=2.75248, test err=0.895
# Trial 6, Epoch: 1000, V1 model, h=50, lr=0.10000, Loss=0.39011, test err=0.229
# Trial 6, Epoch: 2000, V1 model, h=50, lr=0.10000, Loss=0.29317, test err=0.194
# Trial 6, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.24173, test err=0.175
# Trial 7, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=3.06006, test err=0.865
# Trial 7, Epoch: 1000, V1 model, h=50, lr=0.10000, Loss=0.36171, test err=0.223
# Trial 7, Epoch: 2000, V1 model, h=50, lr=0.10000, Loss=0.27152, test err=0.188
# Trial 7, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.22535, test err=0.168
# Trial 8, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=3.04336, test err=0.882
# Trial 8, Epoch: 1000, V1 model, h=50, lr=0.10000, Loss=0.39230, test err=0.237
# Trial 8, Epoch: 2000, V1 model, h=50, lr=0.10000, Loss=0.29026, test err=0.192
# Trial 8, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.23888, test err=0.173
# Trial 9, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=2.53499, test err=0.885
# Trial 9, Epoch: 1000, V1 model, h=50, lr=0.10000, Loss=0.38113, test err=0.235
# Trial 9, Epoch: 2000, V1 model, h=50, lr=0.10000, Loss=0.28726, test err=0.195
# Trial 9, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.23559, test err=0.173
# Trial 0, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.33299, test err=0.887
# Trial 0, Epoch: 1000, He model, h=50, lr=0.10000, Loss=0.40611, test err=0.240
# Trial 0, Epoch: 2000, He model, h=50, lr=0.10000, Loss=0.29570, test err=0.204
# Trial 0, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.23701, test err=0.180
# Trial 1, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.35124, test err=0.928
# Trial 1, Epoch: 1000, He model, h=50, lr=0.10000, Loss=0.40549, test err=0.242
# Trial 1, Epoch: 2000, He model, h=50, lr=0.10000, Loss=0.29399, test err=0.197
# Trial 1, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.23840, test err=0.177
# Trial 2, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.32699, test err=0.886
# Trial 2, Epoch: 1000, He model, h=50, lr=0.10000, Loss=0.38545, test err=0.228
# Trial 2, Epoch: 2000, He model, h=50, lr=0.10000, Loss=0.28478, test err=0.193
# Trial 2, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.23215, test err=0.174
# Trial 3, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.30633, test err=0.912
# Trial 3, Epoch: 1000, He model, h=50, lr=0.10000, Loss=0.40645, test err=0.243
# Trial 3, Epoch: 2000, He model, h=50, lr=0.10000, Loss=0.29994, test err=0.201
# Trial 3, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.24250, test err=0.180
# Trial 4, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.33743, test err=0.893
# Trial 4, Epoch: 1000, He model, h=50, lr=0.10000, Loss=0.39873, test err=0.238
# Trial 4, Epoch: 2000, He model, h=50, lr=0.10000, Loss=0.29530, test err=0.196
# Trial 4, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.24164, test err=0.176
# Trial 5, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.32859, test err=0.900
# Trial 5, Epoch: 1000, He model, h=50, lr=0.10000, Loss=0.39901, test err=0.242
# Trial 5, Epoch: 2000, He model, h=50, lr=0.10000, Loss=0.29824, test err=0.202
# Trial 5, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.24175, test err=0.182
# Trial 6, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.35298, test err=0.886
# Trial 6, Epoch: 1000, He model, h=50, lr=0.10000, Loss=0.40099, test err=0.238
# Trial 6, Epoch: 2000, He model, h=50, lr=0.10000, Loss=0.29473, test err=0.199
# Trial 6, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.24020, test err=0.177
# Trial 7, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.27895, test err=0.877
# Trial 7, Epoch: 1000, He model, h=50, lr=0.10000, Loss=0.40220, test err=0.243
# Trial 7, Epoch: 2000, He model, h=50, lr=0.10000, Loss=0.29680, test err=0.201
# Trial 7, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.24147, test err=0.179
# Trial 8, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.33413, test err=0.889
# Trial 8, Epoch: 1000, He model, h=50, lr=0.10000, Loss=0.38758, test err=0.237
# Trial 8, Epoch: 2000, He model, h=50, lr=0.10000, Loss=0.28738, test err=0.200
# Trial 8, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.23449, test err=0.179
# Trial 9, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.33091, test err=0.913
# Trial 9, Epoch: 1000, He model, h=50, lr=0.10000, Loss=0.40155, test err=0.241
# Trial 9, Epoch: 2000, He model, h=50, lr=0.10000, Loss=0.29338, test err=0.201
# Trial 9, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.23640, test err=0.178
# Trial 0, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=2.71797, test err=0.850
# Trial 0, Epoch: 1000, V1 model, h=50, lr=1.00000, Loss=0.18465, test err=0.166
# Trial 0, Epoch: 2000, V1 model, h=50, lr=1.00000, Loss=0.09133, test err=0.150
# Trial 0, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=0.05474, test err=0.144
# Trial 1, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=2.70291, test err=0.847
# Trial 1, Epoch: 1000, V1 model, h=50, lr=1.00000, Loss=0.12366, test err=0.143
# Trial 1, Epoch: 2000, V1 model, h=50, lr=1.00000, Loss=0.07569, test err=0.141
# Trial 1, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=0.10927, test err=0.156
# Trial 2, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=2.60149, test err=0.814
# Trial 2, Epoch: 1000, V1 model, h=50, lr=1.00000, Loss=0.12797, test err=0.145
# Trial 2, Epoch: 2000, V1 model, h=50, lr=1.00000, Loss=0.46696, test err=0.271
# Trial 2, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=0.42784, test err=0.265
# Trial 3, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=2.63116, test err=0.763
# Trial 3, Epoch: 1000, V1 model, h=50, lr=1.00000, Loss=0.13622, test err=0.152
# Trial 3, Epoch: 2000, V1 model, h=50, lr=1.00000, Loss=0.39005, test err=0.261
# Trial 3, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=0.26970, test err=0.207
# Trial 4, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=2.47943, test err=0.866
# Trial 4, Epoch: 1000, V1 model, h=50, lr=1.00000, Loss=0.11494, test err=0.142
# Trial 4, Epoch: 2000, V1 model, h=50, lr=1.00000, Loss=0.06827, test err=0.140
# Trial 4, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=0.03981, test err=0.143
# Trial 5, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=2.46257, test err=0.786
# Trial 5, Epoch: 1000, V1 model, h=50, lr=1.00000, Loss=0.12306, test err=0.139
# Trial 5, Epoch: 2000, V1 model, h=50, lr=1.00000, Loss=0.15602, test err=0.165
# Trial 5, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=0.09745, test err=0.155
# Trial 6, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=2.51463, test err=0.802
# Trial 6, Epoch: 1000, V1 model, h=50, lr=1.00000, Loss=0.11966, test err=0.140
# Trial 6, Epoch: 2000, V1 model, h=50, lr=1.00000, Loss=0.13374, test err=0.156
# Trial 6, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=0.09546, test err=0.151
# Trial 7, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=2.55386, test err=0.803
# Trial 7, Epoch: 1000, V1 model, h=50, lr=1.00000, Loss=0.12430, test err=0.147
# Trial 7, Epoch: 2000, V1 model, h=50, lr=1.00000, Loss=0.11171, test err=0.152
# Trial 7, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=0.26438, test err=0.221
# Trial 8, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=2.51597, test err=0.819
# Trial 8, Epoch: 1000, V1 model, h=50, lr=1.00000, Loss=0.11962, test err=0.143
# Trial 8, Epoch: 2000, V1 model, h=50, lr=1.00000, Loss=0.10733, test err=0.151
# Trial 8, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=0.07193, test err=0.152
# Trial 9, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=2.64266, test err=0.833
# Trial 9, Epoch: 1000, V1 model, h=50, lr=1.00000, Loss=0.12380, test err=0.146
# Trial 9, Epoch: 2000, V1 model, h=50, lr=1.00000, Loss=0.13108, test err=0.152
# Trial 9, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=0.74540, test err=0.353
# Trial 0, Epoch: 0, He model, h=50, lr=1.00000, Loss=2.32676, test err=0.774
# Trial 0, Epoch: 1000, He model, h=50, lr=1.00000, Loss=0.11807, test err=0.142
# Trial 0, Epoch: 2000, He model, h=50, lr=1.00000, Loss=0.56262, test err=0.315
# Trial 0, Epoch: 3000, He model, h=50, lr=1.00000, Loss=0.26756, test err=0.213
# Trial 1, Epoch: 0, He model, h=50, lr=1.00000, Loss=2.33932, test err=0.782
# Trial 1, Epoch: 1000, He model, h=50, lr=1.00000, Loss=0.12376, test err=0.144
# Trial 1, Epoch: 2000, He model, h=50, lr=1.00000, Loss=0.20571, test err=0.194
# Trial 1, Epoch: 3000, He model, h=50, lr=1.00000, Loss=0.14475, test err=0.174
# Trial 2, Epoch: 0, He model, h=50, lr=1.00000, Loss=2.33145, test err=0.776
# Trial 2, Epoch: 1000, He model, h=50, lr=1.00000, Loss=0.12590, test err=0.146
# Trial 2, Epoch: 2000, He model, h=50, lr=1.00000, Loss=0.16070, test err=0.170
# Trial 2, Epoch: 3000, He model, h=50, lr=1.00000, Loss=0.20631, test err=0.191
# Trial 3, Epoch: 0, He model, h=50, lr=1.00000, Loss=2.32117, test err=0.785
# Trial 3, Epoch: 1000, He model, h=50, lr=1.00000, Loss=0.38567, test err=0.270
# Trial 3, Epoch: 2000, He model, h=50, lr=1.00000, Loss=0.13749, test err=0.159
# Trial 3, Epoch: 3000, He model, h=50, lr=1.00000, Loss=0.12985, test err=0.168
# Trial 4, Epoch: 0, He model, h=50, lr=1.00000, Loss=2.32107, test err=0.753
# Trial 4, Epoch: 1000, He model, h=50, lr=1.00000, Loss=0.12260, test err=0.139
# Trial 4, Epoch: 2000, He model, h=50, lr=1.00000, Loss=0.08314, test err=0.141
# Trial 4, Epoch: 3000, He model, h=50, lr=1.00000, Loss=0.09955, test err=0.157
# Trial 5, Epoch: 0, He model, h=50, lr=1.00000, Loss=2.29106, test err=0.684
# Trial 5, Epoch: 1000, He model, h=50, lr=1.00000, Loss=0.11740, test err=0.137
# Trial 5, Epoch: 2000, He model, h=50, lr=1.00000, Loss=0.17989, test err=0.178
# Trial 5, Epoch: 3000, He model, h=50, lr=1.00000, Loss=0.16635, test err=0.171
# Trial 6, Epoch: 0, He model, h=50, lr=1.00000, Loss=2.36533, test err=0.799
# Trial 6, Epoch: 1000, He model, h=50, lr=1.00000, Loss=0.12219, test err=0.143
# Trial 6, Epoch: 2000, He model, h=50, lr=1.00000, Loss=0.12959, test err=0.157
# Trial 6, Epoch: 3000, He model, h=50, lr=1.00000, Loss=1.09575, test err=0.424
# Trial 7, Epoch: 0, He model, h=50, lr=1.00000, Loss=2.32429, test err=0.764
# Trial 7, Epoch: 1000, He model, h=50, lr=1.00000, Loss=0.15071, test err=0.154
# Trial 7, Epoch: 2000, He model, h=50, lr=1.00000, Loss=0.15550, test err=0.167
# Trial 7, Epoch: 3000, He model, h=50, lr=1.00000, Loss=0.15313, test err=0.187
# Trial 8, Epoch: 0, He model, h=50, lr=1.00000, Loss=2.31489, test err=0.732
# Trial 8, Epoch: 1000, He model, h=50, lr=1.00000, Loss=0.13963, test err=0.148
# Trial 8, Epoch: 2000, He model, h=50, lr=1.00000, Loss=0.08733, test err=0.144
# Trial 8, Epoch: 3000, He model, h=50, lr=1.00000, Loss=0.13835, test err=0.168
# Trial 9, Epoch: 0, He model, h=50, lr=1.00000, Loss=2.34082, test err=0.745
# Trial 9, Epoch: 1000, He model, h=50, lr=1.00000, Loss=0.16007, test err=0.162
# Trial 9, Epoch: 2000, He model, h=50, lr=1.00000, Loss=0.11416, test err=0.158
# Trial 9, Epoch: 3000, He model, h=50, lr=1.00000, Loss=0.06912, test err=0.157
# Trial 0, Epoch: 0, V1 model, h=100, lr=0.00100, Loss=2.53110, test err=0.879
# Trial 0, Epoch: 1000, V1 model, h=100, lr=0.00100, Loss=1.67639, test err=0.602
# Trial 0, Epoch: 2000, V1 model, h=100, lr=0.00100, Loss=1.38552, test err=0.525
# Trial 0, Epoch: 3000, V1 model, h=100, lr=0.00100, Loss=1.21344, test err=0.493
# Trial 1, Epoch: 0, V1 model, h=100, lr=0.00100, Loss=2.57253, test err=0.917
# Trial 1, Epoch: 1000, V1 model, h=100, lr=0.00100, Loss=1.58750, test err=0.556
# Trial 1, Epoch: 2000, V1 model, h=100, lr=0.00100, Loss=1.33012, test err=0.504
# Trial 1, Epoch: 3000, V1 model, h=100, lr=0.00100, Loss=1.19348, test err=0.475
# Trial 2, Epoch: 0, V1 model, h=100, lr=0.00100, Loss=2.72243, test err=0.910
# Trial 2, Epoch: 1000, V1 model, h=100, lr=0.00100, Loss=1.48442, test err=0.556
# Trial 2, Epoch: 2000, V1 model, h=100, lr=0.00100, Loss=1.21009, test err=0.491
# Trial 2, Epoch: 3000, V1 model, h=100, lr=0.00100, Loss=1.07295, test err=0.455
# Trial 3, Epoch: 0, V1 model, h=100, lr=0.00100, Loss=2.71572, test err=0.895
# Trial 3, Epoch: 1000, V1 model, h=100, lr=0.00100, Loss=1.61638, test err=0.614
# Trial 3, Epoch: 2000, V1 model, h=100, lr=0.00100, Loss=1.34217, test err=0.526
# Trial 3, Epoch: 3000, V1 model, h=100, lr=0.00100, Loss=1.19193, test err=0.493
# Trial 4, Epoch: 0, V1 model, h=100, lr=0.00100, Loss=2.78942, test err=0.920
# Trial 4, Epoch: 1000, V1 model, h=100, lr=0.00100, Loss=1.51754, test err=0.559
# Trial 4, Epoch: 2000, V1 model, h=100, lr=0.00100, Loss=1.23753, test err=0.490
# Trial 4, Epoch: 3000, V1 model, h=100, lr=0.00100, Loss=1.09102, test err=0.455
# Trial 5, Epoch: 0, V1 model, h=100, lr=0.00100, Loss=2.60827, test err=0.907
# Trial 5, Epoch: 1000, V1 model, h=100, lr=0.00100, Loss=1.51594, test err=0.562
# Trial 5, Epoch: 2000, V1 model, h=100, lr=0.00100, Loss=1.25152, test err=0.502
# Trial 5, Epoch: 3000, V1 model, h=100, lr=0.00100, Loss=1.11207, test err=0.475
# Trial 6, Epoch: 0, V1 model, h=100, lr=0.00100, Loss=2.60963, test err=0.898
# Trial 6, Epoch: 1000, V1 model, h=100, lr=0.00100, Loss=1.53663, test err=0.577
# Trial 6, Epoch: 2000, V1 model, h=100, lr=0.00100, Loss=1.25894, test err=0.510
# Trial 6, Epoch: 3000, V1 model, h=100, lr=0.00100, Loss=1.11953, test err=0.487
# Trial 7, Epoch: 0, V1 model, h=100, lr=0.00100, Loss=2.61833, test err=0.920
# Trial 7, Epoch: 1000, V1 model, h=100, lr=0.00100, Loss=1.43450, test err=0.551
# Trial 7, Epoch: 2000, V1 model, h=100, lr=0.00100, Loss=1.18429, test err=0.503
# Trial 7, Epoch: 3000, V1 model, h=100, lr=0.00100, Loss=1.05682, test err=0.473
# Trial 8, Epoch: 0, V1 model, h=100, lr=0.00100, Loss=2.36909, test err=0.875
# Trial 8, Epoch: 1000, V1 model, h=100, lr=0.00100, Loss=1.53637, test err=0.586
# Trial 8, Epoch: 2000, V1 model, h=100, lr=0.00100, Loss=1.25348, test err=0.519
# Trial 8, Epoch: 3000, V1 model, h=100, lr=0.00100, Loss=1.10348, test err=0.486
# Trial 9, Epoch: 0, V1 model, h=100, lr=0.00100, Loss=2.54392, test err=0.915
# Trial 9, Epoch: 1000, V1 model, h=100, lr=0.00100, Loss=1.47282, test err=0.563
# Trial 9, Epoch: 2000, V1 model, h=100, lr=0.00100, Loss=1.21338, test err=0.496
# Trial 9, Epoch: 3000, V1 model, h=100, lr=0.00100, Loss=1.07092, test err=0.456
# Trial 0, Epoch: 0, He model, h=100, lr=0.00100, Loss=2.31017, test err=0.898
# Trial 0, Epoch: 1000, He model, h=100, lr=0.00100, Loss=2.06648, test err=0.672
# Trial 0, Epoch: 2000, He model, h=100, lr=0.00100, Loss=1.81226, test err=0.574
# Trial 0, Epoch: 3000, He model, h=100, lr=0.00100, Loss=1.57016, test err=0.518
# Trial 1, Epoch: 0, He model, h=100, lr=0.00100, Loss=2.34259, test err=0.919
# Trial 1, Epoch: 1000, He model, h=100, lr=0.00100, Loss=2.10807, test err=0.706
# Trial 1, Epoch: 2000, He model, h=100, lr=0.00100, Loss=1.84994, test err=0.599
# Trial 1, Epoch: 3000, He model, h=100, lr=0.00100, Loss=1.58826, test err=0.544
# Trial 2, Epoch: 0, He model, h=100, lr=0.00100, Loss=2.34973, test err=0.930
# Trial 2, Epoch: 1000, He model, h=100, lr=0.00100, Loss=2.09929, test err=0.727
# Trial 2, Epoch: 2000, He model, h=100, lr=0.00100, Loss=1.83941, test err=0.609
# Trial 2, Epoch: 3000, He model, h=100, lr=0.00100, Loss=1.59423, test err=0.542
# Trial 3, Epoch: 0, He model, h=100, lr=0.00100, Loss=2.35252, test err=0.910
# Trial 3, Epoch: 1000, He model, h=100, lr=0.00100, Loss=2.11599, test err=0.706
# Trial 3, Epoch: 2000, He model, h=100, lr=0.00100, Loss=1.86226, test err=0.568
# Trial 3, Epoch: 3000, He model, h=100, lr=0.00100, Loss=1.60763, test err=0.514
# Trial 4, Epoch: 0, He model, h=100, lr=0.00100, Loss=2.33397, test err=0.905
# Trial 4, Epoch: 1000, He model, h=100, lr=0.00100, Loss=2.08120, test err=0.705
# Trial 4, Epoch: 2000, He model, h=100, lr=0.00100, Loss=1.82976, test err=0.604
# Trial 4, Epoch: 3000, He model, h=100, lr=0.00100, Loss=1.59406, test err=0.542
# Trial 5, Epoch: 0, He model, h=100, lr=0.00100, Loss=2.33327, test err=0.894
# Trial 5, Epoch: 1000, He model, h=100, lr=0.00100, Loss=2.11728, test err=0.721
# Trial 5, Epoch: 2000, He model, h=100, lr=0.00100, Loss=1.87453, test err=0.625
# Trial 5, Epoch: 3000, He model, h=100, lr=0.00100, Loss=1.63304, test err=0.559
# Trial 6, Epoch: 0, He model, h=100, lr=0.00100, Loss=2.33030, test err=0.897
# Trial 6, Epoch: 1000, He model, h=100, lr=0.00100, Loss=2.02939, test err=0.672
# Trial 6, Epoch: 2000, He model, h=100, lr=0.00100, Loss=1.75782, test err=0.571
# Trial 6, Epoch: 3000, He model, h=100, lr=0.00100, Loss=1.51812, test err=0.517
# Trial 7, Epoch: 0, He model, h=100, lr=0.00100, Loss=2.34434, test err=0.892
# Trial 7, Epoch: 1000, He model, h=100, lr=0.00100, Loss=2.07251, test err=0.688
# Trial 7, Epoch: 2000, He model, h=100, lr=0.00100, Loss=1.80652, test err=0.587
# Trial 7, Epoch: 3000, He model, h=100, lr=0.00100, Loss=1.56324, test err=0.521
# Trial 8, Epoch: 0, He model, h=100, lr=0.00100, Loss=2.32612, test err=0.907
# Trial 8, Epoch: 1000, He model, h=100, lr=0.00100, Loss=2.08012, test err=0.709
# Trial 8, Epoch: 2000, He model, h=100, lr=0.00100, Loss=1.82541, test err=0.613
# Trial 8, Epoch: 3000, He model, h=100, lr=0.00100, Loss=1.58995, test err=0.552
# Trial 9, Epoch: 0, He model, h=100, lr=0.00100, Loss=2.30541, test err=0.892
# Trial 9, Epoch: 1000, He model, h=100, lr=0.00100, Loss=2.07282, test err=0.686
# Trial 9, Epoch: 2000, He model, h=100, lr=0.00100, Loss=1.81080, test err=0.575
# Trial 9, Epoch: 3000, He model, h=100, lr=0.00100, Loss=1.55942, test err=0.520
# Trial 0, Epoch: 0, V1 model, h=100, lr=0.01000, Loss=3.09160, test err=0.927
# Trial 0, Epoch: 1000, V1 model, h=100, lr=0.01000, Loss=0.75291, test err=0.371
# Trial 0, Epoch: 2000, V1 model, h=100, lr=0.01000, Loss=0.60488, test err=0.319
# Trial 0, Epoch: 3000, V1 model, h=100, lr=0.01000, Loss=0.53220, test err=0.290
# Trial 1, Epoch: 0, V1 model, h=100, lr=0.01000, Loss=2.50538, test err=0.865
# Trial 1, Epoch: 1000, V1 model, h=100, lr=0.01000, Loss=0.75216, test err=0.361
# Trial 1, Epoch: 2000, V1 model, h=100, lr=0.01000, Loss=0.59435, test err=0.312
# Trial 1, Epoch: 3000, V1 model, h=100, lr=0.01000, Loss=0.51790, test err=0.285
# Trial 2, Epoch: 0, V1 model, h=100, lr=0.01000, Loss=2.65236, test err=0.906
# Trial 2, Epoch: 1000, V1 model, h=100, lr=0.01000, Loss=0.77877, test err=0.377
# Trial 2, Epoch: 2000, V1 model, h=100, lr=0.01000, Loss=0.61399, test err=0.318
# Trial 2, Epoch: 3000, V1 model, h=100, lr=0.01000, Loss=0.53630, test err=0.289
# Trial 3, Epoch: 0, V1 model, h=100, lr=0.01000, Loss=2.40857, test err=0.849
# Trial 3, Epoch: 1000, V1 model, h=100, lr=0.01000, Loss=0.76484, test err=0.368
# Trial 3, Epoch: 2000, V1 model, h=100, lr=0.01000, Loss=0.60857, test err=0.315
# Trial 3, Epoch: 3000, V1 model, h=100, lr=0.01000, Loss=0.53146, test err=0.291
# Trial 4, Epoch: 0, V1 model, h=100, lr=0.01000, Loss=2.51468, test err=0.867
# Trial 4, Epoch: 1000, V1 model, h=100, lr=0.01000, Loss=0.76974, test err=0.373
# Trial 4, Epoch: 2000, V1 model, h=100, lr=0.01000, Loss=0.62489, test err=0.324
# Trial 4, Epoch: 3000, V1 model, h=100, lr=0.01000, Loss=0.55278, test err=0.298
# Trial 5, Epoch: 0, V1 model, h=100, lr=0.01000, Loss=2.71020, test err=0.912
# Trial 5, Epoch: 1000, V1 model, h=100, lr=0.01000, Loss=0.74537, test err=0.360
# Trial 5, Epoch: 2000, V1 model, h=100, lr=0.01000, Loss=0.60301, test err=0.308
# Trial 5, Epoch: 3000, V1 model, h=100, lr=0.01000, Loss=0.52892, test err=0.285
# Trial 6, Epoch: 0, V1 model, h=100, lr=0.01000, Loss=2.64468, test err=0.873
# Trial 6, Epoch: 1000, V1 model, h=100, lr=0.01000, Loss=0.72032, test err=0.344
# Trial 6, Epoch: 2000, V1 model, h=100, lr=0.01000, Loss=0.58184, test err=0.302
# Trial 6, Epoch: 3000, V1 model, h=100, lr=0.01000, Loss=0.51255, test err=0.275
# Trial 7, Epoch: 0, V1 model, h=100, lr=0.01000, Loss=2.55139, test err=0.880
# Trial 7, Epoch: 1000, V1 model, h=100, lr=0.01000, Loss=0.76238, test err=0.373
# Trial 7, Epoch: 2000, V1 model, h=100, lr=0.01000, Loss=0.61735, test err=0.318
# Trial 7, Epoch: 3000, V1 model, h=100, lr=0.01000, Loss=0.54113, test err=0.292
# Trial 8, Epoch: 0, V1 model, h=100, lr=0.01000, Loss=2.65243, test err=0.881
# Trial 8, Epoch: 1000, V1 model, h=100, lr=0.01000, Loss=0.75505, test err=0.363
# Trial 8, Epoch: 2000, V1 model, h=100, lr=0.01000, Loss=0.59728, test err=0.312
# Trial 8, Epoch: 3000, V1 model, h=100, lr=0.01000, Loss=0.51953, test err=0.284
# Trial 9, Epoch: 0, V1 model, h=100, lr=0.01000, Loss=2.48311, test err=0.874
# Trial 9, Epoch: 1000, V1 model, h=100, lr=0.01000, Loss=0.76179, test err=0.368
# Trial 9, Epoch: 2000, V1 model, h=100, lr=0.01000, Loss=0.59865, test err=0.317
# Trial 9, Epoch: 3000, V1 model, h=100, lr=0.01000, Loss=0.52027, test err=0.290
# Trial 0, Epoch: 0, He model, h=100, lr=0.01000, Loss=2.36463, test err=0.922
# Trial 0, Epoch: 1000, He model, h=100, lr=0.01000, Loss=0.87050, test err=0.392
# Trial 0, Epoch: 2000, He model, h=100, lr=0.01000, Loss=0.65656, test err=0.328
# Trial 0, Epoch: 3000, He model, h=100, lr=0.01000, Loss=0.57511, test err=0.300
# Trial 1, Epoch: 0, He model, h=100, lr=0.01000, Loss=2.30495, test err=0.889
# Trial 1, Epoch: 1000, He model, h=100, lr=0.01000, Loss=0.87111, test err=0.393
# Trial 1, Epoch: 2000, He model, h=100, lr=0.01000, Loss=0.66890, test err=0.337
# Trial 1, Epoch: 3000, He model, h=100, lr=0.01000, Loss=0.58789, test err=0.308
# Trial 2, Epoch: 0, He model, h=100, lr=0.01000, Loss=2.34842, test err=0.927
# Trial 2, Epoch: 1000, He model, h=100, lr=0.01000, Loss=0.89107, test err=0.412
# Trial 2, Epoch: 2000, He model, h=100, lr=0.01000, Loss=0.67290, test err=0.340
# Trial 2, Epoch: 3000, He model, h=100, lr=0.01000, Loss=0.58767, test err=0.309
# Trial 3, Epoch: 0, He model, h=100, lr=0.01000, Loss=2.34031, test err=0.925
# Trial 3, Epoch: 1000, He model, h=100, lr=0.01000, Loss=0.88180, test err=0.403
# Trial 3, Epoch: 2000, He model, h=100, lr=0.01000, Loss=0.67768, test err=0.343
# Trial 3, Epoch: 3000, He model, h=100, lr=0.01000, Loss=0.59329, test err=0.311
# Trial 4, Epoch: 0, He model, h=100, lr=0.01000, Loss=2.32979, test err=0.904
# Trial 4, Epoch: 1000, He model, h=100, lr=0.01000, Loss=0.89636, test err=0.411
# Trial 4, Epoch: 2000, He model, h=100, lr=0.01000, Loss=0.67515, test err=0.343
# Trial 4, Epoch: 3000, He model, h=100, lr=0.01000, Loss=0.58741, test err=0.311
# Trial 5, Epoch: 0, He model, h=100, lr=0.01000, Loss=2.31846, test err=0.880
# Trial 5, Epoch: 1000, He model, h=100, lr=0.01000, Loss=0.86240, test err=0.396
# Trial 5, Epoch: 2000, He model, h=100, lr=0.01000, Loss=0.65695, test err=0.336
# Trial 5, Epoch: 3000, He model, h=100, lr=0.01000, Loss=0.57372, test err=0.304
# Trial 6, Epoch: 0, He model, h=100, lr=0.01000, Loss=2.33328, test err=0.918
# Trial 6, Epoch: 1000, He model, h=100, lr=0.01000, Loss=0.90073, test err=0.410
# Trial 6, Epoch: 2000, He model, h=100, lr=0.01000, Loss=0.67672, test err=0.337
# Trial 6, Epoch: 3000, He model, h=100, lr=0.01000, Loss=0.58699, test err=0.307
# Trial 7, Epoch: 0, He model, h=100, lr=0.01000, Loss=2.30429, test err=0.881
# Trial 7, Epoch: 1000, He model, h=100, lr=0.01000, Loss=0.86824, test err=0.386
# Trial 7, Epoch: 2000, He model, h=100, lr=0.01000, Loss=0.66005, test err=0.329
# Trial 7, Epoch: 3000, He model, h=100, lr=0.01000, Loss=0.57829, test err=0.302
# Trial 8, Epoch: 0, He model, h=100, lr=0.01000, Loss=2.34036, test err=0.895
# Trial 8, Epoch: 1000, He model, h=100, lr=0.01000, Loss=0.88034, test err=0.403
# Trial 8, Epoch: 2000, He model, h=100, lr=0.01000, Loss=0.66987, test err=0.343
# Trial 8, Epoch: 3000, He model, h=100, lr=0.01000, Loss=0.58422, test err=0.310
# Trial 9, Epoch: 0, He model, h=100, lr=0.01000, Loss=2.35021, test err=0.899
# Trial 9, Epoch: 1000, He model, h=100, lr=0.01000, Loss=0.87311, test err=0.396
# Trial 9, Epoch: 2000, He model, h=100, lr=0.01000, Loss=0.66129, test err=0.334
# Trial 9, Epoch: 3000, He model, h=100, lr=0.01000, Loss=0.57614, test err=0.305
# Trial 0, Epoch: 0, V1 model, h=100, lr=0.10000, Loss=2.61217, test err=0.844
# Trial 0, Epoch: 1000, V1 model, h=100, lr=0.10000, Loss=0.34742, test err=0.217
# Trial 0, Epoch: 2000, V1 model, h=100, lr=0.10000, Loss=0.24857, test err=0.178
# Trial 0, Epoch: 3000, V1 model, h=100, lr=0.10000, Loss=0.19460, test err=0.154
# Trial 1, Epoch: 0, V1 model, h=100, lr=0.10000, Loss=2.67092, test err=0.821
# Trial 1, Epoch: 1000, V1 model, h=100, lr=0.10000, Loss=0.33855, test err=0.213
# Trial 1, Epoch: 2000, V1 model, h=100, lr=0.10000, Loss=0.24456, test err=0.177
# Trial 1, Epoch: 3000, V1 model, h=100, lr=0.10000, Loss=0.19330, test err=0.157
# Trial 2, Epoch: 0, V1 model, h=100, lr=0.10000, Loss=2.79529, test err=0.822
# Trial 2, Epoch: 1000, V1 model, h=100, lr=0.10000, Loss=0.32894, test err=0.212
# Trial 2, Epoch: 2000, V1 model, h=100, lr=0.10000, Loss=0.23161, test err=0.169
# Trial 2, Epoch: 3000, V1 model, h=100, lr=0.10000, Loss=0.18227, test err=0.150
# Trial 3, Epoch: 0, V1 model, h=100, lr=0.10000, Loss=2.73563, test err=0.888
# Trial 3, Epoch: 1000, V1 model, h=100, lr=0.10000, Loss=0.32922, test err=0.209
# Trial 3, Epoch: 2000, V1 model, h=100, lr=0.10000, Loss=0.23285, test err=0.173
# Trial 3, Epoch: 3000, V1 model, h=100, lr=0.10000, Loss=0.18291, test err=0.152
# Trial 4, Epoch: 0, V1 model, h=100, lr=0.10000, Loss=2.76361, test err=0.840
# Trial 4, Epoch: 1000, V1 model, h=100, lr=0.10000, Loss=0.33032, test err=0.208
# Trial 4, Epoch: 2000, V1 model, h=100, lr=0.10000, Loss=0.23481, test err=0.171
# Trial 4, Epoch: 3000, V1 model, h=100, lr=0.10000, Loss=0.18318, test err=0.150
# Trial 5, Epoch: 0, V1 model, h=100, lr=0.10000, Loss=2.51938, test err=0.830
# Trial 5, Epoch: 1000, V1 model, h=100, lr=0.10000, Loss=0.32482, test err=0.209
# Trial 5, Epoch: 2000, V1 model, h=100, lr=0.10000, Loss=0.23313, test err=0.169
# Trial 5, Epoch: 3000, V1 model, h=100, lr=0.10000, Loss=0.18421, test err=0.147
# Trial 6, Epoch: 0, V1 model, h=100, lr=0.10000, Loss=2.66677, test err=0.859
# Trial 6, Epoch: 1000, V1 model, h=100, lr=0.10000, Loss=0.33472, test err=0.216
# Trial 6, Epoch: 2000, V1 model, h=100, lr=0.10000, Loss=0.23868, test err=0.175
# Trial 6, Epoch: 3000, V1 model, h=100, lr=0.10000, Loss=0.18910, test err=0.158
# Trial 7, Epoch: 0, V1 model, h=100, lr=0.10000, Loss=2.56812, test err=0.882
# Trial 7, Epoch: 1000, V1 model, h=100, lr=0.10000, Loss=0.33555, test err=0.207
# Trial 7, Epoch: 2000, V1 model, h=100, lr=0.10000, Loss=0.24023, test err=0.173
# Trial 7, Epoch: 3000, V1 model, h=100, lr=0.10000, Loss=0.19043, test err=0.154
# Trial 8, Epoch: 0, V1 model, h=100, lr=0.10000, Loss=2.63048, test err=0.840
# Trial 8, Epoch: 1000, V1 model, h=100, lr=0.10000, Loss=0.31902, test err=0.206
# Trial 8, Epoch: 2000, V1 model, h=100, lr=0.10000, Loss=0.22422, test err=0.165
# Trial 8, Epoch: 3000, V1 model, h=100, lr=0.10000, Loss=0.17689, test err=0.147
# Trial 9, Epoch: 0, V1 model, h=100, lr=0.10000, Loss=2.54849, test err=0.872
# Trial 9, Epoch: 1000, V1 model, h=100, lr=0.10000, Loss=0.33032, test err=0.208
# Trial 9, Epoch: 2000, V1 model, h=100, lr=0.10000, Loss=0.23712, test err=0.170
# Trial 9, Epoch: 3000, V1 model, h=100, lr=0.10000, Loss=0.18640, test err=0.152
# Trial 0, Epoch: 0, He model, h=100, lr=0.10000, Loss=2.29779, test err=0.826
# Trial 0, Epoch: 1000, He model, h=100, lr=0.10000, Loss=0.36431, test err=0.225
# Trial 0, Epoch: 2000, He model, h=100, lr=0.10000, Loss=0.26041, test err=0.181
# Trial 0, Epoch: 3000, He model, h=100, lr=0.10000, Loss=0.20299, test err=0.158
# Trial 1, Epoch: 0, He model, h=100, lr=0.10000, Loss=2.36859, test err=0.893
# Trial 1, Epoch: 1000, He model, h=100, lr=0.10000, Loss=0.37472, test err=0.228
# Trial 1, Epoch: 2000, He model, h=100, lr=0.10000, Loss=0.27030, test err=0.183
# Trial 1, Epoch: 3000, He model, h=100, lr=0.10000, Loss=0.21261, test err=0.161
# Trial 2, Epoch: 0, He model, h=100, lr=0.10000, Loss=2.33605, test err=0.888
# Trial 2, Epoch: 1000, He model, h=100, lr=0.10000, Loss=0.37519, test err=0.228
# Trial 2, Epoch: 2000, He model, h=100, lr=0.10000, Loss=0.27016, test err=0.188
# Trial 2, Epoch: 3000, He model, h=100, lr=0.10000, Loss=0.21091, test err=0.167
# Trial 3, Epoch: 0, He model, h=100, lr=0.10000, Loss=2.31286, test err=0.865
# Trial 3, Epoch: 1000, He model, h=100, lr=0.10000, Loss=0.37755, test err=0.230
# Trial 3, Epoch: 2000, He model, h=100, lr=0.10000, Loss=0.26426, test err=0.182
# Trial 3, Epoch: 3000, He model, h=100, lr=0.10000, Loss=0.20547, test err=0.164
# Trial 4, Epoch: 0, He model, h=100, lr=0.10000, Loss=2.32477, test err=0.887
# Trial 4, Epoch: 1000, He model, h=100, lr=0.10000, Loss=0.36065, test err=0.222
# Trial 4, Epoch: 2000, He model, h=100, lr=0.10000, Loss=0.25788, test err=0.181
# Trial 4, Epoch: 3000, He model, h=100, lr=0.10000, Loss=0.20198, test err=0.159
# Trial 5, Epoch: 0, He model, h=100, lr=0.10000, Loss=2.34881, test err=0.911
# Trial 5, Epoch: 1000, He model, h=100, lr=0.10000, Loss=0.37150, test err=0.229
# Trial 5, Epoch: 2000, He model, h=100, lr=0.10000, Loss=0.26466, test err=0.186
# Trial 5, Epoch: 3000, He model, h=100, lr=0.10000, Loss=0.20603, test err=0.165
# Trial 6, Epoch: 0, He model, h=100, lr=0.10000, Loss=2.30130, test err=0.881
# Trial 6, Epoch: 1000, He model, h=100, lr=0.10000, Loss=0.36768, test err=0.227
# Trial 6, Epoch: 2000, He model, h=100, lr=0.10000, Loss=0.26438, test err=0.185
# Trial 6, Epoch: 3000, He model, h=100, lr=0.10000, Loss=0.20776, test err=0.163
# Trial 7, Epoch: 0, He model, h=100, lr=0.10000, Loss=2.35575, test err=0.894
# Trial 7, Epoch: 1000, He model, h=100, lr=0.10000, Loss=0.37693, test err=0.230
# Trial 7, Epoch: 2000, He model, h=100, lr=0.10000, Loss=0.26520, test err=0.186
# Trial 7, Epoch: 3000, He model, h=100, lr=0.10000, Loss=0.20549, test err=0.166
# Trial 8, Epoch: 0, He model, h=100, lr=0.10000, Loss=2.34795, test err=0.880
# Trial 8, Epoch: 1000, He model, h=100, lr=0.10000, Loss=0.38011, test err=0.234
# Trial 8, Epoch: 2000, He model, h=100, lr=0.10000, Loss=0.26498, test err=0.185
# Trial 8, Epoch: 3000, He model, h=100, lr=0.10000, Loss=0.20442, test err=0.166
# Trial 9, Epoch: 0, He model, h=100, lr=0.10000, Loss=2.32134, test err=0.916
# Trial 9, Epoch: 1000, He model, h=100, lr=0.10000, Loss=0.36845, test err=0.227
# Trial 9, Epoch: 2000, He model, h=100, lr=0.10000, Loss=0.25838, test err=0.184
# Trial 9, Epoch: 3000, He model, h=100, lr=0.10000, Loss=0.20081, test err=0.160
# Trial 0, Epoch: 0, V1 model, h=100, lr=1.00000, Loss=2.73191, test err=0.798
# Trial 0, Epoch: 1000, V1 model, h=100, lr=1.00000, Loss=0.08198, test err=0.126
# Trial 0, Epoch: 2000, V1 model, h=100, lr=1.00000, Loss=0.03303, test err=0.121
# Trial 0, Epoch: 3000, V1 model, h=100, lr=1.00000, Loss=0.01584, test err=0.123
# Trial 1, Epoch: 0, V1 model, h=100, lr=1.00000, Loss=2.63394, test err=0.703
# Trial 1, Epoch: 1000, V1 model, h=100, lr=1.00000, Loss=0.07107, test err=0.120
# Trial 1, Epoch: 2000, V1 model, h=100, lr=1.00000, Loss=0.02783, test err=0.117
# Trial 1, Epoch: 3000, V1 model, h=100, lr=1.00000, Loss=0.01296, test err=0.115
# Trial 2, Epoch: 0, V1 model, h=100, lr=1.00000, Loss=2.42336, test err=0.711
# Trial 2, Epoch: 1000, V1 model, h=100, lr=1.00000, Loss=0.06625, test err=0.110
# Trial 2, Epoch: 2000, V1 model, h=100, lr=1.00000, Loss=0.02478, test err=0.108
# Trial 2, Epoch: 3000, V1 model, h=100, lr=1.00000, Loss=0.01165, test err=0.110
# Trial 3, Epoch: 0, V1 model, h=100, lr=1.00000, Loss=2.66041, test err=0.864
# Trial 3, Epoch: 1000, V1 model, h=100, lr=1.00000, Loss=0.07484, test err=0.123
# Trial 3, Epoch: 2000, V1 model, h=100, lr=1.00000, Loss=0.02830, test err=0.118
# Trial 3, Epoch: 3000, V1 model, h=100, lr=1.00000, Loss=0.01362, test err=0.117
# Trial 4, Epoch: 0, V1 model, h=100, lr=1.00000, Loss=2.85070, test err=0.812
# Trial 4, Epoch: 1000, V1 model, h=100, lr=1.00000, Loss=0.08335, test err=0.126
# Trial 4, Epoch: 2000, V1 model, h=100, lr=1.00000, Loss=0.03471, test err=0.122
# Trial 4, Epoch: 3000, V1 model, h=100, lr=1.00000, Loss=0.01679, test err=0.122
# Trial 5, Epoch: 0, V1 model, h=100, lr=1.00000, Loss=2.67471, test err=0.810
# Trial 5, Epoch: 1000, V1 model, h=100, lr=1.00000, Loss=0.07910, test err=0.123
# Trial 5, Epoch: 2000, V1 model, h=100, lr=1.00000, Loss=0.02782, test err=0.120
# Trial 5, Epoch: 3000, V1 model, h=100, lr=1.00000, Loss=0.01310, test err=0.119
# Trial 6, Epoch: 0, V1 model, h=100, lr=1.00000, Loss=2.77999, test err=0.897
# Trial 6, Epoch: 1000, V1 model, h=100, lr=1.00000, Loss=0.08222, test err=0.123
# Trial 6, Epoch: 2000, V1 model, h=100, lr=1.00000, Loss=0.05127, test err=0.123
# Trial 6, Epoch: 3000, V1 model, h=100, lr=1.00000, Loss=0.02381, test err=0.122
# Trial 7, Epoch: 0, V1 model, h=100, lr=1.00000, Loss=2.63820, test err=0.857
# Trial 7, Epoch: 1000, V1 model, h=100, lr=1.00000, Loss=0.10591, test err=0.131
# Trial 7, Epoch: 2000, V1 model, h=100, lr=1.00000, Loss=0.03966, test err=0.119
# Trial 7, Epoch: 3000, V1 model, h=100, lr=1.00000, Loss=0.01986, test err=0.121
# Trial 8, Epoch: 0, V1 model, h=100, lr=1.00000, Loss=2.74890, test err=0.807
# Trial 8, Epoch: 1000, V1 model, h=100, lr=1.00000, Loss=0.07964, test err=0.118
# Trial 8, Epoch: 2000, V1 model, h=100, lr=1.00000, Loss=0.08104, test err=0.127
# Trial 8, Epoch: 3000, V1 model, h=100, lr=1.00000, Loss=0.03471, test err=0.123
# Trial 9, Epoch: 0, V1 model, h=100, lr=1.00000, Loss=2.63579, test err=0.768
# Trial 9, Epoch: 1000, V1 model, h=100, lr=1.00000, Loss=0.07026, test err=0.117
# Trial 9, Epoch: 2000, V1 model, h=100, lr=1.00000, Loss=0.02731, test err=0.114
# Trial 9, Epoch: 3000, V1 model, h=100, lr=1.00000, Loss=0.01307, test err=0.116
# Trial 0, Epoch: 0, He model, h=100, lr=1.00000, Loss=2.31471, test err=0.690
# Trial 0, Epoch: 1000, He model, h=100, lr=1.00000, Loss=0.07550, test err=0.120
# Trial 0, Epoch: 2000, He model, h=100, lr=1.00000, Loss=0.02818, test err=0.118
# Trial 0, Epoch: 3000, He model, h=100, lr=1.00000, Loss=0.01323, test err=0.119
# Trial 1, Epoch: 0, He model, h=100, lr=1.00000, Loss=2.31203, test err=0.733
# Trial 1, Epoch: 1000, He model, h=100, lr=1.00000, Loss=0.07833, test err=0.122
# Trial 1, Epoch: 2000, He model, h=100, lr=1.00000, Loss=0.02950, test err=0.117
# Trial 1, Epoch: 3000, He model, h=100, lr=1.00000, Loss=0.01388, test err=0.117
# Trial 2, Epoch: 0, He model, h=100, lr=1.00000, Loss=2.35696, test err=0.766
# ...
# Trial 0, Epoch: 1000, He model, h=1000, lr=0.01000, Loss=0.70760, test err=0.343
# Trial 0, Epoch: 2000, He model, h=1000, lr=0.01000, Loss=0.57436, test err=0.302
# Trial 0, Epoch: 3000, He model, h=1000, lr=0.01000, Loss=0.50725, test err=0.275
# Trial 1, Epoch: 0, He model, h=1000, lr=0.01000, Loss=2.31649, test err=0.873
# Trial 1, Epoch: 1000, He model, h=1000, lr=0.01000, Loss=0.70967, test err=0.346
# Trial 1, Epoch: 2000, He model, h=1000, lr=0.01000, Loss=0.57458, test err=0.306
# Trial 1, Epoch: 3000, He model, h=1000, lr=0.01000, Loss=0.50751, test err=0.281
# Trial 2, Epoch: 0, He model, h=1000, lr=0.01000, Loss=2.29055, test err=0.854
# Trial 2, Epoch: 1000, He model, h=1000, lr=0.01000, Loss=0.70541, test err=0.343
# Trial 2, Epoch: 2000, He model, h=1000, lr=0.01000, Loss=0.57103, test err=0.302
# Trial 2, Epoch: 3000, He model, h=1000, lr=0.01000, Loss=0.50383, test err=0.274
# Trial 3, Epoch: 0, He model, h=1000, lr=0.01000, Loss=2.35625, test err=0.912
# Trial 3, Epoch: 1000, He model, h=1000, lr=0.01000, Loss=0.71104, test err=0.351
# Trial 3, Epoch: 2000, He model, h=1000, lr=0.01000, Loss=0.57658, test err=0.307
# Trial 3, Epoch: 3000, He model, h=1000, lr=0.01000, Loss=0.51019, test err=0.283
# Trial 4, Epoch: 0, He model, h=1000, lr=0.01000, Loss=2.30854, test err=0.922
# Trial 4, Epoch: 1000, He model, h=1000, lr=0.01000, Loss=0.70382, test err=0.344
# Trial 4, Epoch: 2000, He model, h=1000, lr=0.01000, Loss=0.57061, test err=0.305
# Trial 4, Epoch: 3000, He model, h=1000, lr=0.01000, Loss=0.50419, test err=0.279
# Trial 5, Epoch: 0, He model, h=1000, lr=0.01000, Loss=2.32213, test err=0.900
# Trial 5, Epoch: 1000, He model, h=1000, lr=0.01000, Loss=0.70400, test err=0.340
# Trial 5, Epoch: 2000, He model, h=1000, lr=0.01000, Loss=0.57181, test err=0.303
# Trial 5, Epoch: 3000, He model, h=1000, lr=0.01000, Loss=0.50573, test err=0.279
# Trial 6, Epoch: 0, He model, h=1000, lr=0.01000, Loss=2.33467, test err=0.904
# Trial 6, Epoch: 1000, He model, h=1000, lr=0.01000, Loss=0.71131, test err=0.343
# Trial 6, Epoch: 2000, He model, h=1000, lr=0.01000, Loss=0.57389, test err=0.304
# Trial 6, Epoch: 3000, He model, h=1000, lr=0.01000, Loss=0.50647, test err=0.278
# Trial 7, Epoch: 0, He model, h=1000, lr=0.01000, Loss=2.35530, test err=0.903
# Trial 7, Epoch: 1000, He model, h=1000, lr=0.01000, Loss=0.70964, test err=0.345
# Trial 7, Epoch: 2000, He model, h=1000, lr=0.01000, Loss=0.57520, test err=0.304
# Trial 7, Epoch: 3000, He model, h=1000, lr=0.01000, Loss=0.50762, test err=0.279
# Trial 8, Epoch: 0, He model, h=1000, lr=0.01000, Loss=2.34986, test err=0.890
# Trial 8, Epoch: 1000, He model, h=1000, lr=0.01000, Loss=0.70995, test err=0.345
# Trial 8, Epoch: 2000, He model, h=1000, lr=0.01000, Loss=0.57485, test err=0.304
# Trial 8, Epoch: 3000, He model, h=1000, lr=0.01000, Loss=0.50678, test err=0.279
# Trial 9, Epoch: 0, He model, h=1000, lr=0.01000, Loss=2.33030, test err=0.891
# Trial 9, Epoch: 1000, He model, h=1000, lr=0.01000, Loss=0.71229, test err=0.345
# Trial 9, Epoch: 2000, He model, h=1000, lr=0.01000, Loss=0.57518, test err=0.301
# Trial 9, Epoch: 3000, He model, h=1000, lr=0.01000, Loss=0.50697, test err=0.276
# Trial 0, Epoch: 0, V1 model, h=1000, lr=0.10000, Loss=2.56233, test err=0.855
# Trial 0, Epoch: 1000, V1 model, h=1000, lr=0.10000, Loss=0.19472, test err=0.139
# Trial 0, Epoch: 2000, V1 model, h=1000, lr=0.10000, Loss=0.13059, test err=0.108
# Trial 0, Epoch: 3000, V1 model, h=1000, lr=0.10000, Loss=0.09801, test err=0.097
# Trial 1, Epoch: 0, V1 model, h=1000, lr=0.10000, Loss=2.49806, test err=0.758
# Trial 1, Epoch: 1000, V1 model, h=1000, lr=0.10000, Loss=0.19748, test err=0.145
# Trial 1, Epoch: 2000, V1 model, h=1000, lr=0.10000, Loss=0.13213, test err=0.114
# Trial 1, Epoch: 3000, V1 model, h=1000, lr=0.10000, Loss=0.09920, test err=0.101
# Trial 2, Epoch: 0, V1 model, h=1000, lr=0.10000, Loss=2.69791, test err=0.803
# Trial 2, Epoch: 1000, V1 model, h=1000, lr=0.10000, Loss=0.19338, test err=0.136
# Trial 2, Epoch: 2000, V1 model, h=1000, lr=0.10000, Loss=0.13076, test err=0.111
# Trial 2, Epoch: 3000, V1 model, h=1000, lr=0.10000, Loss=0.09881, test err=0.099
# Trial 3, Epoch: 0, V1 model, h=1000, lr=0.10000, Loss=2.59502, test err=0.875
# Trial 3, Epoch: 1000, V1 model, h=1000, lr=0.10000, Loss=0.19581, test err=0.139
# Trial 3, Epoch: 2000, V1 model, h=1000, lr=0.10000, Loss=0.13277, test err=0.114
# Trial 3, Epoch: 3000, V1 model, h=1000, lr=0.10000, Loss=0.09999, test err=0.102
# Trial 4, Epoch: 0, V1 model, h=1000, lr=0.10000, Loss=2.64799, test err=0.850
# Trial 4, Epoch: 1000, V1 model, h=1000, lr=0.10000, Loss=0.19790, test err=0.142
# Trial 4, Epoch: 2000, V1 model, h=1000, lr=0.10000, Loss=0.13378, test err=0.114
# Trial 4, Epoch: 3000, V1 model, h=1000, lr=0.10000, Loss=0.10083, test err=0.101
# Trial 5, Epoch: 0, V1 model, h=1000, lr=0.10000, Loss=2.62494, test err=0.899
# Trial 5, Epoch: 1000, V1 model, h=1000, lr=0.10000, Loss=0.19749, test err=0.139
# Trial 5, Epoch: 2000, V1 model, h=1000, lr=0.10000, Loss=0.13249, test err=0.110
# Trial 5, Epoch: 3000, V1 model, h=1000, lr=0.10000, Loss=0.09954, test err=0.099
# Trial 6, Epoch: 0, V1 model, h=1000, lr=0.10000, Loss=2.87279, test err=0.788
# Trial 6, Epoch: 1000, V1 model, h=1000, lr=0.10000, Loss=0.19670, test err=0.139
# Trial 6, Epoch: 2000, V1 model, h=1000, lr=0.10000, Loss=0.13243, test err=0.112
# Trial 6, Epoch: 3000, V1 model, h=1000, lr=0.10000, Loss=0.09958, test err=0.101
# Trial 7, Epoch: 0, V1 model, h=1000, lr=0.10000, Loss=2.67965, test err=0.852
# Trial 7, Epoch: 1000, V1 model, h=1000, lr=0.10000, Loss=0.18747, test err=0.134
# Trial 7, Epoch: 2000, V1 model, h=1000, lr=0.10000, Loss=0.12707, test err=0.111
# Trial 7, Epoch: 3000, V1 model, h=1000, lr=0.10000, Loss=0.09602, test err=0.097
# Trial 8, Epoch: 0, V1 model, h=1000, lr=0.10000, Loss=2.57021, test err=0.770
# Trial 8, Epoch: 1000, V1 model, h=1000, lr=0.10000, Loss=0.19333, test err=0.138
# Trial 8, Epoch: 2000, V1 model, h=1000, lr=0.10000, Loss=0.13077, test err=0.111
# Trial 8, Epoch: 3000, V1 model, h=1000, lr=0.10000, Loss=0.09882, test err=0.099
# Trial 9, Epoch: 0, V1 model, h=1000, lr=0.10000, Loss=2.62560, test err=0.798
# Trial 9, Epoch: 1000, V1 model, h=1000, lr=0.10000, Loss=0.19359, test err=0.142
# Trial 9, Epoch: 2000, V1 model, h=1000, lr=0.10000, Loss=0.13052, test err=0.112
# Trial 9, Epoch: 3000, V1 model, h=1000, lr=0.10000, Loss=0.09854, test err=0.100
# Trial 0, Epoch: 0, He model, h=1000, lr=0.10000, Loss=2.34735, test err=0.818
# Trial 0, Epoch: 1000, He model, h=1000, lr=0.10000, Loss=0.30525, test err=0.201
# Trial 0, Epoch: 2000, He model, h=1000, lr=0.10000, Loss=0.19923, test err=0.157
# Trial 0, Epoch: 3000, He model, h=1000, lr=0.10000, Loss=0.14335, test err=0.134
# Trial 1, Epoch: 0, He model, h=1000, lr=0.10000, Loss=2.32100, test err=0.786
# Trial 1, Epoch: 1000, He model, h=1000, lr=0.10000, Loss=0.30381, test err=0.197
# Trial 1, Epoch: 2000, He model, h=1000, lr=0.10000, Loss=0.19796, test err=0.156
# Trial 1, Epoch: 3000, He model, h=1000, lr=0.10000, Loss=0.14248, test err=0.133
# Trial 2, Epoch: 0, He model, h=1000, lr=0.10000, Loss=2.31938, test err=0.805
# Trial 2, Epoch: 1000, He model, h=1000, lr=0.10000, Loss=0.30808, test err=0.202
# Trial 2, Epoch: 2000, He model, h=1000, lr=0.10000, Loss=0.20033, test err=0.157
# Trial 2, Epoch: 3000, He model, h=1000, lr=0.10000, Loss=0.14401, test err=0.133
# Trial 3, Epoch: 0, He model, h=1000, lr=0.10000, Loss=2.34588, test err=0.803
# Trial 3, Epoch: 1000, He model, h=1000, lr=0.10000, Loss=0.30815, test err=0.202
# Trial 3, Epoch: 2000, He model, h=1000, lr=0.10000, Loss=0.20130, test err=0.161
# Trial 3, Epoch: 3000, He model, h=1000, lr=0.10000, Loss=0.14532, test err=0.137
# Trial 4, Epoch: 0, He model, h=1000, lr=0.10000, Loss=2.34278, test err=0.817
# Trial 4, Epoch: 1000, He model, h=1000, lr=0.10000, Loss=0.30783, test err=0.201
# Trial 4, Epoch: 2000, He model, h=1000, lr=0.10000, Loss=0.20176, test err=0.159
# Trial 4, Epoch: 3000, He model, h=1000, lr=0.10000, Loss=0.14521, test err=0.135
# Trial 5, Epoch: 0, He model, h=1000, lr=0.10000, Loss=2.35056, test err=0.846
# Trial 5, Epoch: 1000, He model, h=1000, lr=0.10000, Loss=0.30541, test err=0.201
# Trial 5, Epoch: 2000, He model, h=1000, lr=0.10000, Loss=0.19856, test err=0.159
# Trial 5, Epoch: 3000, He model, h=1000, lr=0.10000, Loss=0.14290, test err=0.134
# Trial 6, Epoch: 0, He model, h=1000, lr=0.10000, Loss=2.30019, test err=0.796
# Trial 6, Epoch: 1000, He model, h=1000, lr=0.10000, Loss=0.30883, test err=0.204
# Trial 6, Epoch: 2000, He model, h=1000, lr=0.10000, Loss=0.20133, test err=0.160
# Trial 6, Epoch: 3000, He model, h=1000, lr=0.10000, Loss=0.14529, test err=0.136
# Trial 7, Epoch: 0, He model, h=1000, lr=0.10000, Loss=2.30851, test err=0.763
# Trial 7, Epoch: 1000, He model, h=1000, lr=0.10000, Loss=0.30386, test err=0.201
# Trial 7, Epoch: 2000, He model, h=1000, lr=0.10000, Loss=0.19888, test err=0.156
# Trial 7, Epoch: 3000, He model, h=1000, lr=0.10000, Loss=0.14404, test err=0.137
# Trial 8, Epoch: 0, He model, h=1000, lr=0.10000, Loss=2.31079, test err=0.817
# Trial 8, Epoch: 1000, He model, h=1000, lr=0.10000, Loss=0.30558, test err=0.201
# Trial 8, Epoch: 2000, He model, h=1000, lr=0.10000, Loss=0.19931, test err=0.156
# Trial 8, Epoch: 3000, He model, h=1000, lr=0.10000, Loss=0.14380, test err=0.133
# Trial 9, Epoch: 0, He model, h=1000, lr=0.10000, Loss=2.34826, test err=0.826
# Trial 9, Epoch: 1000, He model, h=1000, lr=0.10000, Loss=0.30919, test err=0.202
# Trial 9, Epoch: 2000, He model, h=1000, lr=0.10000, Loss=0.20144, test err=0.160
# Trial 9, Epoch: 3000, He model, h=1000, lr=0.10000, Loss=0.14503, test err=0.135
# Trial 0, Epoch: 0, V1 model, h=1000, lr=1.00000, Loss=2.59567, test err=0.765
# Trial 0, Epoch: 1000, V1 model, h=1000, lr=1.00000, Loss=0.03054, test err=0.085
# Trial 0, Epoch: 2000, V1 model, h=1000, lr=1.00000, Loss=0.00943, test err=0.081
# Trial 0, Epoch: 3000, V1 model, h=1000, lr=1.00000, Loss=0.00474, test err=0.080
# Trial 1, Epoch: 0, V1 model, h=1000, lr=1.00000, Loss=2.47250, test err=0.825
# Trial 1, Epoch: 1000, V1 model, h=1000, lr=1.00000, Loss=0.03317, test err=0.089
# Trial 1, Epoch: 2000, V1 model, h=1000, lr=1.00000, Loss=0.01026, test err=0.084
# Trial 1, Epoch: 3000, V1 model, h=1000, lr=1.00000, Loss=0.00503, test err=0.082
# Trial 2, Epoch: 0, V1 model, h=1000, lr=1.00000, Loss=2.50821, test err=0.776
# Trial 2, Epoch: 1000, V1 model, h=1000, lr=1.00000, Loss=0.03077, test err=0.085
# Trial 2, Epoch: 2000, V1 model, h=1000, lr=1.00000, Loss=0.00946, test err=0.082
# Trial 2, Epoch: 3000, V1 model, h=1000, lr=1.00000, Loss=0.00473, test err=0.081
# Trial 3, Epoch: 0, V1 model, h=1000, lr=1.00000, Loss=2.48601, test err=0.831
# Trial 3, Epoch: 1000, V1 model, h=1000, lr=1.00000, Loss=0.03173, test err=0.088
# Trial 3, Epoch: 2000, V1 model, h=1000, lr=1.00000, Loss=0.00977, test err=0.083
# Trial 3, Epoch: 3000, V1 model, h=1000, lr=1.00000, Loss=0.00486, test err=0.082
# Trial 4, Epoch: 0, V1 model, h=1000, lr=1.00000, Loss=2.73046, test err=0.890
# Trial 4, Epoch: 1000, V1 model, h=1000, lr=1.00000, Loss=0.03332, test err=0.090
# Trial 4, Epoch: 2000, V1 model, h=1000, lr=1.00000, Loss=0.01054, test err=0.085
# Trial 4, Epoch: 3000, V1 model, h=1000, lr=1.00000, Loss=0.00519, test err=0.084
# Trial 5, Epoch: 0, V1 model, h=1000, lr=1.00000, Loss=2.60794, test err=0.884
# Trial 5, Epoch: 1000, V1 model, h=1000, lr=1.00000, Loss=0.03280, test err=0.088
# Trial 5, Epoch: 2000, V1 model, h=1000, lr=1.00000, Loss=0.00991, test err=0.085
# Trial 5, Epoch: 3000, V1 model, h=1000, lr=1.00000, Loss=0.00491, test err=0.083
# Trial 6, Epoch: 0, V1 model, h=1000, lr=1.00000, Loss=2.42924, test err=0.865
# Trial 6, Epoch: 1000, V1 model, h=1000, lr=1.00000, Loss=0.03270, test err=0.086
# Trial 6, Epoch: 2000, V1 model, h=1000, lr=1.00000, Loss=0.01030, test err=0.082
# Trial 6, Epoch: 3000, V1 model, h=1000, lr=1.00000, Loss=0.00505, test err=0.080
# Trial 7, Epoch: 0, V1 model, h=1000, lr=1.00000, Loss=2.56325, test err=0.771
# Trial 7, Epoch: 1000, V1 model, h=1000, lr=1.00000, Loss=0.03034, test err=0.084
# Trial 7, Epoch: 2000, V1 model, h=1000, lr=1.00000, Loss=0.00931, test err=0.081
# Trial 7, Epoch: 3000, V1 model, h=1000, lr=1.00000, Loss=0.00469, test err=0.079
# Trial 8, Epoch: 0, V1 model, h=1000, lr=1.00000, Loss=2.43303, test err=0.836
# Trial 8, Epoch: 1000, V1 model, h=1000, lr=1.00000, Loss=0.03182, test err=0.087
# Trial 8, Epoch: 2000, V1 model, h=1000, lr=1.00000, Loss=0.00987, test err=0.085
# Trial 8, Epoch: 3000, V1 model, h=1000, lr=1.00000, Loss=0.00489, test err=0.083
# Trial 9, Epoch: 0, V1 model, h=1000, lr=1.00000, Loss=2.95833, test err=0.900
# Trial 9, Epoch: 1000, V1 model, h=1000, lr=1.00000, Loss=0.03400, test err=0.090
# Trial 9, Epoch: 2000, V1 model, h=1000, lr=1.00000, Loss=0.01059, test err=0.085
# Trial 9, Epoch: 3000, V1 model, h=1000, lr=1.00000, Loss=0.00517, test err=0.084
# Trial 0, Epoch: 0, He model, h=1000, lr=1.00000, Loss=2.33759, test err=0.710
# Trial 0, Epoch: 1000, He model, h=1000, lr=1.00000, Loss=0.03181, test err=0.097
# Trial 0, Epoch: 2000, He model, h=1000, lr=1.00000, Loss=0.00916, test err=0.092
# Trial 0, Epoch: 3000, He model, h=1000, lr=1.00000, Loss=0.00459, test err=0.091
# Trial 1, Epoch: 0, He model, h=1000, lr=1.00000, Loss=2.32443, test err=0.775
# Trial 1, Epoch: 1000, He model, h=1000, lr=1.00000, Loss=0.03199, test err=0.095
# Trial 1, Epoch: 2000, He model, h=1000, lr=1.00000, Loss=0.00920, test err=0.094
# Trial 1, Epoch: 3000, He model, h=1000, lr=1.00000, Loss=0.00461, test err=0.092
# Trial 2, Epoch: 0, He model, h=1000, lr=1.00000, Loss=2.32710, test err=0.757
# Trial 2, Epoch: 1000, He model, h=1000, lr=1.00000, Loss=0.03272, test err=0.097
# Trial 2, Epoch: 2000, He model, h=1000, lr=1.00000, Loss=0.00944, test err=0.092
# Trial 2, Epoch: 3000, He model, h=1000, lr=1.00000, Loss=0.00471, test err=0.091
# Trial 3, Epoch: 0, He model, h=1000, lr=1.00000, Loss=2.35304, test err=0.807
# Trial 3, Epoch: 1000, He model, h=1000, lr=1.00000, Loss=0.03243, test err=0.095
# Trial 3, Epoch: 2000, He model, h=1000, lr=1.00000, Loss=0.00934, test err=0.091
# Trial 3, Epoch: 3000, He model, h=1000, lr=1.00000, Loss=0.00466, test err=0.089
# Trial 4, Epoch: 0, He model, h=1000, lr=1.00000, Loss=2.33887, test err=0.886
# Trial 4, Epoch: 1000, He model, h=1000, lr=1.00000, Loss=0.03216, test err=0.097
# Trial 4, Epoch: 2000, He model, h=1000, lr=1.00000, Loss=0.00934, test err=0.093
# Trial 4, Epoch: 3000, He model, h=1000, lr=1.00000, Loss=0.00467, test err=0.091
# Trial 5, Epoch: 0, He model, h=1000, lr=1.00000, Loss=2.30701, test err=0.792
# Trial 5, Epoch: 1000, He model, h=1000, lr=1.00000, Loss=0.03221, test err=0.093
# Trial 5, Epoch: 2000, He model, h=1000, lr=1.00000, Loss=0.00927, test err=0.090
# Trial 5, Epoch: 3000, He model, h=1000, lr=1.00000, Loss=0.00463, test err=0.088
# Trial 6, Epoch: 0, He model, h=1000, lr=1.00000, Loss=2.31853, test err=0.736
# Trial 6, Epoch: 1000, He model, h=1000, lr=1.00000, Loss=0.03169, test err=0.096
# Trial 6, Epoch: 2000, He model, h=1000, lr=1.00000, Loss=0.00907, test err=0.092
# Trial 6, Epoch: 3000, He model, h=1000, lr=1.00000, Loss=0.00456, test err=0.091
# Trial 7, Epoch: 0, He model, h=1000, lr=1.00000, Loss=2.32338, test err=0.767
# Trial 7, Epoch: 1000, He model, h=1000, lr=1.00000, Loss=0.03140, test err=0.098
# Trial 7, Epoch: 2000, He model, h=1000, lr=1.00000, Loss=0.00911, test err=0.095
# Trial 7, Epoch: 3000, He model, h=1000, lr=1.00000, Loss=0.00458, test err=0.091
# Trial 8, Epoch: 0, He model, h=1000, lr=1.00000, Loss=2.28866, test err=0.743
# Trial 8, Epoch: 1000, He model, h=1000, lr=1.00000, Loss=0.03251, test err=0.098
# Trial 8, Epoch: 2000, He model, h=1000, lr=1.00000, Loss=0.00933, test err=0.093
# Trial 8, Epoch: 3000, He model, h=1000, lr=1.00000, Loss=0.00466, test err=0.092
# Trial 9, Epoch: 0, He model, h=1000, lr=1.00000, Loss=2.31904, test err=0.709
# Trial 9, Epoch: 1000, He model, h=1000, lr=1.00000, Loss=0.03223, test err=0.095
# Trial 9, Epoch: 2000, He model, h=1000, lr=1.00000, Loss=0.00923, test err=0.089
# Trial 9, Epoch: 3000, He model, h=1000, lr=1.00000, Loss=0.00462, test err=0.088

# %% [markdown]
# ## plot results

# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt

t, l, n_epochs= 5, 2, 3001
models = ['V1', 'He']
h_list = [50, 100, 400, 1000]
lr_list = [1e-3, 1e-2, 1e-1, 1e0]

for h in h_list:
    for lr in lr_list:
        with open('results/initialize_kmnist/full_data/clf_t=%0.2f_l=%0.2f.pickle' % (t, l), 'rb') as handle:
            sims = pickle.load(handle)

        fig = plt.figure(figsize=(12, 5))
        plt.suptitle(r'Shallow FFW FC net w/ GD. h=%d, lr=%0.4f, '% (h, lr), fontsize=16)
        
        # loss
        ax = fig.add_subplot(131)
        plt.title('Network loss', fontsize=16)
        for m in models:
            avg_loss = np.mean(sims['loss'][m][h][lr], axis=0)
            std_loss = np.std(sims['loss'][m][h][lr], axis=0)                       
            plt.plot(np.arange(n_epochs), avg_loss, label=m, lw=3)
            plt.fill_between(np.arange(n_epochs), avg_loss - std_loss, avg_loss + std_loss, alpha=0.2)
        plt.xlabel('Epoch', fontsize=20)
        plt.ylabel('Training loss', fontsize=20)
        ax.tick_params(axis = 'both', which = 'major', labelsize = 14, width=2, length=6)
        plt.yscale('log')
        plt.legend(fontsize=18)
        
        # train err
        ax = fig.add_subplot(132)
        plt.title('Train error', fontsize=16)
        for m in models:
            avg_train_err = np.mean(sims['train_err'][m][h][lr], axis=0)
            std_train_err = np.std(sims['train_err'][m][h][lr], axis=0)
            plt.plot(np.arange(n_epochs), avg_train_err, label=m, lw=3)
            plt.fill_between(np.arange(n_epochs), avg_train_err - std_train_err, avg_train_err + std_train_err,  alpha=0.2)
        
        plt.xlabel('Epoch', fontsize=20)
        plt.ylabel('Training error', fontsize=20)
        ax.tick_params(axis = 'both', which = 'major', labelsize = 14, width=2, length=6)
        plt.yticks(np.arange(0, 1, 0.2))
        plt.yscale('log')
        plt.legend(fontsize=18)

        # test err
        ax = fig.add_subplot(133)
        plt.title('Test error', fontsize=16)
        for m in models:
            avg_test_err = np.mean(sims['test_err'][m][h][lr], axis=0)
            std_test_err = np.std(sims['test_err'][m][h][lr], axis=0)
            plt.plot(np.arange(n_epochs), avg_test_err, label=m, lw=3)
            plt.fill_between(np.arange(n_epochs), avg_test_err - std_test_err, avg_test_err + std_test_err, alpha=0.2)

        plt.xlabel('Epoch', fontsize=20)
        plt.ylabel('Test error', fontsize=20)
        ax.tick_params(axis = 'both', which = 'major', labelsize = 14, width=2, length=6)
        plt.yticks(np.arange(0, 1, 0.2))
        plt.yscale('log')
        plt.legend(fontsize=18)

        plt.tight_layout()
        plt.subplots_adjust(top=0.8)    

        print(h, lr)
        plt.savefig('results/initialize_kmnist/full_data/init_t=%0.2f_l=%0.2f_h=%d_lr=%0.4f.png' % (t, l, h, lr))
        plt.close()
# Out:
# 50 0.001
# 50 0.01
# 50 0.1
# 50 1.0
# 100 0.001
# 100 0.01
# 100 0.1
# 100 1.0
# 400 0.001
# 400 0.01
# 400 0.1
# 400 1.0
# 1000 0.001
# 1000 0.01
# 1000 0.1
# 1000 1.0

# %% [markdown]
# ## Test the speed of training networks on GPUs vs CPU

# %%
import numpy as np
import numpy.linalg as la
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from estimator import classical_weights, V1_inspired_weights
from data_fns import load_kmnist

# %%
torch.cuda.set_device(0)
train, train_labels, test, test_labels = load_kmnist('./data/kmnist/')
X_train = torch.from_numpy(train).float().to('cuda')
X_test = torch.from_numpy(test).float().to('cuda')
y_train = torch.from_numpy(train_labels).long().to('cuda')
y_test = torch.from_numpy(test_labels).long().to('cuda')
n, d = X_train.shape

# %%
class V1_net(nn.Module):
    def __init__(self, hidden_size, scale):
        super().__init__()
        self.fc1 = nn.Linear(d, hidden_size)
        self.fc1.weight.data = torch.FloatTensor(V1_inspired_weights(hidden_size, d, t=5, l=2, scale=scale))
        self.output = nn.Linear(hidden_size, 10)
        
    def forward(self, inputs):
        x = torch.relu(self.fc1(inputs))
        return self.output(x)
    
class He_net(nn.Module):
    def __init__(self, hidden_size, scale):
        super().__init__()
        self.fc1 = nn.Linear(d, hidden_size)
        torch.nn.init.kaiming_normal_(self.fc1.weight)
        self.output = nn.Linear(hidden_size, 10)
        
    def forward(self, inputs):
        x = torch.relu(self.fc1(inputs))
        return self.output(x)   
    
    
def predict(model, X):
    return model(X).data.max(1)[1]

def error(model, X, y):
    y_pred = predict(model, X)
    accuracy = 1.0 * torch.sum(y_pred == y) / len(y)
    return 1 - accuracy

# %%
# %%time
## Run on GPU
h, lr, scale = 500, 1, 2/d
n_epochs = 2001
model = V1_net(h, scale=scale).to('cuda')
loss_func = nn.CrossEntropyLoss()
optim = torch.optim.SGD(model.parameters(), lr=lr)

test_err_list_V1 = []
for i in range(n_epochs):
    optim.zero_grad()
    loss = loss_func(model(X_train), y_train)
    loss.backward()
    optim.step()
    
    train_err = error(model, X_train, y_train)
    test_err = error(model, X_test, y_test)
    test_err_list_V1.append(test_err)
    
    if (i % 200 == 0):
        print('Epoch: %d, Loss=%0.5f, train_err=%0.5f, test_err=%0.5f' % (i, loss.data, train_err, test_err))

# %%
# %%time
## Run on GPU
h, lr, scale = 500, 1, 2/d
n_epochs = 2001
model = He_net(h, scale=scale).to('cuda')
loss_func = nn.CrossEntropyLoss()
optim = torch.optim.SGD(model.parameters(), lr=lr)

test_err_list_He = []
for i in range(n_epochs):
    optim.zero_grad()
    loss = loss_func(model(X_train), y_train)
    loss.backward()
    optim.step()
    
    train_err = error(model, X_train, y_train)
    test_err = error(model, X_test, y_test)
    test_err_list_He.append(test_err)
    
    if (i % 200 == 0):
        print('Epoch: %d, Loss=%0.5f, train_err=%0.5f, test_err=%0.5f' % (i, loss.data, train_err, test_err))

# %%
fig = plt.figure()
plt.plot(np.arange(n_epochs), test_err_list_V1, label='V1')
plt.plot(np.arange(n_epochs), test_err_list_He, label='He')
plt.yscale('log')
plt.legend()

# %%
ls data/
