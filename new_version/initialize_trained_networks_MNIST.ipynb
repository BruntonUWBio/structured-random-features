# %%
import numpy as np
import numpy.linalg as la
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from estimator import classical_weights, V1_inspired_weights
import pickle

# %%
from mnist import MNIST
mndata = MNIST('./data/mnist/')
train, train_labels = map(torch.FloatTensor, mndata.load_training())
test, test_labels = map(torch.FloatTensor, mndata.load_testing())
X_train = train/255.0
X_test = test/255.0
                    
n, d = X_train.shape

y_train = train_labels.to(dtype=torch.long)
y_test = test_labels.to(dtype=torch.long)

# %%
class V1_net(nn.Module):
    def __init__(self, hidden_size, scale):
        super().__init__()
        self.fc1 = nn.Linear(d, hidden_size)
        self.fc1.weight.data = torch.FloatTensor(V1_inspired_weights(hidden_size, d, t=5, l=2, scale=scale))
        self.output = nn.Linear(hidden_size, 10)
        
    def forward(self, inputs):
        x = torch.relu(self.fc1(inputs))
        return self.output(x)
    
class He_net(nn.Module):
    def __init__(self, hidden_size, scale):
        super().__init__()
        self.fc1 = nn.Linear(d, hidden_size)
        torch.nn.init.kaiming_normal_(self.fc1.weight)
        self.output = nn.Linear(hidden_size, 10)
        
    def forward(self, inputs):
        x = torch.relu(self.fc1(inputs))
        return self.output(x)
    
class RF_net(nn.Module):
    def __init__(self, hidden_size, scale):
        super().__init__()
        self.fc1 = nn.Linear(d, hidden_size)
        self.fc1.weight.data = torch.FloatTensor(classical_weights(hidden_size, d, scale=scale))
        self.output = nn.Linear(hidden_size, 10)
        
    def forward(self, inputs):
        x = torch.relu(self.fc1(inputs))
        return self.output(x)

# %%
def predict(model, X):
    return model(X).data.max(1)[1]

def error(model, X, y):
    y_pred = predict(model, X)
    accuracy = 1.0 * torch.sum(y_pred == y) / len(y)
    return 1 - accuracy

# %%
V1_model = V1_net(32, 1/32)
RF_model = RF_net(32, 1/32)
He_model= He_net(32, 1/32)
print('V1', torch.mean(torch.norm(V1_model.fc1.weight.data, dim=1)))
print('He', torch.mean(torch.norm(He_model.fc1.weight.data, dim=1)))
print('RF', torch.mean(torch.norm(RF_model.fc1.weight.data, dim=1)))
w = torch.mean(torch.norm(RF_model.fc1.weight.data, dim=1))
# Out:
# V1 tensor(4.6528)
# He tensor(1.4180)
# RF tensor(4.9700)

# %%
scale = 1/32
models = {'V1': V1_net, 'RF': RF_net, 'He': He_net}
n_epochs = 1001
n_trials = 3
t, l = 5, 3
loss_func = nn.CrossEntropyLoss()

for h in [50, 100, 400, 1000]:
    for lr in [1e-3, 1e-2, 1e-1, 1e0]:
        train_err = {m: np.zeros((n_trials, n_epochs)) for m in models.keys()}
        test_err = {m: np.zeros((n_trials, n_epochs)) for m in models.keys()}
        loss_list = {m: np.zeros((n_trials, n_epochs)) for m in models.keys()}
        for m, network in models.items():
            for i in range(n_trials):
                model = network(h, scale)
                optim = torch.optim.SGD(model.parameters(), lr=lr)
                for j in range(n_epochs):
                    optim.zero_grad()
                    loss = loss_func(model(X_train), y_train)
                    loss.backward()
                    optim.step()

                    train_err[m][i, j] = error(model, X_train, y_train)
                    test_err[m][i, j] = error(model, X_test, y_test)
                    loss_list[m][i, j] = loss.data

                    if (j % 100 == 0):
                        print('Trial %d, Epoch: %d, %s model, h=%d, lr=%0.5f, Loss=%0.5f, test err=%0.3f' % (i,j, m, 
                                                                                                             h, lr, 
                                                                                                             loss, 
                                                                                                  test_err[m][i, j]))

        results = {'test_err': test_err, 'train_err': train_err, 'loss': loss_list}
        with open('results/initialize_mnist/clf_t=%0.2f_l=%0.2f_h=%d_lr=%0.4f_scale=%0.6f.pickle' % (t, l, 
                                                                                                     h, lr, 
                                                                                                     scale), 
                  'wb') as handle:
            pickle.dump(results, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# Trial 0, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=4.32108, test err=0.952
# Trial 0, Epoch: 100, V1 model, h=50, lr=0.00100, Loss=2.31125, test err=0.790
# Trial 0, Epoch: 200, V1 model, h=50, lr=0.00100, Loss=1.96239, test err=0.676
# Trial 0, Epoch: 300, V1 model, h=50, lr=0.00100, Loss=1.74155, test err=0.601
# Trial 0, Epoch: 400, V1 model, h=50, lr=0.00100, Loss=1.58059, test err=0.518
# Trial 0, Epoch: 500, V1 model, h=50, lr=0.00100, Loss=1.45714, test err=0.440
# Trial 0, Epoch: 600, V1 model, h=50, lr=0.00100, Loss=1.35917, test err=0.390
# Trial 0, Epoch: 700, V1 model, h=50, lr=0.00100, Loss=1.27945, test err=0.352
# Trial 0, Epoch: 800, V1 model, h=50, lr=0.00100, Loss=1.21329, test err=0.326
# Trial 0, Epoch: 900, V1 model, h=50, lr=0.00100, Loss=1.15750, test err=0.306
# Trial 0, Epoch: 1000, V1 model, h=50, lr=0.00100, Loss=1.10983, test err=0.291
# Trial 1, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=4.20815, test err=0.915
# Trial 1, Epoch: 100, V1 model, h=50, lr=0.00100, Loss=2.18770, test err=0.811
# Trial 1, Epoch: 200, V1 model, h=50, lr=0.00100, Loss=1.69208, test err=0.549
# Trial 1, Epoch: 300, V1 model, h=50, lr=0.00100, Loss=1.44131, test err=0.434
# Trial 1, Epoch: 400, V1 model, h=50, lr=0.00100, Loss=1.29329, test err=0.377
# Trial 1, Epoch: 500, V1 model, h=50, lr=0.00100, Loss=1.19472, test err=0.347
# Trial 1, Epoch: 600, V1 model, h=50, lr=0.00100, Loss=1.12331, test err=0.325
# Trial 1, Epoch: 700, V1 model, h=50, lr=0.00100, Loss=1.06842, test err=0.310
# Trial 1, Epoch: 800, V1 model, h=50, lr=0.00100, Loss=1.02437, test err=0.298
# Trial 1, Epoch: 900, V1 model, h=50, lr=0.00100, Loss=0.98789, test err=0.286
# Trial 1, Epoch: 1000, V1 model, h=50, lr=0.00100, Loss=0.95691, test err=0.278
# Trial 2, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=3.71481, test err=0.923
# Trial 2, Epoch: 100, V1 model, h=50, lr=0.00100, Loss=2.06007, test err=0.675
# Trial 2, Epoch: 200, V1 model, h=50, lr=0.00100, Loss=1.67908, test err=0.532
# Trial 2, Epoch: 300, V1 model, h=50, lr=0.00100, Loss=1.46178, test err=0.449
# Trial 2, Epoch: 400, V1 model, h=50, lr=0.00100, Loss=1.32124, test err=0.403
# Trial 2, Epoch: 500, V1 model, h=50, lr=0.00100, Loss=1.22192, test err=0.368
# Trial 2, Epoch: 600, V1 model, h=50, lr=0.00100, Loss=1.14733, test err=0.342
# Trial 2, Epoch: 700, V1 model, h=50, lr=0.00100, Loss=1.08882, test err=0.319
# Trial 2, Epoch: 800, V1 model, h=50, lr=0.00100, Loss=1.04140, test err=0.304
# Trial 2, Epoch: 900, V1 model, h=50, lr=0.00100, Loss=1.00196, test err=0.291
# Trial 2, Epoch: 1000, V1 model, h=50, lr=0.00100, Loss=0.96850, test err=0.280
# Trial 0, Epoch: 0, RF model, h=50, lr=0.00100, Loss=2.46665, test err=0.895
# Trial 0, Epoch: 100, RF model, h=50, lr=0.00100, Loss=2.36785, test err=0.869
# Trial 0, Epoch: 200, RF model, h=50, lr=0.00100, Loss=2.29305, test err=0.841
# Trial 0, Epoch: 300, RF model, h=50, lr=0.00100, Loss=2.22936, test err=0.806
# Trial 0, Epoch: 400, RF model, h=50, lr=0.00100, Loss=2.17154, test err=0.774
# Trial 0, Epoch: 500, RF model, h=50, lr=0.00100, Loss=2.11726, test err=0.737
# Trial 0, Epoch: 600, RF model, h=50, lr=0.00100, Loss=2.06542, test err=0.694
# Trial 0, Epoch: 700, RF model, h=50, lr=0.00100, Loss=2.01545, test err=0.653
# Trial 0, Epoch: 800, RF model, h=50, lr=0.00100, Loss=1.96699, test err=0.612
# Trial 0, Epoch: 900, RF model, h=50, lr=0.00100, Loss=1.91989, test err=0.570
# Trial 0, Epoch: 1000, RF model, h=50, lr=0.00100, Loss=1.87396, test err=0.530
# Trial 1, Epoch: 0, RF model, h=50, lr=0.00100, Loss=2.52123, test err=0.913
# Trial 1, Epoch: 100, RF model, h=50, lr=0.00100, Loss=2.34513, test err=0.898
# Trial 1, Epoch: 200, RF model, h=50, lr=0.00100, Loss=2.24607, test err=0.863
# Trial 1, Epoch: 300, RF model, h=50, lr=0.00100, Loss=2.17109, test err=0.819
# Trial 1, Epoch: 400, RF model, h=50, lr=0.00100, Loss=2.10710, test err=0.774
# Trial 1, Epoch: 500, RF model, h=50, lr=0.00100, Loss=2.04901, test err=0.725
# Trial 1, Epoch: 600, RF model, h=50, lr=0.00100, Loss=1.99454, test err=0.677
# Trial 1, Epoch: 700, RF model, h=50, lr=0.00100, Loss=1.94262, test err=0.630
# Trial 1, Epoch: 800, RF model, h=50, lr=0.00100, Loss=1.89269, test err=0.593
# Trial 1, Epoch: 900, RF model, h=50, lr=0.00100, Loss=1.84445, test err=0.558
# Trial 1, Epoch: 1000, RF model, h=50, lr=0.00100, Loss=1.79776, test err=0.527
# Trial 2, Epoch: 0, RF model, h=50, lr=0.00100, Loss=2.58625, test err=0.886
# Trial 2, Epoch: 100, RF model, h=50, lr=0.00100, Loss=2.45739, test err=0.871
# Trial 2, Epoch: 200, RF model, h=50, lr=0.00100, Loss=2.36652, test err=0.853
# Trial 2, Epoch: 300, RF model, h=50, lr=0.00100, Loss=2.29616, test err=0.828
# Trial 2, Epoch: 400, RF model, h=50, lr=0.00100, Loss=2.23740, test err=0.801
# Trial 2, Epoch: 500, RF model, h=50, lr=0.00100, Loss=2.18541, test err=0.766
# Trial 2, Epoch: 600, RF model, h=50, lr=0.00100, Loss=2.13758, test err=0.734
# Trial 2, Epoch: 700, RF model, h=50, lr=0.00100, Loss=2.09249, test err=0.702
# Trial 2, Epoch: 800, RF model, h=50, lr=0.00100, Loss=2.04932, test err=0.672
# Trial 2, Epoch: 900, RF model, h=50, lr=0.00100, Loss=2.00760, test err=0.645
# Trial 2, Epoch: 1000, RF model, h=50, lr=0.00100, Loss=1.96704, test err=0.620
# Trial 0, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.33178, test err=0.914
# Trial 0, Epoch: 100, He model, h=50, lr=0.00100, Loss=2.30611, test err=0.895
# Trial 0, Epoch: 200, He model, h=50, lr=0.00100, Loss=2.28282, test err=0.872
# Trial 0, Epoch: 300, He model, h=50, lr=0.00100, Loss=2.26115, test err=0.847
# Trial 0, Epoch: 400, He model, h=50, lr=0.00100, Loss=2.24054, test err=0.810
# Trial 0, Epoch: 500, He model, h=50, lr=0.00100, Loss=2.22056, test err=0.775
# Trial 0, Epoch: 600, He model, h=50, lr=0.00100, Loss=2.20082, test err=0.738
# Trial 0, Epoch: 700, He model, h=50, lr=0.00100, Loss=2.18102, test err=0.697
# Trial 0, Epoch: 800, He model, h=50, lr=0.00100, Loss=2.16093, test err=0.651
# Trial 0, Epoch: 900, He model, h=50, lr=0.00100, Loss=2.14029, test err=0.617
# Trial 0, Epoch: 1000, He model, h=50, lr=0.00100, Loss=2.11901, test err=0.584
# Trial 1, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.31996, test err=0.893
# Trial 1, Epoch: 100, He model, h=50, lr=0.00100, Loss=2.29109, test err=0.882
# Trial 1, Epoch: 200, He model, h=50, lr=0.00100, Loss=2.26536, test err=0.863
# Trial 1, Epoch: 300, He model, h=50, lr=0.00100, Loss=2.24156, test err=0.841
# Trial 1, Epoch: 400, He model, h=50, lr=0.00100, Loss=2.21885, test err=0.816
# Trial 1, Epoch: 500, He model, h=50, lr=0.00100, Loss=2.19666, test err=0.794
# Trial 1, Epoch: 600, He model, h=50, lr=0.00100, Loss=2.17458, test err=0.769
# Trial 1, Epoch: 700, He model, h=50, lr=0.00100, Loss=2.15237, test err=0.740
# Trial 1, Epoch: 800, He model, h=50, lr=0.00100, Loss=2.12979, test err=0.706
# Trial 1, Epoch: 900, He model, h=50, lr=0.00100, Loss=2.10671, test err=0.667
# Trial 1, Epoch: 1000, He model, h=50, lr=0.00100, Loss=2.08301, test err=0.631
# Trial 2, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.32559, test err=0.894
# Trial 2, Epoch: 100, He model, h=50, lr=0.00100, Loss=2.29882, test err=0.870
# Trial 2, Epoch: 200, He model, h=50, lr=0.00100, Loss=2.27419, test err=0.839
# Trial 2, Epoch: 300, He model, h=50, lr=0.00100, Loss=2.25103, test err=0.794
# Trial 2, Epoch: 400, He model, h=50, lr=0.00100, Loss=2.22880, test err=0.747
# Trial 2, Epoch: 500, He model, h=50, lr=0.00100, Loss=2.20700, test err=0.705
# Trial 2, Epoch: 600, He model, h=50, lr=0.00100, Loss=2.18529, test err=0.664
# Trial 2, Epoch: 700, He model, h=50, lr=0.00100, Loss=2.16337, test err=0.628
# Trial 2, Epoch: 800, He model, h=50, lr=0.00100, Loss=2.14095, test err=0.596
# Trial 2, Epoch: 900, He model, h=50, lr=0.00100, Loss=2.11790, test err=0.570
# Trial 2, Epoch: 1000, He model, h=50, lr=0.00100, Loss=2.09402, test err=0.544
# Trial 0, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=3.24561, test err=0.790
# Trial 0, Epoch: 100, V1 model, h=50, lr=0.01000, Loss=0.97806, test err=0.265
# Trial 0, Epoch: 200, V1 model, h=50, lr=0.01000, Loss=0.78785, test err=0.209
# Trial 0, Epoch: 300, V1 model, h=50, lr=0.01000, Loss=0.69666, test err=0.186
# Trial 0, Epoch: 400, V1 model, h=50, lr=0.01000, Loss=0.63972, test err=0.174
# Trial 0, Epoch: 500, V1 model, h=50, lr=0.01000, Loss=0.59952, test err=0.164
# Trial 0, Epoch: 600, V1 model, h=50, lr=0.01000, Loss=0.56904, test err=0.156
# Trial 0, Epoch: 700, V1 model, h=50, lr=0.01000, Loss=0.54484, test err=0.151
# Trial 0, Epoch: 800, V1 model, h=50, lr=0.01000, Loss=0.52497, test err=0.146
# Trial 0, Epoch: 900, V1 model, h=50, lr=0.01000, Loss=0.50824, test err=0.142
# Trial 0, Epoch: 1000, V1 model, h=50, lr=0.01000, Loss=0.49386, test err=0.139
# Trial 1, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=5.11700, test err=0.852
# Trial 1, Epoch: 100, V1 model, h=50, lr=0.01000, Loss=0.86228, test err=0.244
# Trial 1, Epoch: 200, V1 model, h=50, lr=0.01000, Loss=0.70122, test err=0.195
# Trial 1, Epoch: 300, V1 model, h=50, lr=0.01000, Loss=0.62731, test err=0.173
# Trial 1, Epoch: 400, V1 model, h=50, lr=0.01000, Loss=0.58172, test err=0.161
# Trial 1, Epoch: 500, V1 model, h=50, lr=0.01000, Loss=0.54949, test err=0.152
# Trial 1, Epoch: 600, V1 model, h=50, lr=0.01000, Loss=0.52483, test err=0.146
# Trial 1, Epoch: 700, V1 model, h=50, lr=0.01000, Loss=0.50499, test err=0.140
# Trial 1, Epoch: 800, V1 model, h=50, lr=0.01000, Loss=0.48845, test err=0.138
# Trial 1, Epoch: 900, V1 model, h=50, lr=0.01000, Loss=0.47429, test err=0.134
# Trial 1, Epoch: 1000, V1 model, h=50, lr=0.01000, Loss=0.46194, test err=0.130
# Trial 2, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=3.55676, test err=0.907
# Trial 2, Epoch: 100, V1 model, h=50, lr=0.01000, Loss=1.00209, test err=0.275
# Trial 2, Epoch: 200, V1 model, h=50, lr=0.01000, Loss=0.79803, test err=0.212
# Trial 2, Epoch: 300, V1 model, h=50, lr=0.01000, Loss=0.69993, test err=0.185
# Trial 2, Epoch: 400, V1 model, h=50, lr=0.01000, Loss=0.63767, test err=0.170
# Trial 2, Epoch: 500, V1 model, h=50, lr=0.01000, Loss=0.59321, test err=0.158
# Trial 2, Epoch: 600, V1 model, h=50, lr=0.01000, Loss=0.55930, test err=0.149
# Trial 2, Epoch: 700, V1 model, h=50, lr=0.01000, Loss=0.53228, test err=0.142
# Trial 2, Epoch: 800, V1 model, h=50, lr=0.01000, Loss=0.51008, test err=0.138
# Trial 2, Epoch: 900, V1 model, h=50, lr=0.01000, Loss=0.49145, test err=0.133
# Trial 2, Epoch: 1000, V1 model, h=50, lr=0.01000, Loss=0.47550, test err=0.129
# Trial 0, Epoch: 0, RF model, h=50, lr=0.01000, Loss=2.45761, test err=0.887
# Trial 0, Epoch: 100, RF model, h=50, lr=0.01000, Loss=1.90479, test err=0.586
# Trial 0, Epoch: 200, RF model, h=50, lr=0.01000, Loss=1.51393, test err=0.359
# Trial 0, Epoch: 300, RF model, h=50, lr=0.01000, Loss=1.20993, test err=0.281
# Trial 0, Epoch: 400, RF model, h=50, lr=0.01000, Loss=1.00512, test err=0.243
# Trial 0, Epoch: 500, RF model, h=50, lr=0.01000, Loss=0.87151, test err=0.218
# Trial 0, Epoch: 600, RF model, h=50, lr=0.01000, Loss=0.78103, test err=0.201
# Trial 0, Epoch: 700, RF model, h=50, lr=0.01000, Loss=0.71652, test err=0.189
# Trial 0, Epoch: 800, RF model, h=50, lr=0.01000, Loss=0.66827, test err=0.181
# Trial 0, Epoch: 900, RF model, h=50, lr=0.01000, Loss=0.63076, test err=0.173
# Trial 0, Epoch: 1000, RF model, h=50, lr=0.01000, Loss=0.60067, test err=0.167
# Trial 1, Epoch: 0, RF model, h=50, lr=0.01000, Loss=2.44188, test err=0.824
# Trial 1, Epoch: 100, RF model, h=50, lr=0.01000, Loss=1.75394, test err=0.474
# Trial 1, Epoch: 200, RF model, h=50, lr=0.01000, Loss=1.39366, test err=0.342
# Trial 1, Epoch: 300, RF model, h=50, lr=0.01000, Loss=1.14123, test err=0.275
# Trial 1, Epoch: 400, RF model, h=50, lr=0.01000, Loss=0.97280, test err=0.243
# Trial 1, Epoch: 500, RF model, h=50, lr=0.01000, Loss=0.85874, test err=0.221
# Trial 1, Epoch: 600, RF model, h=50, lr=0.01000, Loss=0.77799, test err=0.202
# Trial 1, Epoch: 700, RF model, h=50, lr=0.01000, Loss=0.71807, test err=0.188
# Trial 1, Epoch: 800, RF model, h=50, lr=0.01000, Loss=0.67181, test err=0.177
# Trial 1, Epoch: 900, RF model, h=50, lr=0.01000, Loss=0.63497, test err=0.169
# Trial 1, Epoch: 1000, RF model, h=50, lr=0.01000, Loss=0.60487, test err=0.162
# Trial 2, Epoch: 0, RF model, h=50, lr=0.01000, Loss=2.58133, test err=0.910
# Trial 2, Epoch: 100, RF model, h=50, lr=0.01000, Loss=1.95378, test err=0.618
# Trial 2, Epoch: 200, RF model, h=50, lr=0.01000, Loss=1.58270, test err=0.422
# Trial 2, Epoch: 300, RF model, h=50, lr=0.01000, Loss=1.28708, test err=0.331
# Trial 2, Epoch: 400, RF model, h=50, lr=0.01000, Loss=1.07451, test err=0.280
# Trial 2, Epoch: 500, RF model, h=50, lr=0.01000, Loss=0.92801, test err=0.243
# Trial 2, Epoch: 600, RF model, h=50, lr=0.01000, Loss=0.82548, test err=0.220
# Trial 2, Epoch: 700, RF model, h=50, lr=0.01000, Loss=0.75116, test err=0.204
# Trial 2, Epoch: 800, RF model, h=50, lr=0.01000, Loss=0.69524, test err=0.192
# Trial 2, Epoch: 900, RF model, h=50, lr=0.01000, Loss=0.65172, test err=0.184
# Trial 2, Epoch: 1000, RF model, h=50, lr=0.01000, Loss=0.61683, test err=0.175
# Trial 0, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.31267, test err=0.878
# Trial 0, Epoch: 100, He model, h=50, lr=0.01000, Loss=2.08200, test err=0.516
# Trial 0, Epoch: 200, He model, h=50, lr=0.01000, Loss=1.79220, test err=0.343
# Trial 0, Epoch: 300, He model, h=50, lr=0.01000, Loss=1.46089, test err=0.272
# Trial 0, Epoch: 400, He model, h=50, lr=0.01000, Loss=1.17723, test err=0.226
# Trial 0, Epoch: 500, He model, h=50, lr=0.01000, Loss=0.97621, test err=0.200
# Trial 0, Epoch: 600, He model, h=50, lr=0.01000, Loss=0.84052, test err=0.181
# Trial 0, Epoch: 700, He model, h=50, lr=0.01000, Loss=0.74672, test err=0.168
# Trial 0, Epoch: 800, He model, h=50, lr=0.01000, Loss=0.67901, test err=0.156
# Trial 0, Epoch: 900, He model, h=50, lr=0.01000, Loss=0.62805, test err=0.145
# Trial 0, Epoch: 1000, He model, h=50, lr=0.01000, Loss=0.58832, test err=0.136
# Trial 1, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.33435, test err=0.891
# Trial 1, Epoch: 100, He model, h=50, lr=0.01000, Loss=2.15476, test err=0.622
# Trial 1, Epoch: 200, He model, h=50, lr=0.01000, Loss=1.92306, test err=0.439
# Trial 1, Epoch: 300, He model, h=50, lr=0.01000, Loss=1.62425, test err=0.339
# Trial 1, Epoch: 400, He model, h=50, lr=0.01000, Loss=1.32597, test err=0.268
# Trial 1, Epoch: 500, He model, h=50, lr=0.01000, Loss=1.09234, test err=0.217
# Trial 1, Epoch: 600, He model, h=50, lr=0.01000, Loss=0.92826, test err=0.191
# Trial 1, Epoch: 700, He model, h=50, lr=0.01000, Loss=0.81288, test err=0.174
# Trial 1, Epoch: 800, He model, h=50, lr=0.01000, Loss=0.72908, test err=0.160
# Trial 1, Epoch: 900, He model, h=50, lr=0.01000, Loss=0.66617, test err=0.149
# Trial 1, Epoch: 1000, He model, h=50, lr=0.01000, Loss=0.61752, test err=0.142
# Trial 2, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.30199, test err=0.903
# Trial 2, Epoch: 100, He model, h=50, lr=0.01000, Loss=2.10390, test err=0.610
# Trial 2, Epoch: 200, He model, h=50, lr=0.01000, Loss=1.84518, test err=0.447
# Trial 2, Epoch: 300, He model, h=50, lr=0.01000, Loss=1.54522, test err=0.321
# Trial 2, Epoch: 400, He model, h=50, lr=0.01000, Loss=1.27095, test err=0.255
# Trial 2, Epoch: 500, He model, h=50, lr=0.01000, Loss=1.05999, test err=0.216
# Trial 2, Epoch: 600, He model, h=50, lr=0.01000, Loss=0.90905, test err=0.191
# Trial 2, Epoch: 700, He model, h=50, lr=0.01000, Loss=0.80132, test err=0.173
# Trial 2, Epoch: 800, He model, h=50, lr=0.01000, Loss=0.72244, test err=0.161
# Trial 2, Epoch: 900, He model, h=50, lr=0.01000, Loss=0.66285, test err=0.151
# Trial 2, Epoch: 1000, He model, h=50, lr=0.01000, Loss=0.61648, test err=0.143
# Trial 0, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=4.19614, test err=0.772
# Trial 0, Epoch: 100, V1 model, h=50, lr=0.10000, Loss=0.52379, test err=0.144
# Trial 0, Epoch: 200, V1 model, h=50, lr=0.10000, Loss=0.39951, test err=0.105
# Trial 0, Epoch: 300, V1 model, h=50, lr=0.10000, Loss=0.34697, test err=0.091
# Trial 0, Epoch: 400, V1 model, h=50, lr=0.10000, Loss=0.31372, test err=0.080
# Trial 0, Epoch: 500, V1 model, h=50, lr=0.10000, Loss=0.29020, test err=0.075
# Trial 0, Epoch: 600, V1 model, h=50, lr=0.10000, Loss=0.27239, test err=0.072
# Trial 0, Epoch: 700, V1 model, h=50, lr=0.10000, Loss=0.25817, test err=0.068
# Trial 0, Epoch: 800, V1 model, h=50, lr=0.10000, Loss=0.24645, test err=0.066
# Trial 0, Epoch: 900, V1 model, h=50, lr=0.10000, Loss=0.23654, test err=0.063
# Trial 0, Epoch: 1000, V1 model, h=50, lr=0.10000, Loss=0.22794, test err=0.061
# Trial 1, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=4.13838, test err=0.793
# Trial 1, Epoch: 100, V1 model, h=50, lr=0.10000, Loss=0.47129, test err=0.136
# Trial 1, Epoch: 200, V1 model, h=50, lr=0.10000, Loss=0.38558, test err=0.113
# Trial 1, Epoch: 300, V1 model, h=50, lr=0.10000, Loss=0.34118, test err=0.100
# Trial 1, Epoch: 400, V1 model, h=50, lr=0.10000, Loss=0.31273, test err=0.091
# Trial 1, Epoch: 500, V1 model, h=50, lr=0.10000, Loss=0.29207, test err=0.084
# Trial 1, Epoch: 600, V1 model, h=50, lr=0.10000, Loss=0.27585, test err=0.080
# Trial 1, Epoch: 700, V1 model, h=50, lr=0.10000, Loss=0.26247, test err=0.078
# Trial 1, Epoch: 800, V1 model, h=50, lr=0.10000, Loss=0.25106, test err=0.075
# Trial 1, Epoch: 900, V1 model, h=50, lr=0.10000, Loss=0.24114, test err=0.072
# Trial 1, Epoch: 1000, V1 model, h=50, lr=0.10000, Loss=0.23232, test err=0.070
# Trial 2, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=4.14497, test err=0.880
# Trial 2, Epoch: 100, V1 model, h=50, lr=0.10000, Loss=0.47007, test err=0.127
# Trial 2, Epoch: 200, V1 model, h=50, lr=0.10000, Loss=0.38949, test err=0.105
# Trial 2, Epoch: 300, V1 model, h=50, lr=0.10000, Loss=0.34573, test err=0.092
# Trial 2, Epoch: 400, V1 model, h=50, lr=0.10000, Loss=0.31644, test err=0.084
# Trial 2, Epoch: 500, V1 model, h=50, lr=0.10000, Loss=0.29482, test err=0.079
# Trial 2, Epoch: 600, V1 model, h=50, lr=0.10000, Loss=0.27790, test err=0.075
# Trial 2, Epoch: 700, V1 model, h=50, lr=0.10000, Loss=0.26413, test err=0.072
# Trial 2, Epoch: 800, V1 model, h=50, lr=0.10000, Loss=0.25259, test err=0.069
# Trial 2, Epoch: 900, V1 model, h=50, lr=0.10000, Loss=0.24267, test err=0.068
# Trial 2, Epoch: 1000, V1 model, h=50, lr=0.10000, Loss=0.23403, test err=0.066
# Trial 0, Epoch: 0, RF model, h=50, lr=0.10000, Loss=2.68033, test err=0.927
# Trial 0, Epoch: 100, RF model, h=50, lr=0.10000, Loss=0.58302, test err=0.157
# Trial 0, Epoch: 200, RF model, h=50, lr=0.10000, Loss=0.44626, test err=0.122
# Trial 0, Epoch: 300, RF model, h=50, lr=0.10000, Loss=0.39195, test err=0.108
# Trial 0, Epoch: 400, RF model, h=50, lr=0.10000, Loss=0.35949, test err=0.101
# Trial 0, Epoch: 500, RF model, h=50, lr=0.10000, Loss=0.33640, test err=0.095
# Trial 0, Epoch: 600, RF model, h=50, lr=0.10000, Loss=0.31835, test err=0.090
# Trial 0, Epoch: 700, RF model, h=50, lr=0.10000, Loss=0.30337, test err=0.086
# Trial 0, Epoch: 800, RF model, h=50, lr=0.10000, Loss=0.29046, test err=0.082
# Trial 0, Epoch: 900, RF model, h=50, lr=0.10000, Loss=0.27904, test err=0.079
# Trial 0, Epoch: 1000, RF model, h=50, lr=0.10000, Loss=0.26874, test err=0.075
# Trial 1, Epoch: 0, RF model, h=50, lr=0.10000, Loss=2.49030, test err=0.891
# Trial 1, Epoch: 100, RF model, h=50, lr=0.10000, Loss=0.60193, test err=0.163
# Trial 1, Epoch: 200, RF model, h=50, lr=0.10000, Loss=0.45313, test err=0.126
# Trial 1, Epoch: 300, RF model, h=50, lr=0.10000, Loss=0.39751, test err=0.112
# Trial 1, Epoch: 400, RF model, h=50, lr=0.10000, Loss=0.36606, test err=0.105
# Trial 1, Epoch: 500, RF model, h=50, lr=0.10000, Loss=0.34439, test err=0.100
# Trial 1, Epoch: 600, RF model, h=50, lr=0.10000, Loss=0.32765, test err=0.096
# Trial 1, Epoch: 700, RF model, h=50, lr=0.10000, Loss=0.31376, test err=0.091
# Trial 1, Epoch: 800, RF model, h=50, lr=0.10000, Loss=0.30172, test err=0.088
# Trial 1, Epoch: 900, RF model, h=50, lr=0.10000, Loss=0.29094, test err=0.085
# Trial 1, Epoch: 1000, RF model, h=50, lr=0.10000, Loss=0.28115, test err=0.082
# Trial 2, Epoch: 0, RF model, h=50, lr=0.10000, Loss=2.48303, test err=0.888
# Trial 2, Epoch: 100, RF model, h=50, lr=0.10000, Loss=0.61705, test err=0.169
# Trial 2, Epoch: 200, RF model, h=50, lr=0.10000, Loss=0.45560, test err=0.129
# Trial 2, Epoch: 300, RF model, h=50, lr=0.10000, Loss=0.39483, test err=0.111
# Trial 2, Epoch: 400, RF model, h=50, lr=0.10000, Loss=0.36030, test err=0.102
# Trial 2, Epoch: 500, RF model, h=50, lr=0.10000, Loss=0.33657, test err=0.096
# Trial 2, Epoch: 600, RF model, h=50, lr=0.10000, Loss=0.31837, test err=0.090
# Trial 2, Epoch: 700, RF model, h=50, lr=0.10000, Loss=0.30353, test err=0.085
# Trial 2, Epoch: 800, RF model, h=50, lr=0.10000, Loss=0.29088, test err=0.081
# Trial 2, Epoch: 900, RF model, h=50, lr=0.10000, Loss=0.27971, test err=0.079
# Trial 2, Epoch: 1000, RF model, h=50, lr=0.10000, Loss=0.26977, test err=0.076
# Trial 0, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.33193, test err=0.913
# Trial 0, Epoch: 100, He model, h=50, lr=0.10000, Loss=0.63009, test err=0.149
# Trial 0, Epoch: 200, He model, h=50, lr=0.10000, Loss=0.43591, test err=0.111
# Trial 0, Epoch: 300, He model, h=50, lr=0.10000, Loss=0.37331, test err=0.098
# Trial 0, Epoch: 400, He model, h=50, lr=0.10000, Loss=0.34102, test err=0.091
# Trial 0, Epoch: 500, He model, h=50, lr=0.10000, Loss=0.31966, test err=0.087
# Trial 0, Epoch: 600, He model, h=50, lr=0.10000, Loss=0.30340, test err=0.082
# Trial 0, Epoch: 700, He model, h=50, lr=0.10000, Loss=0.28982, test err=0.079
# Trial 0, Epoch: 800, He model, h=50, lr=0.10000, Loss=0.27780, test err=0.075
# Trial 0, Epoch: 900, He model, h=50, lr=0.10000, Loss=0.26688, test err=0.073
# Trial 0, Epoch: 1000, He model, h=50, lr=0.10000, Loss=0.25679, test err=0.071
# Trial 1, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.30837, test err=0.886
# Trial 1, Epoch: 100, He model, h=50, lr=0.10000, Loss=0.61734, test err=0.145
# Trial 1, Epoch: 200, He model, h=50, lr=0.10000, Loss=0.42838, test err=0.110
# Trial 1, Epoch: 300, He model, h=50, lr=0.10000, Loss=0.37099, test err=0.100
# Trial 1, Epoch: 400, He model, h=50, lr=0.10000, Loss=0.34090, test err=0.092
# Trial 1, Epoch: 500, He model, h=50, lr=0.10000, Loss=0.32050, test err=0.087
# Trial 1, Epoch: 600, He model, h=50, lr=0.10000, Loss=0.30460, test err=0.084
# Trial 1, Epoch: 700, He model, h=50, lr=0.10000, Loss=0.29129, test err=0.080
# Trial 1, Epoch: 800, He model, h=50, lr=0.10000, Loss=0.27949, test err=0.077
# Trial 1, Epoch: 900, He model, h=50, lr=0.10000, Loss=0.26894, test err=0.074
# Trial 1, Epoch: 1000, He model, h=50, lr=0.10000, Loss=0.25931, test err=0.071
# Trial 2, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.33104, test err=0.891
# Trial 2, Epoch: 100, He model, h=50, lr=0.10000, Loss=0.60413, test err=0.141
# Trial 2, Epoch: 200, He model, h=50, lr=0.10000, Loss=0.42708, test err=0.109
# Trial 2, Epoch: 300, He model, h=50, lr=0.10000, Loss=0.37040, test err=0.100
# Trial 2, Epoch: 400, He model, h=50, lr=0.10000, Loss=0.34022, test err=0.093
# Trial 2, Epoch: 500, He model, h=50, lr=0.10000, Loss=0.31988, test err=0.090
# Trial 2, Epoch: 600, He model, h=50, lr=0.10000, Loss=0.30428, test err=0.085
# Trial 2, Epoch: 700, He model, h=50, lr=0.10000, Loss=0.29134, test err=0.081
# Trial 2, Epoch: 800, He model, h=50, lr=0.10000, Loss=0.28000, test err=0.078
# Trial 2, Epoch: 900, He model, h=50, lr=0.10000, Loss=0.26984, test err=0.076
# Trial 2, Epoch: 1000, He model, h=50, lr=0.10000, Loss=0.26060, test err=0.073
# Trial 0, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=5.20584, test err=0.714
# Trial 0, Epoch: 100, V1 model, h=50, lr=1.00000, Loss=0.26333, test err=0.078
# Trial 0, Epoch: 200, V1 model, h=50, lr=1.00000, Loss=0.20382, test err=0.060
# Trial 0, Epoch: 300, V1 model, h=50, lr=1.00000, Loss=0.17498, test err=0.054
# Trial 0, Epoch: 400, V1 model, h=50, lr=1.00000, Loss=0.15290, test err=0.051
# Trial 0, Epoch: 500, V1 model, h=50, lr=1.00000, Loss=0.13712, test err=0.046
# Trial 0, Epoch: 600, V1 model, h=50, lr=1.00000, Loss=0.12457, test err=0.044
# Trial 0, Epoch: 700, V1 model, h=50, lr=1.00000, Loss=0.11585, test err=0.040
# Trial 0, Epoch: 800, V1 model, h=50, lr=1.00000, Loss=0.10832, test err=0.039
# Trial 0, Epoch: 900, V1 model, h=50, lr=1.00000, Loss=0.10045, test err=0.038
# Trial 0, Epoch: 1000, V1 model, h=50, lr=1.00000, Loss=0.09306, test err=0.037
# Trial 1, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=3.47386, test err=0.693
# Trial 1, Epoch: 100, V1 model, h=50, lr=1.00000, Loss=0.24048, test err=0.070
# Trial 1, Epoch: 200, V1 model, h=50, lr=1.00000, Loss=0.17903, test err=0.053
# Trial 1, Epoch: 300, V1 model, h=50, lr=1.00000, Loss=0.14847, test err=0.045
# Trial 1, Epoch: 400, V1 model, h=50, lr=1.00000, Loss=0.12795, test err=0.042
# Trial 1, Epoch: 500, V1 model, h=50, lr=1.00000, Loss=0.11324, test err=0.038
# Trial 1, Epoch: 600, V1 model, h=50, lr=1.00000, Loss=0.10206, test err=0.036
# Trial 1, Epoch: 700, V1 model, h=50, lr=1.00000, Loss=0.09313, test err=0.034
# Trial 1, Epoch: 800, V1 model, h=50, lr=1.00000, Loss=0.08572, test err=0.033
# Trial 1, Epoch: 900, V1 model, h=50, lr=1.00000, Loss=0.07949, test err=0.031
# Trial 1, Epoch: 1000, V1 model, h=50, lr=1.00000, Loss=0.07424, test err=0.030
# Trial 2, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=4.56824, test err=0.711
# Trial 2, Epoch: 100, V1 model, h=50, lr=1.00000, Loss=0.28874, test err=0.081
# Trial 2, Epoch: 200, V1 model, h=50, lr=1.00000, Loss=0.20541, test err=0.059
# Trial 2, Epoch: 300, V1 model, h=50, lr=1.00000, Loss=0.22519, test err=0.065
# Trial 2, Epoch: 400, V1 model, h=50, lr=1.00000, Loss=0.18721, test err=0.055
# Trial 2, Epoch: 500, V1 model, h=50, lr=1.00000, Loss=0.14949, test err=0.047
# Trial 2, Epoch: 600, V1 model, h=50, lr=1.00000, Loss=0.13420, test err=0.045
# Trial 2, Epoch: 700, V1 model, h=50, lr=1.00000, Loss=0.12321, test err=0.042
# Trial 2, Epoch: 800, V1 model, h=50, lr=1.00000, Loss=0.12185, test err=0.041
# Trial 2, Epoch: 900, V1 model, h=50, lr=1.00000, Loss=0.10873, test err=0.039
# Trial 2, Epoch: 1000, V1 model, h=50, lr=1.00000, Loss=0.10184, test err=0.037
# Trial 0, Epoch: 0, RF model, h=50, lr=1.00000, Loss=2.50317, test err=0.676
# Trial 0, Epoch: 100, RF model, h=50, lr=1.00000, Loss=0.26236, test err=0.076
# Trial 0, Epoch: 200, RF model, h=50, lr=1.00000, Loss=0.19323, test err=0.056
# Trial 0, Epoch: 300, RF model, h=50, lr=1.00000, Loss=0.15947, test err=0.050
# Trial 0, Epoch: 400, RF model, h=50, lr=1.00000, Loss=0.13744, test err=0.045
# Trial 0, Epoch: 500, RF model, h=50, lr=1.00000, Loss=0.12141, test err=0.043
# Trial 0, Epoch: 600, RF model, h=50, lr=1.00000, Loss=0.10888, test err=0.040
# Trial 0, Epoch: 700, RF model, h=50, lr=1.00000, Loss=0.09877, test err=0.037
# Trial 0, Epoch: 800, RF model, h=50, lr=1.00000, Loss=0.09039, test err=0.036
# Trial 0, Epoch: 900, RF model, h=50, lr=1.00000, Loss=0.08328, test err=0.035
# Trial 0, Epoch: 1000, RF model, h=50, lr=1.00000, Loss=0.07713, test err=0.034
# Trial 1, Epoch: 0, RF model, h=50, lr=1.00000, Loss=2.62174, test err=0.794
# Trial 1, Epoch: 100, RF model, h=50, lr=1.00000, Loss=0.26118, test err=0.074
# Trial 1, Epoch: 200, RF model, h=50, lr=1.00000, Loss=0.19415, test err=0.057
# Trial 1, Epoch: 300, RF model, h=50, lr=1.00000, Loss=0.16077, test err=0.049
# Trial 1, Epoch: 400, RF model, h=50, lr=1.00000, Loss=0.13864, test err=0.043
# Trial 1, Epoch: 500, RF model, h=50, lr=1.00000, Loss=0.12205, test err=0.040
# Trial 1, Epoch: 600, RF model, h=50, lr=1.00000, Loss=0.10917, test err=0.036
# Trial 1, Epoch: 700, RF model, h=50, lr=1.00000, Loss=0.09881, test err=0.035
# Trial 1, Epoch: 800, RF model, h=50, lr=1.00000, Loss=0.09029, test err=0.034
# Trial 1, Epoch: 900, RF model, h=50, lr=1.00000, Loss=0.08310, test err=0.032
# Trial 1, Epoch: 1000, RF model, h=50, lr=1.00000, Loss=0.07693, test err=0.031
# Trial 2, Epoch: 0, RF model, h=50, lr=1.00000, Loss=2.48134, test err=0.790
# Trial 2, Epoch: 100, RF model, h=50, lr=1.00000, Loss=0.26232, test err=0.076
# Trial 2, Epoch: 200, RF model, h=50, lr=1.00000, Loss=0.18942, test err=0.059
# Trial 2, Epoch: 300, RF model, h=50, lr=1.00000, Loss=0.15619, test err=0.050
# Trial 2, Epoch: 400, RF model, h=50, lr=1.00000, Loss=0.13457, test err=0.043
# Trial 2, Epoch: 500, RF model, h=50, lr=1.00000, Loss=0.11874, test err=0.039
# Trial 2, Epoch: 600, RF model, h=50, lr=1.00000, Loss=0.10647, test err=0.035
# Trial 2, Epoch: 700, RF model, h=50, lr=1.00000, Loss=0.09663, test err=0.034
# Trial 2, Epoch: 800, RF model, h=50, lr=1.00000, Loss=0.08845, test err=0.032
# Trial 2, Epoch: 900, RF model, h=50, lr=1.00000, Loss=0.08155, test err=0.032
# Trial 2, Epoch: 1000, RF model, h=50, lr=1.00000, Loss=0.07560, test err=0.032
# Trial 0, Epoch: 0, He model, h=50, lr=1.00000, Loss=2.33071, test err=0.590
# Trial 0, Epoch: 100, He model, h=50, lr=1.00000, Loss=0.30275, test err=0.086
# Trial 0, Epoch: 200, He model, h=50, lr=1.00000, Loss=0.18394, test err=0.054
# Trial 0, Epoch: 300, He model, h=50, lr=1.00000, Loss=0.14865, test err=0.046
# Trial 0, Epoch: 400, He model, h=50, lr=1.00000, Loss=0.12616, test err=0.040
# Trial 0, Epoch: 500, He model, h=50, lr=1.00000, Loss=0.11013, test err=0.038
# Trial 0, Epoch: 600, He model, h=50, lr=1.00000, Loss=0.09807, test err=0.036
# Trial 0, Epoch: 700, He model, h=50, lr=1.00000, Loss=0.08865, test err=0.035
# Trial 0, Epoch: 800, He model, h=50, lr=1.00000, Loss=0.08086, test err=0.034
# Trial 0, Epoch: 900, He model, h=50, lr=1.00000, Loss=0.07463, test err=0.034
# Trial 0, Epoch: 1000, He model, h=50, lr=1.00000, Loss=0.06927, test err=0.033
# Trial 1, Epoch: 0, He model, h=50, lr=1.00000, Loss=2.34162, test err=0.640
# Trial 1, Epoch: 100, He model, h=50, lr=1.00000, Loss=0.26183, test err=0.072
# Trial 1, Epoch: 200, He model, h=50, lr=1.00000, Loss=0.19290, test err=0.057
# Trial 1, Epoch: 300, He model, h=50, lr=1.00000, Loss=0.15998, test err=0.049
# Trial 1, Epoch: 400, He model, h=50, lr=1.00000, Loss=0.13790, test err=0.044
# Trial 1, Epoch: 500, He model, h=50, lr=1.00000, Loss=0.12333, test err=0.041
# Trial 1, Epoch: 600, He model, h=50, lr=1.00000, Loss=0.11226, test err=0.039
# Trial 1, Epoch: 700, He model, h=50, lr=1.00000, Loss=0.10277, test err=0.036
# Trial 1, Epoch: 800, He model, h=50, lr=1.00000, Loss=0.09467, test err=0.035
# Trial 1, Epoch: 900, He model, h=50, lr=1.00000, Loss=0.08760, test err=0.033
# Trial 1, Epoch: 1000, He model, h=50, lr=1.00000, Loss=0.08344, test err=0.033
# Trial 2, Epoch: 0, He model, h=50, lr=1.00000, Loss=2.34974, test err=0.714
# Trial 2, Epoch: 100, He model, h=50, lr=1.00000, Loss=0.27407, test err=0.083
# Trial 2, Epoch: 200, He model, h=50, lr=1.00000, Loss=0.19491, test err=0.060
# Trial 2, Epoch: 300, He model, h=50, lr=1.00000, Loss=0.14964, test err=0.047
# Trial 2, Epoch: 400, He model, h=50, lr=1.00000, Loss=0.13270, test err=0.043
# Trial 2, Epoch: 500, He model, h=50, lr=1.00000, Loss=0.11424, test err=0.039
# Trial 2, Epoch: 600, He model, h=50, lr=1.00000, Loss=0.10110, test err=0.035
# Trial 2, Epoch: 700, He model, h=50, lr=1.00000, Loss=0.09150, test err=0.034
# Trial 2, Epoch: 800, He model, h=50, lr=1.00000, Loss=0.08540, test err=0.034
# Trial 2, Epoch: 900, He model, h=50, lr=1.00000, Loss=0.07789, test err=0.032
# Trial 2, Epoch: 1000, He model, h=50, lr=1.00000, Loss=0.07178, test err=0.031
# Trial 0, Epoch: 0, V1 model, h=100, lr=0.00100, Loss=4.08800, test err=0.875
# Trial 0, Epoch: 100, V1 model, h=100, lr=0.00100, Loss=1.69446, test err=0.584
# Trial 0, Epoch: 200, V1 model, h=100, lr=0.00100, Loss=1.22005, test err=0.369
# Trial 0, Epoch: 300, V1 model, h=100, lr=0.00100, Loss=1.00618, test err=0.283
# Trial 0, Epoch: 400, V1 model, h=100, lr=0.00100, Loss=0.88806, test err=0.239
# Trial 0, Epoch: 500, V1 model, h=100, lr=0.00100, Loss=0.81256, test err=0.213
# Trial 0, Epoch: 600, V1 model, h=100, lr=0.00100, Loss=0.75933, test err=0.198
# Trial 0, Epoch: 700, V1 model, h=100, lr=0.00100, Loss=0.71928, test err=0.187
# Trial 0, Epoch: 800, V1 model, h=100, lr=0.00100, Loss=0.68773, test err=0.177
# Trial 0, Epoch: 900, V1 model, h=100, lr=0.00100, Loss=0.66203, test err=0.171
# Trial 0, Epoch: 1000, V1 model, h=100, lr=0.00100, Loss=0.64056, test err=0.165
# Trial 1, Epoch: 0, V1 model, h=100, lr=0.00100, Loss=5.52653, test err=0.896
# Trial 1, Epoch: 100, V1 model, h=100, lr=0.00100, Loss=1.77610, test err=0.591
# Trial 1, Epoch: 200, V1 model, h=100, lr=0.00100, Loss=1.32566, test err=0.392
# Trial 1, Epoch: 300, V1 model, h=100, lr=0.00100, Loss=1.12157, test err=0.318
# Trial 1, Epoch: 400, V1 model, h=100, lr=0.00100, Loss=1.00200, test err=0.279
# Trial 1, Epoch: 500, V1 model, h=100, lr=0.00100, Loss=0.92221, test err=0.252
# Trial 1, Epoch: 600, V1 model, h=100, lr=0.00100, Loss=0.86448, test err=0.232
# Trial 1, Epoch: 700, V1 model, h=100, lr=0.00100, Loss=0.82027, test err=0.220
# Trial 1, Epoch: 800, V1 model, h=100, lr=0.00100, Loss=0.78502, test err=0.209
# Trial 1, Epoch: 900, V1 model, h=100, lr=0.00100, Loss=0.75604, test err=0.203
# Trial 1, Epoch: 1000, V1 model, h=100, lr=0.00100, Loss=0.73161, test err=0.196
# Trial 2, Epoch: 0, V1 model, h=100, lr=0.00100, Loss=4.51113, test err=0.936
# Trial 2, Epoch: 100, V1 model, h=100, lr=0.00100, Loss=1.71538, test err=0.538
# Trial 2, Epoch: 200, V1 model, h=100, lr=0.00100, Loss=1.29088, test err=0.360
# Trial 2, Epoch: 300, V1 model, h=100, lr=0.00100, Loss=1.09909, test err=0.298
# Trial 2, Epoch: 400, V1 model, h=100, lr=0.00100, Loss=0.98783, test err=0.270
# Trial 2, Epoch: 500, V1 model, h=100, lr=0.00100, Loss=0.91342, test err=0.251
# Trial 2, Epoch: 600, V1 model, h=100, lr=0.00100, Loss=0.85906, test err=0.238
# Trial 2, Epoch: 700, V1 model, h=100, lr=0.00100, Loss=0.81698, test err=0.226
# Trial 2, Epoch: 800, V1 model, h=100, lr=0.00100, Loss=0.78302, test err=0.216
# Trial 2, Epoch: 900, V1 model, h=100, lr=0.00100, Loss=0.75479, test err=0.207
# Trial 2, Epoch: 1000, V1 model, h=100, lr=0.00100, Loss=0.73077, test err=0.202
# Trial 0, Epoch: 0, RF model, h=100, lr=0.00100, Loss=2.49620, test err=0.883
# Trial 0, Epoch: 100, RF model, h=100, lr=0.00100, Loss=2.26239, test err=0.846
# Trial 0, Epoch: 200, RF model, h=100, lr=0.00100, Loss=2.13853, test err=0.779
# Trial 0, Epoch: 300, RF model, h=100, lr=0.00100, Loss=2.03722, test err=0.683
# Trial 0, Epoch: 400, RF model, h=100, lr=0.00100, Loss=1.94563, test err=0.595
# Trial 0, Epoch: 500, RF model, h=100, lr=0.00100, Loss=1.86101, test err=0.531
# Trial 0, Epoch: 600, RF model, h=100, lr=0.00100, Loss=1.78242, test err=0.478
# Trial 0, Epoch: 700, RF model, h=100, lr=0.00100, Loss=1.70939, test err=0.437
# Trial 0, Epoch: 800, RF model, h=100, lr=0.00100, Loss=1.64153, test err=0.409
# Trial 0, Epoch: 900, RF model, h=100, lr=0.00100, Loss=1.57846, test err=0.383
# Trial 0, Epoch: 1000, RF model, h=100, lr=0.00100, Loss=1.51988, test err=0.364
# Trial 1, Epoch: 0, RF model, h=100, lr=0.00100, Loss=2.42511, test err=0.859
# Trial 1, Epoch: 100, RF model, h=100, lr=0.00100, Loss=2.21069, test err=0.776
# Trial 1, Epoch: 200, RF model, h=100, lr=0.00100, Loss=2.07426, test err=0.700
# Trial 1, Epoch: 300, RF model, h=100, lr=0.00100, Loss=1.96321, test err=0.623
# Trial 1, Epoch: 400, RF model, h=100, lr=0.00100, Loss=1.86475, test err=0.556
# Trial 1, Epoch: 500, RF model, h=100, lr=0.00100, Loss=1.77550, test err=0.495
# Trial 1, Epoch: 600, RF model, h=100, lr=0.00100, Loss=1.69416, test err=0.450
# Trial 1, Epoch: 700, RF model, h=100, lr=0.00100, Loss=1.61983, test err=0.410
# Trial 1, Epoch: 800, RF model, h=100, lr=0.00100, Loss=1.55184, test err=0.379
# Trial 1, Epoch: 900, RF model, h=100, lr=0.00100, Loss=1.48954, test err=0.359
# Trial 1, Epoch: 1000, RF model, h=100, lr=0.00100, Loss=1.43240, test err=0.337
# Trial 2, Epoch: 0, RF model, h=100, lr=0.00100, Loss=2.52009, test err=0.906
# Trial 2, Epoch: 100, RF model, h=100, lr=0.00100, Loss=2.32532, test err=0.859
# Trial 2, Epoch: 200, RF model, h=100, lr=0.00100, Loss=2.19601, test err=0.796
# Trial 2, Epoch: 300, RF model, h=100, lr=0.00100, Loss=2.09065, test err=0.731
# Trial 2, Epoch: 400, RF model, h=100, lr=0.00100, Loss=1.99752, test err=0.655
# Trial 2, Epoch: 500, RF model, h=100, lr=0.00100, Loss=1.91264, test err=0.585
# Trial 2, Epoch: 600, RF model, h=100, lr=0.00100, Loss=1.83435, test err=0.526
# Trial 2, Epoch: 700, RF model, h=100, lr=0.00100, Loss=1.76179, test err=0.486
# Trial 2, Epoch: 800, RF model, h=100, lr=0.00100, Loss=1.69441, test err=0.451
# Trial 2, Epoch: 900, RF model, h=100, lr=0.00100, Loss=1.63178, test err=0.419
# Trial 2, Epoch: 1000, RF model, h=100, lr=0.00100, Loss=1.57346, test err=0.396
# Trial 0, Epoch: 0, He model, h=100, lr=0.00100, Loss=2.31051, test err=0.870
# Trial 0, Epoch: 100, He model, h=100, lr=0.00100, Loss=2.28712, test err=0.833
# Trial 0, Epoch: 200, He model, h=100, lr=0.00100, Loss=2.26461, test err=0.798
# Trial 0, Epoch: 300, He model, h=100, lr=0.00100, Loss=2.24259, test err=0.771
# Trial 0, Epoch: 400, He model, h=100, lr=0.00100, Loss=2.22078, test err=0.743
# Trial 0, Epoch: 500, He model, h=100, lr=0.00100, Loss=2.19893, test err=0.717
# Trial 0, Epoch: 600, He model, h=100, lr=0.00100, Loss=2.17682, test err=0.690
# Trial 0, Epoch: 700, He model, h=100, lr=0.00100, Loss=2.15430, test err=0.665
# Trial 0, Epoch: 800, He model, h=100, lr=0.00100, Loss=2.13123, test err=0.639
# Trial 0, Epoch: 900, He model, h=100, lr=0.00100, Loss=2.10752, test err=0.610
# Trial 0, Epoch: 1000, He model, h=100, lr=0.00100, Loss=2.08304, test err=0.586
# Trial 1, Epoch: 0, He model, h=100, lr=0.00100, Loss=2.29671, test err=0.871
# Trial 1, Epoch: 100, He model, h=100, lr=0.00100, Loss=2.27168, test err=0.847
# Trial 1, Epoch: 200, He model, h=100, lr=0.00100, Loss=2.24715, test err=0.812
# Trial 1, Epoch: 300, He model, h=100, lr=0.00100, Loss=2.22278, test err=0.762
# Trial 1, Epoch: 400, He model, h=100, lr=0.00100, Loss=2.19836, test err=0.706
# Trial 1, Epoch: 500, He model, h=100, lr=0.00100, Loss=2.17371, test err=0.648
# Trial 1, Epoch: 600, He model, h=100, lr=0.00100, Loss=2.14862, test err=0.594
# Trial 1, Epoch: 700, He model, h=100, lr=0.00100, Loss=2.12297, test err=0.552
# Trial 1, Epoch: 800, He model, h=100, lr=0.00100, Loss=2.09663, test err=0.514
# Trial 1, Epoch: 900, He model, h=100, lr=0.00100, Loss=2.06948, test err=0.482
# Trial 1, Epoch: 1000, He model, h=100, lr=0.00100, Loss=2.04146, test err=0.454
# Trial 2, Epoch: 0, He model, h=100, lr=0.00100, Loss=2.32339, test err=0.923
# Trial 2, Epoch: 100, He model, h=100, lr=0.00100, Loss=2.29655, test err=0.893
# Trial 2, Epoch: 200, He model, h=100, lr=0.00100, Loss=2.27070, test err=0.861
# Trial 2, Epoch: 300, He model, h=100, lr=0.00100, Loss=2.24545, test err=0.827
# Trial 2, Epoch: 400, He model, h=100, lr=0.00100, Loss=2.22044, test err=0.791
# Trial 2, Epoch: 500, He model, h=100, lr=0.00100, Loss=2.19547, test err=0.750
# Trial 2, Epoch: 600, He model, h=100, lr=0.00100, Loss=2.17030, test err=0.707
# Trial 2, Epoch: 700, He model, h=100, lr=0.00100, Loss=2.14477, test err=0.658
# Trial 2, Epoch: 800, He model, h=100, lr=0.00100, Loss=2.11869, test err=0.614
# Trial 2, Epoch: 900, He model, h=100, lr=0.00100, Loss=2.09203, test err=0.572
# Trial 2, Epoch: 1000, He model, h=100, lr=0.00100, Loss=2.06469, test err=0.534
# Trial 0, Epoch: 0, V1 model, h=100, lr=0.01000, Loss=5.97544, test err=0.861
# Trial 0, Epoch: 100, V1 model, h=100, lr=0.01000, Loss=0.67470, test err=0.169
# Trial 0, Epoch: 200, V1 model, h=100, lr=0.01000, Loss=0.54730, test err=0.137
# Trial 0, Epoch: 300, V1 model, h=100, lr=0.01000, Loss=0.48953, test err=0.124
# Trial 0, Epoch: 400, V1 model, h=100, lr=0.01000, Loss=0.45430, test err=0.116
# Trial 0, Epoch: 500, V1 model, h=100, lr=0.01000, Loss=0.42958, test err=0.112
# Trial 0, Epoch: 600, V1 model, h=100, lr=0.01000, Loss=0.41079, test err=0.107
# Trial 0, Epoch: 700, V1 model, h=100, lr=0.01000, Loss=0.39573, test err=0.104
# Trial 0, Epoch: 800, V1 model, h=100, lr=0.01000, Loss=0.38322, test err=0.102
# Trial 0, Epoch: 900, V1 model, h=100, lr=0.01000, Loss=0.37253, test err=0.100
# Trial 0, Epoch: 1000, V1 model, h=100, lr=0.01000, Loss=0.36321, test err=0.097
# Trial 1, Epoch: 0, V1 model, h=100, lr=0.01000, Loss=3.76059, test err=0.871
# Trial 1, Epoch: 100, V1 model, h=100, lr=0.01000, Loss=0.79657, test err=0.210
# Trial 1, Epoch: 200, V1 model, h=100, lr=0.01000, Loss=0.64424, test err=0.171
# Trial 1, Epoch: 300, V1 model, h=100, lr=0.01000, Loss=0.57252, test err=0.152
# Trial 1, Epoch: 400, V1 model, h=100, lr=0.01000, Loss=0.52705, test err=0.139
# Trial 1, Epoch: 500, V1 model, h=100, lr=0.01000, Loss=0.49428, test err=0.132
# Trial 1, Epoch: 600, V1 model, h=100, lr=0.01000, Loss=0.46893, test err=0.125
# Trial 1, Epoch: 700, V1 model, h=100, lr=0.01000, Loss=0.44842, test err=0.118
# Trial 1, Epoch: 800, V1 model, h=100, lr=0.01000, Loss=0.43131, test err=0.115
# Trial 1, Epoch: 900, V1 model, h=100, lr=0.01000, Loss=0.41669, test err=0.111
# Trial 1, Epoch: 1000, V1 model, h=100, lr=0.01000, Loss=0.40397, test err=0.108
# Trial 2, Epoch: 0, V1 model, h=100, lr=0.01000, Loss=3.00432, test err=0.824
# Trial 2, Epoch: 100, V1 model, h=100, lr=0.01000, Loss=0.73433, test err=0.201
# Trial 2, Epoch: 200, V1 model, h=100, lr=0.01000, Loss=0.59203, test err=0.158
# Trial 2, Epoch: 300, V1 model, h=100, lr=0.01000, Loss=0.52696, test err=0.143
# Trial 2, Epoch: 400, V1 model, h=100, lr=0.01000, Loss=0.48659, test err=0.131
# Trial 2, Epoch: 500, V1 model, h=100, lr=0.01000, Loss=0.45796, test err=0.122
# Trial 2, Epoch: 600, V1 model, h=100, lr=0.01000, Loss=0.43605, test err=0.117
# Trial 2, Epoch: 700, V1 model, h=100, lr=0.01000, Loss=0.41846, test err=0.112
# Trial 2, Epoch: 800, V1 model, h=100, lr=0.01000, Loss=0.40385, test err=0.108
# Trial 2, Epoch: 900, V1 model, h=100, lr=0.01000, Loss=0.39142, test err=0.104
# Trial 2, Epoch: 1000, V1 model, h=100, lr=0.01000, Loss=0.38064, test err=0.101
# Trial 0, Epoch: 0, RF model, h=100, lr=0.01000, Loss=2.57041, test err=0.902
# Trial 0, Epoch: 100, RF model, h=100, lr=0.01000, Loss=1.61136, test err=0.420
# Trial 0, Epoch: 200, RF model, h=100, lr=0.01000, Loss=1.17900, test err=0.287
# Trial 0, Epoch: 300, RF model, h=100, lr=0.01000, Loss=0.94648, test err=0.234
# Trial 0, Epoch: 400, RF model, h=100, lr=0.01000, Loss=0.80916, test err=0.204
# Trial 0, Epoch: 500, RF model, h=100, lr=0.01000, Loss=0.72004, test err=0.185
# Trial 0, Epoch: 600, RF model, h=100, lr=0.01000, Loss=0.65774, test err=0.173
# Trial 0, Epoch: 700, RF model, h=100, lr=0.01000, Loss=0.61172, test err=0.160
# Trial 0, Epoch: 800, RF model, h=100, lr=0.01000, Loss=0.57623, test err=0.151
# Trial 0, Epoch: 900, RF model, h=100, lr=0.01000, Loss=0.54796, test err=0.145
# Trial 0, Epoch: 1000, RF model, h=100, lr=0.01000, Loss=0.52485, test err=0.138
# Trial 1, Epoch: 0, RF model, h=100, lr=0.01000, Loss=2.58530, test err=0.910
# Trial 1, Epoch: 100, RF model, h=100, lr=0.01000, Loss=1.48871, test err=0.382
# Trial 1, Epoch: 200, RF model, h=100, lr=0.01000, Loss=1.09376, test err=0.265
# Trial 1, Epoch: 300, RF model, h=100, lr=0.01000, Loss=0.89472, test err=0.220
# Trial 1, Epoch: 400, RF model, h=100, lr=0.01000, Loss=0.77872, test err=0.197
# Trial 1, Epoch: 500, RF model, h=100, lr=0.01000, Loss=0.70281, test err=0.179
# Trial 1, Epoch: 600, RF model, h=100, lr=0.01000, Loss=0.64889, test err=0.168
# Trial 1, Epoch: 700, RF model, h=100, lr=0.01000, Loss=0.60831, test err=0.160
# Trial 1, Epoch: 800, RF model, h=100, lr=0.01000, Loss=0.57644, test err=0.153
# Trial 1, Epoch: 900, RF model, h=100, lr=0.01000, Loss=0.55059, test err=0.146
# Trial 1, Epoch: 1000, RF model, h=100, lr=0.01000, Loss=0.52910, test err=0.141
# Trial 2, Epoch: 0, RF model, h=100, lr=0.01000, Loss=2.57065, test err=0.937
# Trial 2, Epoch: 100, RF model, h=100, lr=0.01000, Loss=1.50852, test err=0.378
# Trial 2, Epoch: 200, RF model, h=100, lr=0.01000, Loss=1.10823, test err=0.262
# Trial 2, Epoch: 300, RF model, h=100, lr=0.01000, Loss=0.90633, test err=0.220
# Trial 2, Epoch: 400, RF model, h=100, lr=0.01000, Loss=0.78753, test err=0.195
# Trial 2, Epoch: 500, RF model, h=100, lr=0.01000, Loss=0.70909, test err=0.177
# Trial 2, Epoch: 600, RF model, h=100, lr=0.01000, Loss=0.65295, test err=0.167
# Trial 2, Epoch: 700, RF model, h=100, lr=0.01000, Loss=0.61045, test err=0.160
# Trial 2, Epoch: 800, RF model, h=100, lr=0.01000, Loss=0.57696, test err=0.152
# Trial 2, Epoch: 900, RF model, h=100, lr=0.01000, Loss=0.54979, test err=0.146
# Trial 2, Epoch: 1000, RF model, h=100, lr=0.01000, Loss=0.52724, test err=0.141
# Trial 0, Epoch: 0, He model, h=100, lr=0.01000, Loss=2.31079, test err=0.879
# Trial 0, Epoch: 100, He model, h=100, lr=0.01000, Loss=2.03633, test err=0.536
# Trial 0, Epoch: 200, He model, h=100, lr=0.01000, Loss=1.71601, test err=0.317
# Trial 0, Epoch: 300, He model, h=100, lr=0.01000, Loss=1.38226, test err=0.239
# Trial 0, Epoch: 400, He model, h=100, lr=0.01000, Loss=1.11436, test err=0.203
# Trial 0, Epoch: 500, He model, h=100, lr=0.01000, Loss=0.92961, test err=0.179
# Trial 0, Epoch: 600, He model, h=100, lr=0.01000, Loss=0.80534, test err=0.166
# Trial 0, Epoch: 700, He model, h=100, lr=0.01000, Loss=0.71902, test err=0.156
# Trial 0, Epoch: 800, He model, h=100, lr=0.01000, Loss=0.65635, test err=0.147
# Trial 0, Epoch: 900, He model, h=100, lr=0.01000, Loss=0.60897, test err=0.137
# Trial 0, Epoch: 1000, He model, h=100, lr=0.01000, Loss=0.57195, test err=0.131
# Trial 1, Epoch: 0, He model, h=100, lr=0.01000, Loss=2.33438, test err=0.938
# Trial 1, Epoch: 100, He model, h=100, lr=0.01000, Loss=2.09992, test err=0.503
# Trial 1, Epoch: 200, He model, h=100, lr=0.01000, Loss=1.81218, test err=0.319
# Trial 1, Epoch: 300, He model, h=100, lr=0.01000, Loss=1.48043, test err=0.256
# Trial 1, Epoch: 400, He model, h=100, lr=0.01000, Loss=1.19040, test err=0.208
# Trial 1, Epoch: 500, He model, h=100, lr=0.01000, Loss=0.98003, test err=0.181
# Trial 1, Epoch: 600, He model, h=100, lr=0.01000, Loss=0.83709, test err=0.163
# Trial 1, Epoch: 700, He model, h=100, lr=0.01000, Loss=0.73901, test err=0.153
# Trial 1, Epoch: 800, He model, h=100, lr=0.01000, Loss=0.66920, test err=0.146
# Trial 1, Epoch: 900, He model, h=100, lr=0.01000, Loss=0.61748, test err=0.140
# Trial 1, Epoch: 1000, He model, h=100, lr=0.01000, Loss=0.57773, test err=0.134
# Trial 2, Epoch: 0, He model, h=100, lr=0.01000, Loss=2.29262, test err=0.891
# Trial 2, Epoch: 100, He model, h=100, lr=0.01000, Loss=2.02437, test err=0.512
# Trial 2, Epoch: 200, He model, h=100, lr=0.01000, Loss=1.70310, test err=0.317
# Trial 2, Epoch: 300, He model, h=100, lr=0.01000, Loss=1.36942, test err=0.249
# Trial 2, Epoch: 400, He model, h=100, lr=0.01000, Loss=1.10673, test err=0.210
# Trial 2, Epoch: 500, He model, h=100, lr=0.01000, Loss=0.92740, test err=0.188
# Trial 2, Epoch: 600, He model, h=100, lr=0.01000, Loss=0.80624, test err=0.173
# Trial 2, Epoch: 700, He model, h=100, lr=0.01000, Loss=0.72119, test err=0.160
# Trial 2, Epoch: 800, He model, h=100, lr=0.01000, Loss=0.65882, test err=0.149
# Trial 2, Epoch: 900, He model, h=100, lr=0.01000, Loss=0.61129, test err=0.142
# Trial 2, Epoch: 1000, He model, h=100, lr=0.01000, Loss=0.57392, test err=0.137
# Trial 0, Epoch: 0, V1 model, h=100, lr=0.10000, Loss=4.06815, test err=0.782
# Trial 0, Epoch: 100, V1 model, h=100, lr=0.10000, Loss=0.40001, test err=0.117
# Trial 0, Epoch: 200, V1 model, h=100, lr=0.10000, Loss=0.31392, test err=0.090
# Trial 0, Epoch: 300, V1 model, h=100, lr=0.10000, Loss=0.28086, test err=0.079
# Trial 0, Epoch: 400, V1 model, h=100, lr=0.10000, Loss=0.25725, test err=0.073
# Trial 0, Epoch: 500, V1 model, h=100, lr=0.10000, Loss=0.23890, test err=0.067
# Trial 0, Epoch: 600, V1 model, h=100, lr=0.10000, Loss=0.22404, test err=0.062
# Trial 0, Epoch: 700, V1 model, h=100, lr=0.10000, Loss=0.21162, test err=0.059
# Trial 0, Epoch: 800, V1 model, h=100, lr=0.10000, Loss=0.20101, test err=0.056
# Trial 0, Epoch: 900, V1 model, h=100, lr=0.10000, Loss=0.19179, test err=0.053
# Trial 0, Epoch: 1000, V1 model, h=100, lr=0.10000, Loss=0.18371, test err=0.051
# Trial 1, Epoch: 0, V1 model, h=100, lr=0.10000, Loss=3.21269, test err=0.787
# Trial 1, Epoch: 100, V1 model, h=100, lr=0.10000, Loss=0.38950, test err=0.107
# Trial 1, Epoch: 200, V1 model, h=100, lr=0.10000, Loss=0.31388, test err=0.087
# Trial 1, Epoch: 300, V1 model, h=100, lr=0.10000, Loss=0.27765, test err=0.078
# Trial 1, Epoch: 400, V1 model, h=100, lr=0.10000, Loss=0.25467, test err=0.073
# Trial 1, Epoch: 500, V1 model, h=100, lr=0.10000, Loss=0.23796, test err=0.068
# Trial 1, Epoch: 600, V1 model, h=100, lr=0.10000, Loss=0.22482, test err=0.064
# Trial 1, Epoch: 700, V1 model, h=100, lr=0.10000, Loss=0.21398, test err=0.060
# ...
# Trial 0, Epoch: 600, RF model, h=400, lr=0.10000, Loss=0.22988, test err=0.065
# Trial 0, Epoch: 700, RF model, h=400, lr=0.10000, Loss=0.21829, test err=0.062
# Trial 0, Epoch: 800, RF model, h=400, lr=0.10000, Loss=0.20814, test err=0.060
# Trial 0, Epoch: 900, RF model, h=400, lr=0.10000, Loss=0.19911, test err=0.058
# Trial 0, Epoch: 1000, RF model, h=400, lr=0.10000, Loss=0.19096, test err=0.056
# Trial 1, Epoch: 0, RF model, h=400, lr=0.10000, Loss=2.47393, test err=0.788
# Trial 1, Epoch: 100, RF model, h=400, lr=0.10000, Loss=0.38554, test err=0.100
# Trial 1, Epoch: 200, RF model, h=400, lr=0.10000, Loss=0.31775, test err=0.086
# Trial 1, Epoch: 300, RF model, h=400, lr=0.10000, Loss=0.28428, test err=0.077
# Trial 1, Epoch: 400, RF model, h=400, lr=0.10000, Loss=0.26189, test err=0.071
# Trial 1, Epoch: 500, RF model, h=400, lr=0.10000, Loss=0.24482, test err=0.067
# Trial 1, Epoch: 600, RF model, h=400, lr=0.10000, Loss=0.23089, test err=0.064
# Trial 1, Epoch: 700, RF model, h=400, lr=0.10000, Loss=0.21906, test err=0.062
# Trial 1, Epoch: 800, RF model, h=400, lr=0.10000, Loss=0.20873, test err=0.059
# Trial 1, Epoch: 900, RF model, h=400, lr=0.10000, Loss=0.19956, test err=0.057
# Trial 1, Epoch: 1000, RF model, h=400, lr=0.10000, Loss=0.19132, test err=0.056
# Trial 2, Epoch: 0, RF model, h=400, lr=0.10000, Loss=2.39071, test err=0.732
# Trial 2, Epoch: 100, RF model, h=400, lr=0.10000, Loss=0.38846, test err=0.098
# Trial 2, Epoch: 200, RF model, h=400, lr=0.10000, Loss=0.32281, test err=0.086
# Trial 2, Epoch: 300, RF model, h=400, lr=0.10000, Loss=0.28943, test err=0.079
# Trial 2, Epoch: 400, RF model, h=400, lr=0.10000, Loss=0.26673, test err=0.074
# Trial 2, Epoch: 500, RF model, h=400, lr=0.10000, Loss=0.24934, test err=0.069
# Trial 2, Epoch: 600, RF model, h=400, lr=0.10000, Loss=0.23511, test err=0.067
# Trial 2, Epoch: 700, RF model, h=400, lr=0.10000, Loss=0.22300, test err=0.064
# Trial 2, Epoch: 800, RF model, h=400, lr=0.10000, Loss=0.21244, test err=0.061
# Trial 2, Epoch: 900, RF model, h=400, lr=0.10000, Loss=0.20307, test err=0.058
# Trial 2, Epoch: 1000, RF model, h=400, lr=0.10000, Loss=0.19467, test err=0.057
# Trial 0, Epoch: 0, He model, h=400, lr=0.10000, Loss=2.34754, test err=0.859
# Trial 0, Epoch: 100, He model, h=400, lr=0.10000, Loss=0.51765, test err=0.120
# Trial 0, Epoch: 200, He model, h=400, lr=0.10000, Loss=0.38905, test err=0.100
# Trial 0, Epoch: 300, He model, h=400, lr=0.10000, Loss=0.34197, test err=0.089
# Trial 0, Epoch: 400, He model, h=400, lr=0.10000, Loss=0.31394, test err=0.082
# Trial 0, Epoch: 500, He model, h=400, lr=0.10000, Loss=0.29345, test err=0.078
# Trial 0, Epoch: 600, He model, h=400, lr=0.10000, Loss=0.27682, test err=0.074
# Trial 0, Epoch: 700, He model, h=400, lr=0.10000, Loss=0.26257, test err=0.071
# Trial 0, Epoch: 800, He model, h=400, lr=0.10000, Loss=0.25003, test err=0.067
# Trial 0, Epoch: 900, He model, h=400, lr=0.10000, Loss=0.23881, test err=0.064
# Trial 0, Epoch: 1000, He model, h=400, lr=0.10000, Loss=0.22861, test err=0.062
# Trial 1, Epoch: 0, He model, h=400, lr=0.10000, Loss=2.32128, test err=0.819
# Trial 1, Epoch: 100, He model, h=400, lr=0.10000, Loss=0.50348, test err=0.118
# Trial 1, Epoch: 200, He model, h=400, lr=0.10000, Loss=0.38230, test err=0.100
# Trial 1, Epoch: 300, He model, h=400, lr=0.10000, Loss=0.33751, test err=0.089
# Trial 1, Epoch: 400, He model, h=400, lr=0.10000, Loss=0.31059, test err=0.082
# Trial 1, Epoch: 500, He model, h=400, lr=0.10000, Loss=0.29068, test err=0.076
# Trial 1, Epoch: 600, He model, h=400, lr=0.10000, Loss=0.27443, test err=0.073
# Trial 1, Epoch: 700, He model, h=400, lr=0.10000, Loss=0.26046, test err=0.070
# Trial 1, Epoch: 800, He model, h=400, lr=0.10000, Loss=0.24811, test err=0.068
# Trial 1, Epoch: 900, He model, h=400, lr=0.10000, Loss=0.23695, test err=0.065
# Trial 1, Epoch: 1000, He model, h=400, lr=0.10000, Loss=0.22677, test err=0.062
# Trial 2, Epoch: 0, He model, h=400, lr=0.10000, Loss=2.31083, test err=0.827
# Trial 2, Epoch: 100, He model, h=400, lr=0.10000, Loss=0.50800, test err=0.118
# Trial 2, Epoch: 200, He model, h=400, lr=0.10000, Loss=0.38398, test err=0.097
# Trial 2, Epoch: 300, He model, h=400, lr=0.10000, Loss=0.33797, test err=0.088
# Trial 2, Epoch: 400, He model, h=400, lr=0.10000, Loss=0.31050, test err=0.081
# Trial 2, Epoch: 500, He model, h=400, lr=0.10000, Loss=0.29035, test err=0.076
# Trial 2, Epoch: 600, He model, h=400, lr=0.10000, Loss=0.27397, test err=0.073
# Trial 2, Epoch: 700, He model, h=400, lr=0.10000, Loss=0.25988, test err=0.070
# Trial 2, Epoch: 800, He model, h=400, lr=0.10000, Loss=0.24740, test err=0.067
# Trial 2, Epoch: 900, He model, h=400, lr=0.10000, Loss=0.23620, test err=0.064
# Trial 2, Epoch: 1000, He model, h=400, lr=0.10000, Loss=0.22604, test err=0.062
# Trial 0, Epoch: 0, V1 model, h=400, lr=1.00000, Loss=4.36809, test err=0.881
# Trial 0, Epoch: 100, V1 model, h=400, lr=1.00000, Loss=0.19001, test err=0.052
# Trial 0, Epoch: 200, V1 model, h=400, lr=1.00000, Loss=0.12478, test err=0.037
# Trial 0, Epoch: 300, V1 model, h=400, lr=1.00000, Loss=0.09701, test err=0.032
# Trial 0, Epoch: 400, V1 model, h=400, lr=1.00000, Loss=0.08037, test err=0.029
# Trial 0, Epoch: 500, V1 model, h=400, lr=1.00000, Loss=0.06882, test err=0.027
# Trial 0, Epoch: 600, V1 model, h=400, lr=1.00000, Loss=0.06007, test err=0.025
# Trial 0, Epoch: 700, V1 model, h=400, lr=1.00000, Loss=0.05309, test err=0.025
# Trial 0, Epoch: 800, V1 model, h=400, lr=1.00000, Loss=0.04738, test err=0.023
# Trial 0, Epoch: 900, V1 model, h=400, lr=1.00000, Loss=0.04263, test err=0.023
# Trial 0, Epoch: 1000, V1 model, h=400, lr=1.00000, Loss=0.03859, test err=0.022
# Trial 1, Epoch: 0, V1 model, h=400, lr=1.00000, Loss=4.08539, test err=0.697
# Trial 1, Epoch: 100, V1 model, h=400, lr=1.00000, Loss=0.17477, test err=0.050
# Trial 1, Epoch: 200, V1 model, h=400, lr=1.00000, Loss=0.11771, test err=0.039
# Trial 1, Epoch: 300, V1 model, h=400, lr=1.00000, Loss=0.09216, test err=0.034
# Trial 1, Epoch: 400, V1 model, h=400, lr=1.00000, Loss=0.07638, test err=0.030
# Trial 1, Epoch: 500, V1 model, h=400, lr=1.00000, Loss=0.06533, test err=0.028
# Trial 1, Epoch: 600, V1 model, h=400, lr=1.00000, Loss=0.05704, test err=0.025
# Trial 1, Epoch: 700, V1 model, h=400, lr=1.00000, Loss=0.05050, test err=0.024
# Trial 1, Epoch: 800, V1 model, h=400, lr=1.00000, Loss=0.04518, test err=0.024
# Trial 1, Epoch: 900, V1 model, h=400, lr=1.00000, Loss=0.04071, test err=0.023
# Trial 1, Epoch: 1000, V1 model, h=400, lr=1.00000, Loss=0.03689, test err=0.023
# Trial 2, Epoch: 0, V1 model, h=400, lr=1.00000, Loss=5.02793, test err=0.690
# Trial 2, Epoch: 100, V1 model, h=400, lr=1.00000, Loss=0.18655, test err=0.056
# Trial 2, Epoch: 200, V1 model, h=400, lr=1.00000, Loss=0.12793, test err=0.045
# Trial 2, Epoch: 300, V1 model, h=400, lr=1.00000, Loss=0.10058, test err=0.037
# Trial 2, Epoch: 400, V1 model, h=400, lr=1.00000, Loss=0.08353, test err=0.032
# Trial 2, Epoch: 500, V1 model, h=400, lr=1.00000, Loss=0.07144, test err=0.029
# Trial 2, Epoch: 600, V1 model, h=400, lr=1.00000, Loss=0.06231, test err=0.027
# Trial 2, Epoch: 700, V1 model, h=400, lr=1.00000, Loss=0.05508, test err=0.025
# Trial 2, Epoch: 800, V1 model, h=400, lr=1.00000, Loss=0.04918, test err=0.024
# Trial 2, Epoch: 900, V1 model, h=400, lr=1.00000, Loss=0.04423, test err=0.024
# Trial 2, Epoch: 1000, V1 model, h=400, lr=1.00000, Loss=0.04001, test err=0.023
# Trial 0, Epoch: 0, RF model, h=400, lr=1.00000, Loss=2.50448, test err=0.872
# Trial 0, Epoch: 100, RF model, h=400, lr=1.00000, Loss=0.21046, test err=0.063
# Trial 0, Epoch: 200, RF model, h=400, lr=1.00000, Loss=0.14771, test err=0.049
# Trial 0, Epoch: 300, RF model, h=400, lr=1.00000, Loss=0.11617, test err=0.043
# Trial 0, Epoch: 400, RF model, h=400, lr=1.00000, Loss=0.09583, test err=0.039
# Trial 0, Epoch: 500, RF model, h=400, lr=1.00000, Loss=0.08124, test err=0.036
# Trial 0, Epoch: 600, RF model, h=400, lr=1.00000, Loss=0.06998, test err=0.034
# Trial 0, Epoch: 700, RF model, h=400, lr=1.00000, Loss=0.06098, test err=0.032
# Trial 0, Epoch: 800, RF model, h=400, lr=1.00000, Loss=0.05362, test err=0.031
# Trial 0, Epoch: 900, RF model, h=400, lr=1.00000, Loss=0.04746, test err=0.030
# Trial 0, Epoch: 1000, RF model, h=400, lr=1.00000, Loss=0.04222, test err=0.030
# Trial 1, Epoch: 0, RF model, h=400, lr=1.00000, Loss=2.48162, test err=0.638
# Trial 1, Epoch: 100, RF model, h=400, lr=1.00000, Loss=0.20276, test err=0.058
# Trial 1, Epoch: 200, RF model, h=400, lr=1.00000, Loss=0.14318, test err=0.046
# Trial 1, Epoch: 300, RF model, h=400, lr=1.00000, Loss=0.11298, test err=0.039
# Trial 1, Epoch: 400, RF model, h=400, lr=1.00000, Loss=0.09343, test err=0.035
# Trial 1, Epoch: 500, RF model, h=400, lr=1.00000, Loss=0.07921, test err=0.032
# Trial 1, Epoch: 600, RF model, h=400, lr=1.00000, Loss=0.06813, test err=0.030
# Trial 1, Epoch: 700, RF model, h=400, lr=1.00000, Loss=0.05924, test err=0.029
# Trial 1, Epoch: 800, RF model, h=400, lr=1.00000, Loss=0.05195, test err=0.028
# Trial 1, Epoch: 900, RF model, h=400, lr=1.00000, Loss=0.04587, test err=0.027
# Trial 1, Epoch: 1000, RF model, h=400, lr=1.00000, Loss=0.04072, test err=0.026
# Trial 2, Epoch: 0, RF model, h=400, lr=1.00000, Loss=2.48723, test err=0.825
# Trial 2, Epoch: 100, RF model, h=400, lr=1.00000, Loss=0.20955, test err=0.066
# Trial 2, Epoch: 200, RF model, h=400, lr=1.00000, Loss=0.14810, test err=0.051
# Trial 2, Epoch: 300, RF model, h=400, lr=1.00000, Loss=0.11622, test err=0.042
# Trial 2, Epoch: 400, RF model, h=400, lr=1.00000, Loss=0.09552, test err=0.038
# Trial 2, Epoch: 500, RF model, h=400, lr=1.00000, Loss=0.08057, test err=0.034
# Trial 2, Epoch: 600, RF model, h=400, lr=1.00000, Loss=0.06915, test err=0.033
# Trial 2, Epoch: 700, RF model, h=400, lr=1.00000, Loss=0.06010, test err=0.032
# Trial 2, Epoch: 800, RF model, h=400, lr=1.00000, Loss=0.05276, test err=0.031
# Trial 2, Epoch: 900, RF model, h=400, lr=1.00000, Loss=0.04665, test err=0.029
# Trial 2, Epoch: 1000, RF model, h=400, lr=1.00000, Loss=0.04149, test err=0.028
# Trial 0, Epoch: 0, He model, h=400, lr=1.00000, Loss=2.32012, test err=0.574
# Trial 0, Epoch: 100, He model, h=400, lr=1.00000, Loss=0.19844, test err=0.056
# Trial 0, Epoch: 200, He model, h=400, lr=1.00000, Loss=0.13706, test err=0.041
# Trial 0, Epoch: 300, He model, h=400, lr=1.00000, Loss=0.10592, test err=0.034
# Trial 0, Epoch: 400, He model, h=400, lr=1.00000, Loss=0.08608, test err=0.030
# Trial 0, Epoch: 500, He model, h=400, lr=1.00000, Loss=0.07204, test err=0.028
# Trial 0, Epoch: 600, He model, h=400, lr=1.00000, Loss=0.06146, test err=0.026
# Trial 0, Epoch: 700, He model, h=400, lr=1.00000, Loss=0.05319, test err=0.024
# Trial 0, Epoch: 800, He model, h=400, lr=1.00000, Loss=0.04656, test err=0.024
# Trial 0, Epoch: 900, He model, h=400, lr=1.00000, Loss=0.04109, test err=0.023
# Trial 0, Epoch: 1000, He model, h=400, lr=1.00000, Loss=0.03651, test err=0.023
# Trial 1, Epoch: 0, He model, h=400, lr=1.00000, Loss=2.30228, test err=0.541
# Trial 1, Epoch: 100, He model, h=400, lr=1.00000, Loss=0.20168, test err=0.058
# Trial 1, Epoch: 200, He model, h=400, lr=1.00000, Loss=0.13610, test err=0.039
# Trial 1, Epoch: 300, He model, h=400, lr=1.00000, Loss=0.10480, test err=0.032
# Trial 1, Epoch: 400, He model, h=400, lr=1.00000, Loss=0.08497, test err=0.029
# Trial 1, Epoch: 500, He model, h=400, lr=1.00000, Loss=0.07097, test err=0.026
# Trial 1, Epoch: 600, He model, h=400, lr=1.00000, Loss=0.06051, test err=0.024
# Trial 1, Epoch: 700, He model, h=400, lr=1.00000, Loss=0.05236, test err=0.023
# Trial 1, Epoch: 800, He model, h=400, lr=1.00000, Loss=0.04581, test err=0.022
# Trial 1, Epoch: 900, He model, h=400, lr=1.00000, Loss=0.04042, test err=0.021
# Trial 1, Epoch: 1000, He model, h=400, lr=1.00000, Loss=0.03590, test err=0.020
# Trial 2, Epoch: 0, He model, h=400, lr=1.00000, Loss=2.31599, test err=0.649
# Trial 2, Epoch: 100, He model, h=400, lr=1.00000, Loss=0.20220, test err=0.057
# Trial 2, Epoch: 200, He model, h=400, lr=1.00000, Loss=0.13701, test err=0.041
# Trial 2, Epoch: 300, He model, h=400, lr=1.00000, Loss=0.10532, test err=0.034
# Trial 2, Epoch: 400, He model, h=400, lr=1.00000, Loss=0.08522, test err=0.029
# Trial 2, Epoch: 500, He model, h=400, lr=1.00000, Loss=0.07112, test err=0.026
# Trial 2, Epoch: 600, He model, h=400, lr=1.00000, Loss=0.06063, test err=0.023
# Trial 2, Epoch: 700, He model, h=400, lr=1.00000, Loss=0.05246, test err=0.023
# Trial 2, Epoch: 800, He model, h=400, lr=1.00000, Loss=0.04586, test err=0.022
# Trial 2, Epoch: 900, He model, h=400, lr=1.00000, Loss=0.04044, test err=0.021
# Trial 2, Epoch: 1000, He model, h=400, lr=1.00000, Loss=0.03591, test err=0.020
# Trial 0, Epoch: 0, V1 model, h=1000, lr=0.00100, Loss=4.71803, test err=0.881
# Trial 0, Epoch: 100, V1 model, h=1000, lr=0.00100, Loss=0.57824, test err=0.147
# Trial 0, Epoch: 200, V1 model, h=1000, lr=0.00100, Loss=0.45995, test err=0.118
# Trial 0, Epoch: 300, V1 model, h=1000, lr=0.00100, Loss=0.41060, test err=0.106
# Trial 0, Epoch: 400, V1 model, h=1000, lr=0.00100, Loss=0.38122, test err=0.100
# Trial 0, Epoch: 500, V1 model, h=1000, lr=0.00100, Loss=0.36077, test err=0.095
# Trial 0, Epoch: 600, V1 model, h=1000, lr=0.00100, Loss=0.34527, test err=0.092
# Trial 0, Epoch: 700, V1 model, h=1000, lr=0.00100, Loss=0.33284, test err=0.090
# Trial 0, Epoch: 800, V1 model, h=1000, lr=0.00100, Loss=0.32250, test err=0.087
# Trial 0, Epoch: 900, V1 model, h=1000, lr=0.00100, Loss=0.31366, test err=0.086
# Trial 0, Epoch: 1000, V1 model, h=1000, lr=0.00100, Loss=0.30594, test err=0.084
# Trial 1, Epoch: 0, V1 model, h=1000, lr=0.00100, Loss=3.50226, test err=0.860
# Trial 1, Epoch: 100, V1 model, h=1000, lr=0.00100, Loss=0.56184, test err=0.143
# Trial 1, Epoch: 200, V1 model, h=1000, lr=0.00100, Loss=0.44899, test err=0.115
# Trial 1, Epoch: 300, V1 model, h=1000, lr=0.00100, Loss=0.40100, test err=0.104
# Trial 1, Epoch: 400, V1 model, h=1000, lr=0.00100, Loss=0.37216, test err=0.098
# Trial 1, Epoch: 500, V1 model, h=1000, lr=0.00100, Loss=0.35197, test err=0.093
# Trial 1, Epoch: 600, V1 model, h=1000, lr=0.00100, Loss=0.33659, test err=0.090
# Trial 1, Epoch: 700, V1 model, h=1000, lr=0.00100, Loss=0.32424, test err=0.086
# Trial 1, Epoch: 800, V1 model, h=1000, lr=0.00100, Loss=0.31393, test err=0.084
# Trial 1, Epoch: 900, V1 model, h=1000, lr=0.00100, Loss=0.30512, test err=0.081
# Trial 1, Epoch: 1000, V1 model, h=1000, lr=0.00100, Loss=0.29742, test err=0.078
# Trial 2, Epoch: 0, V1 model, h=1000, lr=0.00100, Loss=4.29329, test err=0.905
# Trial 2, Epoch: 100, V1 model, h=1000, lr=0.00100, Loss=0.56710, test err=0.140
# Trial 2, Epoch: 200, V1 model, h=1000, lr=0.00100, Loss=0.44791, test err=0.110
# Trial 2, Epoch: 300, V1 model, h=1000, lr=0.00100, Loss=0.39731, test err=0.099
# Trial 2, Epoch: 400, V1 model, h=1000, lr=0.00100, Loss=0.36728, test err=0.094
# Trial 2, Epoch: 500, V1 model, h=1000, lr=0.00100, Loss=0.34653, test err=0.089
# Trial 2, Epoch: 600, V1 model, h=1000, lr=0.00100, Loss=0.33087, test err=0.085
# Trial 2, Epoch: 700, V1 model, h=1000, lr=0.00100, Loss=0.31838, test err=0.082
# Trial 2, Epoch: 800, V1 model, h=1000, lr=0.00100, Loss=0.30803, test err=0.081
# Trial 2, Epoch: 900, V1 model, h=1000, lr=0.00100, Loss=0.29919, test err=0.078
# Trial 2, Epoch: 1000, V1 model, h=1000, lr=0.00100, Loss=0.29151, test err=0.076
# Trial 0, Epoch: 0, RF model, h=1000, lr=0.00100, Loss=2.49841, test err=0.912
# Trial 0, Epoch: 100, RF model, h=1000, lr=0.00100, Loss=1.61780, test err=0.381
# Trial 0, Epoch: 200, RF model, h=1000, lr=0.00100, Loss=1.22992, test err=0.257
# Trial 0, Epoch: 300, RF model, h=1000, lr=0.00100, Loss=1.02059, test err=0.208
# Trial 0, Epoch: 400, RF model, h=1000, lr=0.00100, Loss=0.89220, test err=0.181
# Trial 0, Epoch: 500, RF model, h=1000, lr=0.00100, Loss=0.80552, test err=0.165
# Trial 0, Epoch: 600, RF model, h=1000, lr=0.00100, Loss=0.74282, test err=0.154
# Trial 0, Epoch: 700, RF model, h=1000, lr=0.00100, Loss=0.69517, test err=0.146
# Trial 0, Epoch: 800, RF model, h=1000, lr=0.00100, Loss=0.65756, test err=0.140
# Trial 0, Epoch: 900, RF model, h=1000, lr=0.00100, Loss=0.62700, test err=0.135

# %% [markdown]
# ## plot results

# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt

t, l, n_epochs= 5, 3, 1001
models = ['V1', 'RF', 'He']

for scale in [1/8, 1/16, 1/32]:
    for h in [50, 100, 400, 1000]:
        for lr in [1e-3, 1e-2, 1e-1, 1e0]:

            with open('results/initialize_mnist/clf_t=%0.2f_l=%0.2f_h=%d_lr=%0.4f_scale=%0.6f.pickle' % (t, l, 
                                                                                                         h, lr, 
                                                                                                         scale), 
                      'rb') as handle:
                sims = pickle.load(handle)

            avg_train_err = {m: np.mean(sims['train_err'][m], axis=0) for m in models}
            avg_test_err = {m: np.mean(sims['test_err'][m], axis=0) for m in models}
            avg_loss_list = {m: np.mean(sims['loss'][m], axis=0) for m in models}

            std_train_err = {m: np.std(sims['train_err'][m], axis=0) for m in models}
            std_test_err = {m: np.std(sims['train_err'][m], axis=0) for m in models}
            std_loss_list = {m: np.std(sims['train_err'][m], axis=0) for m in models}

            fig = plt.figure(figsize=(12, 5))
            plt.suptitle(r'Shallow FFW FC net w/ GD. h=%d, scale=%0.5f, lr=%0.4f, '%(h, scale, lr), fontsize=16)
            ax = fig.add_subplot(131)
            plt.title('Network loss', fontsize=16)
            plt.plot(np.arange(n_epochs), avg_loss_list['V1'], label='V1-inspired', lw=3)
            plt.plot(np.arange(n_epochs), avg_loss_list['RF'], label='classical', lw=3)
            plt.plot(np.arange(n_epochs), avg_loss_list['He'], label='He', lw=3)

            plt.fill_between(np.arange(n_epochs), avg_loss_list['V1'] - std_loss_list['V1'], 
                             avg_loss_list['V1'] + std_loss_list['V1'], alpha=0.2)
            plt.fill_between(np.arange(n_epochs), avg_loss_list['RF'] - std_loss_list['RF'], 
                             avg_loss_list['RF'] + std_loss_list['RF'], alpha=0.2)
            plt.fill_between(np.arange(n_epochs), avg_loss_list['He'] - std_loss_list['He'], 
                             avg_loss_list['He'] + std_loss_list['He'], alpha=0.2)

            plt.xlabel('Epoch', fontsize=20)
            plt.ylabel('Training loss', fontsize=20)
            ax.tick_params(axis = 'both', which = 'major', labelsize = 14, width=2, length=6)
            plt.yscale('log')
            plt.legend(fontsize=18)

            ax = fig.add_subplot(132)
            plt.title('Train error', fontsize=16)
            plt.plot(np.arange(n_epochs), avg_train_err['V1'], label='V1-inspired', lw=3)
            plt.plot(np.arange(n_epochs), avg_train_err['RF'],  label='classical', lw=3)
            plt.plot(np.arange(n_epochs), avg_train_err['He'],  label='He', lw=3)
            plt.fill_between(np.arange(n_epochs), avg_train_err['V1'] - std_train_err['V1'], 
                             avg_train_err['V1'] + std_train_err['V1'],  alpha=0.2 )
            plt.fill_between(np.arange(n_epochs), avg_train_err['RF'] - std_train_err['RF'], 
                             avg_train_err['RF'] + std_train_err['RF'],  alpha=0.2 )
            plt.fill_between(np.arange(n_epochs), avg_train_err['He'] - std_train_err['He'], 
                             avg_train_err['He'] + std_train_err['He'],  alpha=0.2 )
            plt.xlabel('Epoch', fontsize=20)
            plt.ylabel('Training error', fontsize=20)
            ax.tick_params(axis = 'both', which = 'major', labelsize = 14, width=2, length=6)
            plt.yticks(np.arange(0, 1, 0.2))
            plt.yscale('log')
            plt.legend(fontsize=18)

            ax = fig.add_subplot(133)
            plt.title('Test error', fontsize=16)
            plt.plot(np.arange(n_epochs), avg_test_err['V1'], label='V1-inspired', lw=3)
            plt.plot(np.arange(n_epochs), avg_test_err['RF'], label='classical', lw=3)
            plt.plot(np.arange(n_epochs), avg_test_err['He'], label='He', lw=3)
            plt.fill_between(np.arange(n_epochs), avg_test_err['V1'] - std_test_err['V1'], 
                             avg_test_err['V1'] + std_test_err['V1'], alpha=0.2 )
            plt.fill_between(np.arange(n_epochs), avg_test_err['RF'] - std_test_err['RF'], 
                             avg_test_err['RF'] + std_test_err['RF'], alpha=0.2 )
            plt.fill_between(np.arange(n_epochs), avg_test_err['He'] - std_test_err['He'], 
                             avg_test_err['He'] + std_test_err['He'], alpha=0.2 )
            plt.xlabel('Epoch', fontsize=20)
            plt.ylabel('Test error', fontsize=20)
            ax.tick_params(axis = 'both', which = 'major', labelsize = 14, width=2, length=6)
            plt.yticks(np.arange(0, 1, 0.2))
            plt.yscale('log')
            plt.legend(fontsize=18)

            plt.tight_layout()
            plt.subplots_adjust(top=0.8)    

            print(scale, h, lr, 'Test err, V1: %0.4f, RF: %0.4f, He: %0.4f' % (avg_test_err['V1'][-1], 
                                                                 avg_test_err['RF'][-1],
                                                                avg_test_err['He'][-1]))
            
            plt.savefig('results/initialize_mnist/figures_full_training/init_t=%0.2f_l=%0.2f_h=%d_lr=%0.4f_scale=%0.6f.png' % (t, 
                                                                                                                 l,h, 
                                                                                                                 lr, 
                                                                                                             scale))
            plt.close()
# Out:
# 0.125 50 0.001 Test err, V1: 0.2058, RF: 0.4096, He: 0.5403
# 0.125 50 0.01 Test err, V1: 0.1514, RF: 0.1791, He: 0.1404
# 0.125 50 0.1 Test err, V1: 0.0779, RF: 0.0930, He: 0.0717
# 0.125 50 1.0 Test err, V1: 0.0484, RF: 0.0441, He: 0.0320
# 0.125 100 0.001 Test err, V1: 0.1542, RF: 0.2885, He: 0.4677
# 0.125 100 0.01 Test err, V1: 0.0881, RF: 0.1394, He: 0.1355
# 0.125 100 0.1 Test err, V1: 0.0559, RF: 0.0822, He: 0.0676
# 0.125 100 1.0 Test err, V1: 0.0387, RF: 0.0422, He: 0.0265
# 0.125 400 0.001 Test err, V1: 0.0815, RF: 0.1451, He: 0.3039
# 0.125 400 0.01 Test err, V1: 0.0858, RF: 0.0815, He: 0.1181
# 0.125 400 0.1 Test err, V1: 0.0323, RF: 0.0544, He: 0.0632
# 0.125 400 1.0 Test err, V1: 0.0295, RF: 0.0374, He: 0.0214
# 0.125 1000 0.001 Test err, V1: 0.0620, RF: 0.1015, He: 0.2261
# 0.125 1000 0.01 Test err, V1: 0.0498, RF: 0.0619, He: 0.1092
# 0.125 1000 0.1 Test err, V1: 0.0276, RF: 0.0379, He: 0.0590
# 0.125 1000 1.0 Test err, V1: 0.0291, RF: 0.0370, He: 0.0199
# 0.0625 50 0.001 Test err, V1: 0.2481, RF: 0.5259, He: 0.6060
# 0.0625 50 0.01 Test err, V1: 0.1317, RF: 0.1810, He: 0.1396
# 0.0625 50 0.1 Test err, V1: 0.0687, RF: 0.0846, He: 0.0704
# 0.0625 50 1.0 Test err, V1: 0.0429, RF: 0.0371, He: 0.0841
# 0.0625 100 0.001 Test err, V1: 0.1580, RF: 0.3431, He: 0.4527
# 0.0625 100 0.01 Test err, V1: 0.0921, RF: 0.1386, He: 0.1357
# 0.0625 100 0.1 Test err, V1: 0.0535, RF: 0.0743, He: 0.0707
# 0.0625 100 1.0 Test err, V1: 0.0334, RF: 0.0343, He: 0.0256
# 0.0625 400 0.001 Test err, V1: 0.0888, RF: 0.1606, He: 0.3253
# 0.0625 400 0.01 Test err, V1: 0.0915, RF: 0.0897, He: 0.1194
# 0.0625 400 0.1 Test err, V1: 0.0317, RF: 0.0570, He: 0.0625
# 0.0625 400 1.0 Test err, V1: 0.0244, RF: 0.0306, He: 0.0215
# 0.0625 1000 0.001 Test err, V1: 0.0695, RF: 0.1176, He: 0.2290
# 0.0625 1000 0.01 Test err, V1: 0.1656, RF: 0.0706, He: 0.1097
# 0.0625 1000 0.1 Test err, V1: 0.0261, RF: 0.0409, He: 0.0584
# 0.0625 1000 1.0 Test err, V1: 0.0237, RF: 0.0311, He: 0.0199
# 0.03125 50 0.001 Test err, V1: 0.2829, RF: 0.5591, He: 0.5863
# 0.03125 50 0.01 Test err, V1: 0.1326, RF: 0.1678, He: 0.1407
# 0.03125 50 0.1 Test err, V1: 0.0656, RF: 0.0775, He: 0.0716
# 0.03125 50 1.0 Test err, V1: 0.0347, RF: 0.0320, He: 0.0321
# 0.03125 100 0.001 Test err, V1: 0.1877, RF: 0.3656, He: 0.5245
# 0.03125 100 0.01 Test err, V1: 0.1023, RF: 0.1400, He: 0.1340
# 0.03125 100 0.1 Test err, V1: 0.0532, RF: 0.0709, He: 0.0681
# 0.03125 100 1.0 Test err, V1: 0.0284, RF: 0.0297, He: 0.0267
# 0.03125 400 0.001 Test err, V1: 0.0999, RF: 0.1853, He: 0.3013
# 0.03125 400 0.01 Test err, V1: 0.0594, RF: 0.0986, He: 0.1190
# 0.03125 400 0.1 Test err, V1: 0.0308, RF: 0.0562, He: 0.0619
# 0.03125 400 1.0 Test err, V1: 0.0223, RF: 0.0280, He: 0.0211
# 0.03125 1000 0.001 Test err, V1: 0.0795, RF: 0.1295, He: 0.2268
# 0.03125 1000 0.01 Test err, V1: 0.0443, RF: 0.0779, He: 0.1090
# 0.03125 1000 0.1 Test err, V1: 0.0247, RF: 0.0460, He: 0.0588
# 0.03125 1000 1.0 Test err, V1: 0.0194, RF: 0.0260, He: 0.0204

# %%
h, lr
# Out:
# (1000, 1.0)
